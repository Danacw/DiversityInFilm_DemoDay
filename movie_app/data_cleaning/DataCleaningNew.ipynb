# %% [markdown]
# # The Movie Database: Data Extraction & Cleaning

# %%
#  %pip install cpi

# %%
# Import dependencies
import pandas as pd
import json
import requests
from pprint import pprint
import numpy as np
import cpi
from datetime import datetime

# Import config
from config import api_key, db_user, db_password, db_host, db_port, db_name

# %%
cpi.update()

# %% [markdown]
# ### Testing:

# %%
# Single Test: Discover Most Popular Movies
page_number = 1

# Endpoint for finding most popular movies
discover_movies = "https://api.themoviedb.org/3/discover/movie"
most_popular_url = f"{discover_movies}?api_key={api_key}&page={page_number}&sort_by=popularity.desc"

# Most popular movies
tmdb_response = requests.get(most_popular_url).json()
results = tmdb_response["results"]

json_string = json.dumps(results)
df = pd.read_json(json_string)
df
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg        [28, 12, 14, 878]  524434
# 1   False  /ur19n7Zabzf7wfhK4MrlFDJiZPI.jpg  [16, 10751, 14, 35, 12]  585083
# 2   False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg            [28, 12, 878]  634649
# 3   False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg   [16, 35, 10751, 10402]  438695
# 4   False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg      [16, 35, 10751, 14]  568124
# 5   False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg             [35, 14, 12]  425909
# 6   False  /yfNbZ34Yt2S0DdgGH38bLDhJPiM.jpg                 [28, 53]  860623
# 7   False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg            [27, 28, 878]  460458
# 8   False  /eNI7PtK6DEYgZmHWP9gQNuff8pv.jpg            [878, 28, 12]  624860
# 9   False  /vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg            [878, 28, 12]  580489
# 10  False  /AmLpWYm9R3Ur2FLPgj5CH3wR8wp.jpg                [878, 53]  739413
# 11  False  /8jIRAV5KVZeIP6tjI1NuCfb9Il0.jpg             [28, 12, 14]  566525
# 12  False  /mo57hzhW3BcZL1f7MNteWKHsmlN.jpg                 [28, 53]  763788
# 13  False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg         [28, 35, 80, 53]  512195
# 14  False  /xPpXYnCWfjkt3zzE0dpCNME1pXF.jpg         [16, 28, 12, 14]  635302
# 15  False  /srDyClcl2J0L3ZP9tpahwoTcNxj.jpg             [28, 53, 80]  787310
# 16  False  /9fzNf2QcsHVvdx5g5QUOgAWpADw.jpg           [18, 27, 9648]  516329
# 17  False  /1Wlwnhn5sXUIwlxpJgWszT622PS.jpg          [16, 35, 10751]  585245
# 18  False  /1BqX34aJS5J8PefVnQSfQIEPfkl.jpg             [80, 28, 53]  826749
# 19  False  /7h5WAPAcUzOWpp2jrwHBB48790j.jpg                 [16, 14]  843241
#
#    original_language                             original_title  \
# 0                 en                                   Eternals
# 1                 en          Hotel Transylvania: Transformania
# 2                 en                    Spider-Man: No Way Home
# 3                 en                                     Sing 2
# 4                 en                                    Encanto
# 5                 en                    Ghostbusters: Afterlife
# 6                 en                              Last Man Down
# 7                 en     Resident Evil: Welcome to Raccoon City
# 8                 en                   The Matrix Resurrections
# 9                 en                Venom: Let There Be Carnage
# 10                en                             Mother/Android
# 11                en  Shang-Chi and the Legend of the Ten Rings
# 12                en                                  Dangerous
# 13                en                                 Red Notice
# 14                ja                             劇場版「鬼滅の刃」無限列車編
# 15                en                           Survive the Game
# 16                en                                    Antlers
# 17                en                   Clifford the Big Red Dog
# 18                en                                   Fortress
# 19                ja                        劇場版 七つの大罪 光に呪われし者たち
#
#                                              overview  popularity  \
# 0   The Eternals are a team of ancient aliens who ...   11424.242
# 1   When Van Helsing's mysterious invention, the "...   10200.442
# 2   Peter Parker is unmasked and no longer able to...    5874.670
# 3   Buster and his new cast now have their sights ...    5211.181
# 4   The tale of an extraordinary family, the Madri...    4832.255
# 5   When a single mom and her two kids arrive in a...    3894.636
# 6   After civilization succumbs to a deadly pandem...    3783.290
# 7   Once the booming home of pharmaceutical giant ...    3107.294
# 8   Plagued by strange memories, Neo's life takes ...    2920.594
# 9   After finding a host body in investigative rep...    2444.605
# 10  Georgia and her boyfriend Sam go on a treacher...    2119.020
# 11  Shang-Chi must confront the past he thought he...    1643.610
# 12  A reformed sociopath heads to a remote island ...    1710.560
# 13  An Interpol-issued Red Notice is a global aler...    1349.437
# 14  Tanjirō Kamado, joined with Inosuke Hashibira,...    1277.501
# 15  When cop David is injured in a drug bust gone ...    1318.896
# 16  A small-town Oregon teacher and her brother, t...    1143.488
# 17  As Emily struggles to fit in at home and at sc...    1149.839
# 18  The story revolves around a top-secret resort ...    1093.262
# 19  With the help of the "Dragon Sin of Wrath" Mel...    1062.604
#
#                          poster_path release_date  \
# 0   /b6qUu00iIIkXX13szFy7d0CyNcg.jpg   2021-11-03
# 1   /teCy1egGQa0y8ULJvlrDHQKnxBL.jpg   2022-01-14
# 2   /1g0dhYtq4irTY1GPXvft6k4YLjm.jpg   2021-12-15
# 3   /aWeKITRFbbwY8txG5uCj4rMCfSP.jpg   2021-12-01
# 4   /4j0PNHkMr5ax3IA8tjtxcmPU3QT.jpg   2021-11-24
# 5   /sg4xJaufDiQl7caFEskBtQXfD4x.jpg   2021-11-11
# 6   /4B7liCxNCZIZGONmAMkCnxVlZQV.jpg   2021-10-19
# 7   /7uRbWOXxpWDMtnsd2PF3clu65jc.jpg   2021-11-24
# 8   /8c4a8kE7PizaGQQnditMmI1xbRp.jpg   2021-12-16
# 9   /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg   2021-09-30
# 10  /rO3nV9d1wzHEWsC7xgwxotjZQpM.jpg   2021-12-17
# 11  /1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg   2021-09-01
# 12  /vTtkQGC7qKlSRQJZYtAWAmYdH0A.jpg   2021-11-05
# 13  /lAXONuqg41NwUMuzMiFvicDET9Y.jpg   2021-11-04
# 14  /h8Rb9gBr48ODIwYUttZNYeMWeUU.jpg   2020-10-16
# 15  /xF1uc2pEf34X2G41wvZaF5H0V7C.jpg   2021-10-08
# 16  /cMch3tiexw3FdOEeZxMWVel61Xg.jpg   2021-10-28
# 17  /oifhfVhUcuDjE61V5bS5dfShQrm.jpg   2021-11-10
# 18  /vQxtoPJVfpHgL7DCg9hQFZKDWJa.jpg   2021-12-17
# 19  /k0ThmZQl5nHe4JefC2bXjqtgYp0.jpg   2021-07-02
#
#                                                 title  video  vote_average  \
# 0                                            Eternals  False           7.3
# 1                   Hotel Transylvania: Transformania  False           7.8
# 2                             Spider-Man: No Way Home  False           8.4
# 3                                              Sing 2  False           8.3
# 4                                             Encanto  False           7.8
# 5                             Ghostbusters: Afterlife  False           7.7
# 6                                       Last Man Down  False           6.8
# 7              Resident Evil: Welcome to Raccoon City  False           6.1
# 8                            The Matrix Resurrections  False           6.9
# 9                         Venom: Let There Be Carnage  False           7.1
# 10                                     Mother/Android  False           6.0
# 11          Shang-Chi and the Legend of the Ten Rings  False           7.8
# 12                                          Dangerous  False           6.6
# 13                                         Red Notice  False           6.8
# 14  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...  False           8.4
# 15                                   Survive the Game  False           5.8
# 16                                            Antlers  False           6.4
# 17                           Clifford the Big Red Dog  False           7.4
# 18                                           Fortress  False           6.3
# 19             The Seven Deadly Sins: Cursed by Light  False           8.0
#
#     vote_count
# 0         3139
# 1          770
# 2         4367
# 3         1110
# 4         3157
# 5         1363
# 6          124
# 7          936
# 8         2346
# 9         5911
# 10         279
# 11        5227
# 12         114
# 13        2724
# 14        2047
# 15          81
# 16         371
# 17         898
# 18         119
# 19         283

# %%
#Single Test: Crew
movie_id = 672582

# Endpoint & response
movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
movie_response = requests.get(movie_url).json()

pprint(movie_response)
# Out:
# {'adult': False,
#  'backdrop_path': '/yL9RRZbDVbptqLwiZcK304ck4PL.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 27, 'name': 'Horror'}],
#  'homepage': '',
#  'id': 672582,
#  'imdb_id': 'tt11686490',
#  'original_language': 'en',
#  'original_title': 'The Deep House',
#  'overview': 'While diving in a remote French lake, a couple of YouTubers who '
#              'specialize in underwater exploration videos discover a house '
#              'submerged in the deep waters. What was initially a unique '
#              'finding soon turns into a nightmare when they discover that the '
#              'house was the scene of atrocious crimes. Trapped, with their '
#              'oxygen reserves falling dangerously, they realize the worst is '
#              'yet to come: they are not alone in the house.',
#  'popularity': 427.552,
#  'poster_path': '/5xhAPxRr64oQPEFnUOrttuI4ZEU.jpg',
#  'production_companies': [{'id': 12689,
#                            'logo_path': None,
#                            'name': 'Radar Films',
#                            'origin_country': 'FR'},
#                           {'id': 92840,
#                            'logo_path': None,
#                            'name': 'Logical Pictures',
#                            'origin_country': 'FR'},
#                           {'id': 49755,
#                            'logo_path': '/iom7Z8e1dzoTfCvwq8F4bJvbeIJ.png',
#                            'name': 'Apollo Films',
#                            'origin_country': 'FR'},
#                           {'id': 19037,
#                            'logo_path': '/tceh2aAORA5JxIZSLQ1GkzTBZDL.png',
#                            'name': 'uMedia',
#                            'origin_country': 'BE'},
#                           {'id': 12686,
#                            'logo_path': None,
#                            'name': 'Forecast Pictures',
#                            'origin_country': ''},
#                           {'id': 78299,
#                            'logo_path': None,
#                            'name': 'Screen Flanders',
#                            'origin_country': 'BE'},
#                           {'id': 11620,
#                            'logo_path': '/f3hRdCaK1w9qH1Qs8nLd2L2bae1.png',
#                            'name': 'OCS',
#                            'origin_country': 'FR'},
#                           {'id': 12352,
#                            'logo_path': '/fkIacb6MddD6trIWamr33SIcUAn.png',
#                            'name': 'Wallimage',
#                            'origin_country': 'BE'},
#                           {'id': 114955,
#                            'logo_path': None,
#                            'name': 'Tax Shelter du Gouvernement Fédéral Belge',
#                            'origin_country': 'BE'},
#                           {'id': 102877,
#                            'logo_path': '/zjkjypyhDQA0dNCv8WzIzEmqAQk.png',
#                            'name': 'Investisseurs Tax Shelter',
#                            'origin_country': 'BE'},
#                           {'id': 310,
#                            'logo_path': '/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png',
#                            'name': 'CNC',
#                            'origin_country': 'FR'}],
#  'production_countries': [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#                           {'iso_3166_1': 'FR', 'name': 'France'}],
#  'release_date': '2021-06-30',
#  'revenue': 0,
#  'runtime': 85,
#  'spoken_languages': [{'english_name': 'French',
#                        'iso_639_1': 'fr',
#                        'name': 'Français'},
#                       {'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'Portuguese',
#                        'iso_639_1': 'pt',
#                        'name': 'Português'}],
#  'status': 'Released',
#  'tagline': 'Breathe while you still can.',
#  'title': 'The Deep House',
#  'video': False,
#  'vote_average': 6.5,
#  'vote_count': 443}

# %% [raw]
# # Single Test: Movie Details
# movie_id = 672582
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [raw]
# # Single Test: Credits
# # movie_id = 566525
# movie_id = 284052
#
# movie_credits = f"/movie/{movie_id}/credits"
# credits_url = f"https://api.themoviedb.org/3/{movie_credits}?api_key={api_key}"
#
# # Get the json response for the credits
# credits_response = requests.get(credits_url).json()
# pprint(credits_response)

# %% [raw]
# # Find job names for Writing Department
# for i in credits_response['crew']:
#     if i['department'] == 'Writing':
#         name = i['name']
#         job = i['job']
#         print(f"{name}: {job}")

# %% [raw]
# # Single Test: Movie Recommendations
# movie_id = 32657
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}/recommendations?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [raw]
# # Single Test: Movie Release Date/Certifications
# movie_id = 32657
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}/release_dates?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [markdown]
# # Functions: Define API calls to extract key data points

# %%
# Start Timer Function (check on API call performance)
def start_timer():
    start = datetime.now()
    
    return start

# %%
# Stop Timer Function (check on API call performance)
def stop_timer(start):
    end = datetime.now()
    elapsed_time = (end - start)

    print(f"Total Time Elapsed:  {elapsed_time.total_seconds()} seconds")

# %% [markdown]
# ### API CALLS:

# %%
# Returns most popular movies
def get_most_popular_movies(api_key):
    
    movies = []
    
    # Loop through pages to get results for movies
    for x in range(1, 201):
        page_number = x

        # Endpoint for finding most popular movies
        discover_movies = "https://api.themoviedb.org/3/discover/movie"
        most_popular_url = f"{discover_movies}?api_key={api_key}&page={page_number}&sort_by=popularity.desc"
        
        # Most popular movies
        tmdb_response = requests.get(most_popular_url).json()
        results = tmdb_response["results"]

#         for y in range(len(results)):
#             movies.append(results[y]) 
        for result in results:
            movies.append(result)
            
    return movies

# %%
# Returns movie details as a list
def get_movie_details(api_key, movie_ids):  
    
    movie_details = []
    
    for movie_id in movie_ids:
        # Endpoint & response
        movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
        movie_response = requests.get(movie_url).json()

        # Append results to lists
        movie_details.append(movie_response)
        
    return movie_details

# %%
# Returns keywords as a list
def get_movie_keywords(api_key, movie_ids):
    keyword_details = []
    
    for movie_id in movie_ids:
        # Get keywords for each movie
        keywords_url = f"https://api.themoviedb.org/3/movie/{movie_id}/keywords?api_key={api_key}"
        keywords_response = requests.get(keywords_url).json()
        keywords_results = keywords_response["keywords"]
        
         # Append results to lists
        keyword_details.append(keywords_response)
        
    return keyword_details

# %%
# Returns credits as a list
def get_credits(api_key, movie_ids):
    credit_details = []
    
    for movie_id in movie_ids:
        # Generate movie credits
        movie_credits = f"/movie/{movie_id}/credits"
        credits_url = f"https://api.themoviedb.org/3/{movie_credits}?api_key={api_key}"

        # Get the json response for the credits
        credits_response = requests.get(credits_url).json()
        
        credit_details.append(credits_response)
        
    return credit_details

# %%
# Returns certifications as a list (rating: G, PG, etc.)
def get_certifications(api_key, movie_ids):
    certifications = []
    
    for movie_id in movie_ids:
        # Get certifications for each movie
        certification_url = f"https://api.themoviedb.org/3/movie/{movie_id}/release_dates?api_key={api_key}"
        
        certification_response = requests.get(certification_url).json()
        
        certifications.append(certification_response)
        
    return certifications

# %% [markdown]
# ### GET TITLES & IDS:

# %%
# Returns single title for specified index number
def get_title(results, idx):
    movie_title = results[idx]["title"]
    
    return movie_title

# %%
# Returns ids list
def get_ids(results):
    movie_ids = []
    for x in results:
        movie_ids.append(x["id"])
        
    return movie_ids

# %%
# Returns titles list
def get_titles(results):
    movie_titles = []
    for x in results:
        movie_titles.append(x["title"])
        
    return movie_titles

# %% [markdown]
# ### EXTRACT NEEDED DETAILS FROM COLUMNS: Cast, Crew, Gender, Production Countries etc.

# %%
# Extract the certification (ratings)
def extract_certification(x):
    name = ""
    
    for i in x:
        # Get ratings for US
        if i['iso_3166_1'] == 'US':
             # Append results to lists
            name = i['release_dates'][0]['certification']
            break
    return name

# %%
# Function to get the director out of the crew
def get_director(x):
    names = []
    
    for i in x:
        if i['job'] == 'Director':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the director gender out of the crew
def get_director_gender(x):
    names = []
    
    for i in x:
        if i['job'] == 'Director':
            gender = i['gender']
            names.append(gender)
            
    if(names):
        return names
    
    return np.nan

# %%
def fm_percentage(results):
    fm_count = 0
    total_count = 0
    for x in results:
        if x['gender'] == 1:
            fm_count += 1
        if x['gender'] == 1 or x['gender'] == 2:
            total_count += 1
    
    if total_count == 0:        
        return np.nan
            
    return percentage_format(100 * fm_count/total_count)

# %%
# Function to get the producers out of the crew
def get_producers(x):
    names = []
    
    for i in x:
        if i['job'] == 'Producer':
            name = i['name']
            names.append(name)
        elif i['job'] == "Executive Producer":
            name = i['name']
            names.append(name)
        elif i['job'] == 'Co-Producer':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the screenplay writers out of the crew
def get_writers(x):
    names = []
    for i in x:
        if i['department'] == 'Writing':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to create cast list
def get_cast_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        
        # Condition for cast (keep top 5)
        if len(names) > 5:
            names = names[:5]
        return names

    return []

# %%
# Function to create lists of each feature
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        return names
        
    return []

# %%
# Function to get production companies
def get_production_companies(x):
    names = []
    if isinstance(x, list):
        for i in x:
            name = i['name']
            names.append(name)
        return names
        
    return []

# %%
# Get each production company's country of origin
def get_production_company_country(x):
    names = []
    if isinstance(x, list):
        for i in x:
            country = i['origin_country']
            names.append(country)
        return names
    return []

# %%
# Get list of all languages available for film
def get_languages(x):
    names = []
    for i in x:
        name = i['english_name']
#         iso = i['iso_639_1']
        names.append(name)
    
    if(names):
        return names
    
    return np.nan

# %%
# Create binary column for foreign language films
def original_language_binary(x):
    if (x == 'en'):
        return 0
    elif (x != 'en'):
        return 1
    elif (x == "" | x == " "):
        return 0
    else:
        return 0

# %%
def percentage_format(percentage):
    return "{:,.2f}%".format(percentage)

# %% [markdown]
# ### CLEAN DATA FOR SOUP & CREATE SOUP: Used for Machine Learning

# %%
# Convert all strings to lower case and strip names of spaces
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else: 
            return ''

# %%
# Clean the overview column (by converting to lowercase)
def clean_overview(x):
    if isinstance(x, str):
        return x.lower()
    else: 
        return ''

# %%
# Create soup of words
def create_soup(x):
    space = ' '
    return (space.join(x['keywords_cleaned']) + space + space.join(x['cast_cleaned']) + space 
            + space.join(x['director_cleaned']) + space + space.join(x['producers_cleaned']) + space 
            + space.join(x['writers_cleaned']) + space + space.join(x['genres_cleaned']) + space 
            + space.join(x['production_companies_cleaned']))

# %%
# Create soup of words - 2 keywords, 2 genres & overview
def create_soup_overview(x):
    space = ' '
    return (space.join(x['keywords_cleaned']) + space + space.join(x['keywords_cleaned']) + space 
            + space.join(x['cast_cleaned']) + space + space.join(x['director_cleaned']) + space 
            + space.join(x['producers_cleaned']) + space + space.join(x['writers_cleaned']) + space 
            + space.join(x['genres_cleaned']) + space + space.join(x['genres_cleaned']) + space 
            + space.join(x['production_companies_cleaned']) + space + x['overview_cleaned'])

# %% [markdown]
# # CALL API

# %% [markdown]
# ### Get Most Popular Movies JSON Results:

# %%
# Start the timer
start = start_timer()

# %%
most_popular_movies = get_most_popular_movies(api_key)
# print(most_popular_movies)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  104.428939 seconds

# %% [markdown]
# ### List of Movie IDs:

# %%
movie_ids = get_ids(most_popular_movies)
#print(movie_ids)

# %%
len(movie_ids)
# Out:
# 4000

# %% [markdown]
# ### List of Titles:

# %%
titles = get_titles(most_popular_movies)
# print(titles)

# %%
len(titles)
# Out:
# 4000

# %% [markdown]
# ### Print Individual Title:

# %%
print(get_title(most_popular_movies, 0))
# Out:
# Eternals

# %% [markdown]
# ### Get Movie Details:

# %%
# Start the timer
start = start_timer()

# %%
details = get_movie_details(api_key, movie_ids)

# %%
pprint(details[0:10])
# Out:
# [{'adult': False,
#   'backdrop_path': '/c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg',
#   'belongs_to_collection': None,
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 14, 'name': 'Fantasy'},
#              {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/the-eternals',
#   'id': 524434,
#   'imdb_id': 'tt9032400',
#   'original_language': 'en',
#   'original_title': 'Eternals',
#   'overview': 'The Eternals are a team of ancient aliens who have been living '
#               'on Earth in secret for thousands of years. When an unexpected '
#               'tragedy forces them out of the shadows, they are forced to '
#               'reunite against mankind’s most ancient enemy, the Deviants.',
#   'popularity': 13124.352,
#   'poster_path': '/b6qUu00iIIkXX13szFy7d0CyNcg.jpg',
#   'production_companies': [{'id': 420,
#                             'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#                             'name': 'Marvel Studios',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-03',
#   'revenue': 401842256,
#   'runtime': 156,
#   'spoken_languages': [{'english_name': 'Arabic',
#                         'iso_639_1': 'ar',
#                         'name': 'العربية'},
#                        {'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Hindi',
#                         'iso_639_1': 'hi',
#                         'name': 'हिन्दी'},
#                        {'english_name': 'Latin',
#                         'iso_639_1': 'la',
#                         'name': 'Latin'},
#                        {'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'In the beginning...',
#   'title': 'Eternals',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 3130},
#  {'adult': False,
#   'backdrop_path': '/ur19n7Zabzf7wfhK4MrlFDJiZPI.jpg',
#   'belongs_to_collection': {'backdrop_path': '/5MJt6g7k9gADQH4xHn5mOEMa3Vr.jpg',
#                             'id': 185103,
#                             'name': 'Hotel Transylvania Collection',
#                             'poster_path': '/9nR1xIcDo84gbbNZeFb9NCZYTdw.jpg'},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#              {'id': 10751, 'name': 'Family'},
#              {'id': 14, 'name': 'Fantasy'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.hoteltmovie.com',
#   'id': 585083,
#   'imdb_id': 'tt9848626',
#   'original_language': 'en',
#   'original_title': 'Hotel Transylvania: Transformania',
#   'overview': 'When Van Helsing\'s mysterious invention, the "Monsterfication '
#               'Ray," goes haywire, Drac and his monster pals are all '
#               'transformed into humans, and Johnny becomes a monster. In their '
#               'new mismatched bodies, Drac and Johnny must team up and race '
#               "across the globe to find a cure before it's too late, and "
#               'before they drive each other crazy.',
#   'popularity': 9932.986,
#   'poster_path': '/teCy1egGQa0y8ULJvlrDHQKnxBL.jpg',
#   'production_companies': [{'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'},
#                            {'id': 2251,
#                             'logo_path': '/6l16UFSkZ1oPpyBYaILgffFZlTc.png',
#                             'name': 'Sony Pictures Animation',
#                             'origin_country': 'US'},
#                            {'id': 34,
#                             'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png',
#                             'name': 'Sony Pictures',
#                             'origin_country': 'US'},
#                            {'id': 2531,
#                             'logo_path': '/pC2iDCDCvV85vOBP7a5Ukxuc0Du.png',
#                             'name': 'MRC',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2022-01-14',
#   'revenue': 0,
#   'runtime': 88,
#   'spoken_languages': [{'english_name': 'Danish',
#                         'iso_639_1': 'da',
#                         'name': 'Dansk'},
#                        {'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'Change can be scary.',
#   'title': 'Hotel Transylvania: Transformania',
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 763},
#  {'adult': False,
#   'backdrop_path': '/1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg',
#   'belongs_to_collection': {'backdrop_path': '/AvnqpRwlEaYNVL6wzC4RN94EdSd.jpg',
#                             'id': 531241,
#                             'name': 'Spider-Man (Avengers) Collection',
#                             'poster_path': '/nogV4th2P5QWYvQIMiWHj4CFLU9.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.spidermannowayhome.movie',
#   'id': 634649,
#   'imdb_id': 'tt10872600',
#   'original_language': 'en',
#   'original_title': 'Spider-Man: No Way Home',
#   'overview': 'Peter Parker is unmasked and no longer able to separate his '
#               'normal life from the high-stakes of being a super-hero. When he '
#               'asks for help from Doctor Strange the stakes become even more '
#               'dangerous, forcing him to discover what it truly means to be '
#               'Spider-Man.',
#   'popularity': 6211.386,
#   'poster_path': '/1g0dhYtq4irTY1GPXvft6k4YLjm.jpg',
#   'production_companies': [{'id': 420,
#                             'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#                             'name': 'Marvel Studios',
#                             'origin_country': 'US'},
#                            {'id': 84041,
#                             'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png',
#                             'name': 'Pascal Pictures',
#                             'origin_country': 'US'},
#                            {'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-12-15',
#   'revenue': 1631853496,
#   'runtime': 148,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Tagalog',
#                         'iso_639_1': 'tl',
#                         'name': ''}],
#   'status': 'Released',
#   'tagline': 'The Multiverse unleashed.',
#   'title': 'Spider-Man: No Way Home',
#   'video': False,
#   'vote_average': 8.4,
#   'vote_count': 4367},
#  {'adult': False,
#   'backdrop_path': '/tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg',
#   'belongs_to_collection': {'backdrop_path': '/z9ft5HYHzWcasR6SGcgeluxTznB.jpg',
#                             'id': 544670,
#                             'name': 'Sing Collection',
#                             'poster_path': '/h151oRzvsxfKRznEmlQJRlnvsid.jpg'},
#   'budget': 85000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 10751, 'name': 'Family'},
#              {'id': 10402, 'name': 'Music'}],
#   'homepage': 'https://www.illumination.com/movie/sing-2/',
#   'id': 438695,
#   'imdb_id': 'tt6467266',
#   'original_language': 'en',
#   'original_title': 'Sing 2',
#   'overview': 'Buster and his new cast now have their sights set on debuting a '
#               'new show at the Crystal Tower Theater in glamorous Redshore '
#               'City. But with no connections, he and his singers must sneak '
#               'into the Crystal Entertainment offices, run by the ruthless '
#               'wolf mogul Jimmy Crystal, where the gang pitches the ridiculous '
#               'idea of casting the lion rock legend Clay Calloway in their '
#               'show. Buster must embark on a quest to find the now-isolated '
#               'Clay and persuade him to return to the stage.',
#   'popularity': 5606.735,
#   'poster_path': '/aWeKITRFbbwY8txG5uCj4rMCfSP.jpg',
#   'production_companies': [{'id': 6704,
#                             'logo_path': '/fOG2oY4m1YuYTQh4bMqqZkmgOAI.png',
#                             'name': 'Illumination Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 33,
#                             'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#                             'name': 'Universal Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-12-01',
#   'revenue': 215000000,
#   'runtime': 110,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Where will your dreams take you?',
#   'title': 'Sing 2',
#   'video': False,
#   'vote_average': 8.3,
#   'vote_count': 1101},
#  {'adult': False,
#   'backdrop_path': '/3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg',
#   'belongs_to_collection': None,
#   'budget': 50000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 10751, 'name': 'Family'},
#              {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://movies.disney.com/encanto',
#   'id': 568124,
#   'imdb_id': 'tt2953050',
#   'original_language': 'en',
#   'original_title': 'Encanto',
#   'overview': 'The tale of an extraordinary family, the Madrigals, who live '
#               'hidden in the mountains of Colombia, in a magical house, in a '
#               'vibrant town, in a wondrous, charmed place called an Encanto. '
#               'The magic of the Encanto has blessed every child in the family '
#               'with a unique gift from super strength to the power to '
#               'heal—every child except one, Mirabel. But when she discovers '
#               'that the magic surrounding the Encanto is in danger, Mirabel '
#               'decides that she, the only ordinary Madrigal, might just be her '
#               "exceptional family's last hope.",
#   'popularity': 4960.193,
#   'poster_path': '/4j0PNHkMr5ax3IA8tjtxcmPU3QT.jpg',
#   'production_companies': [{'id': 6125,
#                             'logo_path': '/tVPmo07IHhBs4HuilrcV0yujsZ9.png',
#                             'name': 'Walt Disney Animation Studios',
#                             'origin_country': 'US'},
#                            {'id': 2,
#                             'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#                             'name': 'Walt Disney Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-24',
#   'revenue': 215000000,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'}],
#   'status': 'Released',
#   'tagline': "There's a little magic in all of us ...almost all of us.",
#   'title': 'Encanto',
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 3154},
#  {'adult': False,
#   'backdrop_path': '/EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg',
#   'belongs_to_collection': {'backdrop_path': '/6Jnlhr2ac8OuDJEowsFLzZY3SXd.jpg',
#                             'id': 2980,
#                             'name': 'Ghostbusters Collection',
#                             'poster_path': '/sctvCtE1M1rDF4f0W2fMrk2BrGB.jpg'},
#   'budget': 75000000,
#   'genres': [{'id': 35, 'name': 'Comedy'},
#              {'id': 14, 'name': 'Fantasy'},
#              {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://ghostbusters.com/',
#   'id': 425909,
#   'imdb_id': 'tt4513678',
#   'original_language': 'en',
#   'original_title': 'Ghostbusters: Afterlife',
#   'overview': 'When a single mom and her two kids arrive in a small town, they '
#               'begin to discover their connection to the original Ghostbusters '
#               'and the secret legacy their grandfather left behind.',
#   'popularity': 4275.13,
#   'poster_path': '/sg4xJaufDiQl7caFEskBtQXfD4x.jpg',
#   'production_companies': [{'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'},
#                            {'id': 13240,
#                             'logo_path': '/aTc07YaNHo8WNgkQSnvLmG6w4nW.png',
#                             'name': 'Bron Studios',
#                             'origin_country': 'CA'},
#                            {'id': 2364,
#                             'logo_path': '/oZyR5maGM96jReVgW7oJ7mXN8ts.png',
#                             'name': 'The Montecito Picture Company',
#                             'origin_country': 'US'},
#                            {'id': 84042,
#                             'logo_path': None,
#                             'name': 'Ghost Corps',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-11',
#   'revenue': 191000000,
#   'runtime': 124,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Ukrainian',
#                         'iso_639_1': 'uk',
#                         'name': 'Український'}],
#   'status': 'Released',
#   'tagline': 'Discover the past. Protect the future.',
#   'title': 'Ghostbusters: Afterlife',
#   'video': False,
#   'vote_average': 7.7,
#   'vote_count': 1363},
#  {'adult': False,
#   'backdrop_path': '/yfNbZ34Yt2S0DdgGH38bLDhJPiM.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'homepage': '',
#   'id': 860623,
#   'imdb_id': 'tt12335692',
#   'original_language': 'en',
#   'original_title': 'Last Man Down',
#   'overview': 'After civilization succumbs to a deadly pandemic and his wife '
#               'is murdered, a special forces soldier abandons his duty and '
#               'becomes a hermit in the Nordic wilderness. Years later, a '
#               "wounded woman appears on his doorstep. She's escaped from a lab "
#               'and her pursuers believe her blood is the key to a worldwide '
#               "cure. He's hesitant to get involved, but all doubts are cast "
#               'aside when he discovers her pursuer is none other than '
#               'Commander Stone, the man that murdered his wife some years ago.',
#   'popularity': 3783.29,
#   'poster_path': '/4B7liCxNCZIZGONmAMkCnxVlZQV.jpg',
#   'production_companies': [{'id': 98610,
#                             'logo_path': None,
#                             'name': 'Daniel Stisen Productions',
#                             'origin_country': ''},
#                            {'id': 161903,
#                             'logo_path': None,
#                             'name': 'Fansu Film',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'SE', 'name': 'Sweden'},
#                            {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2021-10-19',
#   'revenue': 0,
#   'runtime': 87,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'They will pay.',
#   'title': 'Last Man Down',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 128},
#  {'adult': False,
#   'backdrop_path': '/o76ZDm8PS9791XiuieNB93UZcRV.jpg',
#   'belongs_to_collection': None,
#   'budget': 40000000,
#   'genres': [{'id': 27, 'name': 'Horror'},
#              {'id': 28, 'name': 'Action'},
#              {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.residentevil.movie',
#   'id': 460458,
#   'imdb_id': 'tt6920084',
#   'original_language': 'en',
#   'original_title': 'Resident Evil: Welcome to Raccoon City',
#   'overview': 'Once the booming home of pharmaceutical giant Umbrella '
#               'Corporation, Raccoon City is now a dying Midwestern town. The '
#               'company’s exodus left the city a wasteland…with great evil '
#               'brewing below the surface. When that evil is unleashed, the '
#               'townspeople are forever…changed…and a small group of survivors '
#               'must work together to uncover the truth behind Umbrella and '
#               'make it through the night.',
#   'popularity': 3107.294,
#   'poster_path': '/7uRbWOXxpWDMtnsd2PF3clu65jc.jpg',
#   'production_companies': [{'id': 47,
#                             'logo_path': '/i7Z9ot2o3N5Sa3HrF09kniFs2y8.png',
#                             'name': 'Constantin Film',
#                             'origin_country': 'DE'},
#                            {'id': 13161,
#                             'logo_path': None,
#                             'name': 'Tea Shop & Film Company',
#                             'origin_country': 'GB'},
#                            {'id': 342,
#                             'logo_path': None,
#                             'name': 'Davis Films',
#                             'origin_country': 'FR'},
#                            {'id': 36109,
#                             'logo_path': '/wca0Jcidf2N1KAPicYMjGoKOmYu.png',
#                             'name': 'The Fyzz',
#                             'origin_country': 'GB'},
#                            {'id': 3287,
#                             'logo_path': '/bz6GbCQQXGNE56LTW9dwgksW0Iw.png',
#                             'name': 'Screen Gems',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'},
#                            {'iso_3166_1': 'DE', 'name': 'Germany'},
#                            {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-24',
#   'revenue': 31000000,
#   'runtime': 107,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Witness the beginning of evil.',
#   'title': 'Resident Evil: Welcome to Raccoon City',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 936},
#  {'adult': False,
#   'backdrop_path': '/eNI7PtK6DEYgZmHWP9gQNuff8pv.jpg',
#   'belongs_to_collection': {'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg',
#                             'id': 2344,
#                             'name': 'The Matrix Collection',
#                             'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg'},
#   'budget': 190000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#              {'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.whatisthematrix.com',
#   'id': 624860,
#   'imdb_id': 'tt10838180',
#   'original_language': 'en',
#   'original_title': 'The Matrix Resurrections',
#   'overview': "Plagued by strange memories, Neo's life takes an unexpected "
#               'turn when he finds himself back inside the Matrix.',
#   'popularity': 3120.12,
#   'poster_path': '/8c4a8kE7PizaGQQnditMmI1xbRp.jpg',
#   'production_companies': [{'id': 174,
#                             'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#                             'name': 'Warner Bros. Pictures',
#                             'origin_country': 'US'},
#                            {'id': 79,
#                             'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#                             'name': 'Village Roadshow Pictures',
#                             'origin_country': 'US'},
#                            {'id': 84764,
#                             'logo_path': None,
#                             'name': 'Venus Castina Productions',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-12-16',
#   'revenue': 148000000,
#   'runtime': 148,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Return to the source.',
#   'title': 'The Matrix Resurrections',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 2342},
#  {'adult': False,
#   'backdrop_path': '/vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg',
#   'belongs_to_collection': {'backdrop_path': '/rhLspFB1B8ZCkWEHFYmc3NKagzq.jpg',
#                             'id': 558216,
#                             'name': 'Venom Collection',
#                             'poster_path': '/670x9sf0Ru8y6ezBggmYudx61yB.jpg'},
#   'budget': 110000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#              {'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.venom.movie',
#   'id': 580489,
#   'imdb_id': 'tt7097896',
#   'original_language': 'en',
#   'original_title': 'Venom: Let There Be Carnage',
#   'overview': 'After finding a host body in investigative reporter Eddie '
#               'Brock, the alien symbiote must face a new enemy, Carnage, the '
#               'alter ego of serial killer Cletus Kasady.',
#   'popularity': 2594.922,
#   'poster_path': '/rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg',
#   'production_companies': [{'id': 7505,
#                             'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png',
#                             'name': 'Marvel Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'},
#                            {'id': 84041,
#                             'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png',
#                             'name': 'Pascal Pictures',
#                             'origin_country': 'US'},
#                            {'id': 53462,
#                             'logo_path': None,
#                             'name': 'Matt Tolmach Productions',
#                             'origin_country': 'US'},
#                            {'id': 166230,
#                             'logo_path': None,
#                             'name': 'Avi Arad Productions',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-09-30',
#   'revenue': 500000000,
#   'runtime': 97,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Venom: Let There Be Carnage',
#   'video': False,
#   'vote_average': 7.1,
#   'vote_count': 5910}]

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  1177.901674 seconds

# %% [markdown]
# ### Get Keywords:

# %%
# Start the timer
start = start_timer()

# %%
keywords = get_movie_keywords(api_key, movie_ids)

# %%
# print(keywords)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  739.83646 seconds

# %% [markdown]
# ### Get Credits:

# %%
# Start the timer
start = start_timer()

# %%
credits = get_credits(api_key, movie_ids)

# %%
# print(credits)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  718.748118 seconds

# %% [markdown]
# ### Get Certifications:

# %%
# Start the timer
start = start_timer()

# %%
# Get the certifications for each movie (rating: G, PG, etc.)
certifications = get_certifications(api_key, movie_ids)
# certifications = get_certifications(api_key, [32657, 672582])

# %%
# print(certifications)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  790.482216 seconds

# %% [markdown]
# ## Movie Details DataFrame:

# %%
from io import StringIO
# Convert details to json
json_details_string = json.dumps(details)
# Convert json to dataframe
movie_details_df = pd.read_json(StringIO(json_details_string))

# Export to save
# movie_details_df.to_csv("./static/data/movie_details.csv", index=False)

movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg
# 1  False  /ur19n7Zabzf7wfhK4MrlFDJiZPI.jpg
# 2  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 3  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 4  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
#
#                                belongs_to_collection     budget  \
# 0                                               None  200000000
# 1  {'id': 185103, 'name': 'Hotel Transylvania Col...          0
# 2  {'id': 531241, 'name': 'Spider-Man (Avengers) ...  200000000
# 3  {'id': 544670, 'name': 'Sing Collection', 'pos...   85000000
# 4                                               None   50000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                      homepage      id     imdb_id  \
# 0  https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 1                 https://www.hoteltmovie.com  585083   tt9848626
# 2        https://www.spidermannowayhome.movie  634649  tt10872600
# 3  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 4           https://movies.disney.com/encanto  568124   tt2953050
#
#   original_language                     original_title  ... release_date  \
# 0                en                           Eternals  ...   2021-11-03
# 1                en  Hotel Transylvania: Transformania  ...   2022-01-14
# 2                en            Spider-Man: No Way Home  ...   2021-12-15
# 3                en                             Sing 2  ...   2021-12-01
# 4                en                            Encanto  ...   2021-11-24
#
#       revenue runtime                                   spoken_languages  \
# 0   401842256   156.0  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...
# 1           0    88.0  [{'english_name': 'Danish', 'iso_639_1': 'da',...
# 2  1631853496   148.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3   215000000   110.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4   215000000   102.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#      status                                            tagline  \
# 0  Released                                In the beginning...
# 1  Released                               Change can be scary.
# 2  Released                          The Multiverse unleashed.
# 3  Released                   Where will your dreams take you?
# 4  Released  There's a little magic in all of us ...almost ...
#
#                                title  video vote_average vote_count
# 0                           Eternals  False          7.3       3130
# 1  Hotel Transylvania: Transformania  False          7.8        763
# 2            Spider-Man: No Way Home  False          8.4       4367
# 3                             Sing 2  False          8.3       1101
# 4                            Encanto  False          7.8       3154
#
# [5 rows x 25 columns]

# %%
# Extract year from release date
movie_details_df["year"] = pd.DatetimeIndex(movie_details_df['release_date']).year
# Drop any N/A from year
movie_details_df.dropna(inplace=True, how="any", subset=['year','release_date'])
 
# Convert to int
movie_details_df["year"] = movie_details_df["year"].astype(int)
    
# Rename columns to prepare for inflation calculation
movie_details_df = movie_details_df.rename(columns = {
    "revenue": "original_revenue",
    "budget": "original_budget"
})

# %%
len(movie_details_df)
# Out:
# 3978

# %% [markdown]
# ## Adjust Budget & Revenue for Inflation

# %%
# Create dataframe for cpi
cpi_df = pd.DataFrame(columns=['year', 'cpi_2021', 'cpi_old'])

# %%
# Create list of years (1913-2021)
years = []
for i in range(1913, 2022):
    years.append(i)

# %%
# Define 2021 cpi
cpi_2021 = 269.489

# Loop through years to append to dataframe
for year in years:
    if year != 2021:
        cpi_old = cpi.get(year)
        cpi_df = cpi_df.append({"year": year, 'cpi_2021': cpi_2021, 'cpi_old': cpi_old}, ignore_index=True)
    elif year == 2021:
        cpi_df = cpi_df.append({"year": year, 'cpi_2021': cpi_2021, 'cpi_old': cpi_2021}, ignore_index=True)

# %%
# Convert year type to int
cpi_df['year'] = cpi_df['year'].astype(int)
cpi_df.head()
# Out:
#    year  cpi_2021  cpi_old
# 0  1913   269.489      9.9
# 1  1914   269.489     10.0
# 2  1915   269.489     10.1
# 3  1916   269.489     10.9
# 4  1917   269.489     12.8

# %%
# Merge movie details df with cpi df
movie_details_df = movie_details_df.merge(cpi_df, on="year")
movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg
# 1  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 2  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
#
#                                belongs_to_collection  original_budget  \
# 0                                               None        200000000
# 1  {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 2  {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 3                                               None         50000000
# 4  {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
#
#                                      homepage      id     imdb_id  \
# 0  https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 1        https://www.spidermannowayhome.movie  634649  tt10872600
# 2  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4                   https://ghostbusters.com/  425909   tt4513678
#
#   original_language           original_title  ...  \
# 0                en                 Eternals  ...
# 1                en  Spider-Man: No Way Home  ...
# 2                en                   Sing 2  ...
# 3                en                  Encanto  ...
# 4                en  Ghostbusters: Afterlife  ...
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                    title  \
# 0                                In the beginning...                 Eternals
# 1                          The Multiverse unleashed.  Spider-Man: No Way Home
# 2                   Where will your dreams take you?                   Sing 2
# 3  There's a little magic in all of us ...almost ...                  Encanto
# 4             Discover the past. Protect the future.  Ghostbusters: Afterlife
#
#    video vote_average  vote_count  year cpi_2021  cpi_old
# 0  False          7.3        3130  2021  269.489  269.489
# 1  False          8.4        4367  2021  269.489  269.489
# 2  False          8.3        1101  2021  269.489  269.489
# 3  False          7.8        3154  2021  269.489  269.489
# 4  False          7.7        1363  2021  269.489  269.489
#
# [5 rows x 28 columns]

# %%
# Create adjusted column for each feature
features = ["revenue", "budget"]

for feature in features:
    movie_details_df[f'adjusted_{feature}'] = (movie_details_df[f'original_{feature}'] * movie_details_df['cpi_2021']) / movie_details_df['cpi_old']

movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg
# 1  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 2  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
#
#                                belongs_to_collection  original_budget  \
# 0                                               None        200000000
# 1  {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 2  {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 3                                               None         50000000
# 4  {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
#
#                                      homepage      id     imdb_id  \
# 0  https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 1        https://www.spidermannowayhome.movie  634649  tt10872600
# 2  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4                   https://ghostbusters.com/  425909   tt4513678
#
#   original_language           original_title  ...  \
# 0                en                 Eternals  ...
# 1                en  Spider-Man: No Way Home  ...
# 2                en                   Sing 2  ...
# 3                en                  Encanto  ...
# 4                en  Ghostbusters: Afterlife  ...
#
#                                              tagline                    title  \
# 0                                In the beginning...                 Eternals
# 1                          The Multiverse unleashed.  Spider-Man: No Way Home
# 2                   Where will your dreams take you?                   Sing 2
# 3  There's a little magic in all of us ...almost ...                  Encanto
# 4             Discover the past. Protect the future.  Ghostbusters: Afterlife
#
#    video vote_average vote_count  year  cpi_2021  cpi_old adjusted_revenue  \
# 0  False          7.3       3130  2021   269.489  269.489     4.018423e+08
# 1  False          8.4       4367  2021   269.489  269.489     1.631853e+09
# 2  False          8.3       1101  2021   269.489  269.489     2.150000e+08
# 3  False          7.8       3154  2021   269.489  269.489     2.150000e+08
# 4  False          7.7       1363  2021   269.489  269.489     1.910000e+08
#
#   adjusted_budget
# 0     200000000.0
# 1     200000000.0
# 2      85000000.0
# 3      50000000.0
# 4      75000000.0
#
# [5 rows x 30 columns]

# %%
# Check values
movie_details_df[['original_budget', 'adjusted_budget', 'original_revenue', 'adjusted_revenue', 'year']]
# Out:
#       original_budget  adjusted_budget  original_revenue  adjusted_revenue  \
# 0           200000000     2.000000e+08         401842256      4.018423e+08
# 1           200000000     2.000000e+08        1631853496      1.631853e+09
# 2            85000000     8.500000e+07         215000000      2.150000e+08
# 3            50000000     5.000000e+07         215000000      2.150000e+08
# 4            75000000     7.500000e+07         191000000      1.910000e+08
# ...               ...              ...               ...               ...
# 3890                0     0.000000e+00                 0      0.000000e+00
# 3891          6500000     4.772966e+07          81974493      6.019407e+08
# 3892          5500000     4.705363e+07         141195658      1.207958e+09
# 3893           672000     1.393051e+07          10000000      2.072992e+08
# 3894                0     0.000000e+00            600000      1.180244e+07
#
#       year
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021
# ...    ...
# 3890  1969
# 3891  1969
# 3892  1965
# 3893  1933
# 3894  1932
#
# [3895 rows x 5 columns]

# %% [markdown]
# ## Low Budget:

# %%
# Create budget bins
bins = [1, 15000000, 50000000, 150000000, 380000000] 
bin_names = ["1 to 15m", "16m to 50m", "51m to 150m", "151m to 380m"]

# Append a budget bin column
movie_details_df["budget_bins"] = pd.cut(movie_details_df["adjusted_budget"], bins, labels=bin_names)
movie_details_df["budget_bins"].value_counts()
# Out:
# 16m to 50m      709
# 51m to 150m     694
# 1 to 15m        520
# 151m to 380m    314
# Name: budget_bins, dtype: int64

# %%
# Low Budget
movie_details_df.loc[movie_details_df["budget_bins"] == "1 to 15m"].head()
# Out:
#     adult                     backdrop_path  \
# 18  False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 24  False  /7w06baRS9VPm5RYz8lawTCLiR4j.jpg
# 38  False  /lV3UFPPxDIPelh46G9oySXN9Mcz.jpg
# 42  False  /weneJTnAb1IFI94SKcaXzBFmPKH.jpg
# 50  False  /hAv1GwwatyWV1RFXOfaASxgUVm4.jpg
#
#                                 belongs_to_collection  original_budget  \
# 18                                               None          9100000
# 24                                               None         13000000
# 38  {'id': 702624, 'name': 'After Collection', 'po...         14000000
# 42                                               None         12400000
# 50                                               None          2800000
#
#                                                genres homepage      id  \
# 18  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...           589761
# 24  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...           592508
# 38  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...           744275
# 42  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...           818192
# 50  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           657644
#
#        imdb_id original_language original_title  ...             title  video  \
# 18  tt10648714                ru      Чернобыль  ...  Chernobyl: Abyss  False
# 24   tt9531772                hi   Sooryavanshi  ...      Sooryavanshi  False
# 38  tt13069986                en  After We Fell  ...     After We Fell  False
# 42  tt11388416                en        Ida Red  ...           Ida Red  False
# 50   tt7268738                ml   മിന്നൽ മുരളി  ...     Minnal Murali  False
#
#    vote_average vote_count  year cpi_2021  cpi_old  adjusted_revenue  \
# 18          6.3        269  2021  269.489  269.489         5370393.0
# 24          5.9         71  2021  269.489  269.489        37700000.0
# 38          7.2       1362  2021  269.489  269.489        19000000.0
# 42          6.0         20  2021  269.489  269.489               0.0
# 50          7.1        146  2021  269.489  269.489               0.0
#
#    adjusted_budget budget_bins
# 18       9100000.0    1 to 15m
# 24      13000000.0    1 to 15m
# 38      14000000.0    1 to 15m
# 42      12400000.0    1 to 15m
# 50       2800000.0    1 to 15m
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Keywords DataFrame:

# %%
# Convert keywords to json
json_keywords_string = json.dumps(keywords)
# Convert json to dataframe
movie_keywords_df = pd.read_json(json_keywords_string)

# Export to save
# movie_keywords_df.to_csv("./static/data/movie_keywords.csv", index=False)
# pprint(json_keywords_string)

# %% [markdown]
# ## Credits DataFrame:

# %%
# Convert credits to json
json_credits_string = json.dumps(credits)
# Convert json to dataframe
movie_credits_df = pd.read_json(json_credits_string)

# Export to save
# movie_credits_df.to_csv("./static/data/movie_credits.csv", index=False)
movie_credits_df.head()
# Out:
#        id                                               cast  \
# 0  524434  [{'adult': False, 'gender': 1, 'id': 97576, 'k...
# 1  585083  [{'adult': False, 'gender': 1, 'id': 77948, 'k...
# 2  634649  [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3  438695  [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 4  568124  [{'adult': False, 'gender': 1, 'id': 968367, '...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 1722, 'kn...
# 1  [{'adult': False, 'gender': 2, 'id': 5666, 'kn...
# 2  [{'adult': False, 'gender': 1, 'id': 2519, 'kn...
# 3  [{'adult': False, 'gender': 2, 'id': 5720, 'kn...
# 4  [{'adult': False, 'gender': 0, 'id': 8159, 'kn...

# %%
movie_credits_df["cast_crew"] = movie_credits_df["cast"] + movie_credits_df["crew"]
movie_credits_df
# Out:
#           id                                               cast  \
# 0     524434  [{'adult': False, 'gender': 1, 'id': 97576, 'k...
# 1     585083  [{'adult': False, 'gender': 1, 'id': 77948, 'k...
# 2     634649  [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3     438695  [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 4     568124  [{'adult': False, 'gender': 1, 'id': 968367, '...
# ...      ...                                                ...
# 3995      27  [{'adult': False, 'gender': 2, 'id': 176, 'kno...
# 3996    9654  [{'adult': False, 'gender': 2, 'id': 13240, 'k...
# 3997  658009  [{'adult': False, 'gender': 2, 'id': 130597, '...
# 3998    1635  [{'adult': False, 'gender': 2, 'id': 3061, 'kn...
# 3999   32916  [{'adult': False, 'gender': 1, 'id': 86314, 'k...
#
#                                                    crew  \
# 0     [{'adult': False, 'gender': 2, 'id': 1722, 'kn...
# 1     [{'adult': False, 'gender': 2, 'id': 5666, 'kn...
# 2     [{'adult': False, 'gender': 1, 'id': 2519, 'kn...
# 3     [{'adult': False, 'gender': 2, 'id': 5720, 'kn...
# 4     [{'adult': False, 'gender': 0, 'id': 8159, 'kn...
# ...                                                 ...
# 3995  [{'adult': False, 'gender': 2, 'id': 172, 'kno...
# 3996  [{'adult': False, 'gender': 2, 'id': 497, 'kno...
# 3997  [{'adult': False, 'gender': 2, 'id': 2578785, ...
# 3998  [{'adult': False, 'gender': 2, 'id': 947, 'kno...
# 3999  [{'adult': False, 'gender': 2, 'id': 23683, 'k...
#
#                                               cast_crew
# 0     [{'adult': False, 'gender': 1, 'id': 97576, 'k...
# 1     [{'adult': False, 'gender': 1, 'id': 77948, 'k...
# 2     [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3     [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 4     [{'adult': False, 'gender': 1, 'id': 968367, '...
# ...                                                 ...
# 3995  [{'adult': False, 'gender': 2, 'id': 176, 'kno...
# 3996  [{'adult': False, 'gender': 2, 'id': 13240, 'k...
# 3997  [{'adult': False, 'gender': 2, 'id': 130597, '...
# 3998  [{'adult': False, 'gender': 2, 'id': 3061, 'kn...
# 3999  [{'adult': False, 'gender': 1, 'id': 86314, 'k...
#
# [4000 rows x 4 columns]

# %%
movie_credits_df['percent_fm'] = movie_credits_df['cast_crew'].apply(fm_percentage)

# %%
# cast_crew_fm_percentage
movie_credits_df = movie_credits_df.drop(columns=['cast_crew'])
movie_credits_df
# Out:
#           id                                               cast  \
# 0     524434  [{'adult': False, 'gender': 1, 'id': 97576, 'k...
# 1     585083  [{'adult': False, 'gender': 1, 'id': 77948, 'k...
# 2     634649  [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3     438695  [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 4     568124  [{'adult': False, 'gender': 1, 'id': 968367, '...
# ...      ...                                                ...
# 3995      27  [{'adult': False, 'gender': 2, 'id': 176, 'kno...
# 3996    9654  [{'adult': False, 'gender': 2, 'id': 13240, 'k...
# 3997  658009  [{'adult': False, 'gender': 2, 'id': 130597, '...
# 3998    1635  [{'adult': False, 'gender': 2, 'id': 3061, 'kn...
# 3999   32916  [{'adult': False, 'gender': 1, 'id': 86314, 'k...
#
#                                                    crew percent_fm
# 0     [{'adult': False, 'gender': 2, 'id': 1722, 'kn...     27.54%
# 1     [{'adult': False, 'gender': 2, 'id': 5666, 'kn...     40.38%
# 2     [{'adult': False, 'gender': 1, 'id': 2519, 'kn...     25.26%
# 3     [{'adult': False, 'gender': 2, 'id': 5720, 'kn...     25.00%
# 4     [{'adult': False, 'gender': 0, 'id': 8159, 'kn...     42.86%
# ...                                                 ...        ...
# 3995  [{'adult': False, 'gender': 2, 'id': 172, 'kno...      9.09%
# 3996  [{'adult': False, 'gender': 2, 'id': 497, 'kno...     22.00%
# 3997  [{'adult': False, 'gender': 2, 'id': 2578785, ...     28.57%
# 3998  [{'adult': False, 'gender': 2, 'id': 947, 'kno...     19.79%
# 3999  [{'adult': False, 'gender': 2, 'id': 23683, 'k...     33.33%
#
# [4000 rows x 4 columns]

# %% [markdown]
# ## Certifications DataFrame:

# %%
# Convert certifications to json
json_certifications_string = json.dumps(certifications)
# Convert json to dataframe
movie_certifications_df = pd.read_json(StringIO(json_certifications_string))

# Export to save
# movie_certifications_df.to_csv("./static/data/movie_certifications.csv", index=False)
movie_certifications_df.head()
# Out:
#        id                                            results
# 0  524434  [{'iso_3166_1': 'IE', 'release_dates': [{'cert...
# 1  585083  [{'iso_3166_1': 'FR', 'release_dates': [{'cert...
# 2  634649  [{'iso_3166_1': 'NZ', 'release_dates': [{'cert...
# 3  438695  [{'iso_3166_1': 'PL', 'release_dates': [{'cert...
# 4  568124  [{'iso_3166_1': 'FR', 'release_dates': [{'cert...

# %%
# Extract certification information and append to new column
movie_certifications_df['certification'] = movie_certifications_df['results'].apply(extract_certification)
movie_certifications_df = movie_certifications_df[['id', 'certification']]

# %%
movie_certifications_df.head()
# Out:
#        id certification
# 0  524434
# 1  585083            PG
# 2  634649         PG-13
# 3  438695
# 4  568124

# %%
# Convert ids to ints (to merge correctly)
movie_keywords_df['id'] = movie_keywords_df['id'].astype('int')
movie_details_df['id'] = movie_details_df['id'].astype('int')
movie_credits_df['id'] = movie_credits_df['id'].astype('int')
movie_certifications_df['id'] = movie_certifications_df['id'].astype('int')

# %%
# Merge keywords with details
movie_df = movie_details_df.merge(movie_keywords_df, on='id')
movie_df = movie_df.merge(movie_credits_df, on='id')
movie_df = movie_df.merge(movie_certifications_df, on='id')

# Export to save
# movie_df.to_csv("./static/data/movies_merged.csv", index=False)

# %%
movie_df.head(20)
# Out:
#     adult                     backdrop_path  \
# 0   False  /c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg
# 1   False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 2   False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 3   False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4   False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
# 5   False  /yfNbZ34Yt2S0DdgGH38bLDhJPiM.jpg
# 6   False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg
# 7   False  /eNI7PtK6DEYgZmHWP9gQNuff8pv.jpg
# 8   False  /vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg
# 9   False  /AmLpWYm9R3Ur2FLPgj5CH3wR8wp.jpg
# 10  False  /8jIRAV5KVZeIP6tjI1NuCfb9Il0.jpg
# 11  False  /mo57hzhW3BcZL1f7MNteWKHsmlN.jpg
# 12  False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg
# 13  False  /srDyClcl2J0L3ZP9tpahwoTcNxj.jpg
# 14  False  /9fzNf2QcsHVvdx5g5QUOgAWpADw.jpg
# 15  False  /1Wlwnhn5sXUIwlxpJgWszT622PS.jpg
# 16  False  /1BqX34aJS5J8PefVnQSfQIEPfkl.jpg
# 17  False  /7h5WAPAcUzOWpp2jrwHBB48790j.jpg
# 18  False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 19  False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg
#
#                                 belongs_to_collection  original_budget  \
# 0                                                None        200000000
# 1   {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 2   {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 3                                                None         50000000
# 4   {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
# 5                                                None                0
# 6                                                None         40000000
# 7   {'id': 2344, 'name': 'The Matrix Collection', ...        190000000
# 8   {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 9                                                None                0
# 10  {'id': 912503, 'name': 'Shang-Chi Collection',...        150000000
# 11                                               None                0
# 12                                               None        160000000
# 13                                               None                0
# 14                                               None                0
# 15                                               None         64000000
# 16  {'id': 883509, 'name': 'Fortress Collection', ...                0
# 17  {'id': 703485, 'name': 'The Seven Deadly Sins ...                0
# 18                                               None          9100000
# 19                                               None        100000000
#
#                                                genres  \
# 0   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4   [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 6   [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 9   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 12  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 13  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 14  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 16  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 17  [{'id': 16, 'name': 'Animation'}, {'id': 14, '...
# 18  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 19  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
#
#                                              homepage      id     imdb_id  \
# 0          https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 1                https://www.spidermannowayhome.movie  634649  tt10872600
# 2          https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 3                   https://movies.disney.com/encanto  568124   tt2953050
# 4                           https://ghostbusters.com/  425909   tt4513678
# 5                                                      860623  tt12335692
# 6                      https://www.residentevil.movie  460458   tt6920084
# 7                     https://www.whatisthematrix.com  624860  tt10838180
# 8                             https://www.venom.movie  580489   tt7097896
# 9              https://www.netflix.com/title/81038410  739413  tt13029044
# 10  https://www.marvel.com/movies/shang-chi-and-th...  566525   tt9376612
# 11                                                     763788   tt3876910
# 12          https://www.netflix.com/us/title/81161626  512195   tt7991608
# 13                                                     787310  tt12861508
# 14        https://www.searchlightpictures.com/antlers  516329   tt7740510
# 15                                                     585245   tt2397461
# 16                                                     826749  tt14577300
# 17                         https://eiga.7-taizai.net/  843241  tt13884144
# 18                                                     589761  tt10648714
# 19  https://www.20thcenturystudios.com/movies/the-...  617653   tt4244994
#
#    original_language                             original_title  ... cpi_2021  \
# 0                 en                                   Eternals  ...  269.489
# 1                 en                    Spider-Man: No Way Home  ...  269.489
# 2                 en                                     Sing 2  ...  269.489
# 3                 en                                    Encanto  ...  269.489
# 4                 en                    Ghostbusters: Afterlife  ...  269.489
# 5                 en                              Last Man Down  ...  269.489
# 6                 en     Resident Evil: Welcome to Raccoon City  ...  269.489
# 7                 en                   The Matrix Resurrections  ...  269.489
# 8                 en                Venom: Let There Be Carnage  ...  269.489
# 9                 en                             Mother/Android  ...  269.489
# 10                en  Shang-Chi and the Legend of the Ten Rings  ...  269.489
# 11                en                                  Dangerous  ...  269.489
# 12                en                                 Red Notice  ...  269.489
# 13                en                           Survive the Game  ...  269.489
# 14                en                                    Antlers  ...  269.489
# 15                en                   Clifford the Big Red Dog  ...  269.489
# 16                en                                   Fortress  ...  269.489
# 17                ja                        劇場版 七つの大罪 光に呪われし者たち  ...  269.489
# 18                ru                                  Чернобыль  ...  269.489
# 19                en                              The Last Duel  ...  269.489
#
#     cpi_old adjusted_revenue adjusted_budget   budget_bins  \
# 0   269.489     4.018423e+08     200000000.0  151m to 380m
# 1   269.489     1.631853e+09     200000000.0  151m to 380m
# 2   269.489     2.150000e+08      85000000.0   51m to 150m
# 3   269.489     2.150000e+08      50000000.0    16m to 50m
# 4   269.489     1.910000e+08      75000000.0   51m to 150m
# 5   269.489     0.000000e+00             0.0           NaN
# 6   269.489     3.100000e+07      40000000.0    16m to 50m
# 7   269.489     1.480000e+08     190000000.0  151m to 380m
# 8   269.489     5.000000e+08     110000000.0   51m to 150m
# 9   269.489     0.000000e+00             0.0           NaN
# 10  269.489     4.302384e+08     150000000.0   51m to 150m
# 11  269.489     0.000000e+00             0.0           NaN
# 12  269.489     1.781430e+05     160000000.0  151m to 380m
# 13  269.489     0.000000e+00             0.0           NaN
# 14  269.489     1.831220e+07             0.0           NaN
# 15  269.489     6.700000e+07      64000000.0   51m to 150m
# 16  269.489     0.000000e+00             0.0           NaN
# 17  269.489     0.000000e+00             0.0           NaN
# 18  269.489     5.370393e+06       9100000.0      1 to 15m
# 19  269.489     2.700000e+07     100000000.0   51m to 150m
#
#                                              keywords  \
# 0   [{'id': 3925, 'name': 'boredom'}, {'id': 6152,...
# 1   [{'id': 1701, 'name': 'hero'}, {'id': 5451, 'n...
# 2   [{'id': 11477, 'name': 'anthropomorphism'}, {'...
# 3   [{'id': 2343, 'name': 'magic'}, {'id': 4344, '...
# 4   [{'id': 1415, 'name': 'small town'}, {'id': 30...
# 5                                                  []
# 6   [{'id': 1852, 'name': 'mutant'}, {'id': 1865, ...
# 7   [{'id': 310, 'name': 'artificial intelligence'...
# 8   [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 9   [{'id': 310, 'name': 'artificial intelligence'...
# 10  [{'id': 779, 'name': 'martial arts'}, {'id': 9...
# 11                                                 []
# 12  [{'id': 1812, 'name': 'fbi'}, {'id': 6710, 'na...
# 13                                                 []
# 14  [{'id': 798, 'name': 'sheriff'}, {'id': 1897, ...
# 15  [{'id': 818, 'name': 'based on novel or book'}...
# 16                                                 []
# 17  [{'id': 2343, 'name': 'magic'}, {'id': 9663, '...
# 18  [{'id': 269, 'name': 'diving'}, {'id': 1618, '...
# 19  [{'id': 818, 'name': 'based on novel or book'}...
#
#                                                  cast  \
# 0   [{'adult': False, 'gender': 1, 'id': 97576, 'k...
# 1   [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 2   [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 3   [{'adult': False, 'gender': 1, 'id': 968367, '...
# 4   [{'adult': False, 'gender': 1, 'id': 1308445, ...
# 5   [{'adult': False, 'gender': 2, 'id': 1481440, ...
# 6   [{'adult': False, 'gender': 1, 'id': 115150, '...
# 7   [{'adult': False, 'gender': 2, 'id': 6384, 'kn...
# 8   [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 9   [{'adult': False, 'gender': 1, 'id': 56734, 'k...
# 10  [{'adult': False, 'gender': 2, 'id': 1489211, ...
# 11  [{'adult': False, 'gender': 2, 'id': 928572, '...
# 12  [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 13  [{'adult': False, 'gender': 2, 'id': 62747, 'k...
# 14  [{'adult': False, 'gender': 1, 'id': 41292, 'k...
# 15  [{'adult': False, 'gender': 1, 'id': 1696017, ...
# 16  [{'adult': False, 'gender': 2, 'id': 57171, 'k...
# 17  [{'adult': False, 'gender': 2, 'id': 149894, '...
# 18  [{'adult': False, 'gender': 2, 'id': 562730, '...
# 19  [{'adult': False, 'gender': 2, 'id': 1892, 'kn...
#
#                                                  crew percent_fm certification
# 0   [{'adult': False, 'gender': 2, 'id': 1722, 'kn...     27.54%
# 1   [{'adult': False, 'gender': 1, 'id': 2519, 'kn...     25.26%         PG-13
# 2   [{'adult': False, 'gender': 2, 'id': 5720, 'kn...     25.00%
# 3   [{'adult': False, 'gender': 0, 'id': 8159, 'kn...     42.86%
# 4   [{'adult': False, 'gender': 2, 'id': 561, 'kno...     25.40%
# 5   [{'adult': False, 'gender': 2, 'id': 1481440, ...     50.00%             R
# 6   [{'adult': False, 'gender': 2, 'id': 4014, 'kn...     31.58%             R
# 7   [{'adult': False, 'gender': 2, 'id': 1071, 'kn...     25.86%
# 8   [{'adult': False, 'gender': 2, 'id': 149, 'kno...     23.08%         PG-13
# 9   [{'adult': False, 'gender': 2, 'id': 32278, 'k...     34.48%             R
# 10  [{'adult': False, 'gender': 1, 'id': 7232, 'kn...     34.72%         PG-13
# 11  [{'adult': False, 'gender': 2, 'id': 2679, 'kn...     23.33%             R
# 12  [{'adult': False, 'gender': 2, 'id': 9543, 'kn...     14.58%         PG-13
# 13  [{'adult': False, 'gender': 2, 'id': 21003, 'k...     20.00%             R
# 14  [{'adult': False, 'gender': 1, 'id': 1720, 'kn...     36.84%
# 15  [{'adult': False, 'gender': 1, 'id': 8220, 'kn...     40.35%            PG
# 16  [{'adult': False, 'gender': 2, 'id': 17210, 'k...     18.18%             R
# 17  [{'adult': False, 'gender': 2, 'id': 1250035, ...     35.71%
# 18  [{'adult': False, 'gender': 1, 'id': 30247, 'k...     37.14%
# 19  [{'adult': False, 'gender': 2, 'id': 120, 'kno...     26.32%
#
# [20 rows x 36 columns]

# %% [markdown]
# ## Call Functions to Extract Details:

# %%
# Director
movie_df['director'] = movie_df['crew'].apply(get_director)

# Director Gender
movie_df['director_gender'] = movie_df['crew'].apply(get_director_gender)

# Producers
movie_df['producers'] = movie_df['crew'].apply(get_producers)

# Screenplay writers
movie_df['writers'] = movie_df['crew'].apply(get_writers)

# Cast
movie_df['cast'] = movie_df['cast'].apply(get_cast_list)

# Production Company Country of Origin
movie_df['production_company_origin'] = movie_df['production_companies'].apply(get_production_company_country)

# Spoken Languages in Movie
movie_df['spoken_languages']  = movie_df['spoken_languages'].apply(get_languages)

# Create foreign language column for if the original language was not English
movie_df['foreign_language'] = movie_df['original_language'].apply(original_language_binary)

# Get List: Keywords, genres, & production countries
features = ['keywords', 'genres', 'production_companies']
            
for feature in features:
    movie_df[feature] = movie_df[feature].apply(get_list)

# %%
# Show the results
movie_df[['title', 'cast', 'director', 'director_gender', 'percent_fm', 'producers', 'writers', 'keywords', 'genres', 'production_companies', 'production_company_origin', 'spoken_languages', 'original_language', 'foreign_language']].head()
# Out:
#                      title                                               cast  \
# 0                 Eternals  [Gemma Chan, Richard Madden, Angelina Jolie, K...
# 1  Spider-Man: No Way Home  [Tom Holland, Zendaya, Benedict Cumberbatch, J...
# 2                   Sing 2  [Matthew McConaughey, Reese Witherspoon, Scarl...
# 3                  Encanto  [Stephanie Beatriz, María Cecilia Botero, John...
# 4  Ghostbusters: Afterlife  [Carrie Coon, Finn Wolfhard, Mckenna Grace, Pa...
#
#                      director director_gender percent_fm  \
# 0                [Chloé Zhao]             [1]     27.54%
# 1                 [Jon Watts]             [2]     25.26%
# 2            [Garth Jennings]             [2]     25.00%
# 3  [Byron Howard, Jared Bush]          [2, 2]     42.86%
# 4             [Jason Reitman]             [2]     25.40%
#
#                                            producers  \
# 0  [Kevin Feige, Louis D'Esposito, Victoria Alons...
# 1  [Avi Arad, Kevin Feige, Louis D'Esposito, JoAn...
# 2  [Christopher Meledandri, Janet Healy, Dana Kru...
# 3  [Clark Spencer, Jennifer Lee, Yvett Merino Flo...
# 4  [Dan Aykroyd, Ivan Reitman, Gil Kenan, Michael...
#
#                                              writers  \
# 0  [Jack Kirby, Patrick Burleigh, Ryan Firpo, Rya...
# 1  [Stan Lee, Stan Lee, Steve Ditko, Steve Ditko,...
# 2                   [Garth Jennings, Garth Jennings]
# 3                 [Jared Bush, Charise Castro Smith]
# 4  [Dan Aykroyd, Harold Ramis, Jason Reitman, Gil...
#
#                                             keywords  \
# 0  [boredom, supernatural, superhero, based on co...
# 1  [hero, comic book, superhero, based on comic, ...
# 2                        [anthropomorphism, singing]
# 3  [magic, musical, forest, family relationships,...
# 4  [small town, ghostbuster, nostalgia, afterlife...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1           [Action, Adventure, Science Fiction]
# 2             [Animation, Comedy, Family, Music]
# 3           [Animation, Comedy, Family, Fantasy]
# 4                   [Comedy, Fantasy, Adventure]
#
#                                 production_companies  \
# 0                                   [Marvel Studios]
# 1  [Marvel Studios, Pascal Pictures, Columbia Pic...
# 2   [Illumination Entertainment, Universal Pictures]
# 3  [Walt Disney Animation Studios, Walt Disney Pi...
# 4  [Columbia Pictures, Bron Studios, The Montecit...
#
#   production_company_origin                          spoken_languages  \
# 0                      [US]  [Arabic, English, Hindi, Latin, Spanish]
# 1              [US, US, US]                        [English, Tagalog]
# 2                  [US, US]                                 [English]
# 3                  [US, US]                        [English, Spanish]
# 4          [US, CA, US, US]                      [English, Ukrainian]
#
#   original_language  foreign_language
# 0                en                 0
# 1                en                 0
# 2                en                 0
# 3                en                 0
# 4                en                 0

# %%
# Drop NA from selected columns
movie_df.dropna(inplace=True, how="any", subset=['genres', 'production_companies', 'keywords', 'cast'])
movie_df.dropna(inplace=True, how="any", subset=['director', 'producers', 'writers'])

# %%
len(movie_df)
# Out:
# 3308

# %%
# Clean Data: Convert all features to lowercase and remove spaces
features = ['cast', 'director', 'producers', 'writers', 'keywords', 'genres', 'production_companies']

for feature in features:
    movie_df[f"{feature}_cleaned"] = movie_df[feature].apply(clean_data)

# %%
# Call the clean overview function
movie_df['overview_cleaned'] = movie_df['overview'].apply(clean_overview)

# %%
# Create soup columns
movie_df['soup'] = movie_df.apply(create_soup, axis = 1)
movie_df['soup_overview'] = movie_df.apply(create_soup_overview, axis = 1)

# Export to save
# movie_df.to_csv("./static/data/movies_cleaned_soup.csv", index=False)

# %%
movie_df[['soup']].head(5)
# Out:
#                                                 soup
# 0  boredom supernatural superhero basedoncomic su...
# 1  hero comicbook superhero basedoncomic marvelci...
# 2  anthropomorphism singing matthewmcconaughey re...
# 3  magic musical forest familyrelationships femal...
# 4  smalltown ghostbuster nostalgia afterlife sequ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3308 entries, 0 to 3894
# Data columns (total 52 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   adult                         3308 non-null   bool
#  1   backdrop_path                 3281 non-null   object
#  2   belongs_to_collection         1231 non-null   object
#  3   original_budget               3308 non-null   int64
#  4   genres                        3308 non-null   object
#  5   homepage                      3308 non-null   object
#  6   id                            3308 non-null   int64
#  7   imdb_id                       3303 non-null   object
#  8   original_language             3308 non-null   object
#  9   original_title                3308 non-null   object
#  10  overview                      3308 non-null   object
#  11  popularity                    3308 non-null   float64
#  12  poster_path                   3307 non-null   object
#  13  production_companies          3308 non-null   object
#  14  production_countries          3308 non-null   object
#  15  release_date                  3308 non-null   object
#  16  original_revenue              3308 non-null   int64
#  17  runtime                       3308 non-null   float64
#  18  spoken_languages              3300 non-null   object
#  19  status                        3308 non-null   object
#  20  tagline                       3308 non-null   object
#  21  title                         3308 non-null   object
#  22  video                         3308 non-null   bool
#  23  vote_average                  3308 non-null   float64
#  24  vote_count                    3308 non-null   int64
#  25  year                          3308 non-null   int64
#  26  cpi_2021                      3308 non-null   float64
#  27  cpi_old                       3308 non-null   float64
#  28  adjusted_revenue              3308 non-null   float64
#  29  adjusted_budget               3308 non-null   float64
#  30  budget_bins                   2165 non-null   category
#  31  keywords                      3308 non-null   object
#  32  cast                          3308 non-null   object
#  33  crew                          3308 non-null   object
#  34  percent_fm                    3302 non-null   object
#  35  certification                 3308 non-null   object
#  36  director                      3308 non-null   object
#  37  director_gender               3308 non-null   object
#  38  producers                     3308 non-null   object
#  39  writers                       3308 non-null   object
#  40  production_company_origin     3308 non-null   object
#  41  foreign_language              3308 non-null   int64
#  42  cast_cleaned                  3308 non-null   object
#  43  director_cleaned              3308 non-null   object
#  44  producers_cleaned             3308 non-null   object
#  45  writers_cleaned               3308 non-null   object
#  46  keywords_cleaned              3308 non-null   object
#  47  genres_cleaned                3308 non-null   object
#  48  production_companies_cleaned  3308 non-null   object
#  49  overview_cleaned              3308 non-null   object
#  50  soup                          3308 non-null   object
#  51  soup_overview                 3308 non-null   object
# dtypes: bool(2), category(1), float64(7), int64(6), object(36)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Configuration for Posters:

# %%
configuration_url = f"https://api.themoviedb.org/3/configuration?api_key={api_key}"
config_response = requests.get(configuration_url).json()
# config_response

# %%
# Get images structure
images_url = config_response['images']
# Get Base URL
secure_base_url = images_url['secure_base_url']
# secure_base_url

# %%
# Get the size of poster: 2: w185px, 4: w500px, 5: 780px
# images_url['poster_sizes']
poster_size = images_url['poster_sizes'][5]
# poster_size

# %%
# Copy poster paths to new df
poster_df = movie_df[['poster_path']].copy()

# %%
# Create column with full image path for posters
poster_df['poster_url'] = secure_base_url + poster_size + poster_df['poster_path']

# %%
# Export to separate csv
# poster_df.to_csv("./static/data/poster_path.csv", index=False)
poster_df.head()
# Out:
#                         poster_path  \
# 0  /b6qUu00iIIkXX13szFy7d0CyNcg.jpg
# 1  /1g0dhYtq4irTY1GPXvft6k4YLjm.jpg
# 2  /aWeKITRFbbwY8txG5uCj4rMCfSP.jpg
# 3  /4j0PNHkMr5ax3IA8tjtxcmPU3QT.jpg
# 4  /sg4xJaufDiQl7caFEskBtQXfD4x.jpg
#
#                                           poster_url
# 0  https://image.tmdb.org/t/p/w780/b6qUu00iIIkXX1...
# 1  https://image.tmdb.org/t/p/w780/1g0dhYtq4irTY1...
# 2  https://image.tmdb.org/t/p/w780/aWeKITRFbbwY8t...
# 3  https://image.tmdb.org/t/p/w780/4j0PNHkMr5ax3I...
# 4  https://image.tmdb.org/t/p/w780/sg4xJaufDiQl7c...

# %%
# Create column with full image path for posters (in real df this time)
movie_df['poster_url'] = secure_base_url + poster_size + movie_df['poster_path']

# %% [markdown]
# # TESTING

# %% [raw]
# movie_df = pd.read_csv("./static/data/movie_db.csv")

# %% [raw]
# # Converts strings into lists or dictionaries
# from ast import literal_eval
#
# # Selected features to apply function to
# features = ['cast', 'director', 'producers', 'writers', 'keywords', 'genres', 'production_companies']
#
# for feature in features:
#     movie_df[f"{feature}_cleaned"] = movie_df[f"{feature}_cleaned"].apply(literal_eval)

# %% [markdown]
# ## Export CSV:

# %%
# Create a lowercase column for easier search
movie_df["lowercase_title"] = movie_df['title'].apply(lambda x: x.lower())

# %%
# # Save file - used for calling for information
movie_df.to_csv("../static/data/movie_db.csv", index=False)

# %%
movie_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg
# 1  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 2  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
#
#                                belongs_to_collection  original_budget  \
# 0                                               None        200000000
# 1  {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 2  {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 3                                               None         50000000
# 4  {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1           [Action, Adventure, Science Fiction]
# 2             [Animation, Comedy, Family, Music]
# 3           [Animation, Comedy, Family, Fantasy]
# 4                   [Comedy, Fantasy, Adventure]
#
#                                      homepage      id     imdb_id  \
# 0  https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 1        https://www.spidermannowayhome.movie  634649  tt10872600
# 2  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4                   https://ghostbusters.com/  425909   tt4513678
#
#   original_language           original_title  ...  \
# 0                en                 Eternals  ...
# 1                en  Spider-Man: No Way Home  ...
# 2                en                   Sing 2  ...
# 3                en                  Encanto  ...
# 4                en  Ghostbusters: Afterlife  ...
#
#                                    producers_cleaned  \
# 0  [kevinfeige, louisd'esposito, victoriaalonso, ...
# 1  [aviarad, kevinfeige, louisd'esposito, joannpe...
# 2  [christophermeledandri, janethealy, danakrupin...
# 3     [clarkspencer, jenniferlee, yvettmerinoflores]
# 4  [danaykroyd, ivanreitman, gilkenan, michaelbeu...
#
#                                      writers_cleaned  \
# 0  [jackkirby, patrickburleigh, ryanfirpo, ryanfi...
# 1  [stanlee, stanlee, steveditko, steveditko, chr...
# 2                     [garthjennings, garthjennings]
# 3                    [jaredbush, charisecastrosmith]
# 4  [danaykroyd, haroldramis, jasonreitman, gilkenan]
#
#                                     keywords_cleaned  \
# 0  [boredom, supernatural, superhero, basedoncomi...
# 1  [hero, comicbook, superhero, basedoncomic, mar...
# 2                        [anthropomorphism, singing]
# 3  [magic, musical, forest, familyrelationships, ...
# 4  [smalltown, ghostbuster, nostalgia, afterlife,...
#
#                                  genres_cleaned  \
# 0  [action, adventure, fantasy, sciencefiction]
# 1           [action, adventure, sciencefiction]
# 2            [animation, comedy, family, music]
# 3          [animation, comedy, family, fantasy]
# 4                  [comedy, fantasy, adventure]
#
#                         production_companies_cleaned  \
# 0                                    [marvelstudios]
# 1  [marvelstudios, pascalpictures, columbiapictures]
# 2     [illuminationentertainment, universalpictures]
# 3   [waltdisneyanimationstudios, waltdisneypictures]
# 4  [columbiapictures, bronstudios, themontecitopi...
#
#                                     overview_cleaned  \
# 0  the eternals are a team of ancient aliens who ...
# 1  peter parker is unmasked and no longer able to...
# 2  buster and his new cast now have their sights ...
# 3  the tale of an extraordinary family, the madri...
# 4  when a single mom and her two kids arrive in a...
#
#                                                 soup  \
# 0  boredom supernatural superhero basedoncomic su...
# 1  hero comicbook superhero basedoncomic marvelci...
# 2  anthropomorphism singing matthewmcconaughey re...
# 3  magic musical forest familyrelationships femal...
# 4  smalltown ghostbuster nostalgia afterlife sequ...
#
#                                        soup_overview  \
# 0  boredom supernatural superhero basedoncomic su...
# 1  hero comicbook superhero basedoncomic marvelci...
# 2  anthropomorphism singing anthropomorphism sing...
# 3  magic musical forest familyrelationships femal...
# 4  smalltown ghostbuster nostalgia afterlife sequ...
#
#                                           poster_url          lowercase_title
# 0  https://image.tmdb.org/t/p/w780/b6qUu00iIIkXX1...                 eternals
# 1  https://image.tmdb.org/t/p/w780/1g0dhYtq4irTY1...  spider-man: no way home
# 2  https://image.tmdb.org/t/p/w780/aWeKITRFbbwY8t...                   sing 2
# 3  https://image.tmdb.org/t/p/w780/4j0PNHkMr5ax3I...                  encanto
# 4  https://image.tmdb.org/t/p/w780/sg4xJaufDiQl7c...  ghostbusters: afterlife
#
# [5 rows x 54 columns]

# %% [markdown]
# # Machine Learning Recommender:

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Use Count Vectorizer to create counts for each word
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(movie_df['soup_overview'])

# %%
count_matrix.shape
# Out:
# (3308, 46996)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset the index
# movie_df = movie_df.reset_index()
# Create series with index & titles of movies
indices = pd.Series(movie_df.index, index=movie_df['title']).drop_duplicates()

# %%
movie_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg
# 1  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 2  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
#
#                                belongs_to_collection  original_budget  \
# 0                                               None        200000000
# 1  {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 2  {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 3                                               None         50000000
# 4  {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1           [Action, Adventure, Science Fiction]
# 2             [Animation, Comedy, Family, Music]
# 3           [Animation, Comedy, Family, Fantasy]
# 4                   [Comedy, Fantasy, Adventure]
#
#                                      homepage      id     imdb_id  \
# 0  https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 1        https://www.spidermannowayhome.movie  634649  tt10872600
# 2  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4                   https://ghostbusters.com/  425909   tt4513678
#
#   original_language           original_title  ...  \
# 0                en                 Eternals  ...
# 1                en  Spider-Man: No Way Home  ...
# 2                en                   Sing 2  ...
# 3                en                  Encanto  ...
# 4                en  Ghostbusters: Afterlife  ...
#
#                                    producers_cleaned  \
# 0  [kevinfeige, louisd'esposito, victoriaalonso, ...
# 1  [aviarad, kevinfeige, louisd'esposito, joannpe...
# 2  [christophermeledandri, janethealy, danakrupin...
# 3     [clarkspencer, jenniferlee, yvettmerinoflores]
# 4  [danaykroyd, ivanreitman, gilkenan, michaelbeu...
#
#                                      writers_cleaned  \
# 0  [jackkirby, patrickburleigh, ryanfirpo, ryanfi...
# 1  [stanlee, stanlee, steveditko, steveditko, chr...
# 2                     [garthjennings, garthjennings]
# 3                    [jaredbush, charisecastrosmith]
# 4  [danaykroyd, haroldramis, jasonreitman, gilkenan]
#
#                                     keywords_cleaned  \
# 0  [boredom, supernatural, superhero, basedoncomi...
# 1  [hero, comicbook, superhero, basedoncomic, mar...
# 2                        [anthropomorphism, singing]
# 3  [magic, musical, forest, familyrelationships, ...
# 4  [smalltown, ghostbuster, nostalgia, afterlife,...
#
#                                  genres_cleaned  \
# 0  [action, adventure, fantasy, sciencefiction]
# 1           [action, adventure, sciencefiction]
# 2            [animation, comedy, family, music]
# 3          [animation, comedy, family, fantasy]
# 4                  [comedy, fantasy, adventure]
#
#                         production_companies_cleaned  \
# 0                                    [marvelstudios]
# 1  [marvelstudios, pascalpictures, columbiapictures]
# 2     [illuminationentertainment, universalpictures]
# 3   [waltdisneyanimationstudios, waltdisneypictures]
# 4  [columbiapictures, bronstudios, themontecitopi...
#
#                                     overview_cleaned  \
# 0  the eternals are a team of ancient aliens who ...
# 1  peter parker is unmasked and no longer able to...
# 2  buster and his new cast now have their sights ...
# 3  the tale of an extraordinary family, the madri...
# 4  when a single mom and her two kids arrive in a...
#
#                                                 soup  \
# 0  boredom supernatural superhero basedoncomic su...
# 1  hero comicbook superhero basedoncomic marvelci...
# 2  anthropomorphism singing matthewmcconaughey re...
# 3  magic musical forest familyrelationships femal...
# 4  smalltown ghostbuster nostalgia afterlife sequ...
#
#                                        soup_overview  \
# 0  boredom supernatural superhero basedoncomic su...
# 1  hero comicbook superhero basedoncomic marvelci...
# 2  anthropomorphism singing anthropomorphism sing...
# 3  magic musical forest familyrelationships femal...
# 4  smalltown ghostbuster nostalgia afterlife sequ...
#
#                                           poster_url          lowercase_title
# 0  https://image.tmdb.org/t/p/w780/b6qUu00iIIkXX1...                 eternals
# 1  https://image.tmdb.org/t/p/w780/1g0dhYtq4irTY1...  spider-man: no way home
# 2  https://image.tmdb.org/t/p/w780/aWeKITRFbbwY8t...                   sing 2
# 3  https://image.tmdb.org/t/p/w780/4j0PNHkMr5ax3I...                  encanto
# 4  https://image.tmdb.org/t/p/w780/sg4xJaufDiQl7c...  ghostbusters: afterlife
#
# [5 rows x 54 columns]

# %% [markdown]
# ## Function to Recommend Titles:

# %%
def get_similarity_scores(title, cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]
    
    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the most similar movies
    sim_scores = sim_scores[1:11]
#     print(sim_scores)
    
    # Convert list to DataFrame
    sim_scores_df = pd.DataFrame(sim_scores, columns = ["index", "similarity_score"])
    
    # Return top 10 most similar scores
    return sim_scores_df

# %%
def get_recommendations(original_df, score_df):
    original_df = original_df.merge(score_df, on="index")
    original_df = original_df.sort_values("similarity_score", ascending=False)
    
    return original_df

# %%
# Test out function
movie_title = "Get Out"
similarity_scores_df = get_similarity_scores(movie_title, cosine_sim)

# %% [raw]
# # Call Get Recommendations Function
# recommendations = get_recommendations(movie_df, similarity_scores_df)

# %% [raw]
# # Print out dataframe
# # recommendations[['title', 'similarity_score']].to_csv("./soup_test_3.csv")
# recommendations[['title', 'similarity_score', 'id']].head(10)

# %% [markdown]
# ### Convert columns to list for SQL Database connection

# %%
movie_df_columns = list(movie_df.columns)
movie_df_columns
# Out:
# ['adult',
#  'backdrop_path',
#  'belongs_to_collection',
#  'original_budget',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'original_revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count',
#  'year',
#  'cpi_2021',
#  'cpi_old',
#  'adjusted_revenue',
#  'adjusted_budget',
#  'budget_bins',
#  'keywords',
#  'cast',
#  'crew',
#  'percent_fm',
#  'certification',
#  'director',
#  'director_gender',
#  'producers',
#  'writers',
#  'production_company_origin',
#  'foreign_language',
#  'cast_cleaned',
#  'director_cleaned',
#  'producers_cleaned',
#  'writers_cleaned',
#  'keywords_cleaned',
#  'genres_cleaned',
#  'production_companies_cleaned',
#  'overview_cleaned',
#  'soup',
#  'soup_overview',
#  'poster_url',
#  'lowercase_title']

# %%
for column_name in list(movie_df.columns):
    movie_df[column_name] = movie_df[column_name].apply(json.dumps)

# %%
movie_dict = movie_df.applymap(lambda x: isinstance(x, (dict, list))).all()
print(movie_dict)
# Out:
# adult                           False
# backdrop_path                   False
# belongs_to_collection           False
# original_budget                 False
# genres                          False
# homepage                        False
# id                              False
# imdb_id                         False
# original_language               False
# original_title                  False
# overview                        False
# popularity                      False
# poster_path                     False
# production_companies            False
# production_countries            False
# release_date                    False
# original_revenue                False
# runtime                         False
# spoken_languages                False
# status                          False
# tagline                         False
# title                           False
# video                           False
# vote_average                    False
# vote_count                      False
# year                            False
# cpi_2021                        False
# cpi_old                         False
# adjusted_revenue                False
# adjusted_budget                 False
# budget_bins                     False
# keywords                        False
# cast                            False
# crew                            False
# percent_fm                      False
# certification                   False
# director                        False
# director_gender                 False
# producers                       False
# writers                         False
# production_company_origin       False
# foreign_language                False
# cast_cleaned                    False
# director_cleaned                False
# producers_cleaned               False
# writers_cleaned                 False
# keywords_cleaned                False
# genres_cleaned                  False
# production_companies_cleaned    False
# overview_cleaned                False
# soup                            False
# soup_overview                   False
# poster_url                      False
# lowercase_title                 False
# dtype: bool

# %% [markdown]
# ## Database:

# %%
from sqlalchemy import create_engine, inspect

# %%
# configure the connection string
rds_connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
        
# connect to the database
engine = create_engine(rds_connection_string)
conn = engine.connect()

# %%
engine.execute("DROP TABLE IF EXISTS movies")

# %%
# Append data to table
movie_df.to_sql(name='movies', con=conn, if_exists='append', index=False)

# %%
# Use inspector to find table names
Inspector = inspect(engine)
Inspector.get_table_names()
# Out:
# ['duplicate_search',
#  'no_filter',
#  'female_filter',
#  'international_filter',
#  'low_budget_filter',
#  'movies']

# %%
# Check movies table
pd.read_sql_query('select * from movies', con=conn)
# Out:
#       adult                       backdrop_path  \
# 0     false  "/c6H7Z4u73ir3cIoCteuhJh7UCAR.jpg"
# 1     false  "/1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg"
# 2     false  "/tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg"
# 3     false  "/3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg"
# 4     false   "/EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg"
# ...     ...                                 ...
# 3303  false  "/dApZi5U56RxvcFN6zeUJ3wSfONN.jpg"
# 3304  false  "/1kdyLiE2Mqt7cxnivdPX3qckvfW.jpg"
# 3305  false  "/7mn0IFuByr9bsmlprotTdeO71Km.jpg"
# 3306  false  "/lYfHa1AtkUMtplrKx7SRLHpwonW.jpg"
# 3307  false  "/bIv1kaxb7tsiZYPO27PHfVb5eSF.jpg"
#
#                                   belongs_to_collection original_budget  \
# 0                                                  null       200000000
# 1     {"id": 531241, "name": "Spider-Man (Avengers) ...       200000000
# 2     {"id": 544670, "name": "Sing Collection", "pos...        85000000
# 3                                                  null        50000000
# 4     {"id": 2980, "name": "Ghostbusters Collection"...        75000000
# ...                                                 ...             ...
# 3303                                               null               0
# 3304  {"id": 645, "name": "James Bond Collection", "...         6500000
# 3305  {"id": 645, "name": "James Bond Collection", "...         5500000
# 3306  {"id": 135495, "name": "King Kong (1933) Colle...          672000
# 3307                                               null               0
#
#                                                  genres  \
# 0     ["Action", "Adventure", "Fantasy", "Science Fi...
# 1            ["Action", "Adventure", "Science Fiction"]
# 2            ["Animation", "Comedy", "Family", "Music"]
# 3          ["Animation", "Comedy", "Family", "Fantasy"]
# 4                    ["Comedy", "Fantasy", "Adventure"]
# ...                                                 ...
# 3303                      ["Horror", "Science Fiction"]
# 3304                ["Adventure", "Action", "Thriller"]
# 3305                ["Adventure", "Action", "Thriller"]
# 3306                 ["Adventure", "Horror", "Fantasy"]
# 3307           ["Action", "Crime", "Drama", "Thriller"]
#
#                                                homepage      id       imdb_id  \
# 0          "https://www.marvel.com/movies/the-eternals"  524434   "tt9032400"
# 1                "https://www.spidermannowayhome.movie"  634649  "tt10872600"
# 2          "https://www.illumination.com/movie/sing-2/"  438695   "tt6467266"
# 3                   "https://movies.disney.com/encanto"  568124   "tt2953050"
# 4                           "https://ghostbusters.com/"  425909   "tt4513678"
# ...                                                 ...     ...           ...
# 3303                                                 ""   39020   "tt0062433"
# 3304  "https://www.mgm.com/movies/on-her-majestys-se...     668   "tt0064757"
# 3305           "https://www.mgm.com/movies/thunderball"     660   "tt0059800"
# 3306                                                 ""     244   "tt0024216"
# 3307                                                 ""     877   "tt0023427"
#
#      original_language                     original_title  ...  \
# 0                 "en"                         "Eternals"  ...
# 1                 "en"          "Spider-Man: No Way Home"  ...
# 2                 "en"                           "Sing 2"  ...
# 3                 "en"                          "Encanto"  ...
# 4                 "en"          "Ghostbusters: Afterlife"  ...
# ...                ...                                ...  ...
# 3303              "es"             "La venganza del sexo"  ...
# 3304              "en"  "On Her Majesty's Secret Service"  ...
# 3305              "en"                      "Thunderball"  ...
# 3306              "en"                        "King Kong"  ...
# 3307              "en"                         "Scarface"  ...
#
#                                       producers_cleaned  \
# 0     ["kevinfeige", "louisd'esposito", "victoriaalo...
# 1     ["aviarad", "kevinfeige", "louisd'esposito", "...
# 2     ["christophermeledandri", "janethealy", "danak...
# 3     ["clarkspencer", "jenniferlee", "yvettmerinofl...
# 4     ["danaykroyd", "ivanreitman", "gilkenan", "mic...
# ...                                                 ...
# 3303                  ["emiliovieyra", "orestestrucco"]
# 3304  ["albertr.broccoli", "harrysaltzman", "stanley...
# 3305                                   ["kevinmcclory"]
# 3306  ["davido.selznick", "merianc.cooper", "ernestb...
# 3307                    ["howardhawks", "howardhughes"]
#
#                                         writers_cleaned  \
# 0     ["jackkirby", "patrickburleigh", "ryanfirpo", ...
# 1     ["stanlee", "stanlee", "steveditko", "stevedit...
# 2                    ["garthjennings", "garthjennings"]
# 3                   ["jaredbush", "charisecastrosmith"]
# 4     ["danaykroyd", "haroldramis", "jasonreitman", ...
# ...                                                 ...
# 3303                   ["emiliovieyra", "emiliovieyra"]
# 3304                   ["ianfleming", "richardmaibaum"]
# 3305  ["ianfleming", "richardmaibaum", "kevinmcclory...
# 3306  ["merianc.cooper", "jamesashmorecreelman", "ru...
# 3307  ["benhecht", "armitagetrail", "johnleemahin", ...
#
#                                        keywords_cleaned  \
# 0     ["boredom", "supernatural", "superhero", "base...
# 1     ["hero", "comicbook", "superhero", "basedoncom...
# 2                       ["anthropomorphism", "singing"]
# 3     ["magic", "musical", "forest", "familyrelation...
# 4     ["smalltown", "ghostbuster", "nostalgia", "aft...
# ...                                                 ...
# 3303                                   ["madscientist"]
# 3304  ["london,england", "suicide", "england", "base...
# 3305  ["paris,france", "spy", "sea", "florida", "fig...
# 3306  ["newyorkcity", "screenplay", "moviebusiness",...
# 3307  ["siblingrelationship", "chicago,illinois", "a...
#
#                                          genres_cleaned  \
# 0     ["action", "adventure", "fantasy", "sciencefic...
# 1             ["action", "adventure", "sciencefiction"]
# 2            ["animation", "comedy", "family", "music"]
# 3          ["animation", "comedy", "family", "fantasy"]
# 4                    ["comedy", "fantasy", "adventure"]
# ...                                                 ...
# 3303                       ["horror", "sciencefiction"]
# 3304                ["adventure", "action", "thriller"]
# 3305                ["adventure", "action", "thriller"]
# 3306                 ["adventure", "horror", "fantasy"]
# 3307           ["action", "crime", "drama", "thriller"]
#
#                            production_companies_cleaned  \
# 0                                     ["marvelstudios"]
# 1     ["marvelstudios", "pascalpictures", "columbiap...
# 2     ["illuminationentertainment", "universalpictur...
# 3     ["waltdisneyanimationstudios", "waltdisneypict...
# 4     ["columbiapictures", "bronstudios", "themontec...
# ...                                                 ...
# 3303                 ["productoresargentinosasociados"]
# 3304                ["eonproductions", "unitedartists"]
# 3305      ["eonproductions", "danjaq", "unitedartists"]
# 3306                               ["rkoradiopictures"]
# 3307               ["thecaddocompany", "unitedartists"]
#
#                                        overview_cleaned  \
# 0     "the eternals are a team of ancient aliens who...
# 1     "peter parker is unmasked and no longer able t...
# 2     "buster and his new cast now have their sights...
# 3     "the tale of an extraordinary family, the madr...
# 4     "when a single mom and her two kids arrive in ...
# ...                                                 ...
# 3303  "a doctor kidnaps young couples and performs b...
# 3304  "james bond tracks his archnemesis, ernst blof...
# 3305  "a criminal organization has obtained two nucl...
# 3306  "adventurous filmmaker, carl denham, sets out ...
# 3307  "a murderous thug shoots his way to the top of...
#
#                                                    soup  \
# 0     "boredom supernatural superhero basedoncomic s...
# 1     "hero comicbook superhero basedoncomic marvelc...
# 2     "anthropomorphism singing matthewmcconaughey r...
# 3     "magic musical forest familyrelationships fema...
# 4     "smalltown ghostbuster nostalgia afterlife seq...
# ...                                                 ...
# 3303  "madscientist ricardobauleo gloriaprat aldobar...
# 3304  "london,england suicide england basedonnovelor...
# 3305  "paris,france spy sea florida fighterpilot san...
# 3306  "newyorkcity screenplay moviebusiness exoticis...
# 3307  "siblingrelationship chicago,illinois alcohol ...
#
#                                           soup_overview  \
# 0     "boredom supernatural superhero basedoncomic s...
# 1     "hero comicbook superhero basedoncomic marvelc...
# 2     "anthropomorphism singing anthropomorphism sin...
# 3     "magic musical forest familyrelationships fema...
# 4     "smalltown ghostbuster nostalgia afterlife seq...
# ...                                                 ...
# 3303  "madscientist madscientist ricardobauleo glori...
# 3304  "london,england suicide england basedonnovelor...
# 3305  "paris,france spy sea florida fighterpilot san...
# 3306  "newyorkcity screenplay moviebusiness exoticis...
# 3307  "siblingrelationship chicago,illinois alcohol ...
#
#                                              poster_url  \
# 0     "https://image.tmdb.org/t/p/w780/b6qUu00iIIkXX...
# 1     "https://image.tmdb.org/t/p/w780/1g0dhYtq4irTY...
# 2     "https://image.tmdb.org/t/p/w780/aWeKITRFbbwY8...
# 3     "https://image.tmdb.org/t/p/w780/4j0PNHkMr5ax3...
# 4     "https://image.tmdb.org/t/p/w780/sg4xJaufDiQl7...
# ...                                                 ...
# 3303  "https://image.tmdb.org/t/p/w780/h10JuE2o3Rr7O...
# 3304  "https://image.tmdb.org/t/p/w780/iLAp1ODaZ8lbB...
# 3305  "https://image.tmdb.org/t/p/w780/oJ5ybB57eidPL...
# 3306  "https://image.tmdb.org/t/p/w780/lHlnxKL5GbgRi...
# 3307  "https://image.tmdb.org/t/p/w780/zH6q4rZEwGTDB...
#
#                         lowercase_title
# 0                            "eternals"
# 1             "spider-man: no way home"
# 2                              "sing 2"
# 3                             "encanto"
# 4             "ghostbusters: afterlife"
# ...                                 ...
# 3303            "the curious dr. humpp"
# 3304  "on her majesty's secret service"
# 3305                      "thunderball"
# 3306                        "king kong"
# 3307                         "scarface"
#
# [3308 rows x 54 columns]
