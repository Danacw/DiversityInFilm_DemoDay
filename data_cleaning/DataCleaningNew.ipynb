# %% [markdown]
# # The Movie Database: Data Extraction & Cleaning

# %%
#  %pip install cpi

# %%
# Import dependencies
import pandas as pd
import json
import requests
from pprint import pprint
import numpy as np
import cpi

from datetime import datetime

# Import config
from config import api_key, db_user, db_password, db_host, db_port, db_name

# %%
cpi.update()

# %% [markdown]
# ### Testing:

# %%
# Single Test: Discover Most Popular Movies
page_number = 1

# Endpoint for finding most popular movies
discover_movies = "https://api.themoviedb.org/3/discover/movie"
most_popular_url = f"{discover_movies}?api_key={api_key}&page={page_number}&sort_by=popularity.desc"

# Most popular movies
tmdb_response = requests.get(most_popular_url).json()
results = tmdb_response["results"]

json_string = json.dumps(results)
df = pd.read_json(json_string)
df
# Out:
#     adult                     backdrop_path                   genre_ids  \
# 0   False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg               [878, 28, 12]
# 1   False  /7ajHGIAYNMiIzejy1LJWdPrcAx8.jpg            [28, 35, 80, 53]
# 2   False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg             [16, 35, 10751]
# 3   False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg                [28, 18, 36]
# 4   False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg                [28, 12, 14]
# 5   False  /5RuR7GhOI5fElADXZb0X2sr9w5n.jpg  [16, 35, 10751, 14, 10402]
# 6   False   /VlHt27nCqOuTnuX6bku8QZapzO.jpg               [28, 12, 878]
# 7   False  /iUeeZ5PWfZGgUtCJfwcgmCfdzoI.jpg        [16, 878, 10751, 35]
# 8   False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg                [18, 36, 12]
# 9   False  /r2GAjd4rNOHJh6i6Y0FntmYuPQW.jpg                [12, 28, 53]
# 10  False  /39EQTf94Lckdo8yzS1CdWQSgmen.jpg              [27, 9648, 53]
# 11  False  /lyvszvJJqqI8aqBJ70XzdCNoK0y.jpg       [28, 12, 878, 18, 14]
# 12  False  /oE6bhqqVFyIECtBzqIuvh6JdaB5.jpg               [878, 18, 12]
# 13  False  /uWGPC7j70LE64nbetxQGSSYJO53.jpg                 [53, 10752]
# 14  False  /3cMfwbF1J9fglSssim4zKG6scIs.jpg                        [28]
# 15  False  /h3HsfV8Kn9Sz2QWUYYdP5ya23hx.jpg                   [878, 12]
# 16  False  /8Y43POKjjKDGI9MH89NW0NAzzp8.jpg           [35, 28, 12, 878]
# 17  False  /1zgob2Z8xVE3RZUgOKnHKcVPzOE.jpg                [16, 35, 14]
# 18  False  /vJ3ED2jPblACDqaJPZlbN6T1yjy.jpg            [53, 80, 28, 12]
# 19  False  /5WnfgU7myfqgkbl3CSj7LQeHU0e.jpg                        [27]
#
#         id original_language                             original_title  \
# 0   580489                en                Venom: Let There Be Carnage
# 1   512195                en                                 Red Notice
# 2   585245                en                   Clifford the Big Red Dog
# 3   617653                en                              The Last Duel
# 4   566525                en  Shang-Chi and the Legend of the Ten Rings
# 5   568124                en                                    Encanto
# 6   634649                en                    Spider-Man: No Way Home
# 7   482321                en                           Ron's Gone Wrong
# 17  /9xaAT3V3I9xxqnNiEjCivNFfdlh.jpg   2021-11-12
# 18  /qrq7sGXraFM6H9OcHFKQTKe8A3f.jpg   2021-10-08
# 19  /bPq6x47nEqMZED5PrKelcWWpezM.jpg   2021-12-02
#
#                                         title  video  vote_average  vote_count
# 0                 Venom: Let There Be Carnage  False           7.2        4398
# 1                                  Red Notice  False           6.8        1970
# 2                    Clifford the Big Red Dog  False           7.5         530
# 3                               The Last Duel  False           7.6         870
# 4   Shang-Chi and the Legend of the Ten Rings  False           7.8        4201
# 5                                     Encanto  False           7.4         307
# 6                     Spider-Man: No Way Home  False           8.4          42
# 7                            Ron's Gone Wrong  False           8.5         320
# 8                            Chernobyl: Abyss  False           6.3         235
# 9                              No Time to Die  False           7.6        2509
# 10           Paranormal Activity: Next of Kin  False           6.7         146
# 11                                   Eternals  False           7.1        1401
# 12                                      Finch  False           8.2        1418
# 13                             Zeros and Ones  False           5.7          66
# 14                             Garota da Moto  False           4.9           4
# 15                                       Dune  False           8.0        4697
# 16                                   Free Guy  False           7.8        4061
# 17               The Simpsons in Plusaversary  False           6.7         156
# 18                                    Outlaws  False           6.8          65
# 19                            The Whole Truth  False           6.6          41

# %%
#Single Test: Crew
movie_id = 672582

# Endpoint & response
movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
movie_response = requests.get(movie_url).json()

pprint(movie_response)
# Out:
# {'adult': False,
#  'backdrop_path': '/yL9RRZbDVbptqLwiZcK304ck4PL.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 27, 'name': 'Horror'}],
#  'homepage': '',
#  'id': 672582,
#  'imdb_id': 'tt11686490',
#  'original_language': 'en',
#  'original_title': 'The Deep House',
#  'overview': 'While diving in a remote French lake, a couple of YouTubers who '
#              'specialize in underwater exploration videos discover a house '
#              'submerged in the deep waters. What was initially a unique '
#              'finding soon turns into a nightmare when they discover that the '
#              'house was the scene of atrocious crimes. Trapped, with their '
#              'oxygen reserves falling dangerously, they realize the worst is '
#              'yet to come: they are not alone in the house.',
#  'popularity': 449.82,
#  'poster_path': '/5xhAPxRr64oQPEFnUOrttuI4ZEU.jpg',
#  'production_companies': [{'id': 12689,
#                            'logo_path': None,
#                            'name': 'Radar Films',
#                            'origin_country': 'FR'},
#                           {'id': 92840,
#                            'logo_path': None,
#                            'name': 'Logical Pictures',
#                            'origin_country': 'FR'},
#                           {'id': 49755,
#                            'logo_path': '/iom7Z8e1dzoTfCvwq8F4bJvbeIJ.png',
#                            'name': 'Apollo Films',
#                            'origin_country': 'FR'},
#                           {'id': 19037,
#                            'logo_path': '/tceh2aAORA5JxIZSLQ1GkzTBZDL.png',
#                            'name': 'uMedia',
#                            'origin_country': 'BE'},
#                           {'id': 12686,
#                            'logo_path': None,
#                            'name': 'Forecast Pictures',
#                            'origin_country': ''},
#                           {'id': 78299,
#                            'logo_path': None,
#                            'name': 'Screen Flanders',
#                            'origin_country': 'BE'},
#                           {'id': 11620,
#                            'logo_path': '/f3hRdCaK1w9qH1Qs8nLd2L2bae1.png',
#                            'name': 'OCS',
#                            'origin_country': 'FR'},
#                           {'id': 12352,
#                            'logo_path': '/fkIacb6MddD6trIWamr33SIcUAn.png',
#                            'name': 'Wallimage',
#                            'origin_country': 'BE'},
#                           {'id': 114955,
#                            'logo_path': None,
#                            'name': 'Tax Shelter du Gouvernement Fédéral Belge',
#                            'origin_country': 'BE'},
#                           {'id': 102877,
#                            'logo_path': '/zjkjypyhDQA0dNCv8WzIzEmqAQk.png',
#                            'name': 'Investisseurs Tax Shelter',
#                            'origin_country': 'BE'},
#                           {'id': 310,
#                            'logo_path': '/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png',
#                            'name': 'CNC',
#                            'origin_country': 'FR'}],
#  'production_countries': [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#                           {'iso_3166_1': 'FR', 'name': 'France'}],
#  'release_date': '2021-06-30',
#  'revenue': 0,
#  'runtime': 85,
#  'spoken_languages': [{'english_name': 'French',
#                        'iso_639_1': 'fr',
#                        'name': 'Français'},
#                       {'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'Portuguese',
#                        'iso_639_1': 'pt',
#                        'name': 'Português'}],
#  'status': 'Released',
#  'tagline': 'Breathe while you still can.',
#  'title': 'The Deep House',
#  'video': False,
#  'vote_average': 6.5,
#  'vote_count': 328}

# %% [raw]
# # Single Test: Movie Details
# movie_id = 672582
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [raw]
# # Single Test: Credits
# # movie_id = 566525
# movie_id = 284052
#
# movie_credits = f"/movie/{movie_id}/credits"
# credits_url = f"https://api.themoviedb.org/3/{movie_credits}?api_key={api_key}"
#
# # Get the json response for the credits
# credits_response = requests.get(credits_url).json()
# pprint(credits_response)

# %% [raw]
# # Find job names for Writing Department
# for i in credits_response['crew']:
#     if i['department'] == 'Writing':
#         name = i['name']
#         job = i['job']
#         print(f"{name}: {job}")

# %% [raw]
# # Single Test: Movie Recommendations
# movie_id = 32657
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}/recommendations?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [raw]
# # Single Test: Movie Release Date/Certifications
# movie_id = 32657
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}/release_dates?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [markdown]
# # Functions: Define API calls to extract key data points

# %%
# Start Timer Function (check on API call performance)
def start_timer():
    start = datetime.now()
    
    return start

# %%
# Stop Timer Function (check on API call performance)
def stop_timer(start):
    end = datetime.now()
    elapsed_time = (end - start)

    print(f"Total Time Elapsed:  {elapsed_time.total_seconds()} seconds")

# %% [markdown]
# ### API CALLS:

# %%
# Returns most popular movies
def get_most_popular_movies(api_key):
    
    movies = []
    
    # Loop through pages to get results for movies
    for x in range(1, 101):
        page_number = x

        # Endpoint for finding most popular movies
        discover_movies = "https://api.themoviedb.org/3/discover/movie"
        most_popular_url = f"{discover_movies}?api_key={api_key}&page={page_number}&sort_by=popularity.desc"
        
        # Most popular movies
        tmdb_response = requests.get(most_popular_url).json()
        results = tmdb_response["results"]

#         for y in range(len(results)):
#             movies.append(results[y]) 
        for result in results:
            movies.append(result)
            
    return movies

# %%
# Returns movie details as a list
def get_movie_details(api_key, movie_ids):  
    
    movie_details = []
    
    for movie_id in movie_ids:
        # Endpoint & response
        movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
        movie_response = requests.get(movie_url).json()

        # Append results to lists
        movie_details.append(movie_response)
        
    return movie_details

# %%
# Returns keywords as a list
def get_movie_keywords(api_key, movie_ids):
    keyword_details = []
    
    for movie_id in movie_ids:
        # Get keywords for each movie
        keywords_url = f"https://api.themoviedb.org/3/movie/{movie_id}/keywords?api_key={api_key}"
        keywords_response = requests.get(keywords_url).json()
        keywords_results = keywords_response["keywords"]
        
         # Append results to lists
        keyword_details.append(keywords_response)
        
    return keyword_details

# %%
# Returns credits as a list
def get_credits(api_key, movie_ids):
    credit_details = []
    
    for movie_id in movie_ids:
        # Generate movie credits
        movie_credits = f"/movie/{movie_id}/credits"
        credits_url = f"https://api.themoviedb.org/3/{movie_credits}?api_key={api_key}"

        # Get the json response for the credits
        credits_response = requests.get(credits_url).json()
        
        credit_details.append(credits_response)
        
    return credit_details

# %%
# Returns certifications as a list (rating: G, PG, etc.)
def get_certifications(api_key, movie_ids):
    certifications = []
    
    for movie_id in movie_ids:
        # Get certifications for each movie
        certification_url = f"https://api.themoviedb.org/3/movie/{movie_id}/release_dates?api_key={api_key}"
        
        certification_response = requests.get(certification_url).json()
        
        certifications.append(certification_response)
        
    return certifications

# %% [markdown]
# ### GET TITLES & IDS:

# %%
# Returns single title for specified index number
def get_title(results, idx):
    movie_title = results[idx]["title"]
    
    return movie_title

# %%
# Returns ids list
def get_ids(results):
    movie_ids = []
    for x in results:
        movie_ids.append(x["id"])
        
    return movie_ids

# %%
# Returns titles list
def get_titles(results):
    movie_titles = []
    for x in results:
        movie_titles.append(x["title"])
        
    return movie_titles

# %% [markdown]
# ### EXTRACT NEEDED DETAILS FROM COLUMNS: Cast, Crew, Gender, Production Countries etc.

# %%
# Extract the certification (ratings)
def extract_certification(x):
    name = ""
    
    for i in x:
        # Get ratings for US
        if i['iso_3166_1'] == 'US':
             # Append results to lists
            name = i['release_dates'][0]['certification']
            break
    return name

# %%
# Function to get the director out of the crew
def get_director(x):
    names = []
    
    for i in x:
        if i['job'] == 'Director':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the director gender out of the crew
def get_director_gender(x):
    names = []
    
    for i in x:
        if i['job'] == 'Director':
            gender = i['gender']
            names.append(gender)
            
    if(names):
        return names
    
    return np.nan

# %%
def fm_percentage(results):
    fm_count = 0
    total_count = 0
    for x in results:
        if x['gender'] == 1:
            fm_count += 1
        if x['gender'] == 1 or x['gender'] == 2:
            total_count += 1
    
    if total_count == 0:        
        return np.nan
            
    return percentage_format(100 * fm_count/total_count)

# %%
# Function to get the producers out of the crew
def get_producers(x):
    names = []
    
    for i in x:
        if i['job'] == 'Producer':
            name = i['name']
            names.append(name)
        elif i['job'] == "Executive Producer":
            name = i['name']
            names.append(name)
        elif i['job'] == 'Co-Producer':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the screenplay writers out of the crew
def get_writers(x):
    names = []
    for i in x:
        if i['department'] == 'Writing':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to create cast list
def get_cast_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        
        # Condition for cast (keep top 5)
        if len(names) > 5:
            names = names[:5]
        return names

    return []

# %%
# Function to create lists of each feature
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        return names
        
    return []

# %%
# Function to get production companies
def get_production_companies(x):
    names = []
    if isinstance(x, list):
        for i in x:
            name = i['name']
            names.append(name)
        return names
        
    return []

# %%
# Get each production company's country of origin
def get_production_company_country(x):
    names = []
    if isinstance(x, list):
        for i in x:
            country = i['origin_country']
            names.append(country)
        return names
    return []

# %%
# Get list of all languages available for film
def get_languages(x):
    names = []
    for i in x:
        name = i['english_name']
#         iso = i['iso_639_1']
        names.append(name)
    
    if(names):
        return names
    
    return np.nan

# %%
# Create binary column for foreign language films
def original_language_binary(x):
    if (x == 'en'):
        return 0
    elif (x != 'en'):
        return 1
    elif (x == "" | x == " "):
        return 0
    else:
        return 0

# %%
def percentage_format(percentage):
    return "{:,.2f}%".format(percentage)

# %% [markdown]
# ### CLEAN DATA FOR SOUP & CREATE SOUP: Used for Machine Learning

# %%
# Convert all strings to lower case and strip names of spaces
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else: 
            return ''

# %%
# Clean the overview column (by converting to lowercase)
def clean_overview(x):
    if isinstance(x, str):
        return x.lower()
    else: 
        return ''

# %%
# Create soup of words
def create_soup(x):
    space = ' '
    return (space.join(x['keywords_cleaned']) + space + space.join(x['cast_cleaned']) + space 
            + space.join(x['director_cleaned']) + space + space.join(x['producers_cleaned']) + space 
            + space.join(x['writers_cleaned']) + space + space.join(x['genres_cleaned']) + space 
            + space.join(x['production_companies_cleaned']))

# %%
# Create soup of words - 2 keywords, 2 genres & overview
def create_soup_overview(x):
    space = ' '
    return (space.join(x['keywords_cleaned']) + space + space.join(x['keywords_cleaned']) + space 
            + space.join(x['cast_cleaned']) + space + space.join(x['director_cleaned']) + space 
            + space.join(x['producers_cleaned']) + space + space.join(x['writers_cleaned']) + space 
            + space.join(x['genres_cleaned']) + space + space.join(x['genres_cleaned']) + space 
            + space.join(x['production_companies_cleaned']) + space + x['overview_cleaned'])

# %% [markdown]
# # CALL API

# %% [markdown]
# ### Get Most Popular Movies JSON Results:

# %%
# Start the timer
start = start_timer()

# %%
most_popular_movies = get_most_popular_movies(api_key)
# print(most_popular_movies)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  29.319513 seconds

# %% [markdown]
# ### List of Movie IDs:

# %%
movie_ids = get_ids(most_popular_movies)
#print(movie_ids)

# %%
len(movie_ids)
# Out:
# 2000

# %% [markdown]
# ### List of Titles:

# %%
titles = get_titles(most_popular_movies)
# print(titles)

# %%
len(titles)
# Out:
# 2000

# %% [markdown]
# ### Print Individual Title:

# %%
print(get_title(most_popular_movies, 0))
# Out:
# Venom: Let There Be Carnage

# %% [markdown]
# ### Get Movie Details:

# %%
# Start the timer
start = start_timer()

# %%
details = get_movie_details(api_key, movie_ids)

# %%
pprint(details[0:10])
# Out:
# [{'adult': False,
#   'backdrop_path': '/70nxSw3mFBsGmtkvcs91PbjerwD.jpg',
#   'belongs_to_collection': {'backdrop_path': '/rhLspFB1B8ZCkWEHFYmc3NKagzq.jpg',
#                             'id': 558216,
#                             'name': 'Venom Collection',
#                             'poster_path': '/670x9sf0Ru8y6ezBggmYudx61yB.jpg'},
#   'budget': 110000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#              {'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.venom.movie',
#   'id': 580489,
#   'imdb_id': 'tt7097896',
#   'original_language': 'en',
#   'original_title': 'Venom: Let There Be Carnage',
#   'overview': 'After finding a host body in investigative reporter Eddie '
#               'Brock, the alien symbiote must face a new enemy, Carnage, the '
#               'alter ego of serial killer Cletus Kasady.',
#   'popularity': 8633.976,
#   'poster_path': '/rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg',
#   'production_companies': [{'id': 7505,
#                             'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png',
#                             'name': 'Marvel Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'},
#                            {'id': 84041,
#                             'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png',
#                             'name': 'Pascal Pictures',
#                             'origin_country': 'US'},
#                            {'id': 53462,
#                             'logo_path': None,
#                             'name': 'Matt Tolmach Productions',
#                             'origin_country': 'US'},
#                            {'id': 166230,
#                             'logo_path': None,
#                             'name': 'Avi Arad Productions',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-09-30',
#   'revenue': 482000000,
#   'runtime': 97,
#   'spoken_languages': [{'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'},
#                        {'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Venom: Let There Be Carnage',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 4421},
#  {'adult': False,
#   'backdrop_path': '/5uVhMGsps81CN0S4U9NF0Z4tytG.jpg',
#   'belongs_to_collection': None,
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 80, 'name': 'Crime'},
#              {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.netflix.com/us/title/81161626',
#   'id': 512195,
#   'imdb_id': 'tt7991608',
#   'original_language': 'en',
#   'original_title': 'Red Notice',
#   'overview': 'An Interpol-issued Red Notice is a global alert to hunt and '
#               "capture the world's most wanted. But when a daring heist brings "
#               "together the FBI's top profiler and two rival criminals, "
#               "there's no telling what will happen.",
#   'popularity': 4825.133,
#   'poster_path': '/q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg',
#   'production_companies': [{'id': 34081,
#                             'logo_path': None,
#                             'name': 'Flynn Picture Company',
#                             'origin_country': 'US'},
#                            {'id': 73669,
#                             'logo_path': '/7tmSGstK3KwgcDIuBYLTAayjit9.png',
#                             'name': 'Seven Bucks Productions',
#                             'origin_country': 'US'},
#                            {'id': 923,
#                             'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png',
#                             'name': 'Legendary Pictures',
#                             'origin_country': 'US'},
#                            {'id': 102182,
#                             'logo_path': None,
#                             'name': 'Bad Version, Inc.',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-04',
#   'revenue': 0,
#   'runtime': 117,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Italian',
#                         'iso_639_1': 'it',
#                         'name': 'Italiano'},
#                        {'english_name': 'Russian',
#                         'iso_639_1': 'ru',
#                         'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'Pro and cons.',
#   'title': 'Red Notice',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 1982},
#  {'adult': False,
#   'backdrop_path': '/zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 10751, 'name': 'Family'}],
#   'homepage': '',
#   'id': 585245,
#   'imdb_id': 'tt2397461',
#   'original_language': 'en',
#   'original_title': 'Clifford the Big Red Dog',
#   'overview': 'As Emily struggles to fit in at home and at school, she '
#               'discovers a small red puppy who is destined to become her best '
#               'friend. When Clifford magically undergoes one heck of a growth '
#               'spurt, becomes a gigantic dog and attracts the attention of a '
#               'genetics company, Emily and her Uncle Casey have to fight the '
#               'forces of greed as they go on the run across New York City. '
#               'Along the way, Clifford affects the lives of everyone around '
#               'him and teaches Emily and her uncle the true meaning of '
#               'acceptance and unconditional love.',
#   'popularity': 3280.16,
#   'poster_path': '/ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg',
#   'production_companies': [{'id': 4,
#                             'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png',
#                             'name': 'Paramount',
#                             'origin_country': 'US'},
#                            {'id': 8147,
#                             'logo_path': '/q6HOAdSNgCbeOqwoMVRc6REgbXF.png',
#                             'name': 'Entertainment One',
#                             'origin_country': 'CA'},
#                            {'id': 7311,
#                             'logo_path': None,
#                             'name': 'Kerner Entertainment Company',
#                             'origin_country': ''},
#                            {'id': 30246,
#                             'logo_path': None,
#                             'name': 'Scholastic Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 114732,
#                             'logo_path': '/tNCbisMxO5mX2X2bOQxHHQZVYnT.png',
#                             'name': 'New Republic Pictures',
#                             'origin_country': 'US'},
#                            {'id': 10221,
#                             'logo_path': '/99VfWRgKasZoyK9UVB39gnYvFrZ.png',
#                             'name': 'Walden Media',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'},
#                            {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-10',
#   'revenue': 51000000,
#   'runtime': 97,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Adventure has never been bigger.',
#   'title': 'Clifford the Big Red Dog',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 540},
#  {'adult': False,
#   'backdrop_path': '/mFbS5TwN95BcSEfiztdchLgTQ0v.jpg',
#   'belongs_to_collection': None,
#   'budget': 100000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 18, 'name': 'Drama'},
#              {'id': 36, 'name': 'History'}],
#   'homepage': 'https://www.20thcenturystudios.com/movies/the-last-duel',
#   'id': 617653,
#   'imdb_id': 'tt4244994',
#   'original_language': 'en',
#   'original_title': 'The Last Duel',
#   'overview': 'King Charles VI declares that Knight Jean de Carrouges settle '
#               'his dispute with his squire, Jacques Le Gris, by challenging '
#               'him to a duel.',
#   'popularity': 3256.364,
#   'poster_path': '/zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg',
#   'production_companies': [{'id': 127928,
#                             'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#                             'name': '20th Century Studios',
#                             'origin_country': 'US'},
#                            {'id': 1645,
#                             'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png',
#                             'name': 'Scott Free Productions',
#                             'origin_country': 'GB'},
#                            {'id': 29313,
#                             'logo_path': '/1whsMqm5kAPxKBhnTlKNcbXBQJK.png',
#                             'name': 'Pearl Street Films',
#                             'origin_country': 'US'},
#                            {'id': 22213,
#                             'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png',
#                             'name': 'TSG Entertainment',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-10-13',
#   'revenue': 27000000,
#   'runtime': 152,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'French',
#                         'iso_639_1': 'fr',
#                         'name': 'Français'},
#                        {'english_name': 'Latin',
#                         'iso_639_1': 'la',
#                         'name': 'Latin'}],
#   'status': 'Released',
#   'tagline': 'The true story of a woman who defied a nation and made history.',
#   'title': 'The Last Duel',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 885},
#  {'adult': False,
#   'backdrop_path': '/cinER0ESG0eJ49kXlExM0MEWGxW.jpg',
#   'belongs_to_collection': {'backdrop_path': None,
#                             'id': 912503,
#                             'name': 'Shang-Chi Collection',
#                             'poster_path': None},
#   'budget': 150000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://www.marvel.com/movies/shang-chi-and-the-legend-of-the-ten-rings',
#   'id': 566525,
#   'imdb_id': 'tt9376612',
#   'original_language': 'en',
#   'original_title': 'Shang-Chi and the Legend of the Ten Rings',
#   'overview': 'Shang-Chi must confront the past he thought he left behind when '
#               'he is drawn into the web of the mysterious Ten Rings '
#               'organization.',
#   'popularity': 3189.442,
#   'poster_path': '/1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg',
#   'production_companies': [{'id': 420,
#                             'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#                             'name': 'Marvel Studios',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-09-01',
#   'revenue': 430238384,
#   'runtime': 132,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Mandarin',
#                         'iso_639_1': 'zh',
#                         'name': '普通话'}],
#   'status': 'Released',
#   'tagline': "You can't outrun your destiny.",
#   'title': 'Shang-Chi and the Legend of the Ten Rings',
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 4211},
#  {'adult': False,
#   'backdrop_path': '/g2djzUqA6mFplzC03gDk0WSyg99.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#              {'id': 16, 'name': 'Animation'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 10751, 'name': 'Family'},
#              {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://movies.disney.com/encanto',
#   'id': 568124,
#   'imdb_id': 'tt2953050',
#   'original_language': 'en',
#   'original_title': 'Encanto',
#   'overview': 'The tale of an extraordinary family, the Madrigals, who live '
#               'hidden in the mountains of Colombia, in a magical house, in a '
#               'vibrant town, in a wondrous, charmed place called an Encanto. '
#               'The magic of the Encanto has blessed every child in the family '
#               'with a unique gift from super strength to the power to '
#               'heal—every child except one, Mirabel. But when she discovers '
#               'that the magic surrounding the Encanto is in danger, Mirabel '
#               'decides that she, the only ordinary Madrigal, might just be her '
#               "exceptional family's last hope.",
#   'popularity': 2989.673,
#   'poster_path': '/4j0PNHkMr5ax3IA8tjtxcmPU3QT.jpg',
#   'production_companies': [{'id': 6125,
#                             'logo_path': '/tVPmo07IHhBs4HuilrcV0yujsZ9.png',
#                             'name': 'Walt Disney Animation Studios',
#                             'origin_country': 'US'},
#                            {'id': 2,
#                             'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#                             'name': 'Walt Disney Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-24',
#   'revenue': 151000000,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'}],
#   'status': 'Released',
#   'tagline': "There's a little magic in all of us ...almost all of us.",
#   'title': 'Encanto',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 313},
#  {'adult': False,
#   'backdrop_path': '/VlHt27nCqOuTnuX6bku8QZapzO.jpg',
#   'belongs_to_collection': {'backdrop_path': '/AvnqpRwlEaYNVL6wzC4RN94EdSd.jpg',
#                             'id': 531241,
#                             'name': 'Spider-Man (Avengers) Collection',
#                             'poster_path': '/nogV4th2P5QWYvQIMiWHj4CFLU9.jpg'},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.spidermannowayhome.movie',
#   'id': 634649,
#   'imdb_id': 'tt10872600',
#   'original_language': 'en',
#   'original_title': 'Spider-Man: No Way Home',
#   'overview': 'Peter Parker is unmasked and no longer able to separate his '
#               'normal life from the high-stakes of being a super-hero. When he '
#               'asks for help from Doctor Strange the stakes become even more '
#               'dangerous, forcing him to discover what it truly means to be '
#               'Spider-Man.',
#   'popularity': 2774.306,
#   'poster_path': '/1g0dhYtq4irTY1GPXvft6k4YLjm.jpg',
#   'production_companies': [{'id': 420,
#                             'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#                             'name': 'Marvel Studios',
#                             'origin_country': 'US'},
#                            {'id': 84041,
#                             'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png',
#                             'name': 'Pascal Pictures',
#                             'origin_country': 'US'},
#                            {'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-12-15',
#   'revenue': 0,
#   'runtime': 148,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The Multiverse unleashed.',
#   'title': 'Spider-Man: No Way Home',
#   'video': False,
#   'vote_average': 8.4,
#   'vote_count': 44},
#  {'adult': False,
#   'backdrop_path': '/iUeeZ5PWfZGgUtCJfwcgmCfdzoI.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#              {'id': 878, 'name': 'Science Fiction'},
#              {'id': 10751, 'name': 'Family'},
#              {'id': 35, 'name': 'Comedy'}],
#   'homepage': 'https://family.20thcenturystudios.com/movies/rons-gone-wrong',
#   'id': 482321,
#   'imdb_id': 'tt7504818',
#   'original_language': 'en',
#   'original_title': "Ron's Gone Wrong",
#   'overview': 'In a world where walking, talking, digitally connected bots '
#               "have become children's best friends, an 11-year-old finds that "
#               "his robot buddy doesn't quite work the same as the others do.",
#   'popularity': 2662.308,
#   'poster_path': '/gA9QxSravC2EVEkEKgyEmDrfL0e.jpg',
#   'production_companies': [{'id': 121605,
#                             'logo_path': '/4rc0vsJWygNm9ojrxSdPVU9jKyj.png',
#                             'name': 'Locksmith Animation',
#                             'origin_country': 'GB'},
#                            {'id': 127928,
#                             'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#                             'name': '20th Century Studios',
#                             'origin_country': 'US'},
#                            {'id': 141821,
#                             'logo_path': '/dvIQq8TmQJydp9BzBCVyNZBlOnA.png',
#                             'name': '20th Century Animation',
#                             'origin_country': 'US'},
#                            {'id': 22213,
#                             'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png',
#                             'name': 'TSG Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 107183,
#                             'logo_path': None,
#                             'name': 'Double Negative (DNEG)',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-10-15',
#   'revenue': 57000000,
#   'runtime': 106,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Best Friend Forever* (*battery life may vary)',
#   'title': "Ron's Gone Wrong",
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 330},
#  {'adult': False,
#   'backdrop_path': '/xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg',
#   'belongs_to_collection': None,
#   'budget': 9100000,
#   'genres': [{'id': 18, 'name': 'Drama'},
#              {'id': 36, 'name': 'History'},
#              {'id': 12, 'name': 'Adventure'}],
#   'homepage': '',
#   'id': 589761,
#   'imdb_id': 'tt10648714',
#   'original_language': 'ru',
#   'original_title': 'Чернобыль',
#   'overview': 'The aftermath of a shocking explosion at the Chernobyl nuclear '
#               'power station made hundreds of people sacrifice their lives to '
#               'clean up the site of the catastrophe and to successfully '
#               'prevent an even bigger disaster that could have turned a large '
#               'part of the European continent into an uninhabitable exclusion '
#               'zone. This is their story.',
#   'popularity': 2438.508,
#   'poster_path': '/kfQJQWFEoWRVBH8FUKnT0HX1yRS.jpg',
#   'production_companies': [{'id': 5630,
#                             'logo_path': '/s0mHCw53fp6EAapR7g0dwYbz0l5.png',
#                             'name': 'Non-Stop Productions',
#                             'origin_country': 'RU'},
#                            {'id': 103131,
#                             'logo_path': None,
#                             'name': 'DK Entertainment',
#                             'origin_country': 'RU'},
#                            {'id': 3419,
#                             'logo_path': '/byrxE2pJD9JLyBCIzyK0pYVanyG.png',
#                             'name': 'Central Partnership',
#                             'origin_country': 'RU'},
#                            {'id': 99796,
#                             'logo_path': '/86PJsqqWyGhpZdcq6DbtD35tJeQ.png',
#                             'name': 'KIT Film Studio',
#                             'origin_country': 'RU'}],
#   'production_countries': [{'iso_3166_1': 'RU', 'name': 'Russia'}],
#   'release_date': '2021-04-15',
#   'revenue': 5370393,
#   'runtime': 136,
#   'spoken_languages': [{'english_name': 'Russian',
#                         'iso_639_1': 'ru',
#                         'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Chernobyl: Abyss',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 235},
#  {'adult': False,
#   'backdrop_path': '/r2GAjd4rNOHJh6i6Y0FntmYuPQW.jpg',
#   'belongs_to_collection': {'backdrop_path': '/dOSECZImeyZldoq0ObieBE0lwie.jpg',
#                             'id': 645,
#                             'name': 'James Bond Collection',
#                             'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg'},
#   'budget': 242000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#              {'id': 28, 'name': 'Action'},
#              {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.007.com/no-time-to-die/',
#   'id': 370172,
#   'imdb_id': 'tt2382320',
#   'original_language': 'en',
#   'original_title': 'No Time to Die',
#   'overview': 'Bond has left active service and is enjoying a tranquil life in '
#               'Jamaica. His peace is short-lived when his old friend Felix '
#               'Leiter from the CIA turns up asking for help. The mission to '
#               'rescue a kidnapped scientist turns out to be far more '
#               'treacherous than expected, leading Bond onto the trail of a '
#               'mysterious villain armed with dangerous new technology.',
#   'popularity': 1999.424,
#   'poster_path': '/iUgygt3fscRoKWCV1d0C7FbM9TP.jpg',
#   'production_companies': [{'id': 7576,
#                             'logo_path': '/oYcUi1byZ312Z3xiz5ojz9RQLND.png',
#                             'name': 'Eon Productions',
#                             'origin_country': 'GB'},
#                            {'id': 21,
#                             'logo_path': '/aOWKh4gkNrfFZ3Ep7n0ckPhoGb5.png',
#                             'name': 'Metro-Goldwyn-Mayer',
#                             'origin_country': 'US'},
#                            {'id': 60,
#                             'logo_path': '/oJXpAs4I3W46e4dkaOEzCa4yBko.png',
#                             'name': 'United Artists',
#                             'origin_country': 'US'},
#                            {'id': 33,
#                             'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#                             'name': 'Universal Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-09-29',
#   'revenue': 758000000,
#   'runtime': 163,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'French',
#                         'iso_639_1': 'fr',
#                         'name': 'Français'},
#                        {'english_name': 'Italian',
#                         'iso_639_1': 'it',
#                         'name': 'Italiano'},
#                        {'english_name': 'Russian',
#                         'iso_639_1': 'ru',
#                         'name': 'Pусский'},
#                        {'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'The mission that changes everything begins…',
#   'title': 'No Time to Die',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 2521}]

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  624.241883 seconds

# %% [markdown]
# ### Get Keywords:

# %%
# Start the timer
start = start_timer()

# %%
keywords = get_movie_keywords(api_key, movie_ids)

# %%
# print(keywords)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  445.224551 seconds

# %% [markdown]
# ### Get Credits:

# %%
# Start the timer
start = start_timer()

# %%
credits = get_credits(api_key, movie_ids)

# %%
# print(credits)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  468.778203 seconds

# %% [markdown]
# ### Get Certifications:

# %%
# Start the timer
start = start_timer()

# %%
# Get the certifications for each movie (rating: G, PG, etc.)
certifications = get_certifications(api_key, movie_ids)
# certifications = get_certifications(api_key, [32657, 672582])

# %%
# print(certifications)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  461.868641 seconds

# %% [markdown]
# ## Movie Details DataFrame:

# %%
# Convert details to json
json_details_string = json.dumps(details)
# Convert json to dataframe
movie_details_df = pd.read_json(json_details_string)

# Export to save
# movie_details_df.to_csv("./static/data/movie_details.csv", index=False)

movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1  False  /5uVhMGsps81CN0S4U9NF0Z4tytG.jpg
# 2  False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
# 3  False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg
# 4  False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 558216, 'name': 'Venom Collection', 'po...  110000000
# 1                                               None  200000000
# 2                                               None          0
# 3                                               None  100000000
# 4  {'id': 912503, 'name': 'Shang-Chi Collection',...  150000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0                            https://www.venom.movie  580489  tt7097896
# 1          https://www.netflix.com/us/title/81161626  512195  tt7991608
# 2                                                     585245  tt2397461
# 3  https://www.20thcenturystudios.com/movies/the-...  617653  tt4244994
# 4  https://www.marvel.com/movies/shang-chi-and-th...  566525  tt9376612
#
#   original_language                             original_title  \
# 0                en                Venom: Let There Be Carnage
# 1                en                                 Red Notice
# 2                en                   Clifford the Big Red Dog
# 3                en                              The Last Duel
# 4                en  Shang-Chi and the Legend of the Ten Rings
#
#                                             overview  popularity  \
# 0  After finding a host body in investigative rep...    8633.976
# 1  An Interpol-issued Red Notice is a global aler...    4825.133
# 2  As Emily struggles to fit in at home and at sc...    3280.160
# 3  King Charles VI declares that Knight Jean de C...    3256.364
# 4  Shang-Chi must confront the past he thought he...    3189.442
#
#                         poster_path  \
# 0  /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg
# 1  /q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg
# 2  /ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg
# 3  /zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg
# 4  /1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg
#
#                                 production_companies  \
# 0  [{'id': 7505, 'logo_path': '/837VMM4wOkODc1idN...
# 1  [{'id': 34081, 'logo_path': None, 'name': 'Fly...
# 2  [{'id': 4, 'logo_path': '/fycMZt242LVjagMByZOL...
# 3  [{'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEn...
# 4  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
#
#                                 production_countries release_date    revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-30  482000000
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-04          0
# 2  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2021-11-10   51000000
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2021-10-13   27000000
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-01  430238384
#
#    runtime                                   spoken_languages    status  \
# 0       97  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 1      117  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2       97  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3      152  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4      132  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0
# 1                                      Pro and cons.
# 2                   Adventure has never been bigger.
# 3  The true story of a woman who defied a nation ...
# 4                     You can't outrun your destiny.
#
#                                        title  video  vote_average  vote_count
# 0                Venom: Let There Be Carnage  False           7.2        4421
# 1                                 Red Notice  False           6.8        1982
# 2                   Clifford the Big Red Dog  False           7.6         540
# 3                              The Last Duel  False           7.6         885
# 4  Shang-Chi and the Legend of the Ten Rings  False           7.8        4211

# %%
# Extract year from release date
movie_details_df["year"] = pd.DatetimeIndex(movie_details_df['release_date']).year
# Drop any N/A from year
movie_details_df.dropna(inplace=True, how="any", subset=['year','release_date'])
 
# Convert to int
movie_details_df["year"] = movie_details_df["year"].astype(int)
    
# Rename columns to prepare for inflation calculation
movie_details_df = movie_details_df.rename(columns = {
    "revenue": "original_revenue",
    "budget": "original_budget"
})

# %%
len(movie_details_df)
# Out:
# 1991

# %% [markdown]
# ## Adjust Budget & Revenue for Inflation

# %%
# Create dataframe for cpi
cpi_df = pd.DataFrame(columns=['year', 'cpi_2021', 'cpi_old'])

# %%
# Create list of years (1913-2021)
years = []
for i in range(1913, 2022):
    years.append(i)

# %%
# Define 2021 cpi
cpi_2021 = 269.489

# Loop through years to append to dataframe
for year in years:
    if year != 2021:
        cpi_old = cpi.get(year)
        cpi_df = cpi_df.append({"year": year, 'cpi_2021': cpi_2021, 'cpi_old': cpi_old}, ignore_index=True)
    elif year == 2021:
        cpi_df = cpi_df.append({"year": year, 'cpi_2021': cpi_2021, 'cpi_old': cpi_2021}, ignore_index=True)

# %%
# Convert year type to int
cpi_df['year'] = cpi_df['year'].astype(int)
cpi_df.head()
# Out:
#    year  cpi_2021  cpi_old
# 0  1913   269.489      9.9
# 1  1914   269.489     10.0
# 2  1915   269.489     10.1
# 3  1916   269.489     10.9
# 4  1917   269.489     12.8

# %%
# Merge movie details df with cpi df
movie_details_df = movie_details_df.merge(cpi_df, on="year")
movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1  False  /5uVhMGsps81CN0S4U9NF0Z4tytG.jpg
# 2  False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
# 3  False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg
# 4  False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 1                                               None        200000000
# 2                                               None                0
# 3                                               None        100000000
# 4  {'id': 912503, 'name': 'Shang-Chi Collection',...        150000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0                            https://www.venom.movie  580489  tt7097896
# 1          https://www.netflix.com/us/title/81161626  512195  tt7991608
# 2                                                     585245  tt2397461
# 3  https://www.20thcenturystudios.com/movies/the-...  617653  tt4244994
# 4  https://www.marvel.com/movies/shang-chi-and-th...  566525  tt9376612
#
#   original_language                             original_title  \
# 0                en                Venom: Let There Be Carnage
# 1                en                                 Red Notice
# 2                en                   Clifford the Big Red Dog
# 3                en                              The Last Duel
# 4                en  Shang-Chi and the Legend of the Ten Rings
#
#                                             overview  popularity  \
# 0  After finding a host body in investigative rep...    8633.976
# 1  An Interpol-issued Red Notice is a global aler...    4825.133
# 2  As Emily struggles to fit in at home and at sc...    3280.160
# 3  King Charles VI declares that Knight Jean de C...    3256.364
# 4  Shang-Chi must confront the past he thought he...    3189.442
#
#                         poster_path  \
# 0  /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg
# 1  /q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg
# 2  /ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg
# 3  /zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg
# 4  /1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg
#
#                                 production_companies  \
# 0  [{'id': 7505, 'logo_path': '/837VMM4wOkODc1idN...
# 1  [{'id': 34081, 'logo_path': None, 'name': 'Fly...
# 2  [{'id': 4, 'logo_path': '/fycMZt242LVjagMByZOL...
# 3  [{'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEn...
# 4  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-04
# 2  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2021-11-10
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2021-10-13
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-01
#
#    original_revenue  runtime  \
# 0         482000000       97
# 1                 0      117
# 2          51000000       97
# 3          27000000      152
# 4         430238384      132
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0
# 1                                      Pro and cons.
# 2                   Adventure has never been bigger.
# 3  The true story of a woman who defied a nation ...
# 4                     You can't outrun your destiny.
#
#                                        title  video  vote_average  vote_count  \
# 0                Venom: Let There Be Carnage  False           7.2        4421
# 1                                 Red Notice  False           6.8        1982
# 2                   Clifford the Big Red Dog  False           7.6         540
# 3                              The Last Duel  False           7.6         885
# 4  Shang-Chi and the Legend of the Ten Rings  False           7.8        4211
#
#    year  cpi_2021  cpi_old
# 0  2021   269.489  269.489
# 1  2021   269.489  269.489
# 2  2021   269.489  269.489
# 3  2021   269.489  269.489
# 4  2021   269.489  269.489

# %%
# Create adjusted column for each feature
features = ["revenue", "budget"]

for feature in features:
    movie_details_df[f'adjusted_{feature}'] = (movie_details_df[f'original_{feature}'] * movie_details_df['cpi_2021']) / movie_details_df['cpi_old']

movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1  False  /5uVhMGsps81CN0S4U9NF0Z4tytG.jpg
# 2  False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
# 3  False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg
# 4  False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 1                                               None        200000000
# 2                                               None                0
# 3                                               None        100000000
# 4  {'id': 912503, 'name': 'Shang-Chi Collection',...        150000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0                            https://www.venom.movie  580489  tt7097896
# 1          https://www.netflix.com/us/title/81161626  512195  tt7991608
# 2                                                     585245  tt2397461
# 3  https://www.20thcenturystudios.com/movies/the-...  617653  tt4244994
# 4  https://www.marvel.com/movies/shang-chi-and-th...  566525  tt9376612
#
#   original_language                             original_title  \
# 0                en                Venom: Let There Be Carnage
# 1                en                                 Red Notice
# 2                en                   Clifford the Big Red Dog
# 3                en                              The Last Duel
# 4                en  Shang-Chi and the Legend of the Ten Rings
#
#                                             overview  popularity  \
# 0  After finding a host body in investigative rep...    8633.976
# 1  An Interpol-issued Red Notice is a global aler...    4825.133
# 2  As Emily struggles to fit in at home and at sc...    3280.160
# 3  King Charles VI declares that Knight Jean de C...    3256.364
# 4  Shang-Chi must confront the past he thought he...    3189.442
#
#                         poster_path  \
# 0  /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg
# 1  /q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg
# 2  /ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg
# 3  /zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg
# 4  /1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg
#
#                                 production_companies  \
# 0  [{'id': 7505, 'logo_path': '/837VMM4wOkODc1idN...
# 1  [{'id': 34081, 'logo_path': None, 'name': 'Fly...
# 2  [{'id': 4, 'logo_path': '/fycMZt242LVjagMByZOL...
# 3  [{'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEn...
# 4  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-04
# 2  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2021-11-10
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2021-10-13
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-01
#
#    original_revenue  runtime  \
# 0         482000000       97
# 1                 0      117
# 2          51000000       97
# 3          27000000      152
# 4         430238384      132
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0
# 1                                      Pro and cons.
# 2                   Adventure has never been bigger.
# 3  The true story of a woman who defied a nation ...
# 4                     You can't outrun your destiny.
#
#                                        title  video  vote_average  vote_count  \
# 0                Venom: Let There Be Carnage  False           7.2        4421
# 1                                 Red Notice  False           6.8        1982
# 2                   Clifford the Big Red Dog  False           7.6         540
# 3                              The Last Duel  False           7.6         885
# 4  Shang-Chi and the Legend of the Ten Rings  False           7.8        4211
#
#    year  cpi_2021  cpi_old  adjusted_revenue  adjusted_budget
# 0  2021   269.489  269.489       482000000.0      110000000.0
# 1  2021   269.489  269.489               0.0      200000000.0
# 2  2021   269.489  269.489        51000000.0              0.0
# 3  2021   269.489  269.489        27000000.0      100000000.0
# 4  2021   269.489  269.489       430238384.0      150000000.0

# %%
# Check values
movie_details_df[['original_budget', 'adjusted_budget', 'original_revenue', 'adjusted_revenue', 'year']]
# Out:
#       original_budget  adjusted_budget  original_revenue  adjusted_revenue  \
# 0           110000000     1.100000e+08         482000000      4.820000e+08
# 1           200000000     2.000000e+08                 0      0.000000e+00
# 2                   0     0.000000e+00          51000000      5.100000e+07
# 3           100000000     1.000000e+08          27000000      2.700000e+07
# 4           150000000     1.500000e+08         430238384      4.302384e+08
# ...               ...              ...               ...               ...
# 1969                0     0.000000e+00                 0      0.000000e+00
# 1970           660000     2.727956e+06          16000000      6.613227e+07
# 1971          6000000     5.215916e+07         102272727      8.890766e+08
# 1972                0     0.000000e+00                 0      0.000000e+00
# 1973          3180000     4.394744e+07           9644124      1.332813e+08
#
#       year
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021
# ...    ...
# 1969  1978
# 1970  1978
# 1971  1964
# 1972  1964
# 1973  1946
#
# [1974 rows x 5 columns]

# %% [markdown]
# ## Low Budget:

# %%
# Create budget bins
bins = [1, 15000000, 50000000, 150000000, 380000000] 
bin_names = ["1 to 15m", "16m to 50m", "51m to 150m", "151m to 380m"]

# Append a budget bin column
movie_details_df["budget_bins"] = pd.cut(movie_details_df["adjusted_budget"], bins, labels=bin_names)
movie_details_df["budget_bins"].value_counts()
# Out:
# 51m to 150m     382
# 16m to 50m      337
# 151m to 380m    247
# 1 to 15m        198
# Name: budget_bins, dtype: int64

# %%
# Low Budget
movie_details_df.loc[movie_details_df["budget_bins"] == "1 to 15m"].head()
# Out:
#     adult                     backdrop_path  \
# 8   False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 24  False  /4EJSMQOM1bZPHvzqAQe87suBxdf.jpg
# 29  False  /qXctHIfK4LAgHH7qZiJJVCPclaY.jpg
# 30  False  /lV3UFPPxDIPelh46G9oySXN9Mcz.jpg
# 39  False  /dIibeeq4QMay5bTJ2vjr72IFFRo.jpg
#
#                                 belongs_to_collection  original_budget  \
# 8                                                None          9100000
# 24                                               None           250000
# 29                                               None            45223
# 30  {'id': 702624, 'name': 'After Collection', 'po...         14000000
# 39  {'id': 589755, 'name': 'Последний богатырь (Ко...          8400000
#
#                                                genres  \
# 8   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 24  [{'id': 10752, 'name': 'War'}, {'id': 36, 'nam...
# 29  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 30  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 39  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
#
#                                              homepage      id     imdb_id  \
# 8                                                      589761  tt10648714
# 24             https://www.netflix.com/title/81450071  885110  tt15847872
# 29  https://www.disneyplus.com/movies/ciao-alberto...  876716  tt15476620
# 30                                                     744275  tt13069986
# 39                                                     589754  tt13606158
#
#    original_language                  original_title  \
# 8                 ru                       Чернобыль
# 24                en                           Amina
# 29                en                    Ciao Alberto
# 30                en                   After We Fell
# 39                ru  Последний богатырь: Корень зла
#
#                                              overview  popularity  \
# 8   The aftermath of a shocking explosion at the C...    2438.508
# 24  In 16th-century Zazzau, now Zaria, Nigeria, Am...    1255.799
# 29  With his best friend Luca away at school, Albe...     911.505
# 30  Just as Tessa's life begins to become unglued,...     843.613
# 39  Peace and tranquility have set in Belogorie. T...     692.329
#
#                          poster_path  \
# 8   /kfQJQWFEoWRVBH8FUKnT0HX1yRS.jpg
# 24  /hMIQiwLpBfTfe3ZbRlNx4225Mgg.jpg
# 29  /1SyTnaY0wte69oKdqxQLvxPT3hs.jpg
# 30  /dU4HfnTEJDf9KvxGS9hgO7BVeju.jpg
# 39  /5VJSIAhSn4qUsg5nOj4MhQhF5wQ.jpg
#
#                                  production_companies  \
# 8   [{'id': 5630, 'logo_path': '/s0mHCw53fp6EAapR7...
# 24  [{'id': 162630, 'logo_path': None, 'name': 'Vi...
# 29  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 30  [{'id': 6626, 'logo_path': '/A1BnMoWjzjOrjzpWi...
# 39  [{'id': 42877, 'logo_path': '/15THT1W3NROsbDXP...
#
#                                  production_countries release_date  \
# 8            [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2021-04-15
# 24          [{'iso_3166_1': 'NG', 'name': 'Nigeria'}]   2021-11-04
# 29  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-12
# 30  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2021-09-01
# 39           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2021-01-01
#
#     original_revenue  runtime  \
# 8            5370393      136
# 24                 0      120
# 29                 0        7
# 30          19000000       99
# 39          27658331      120
#
#                                      spoken_languages    status  \
# 8   [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 24  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 29  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 30  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 39  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
#
#                                    tagline                           title  \
# 8                                                         Chernobyl: Abyss
# 24      She is Amina and she fears nobody.                           Amina
# 29  They go together like pasta and pesto.                    Ciao Alberto
# 30                                                           After We Fell
# 39                                          The Last Warrior: Root of Evil
#
#     video  vote_average  vote_count  year  cpi_2021  cpi_old  \
# 8   False           6.3         235  2021   269.489  269.489
# 24  False           6.3          55  2021   269.489  269.489
# 29  False           7.7         252  2021   269.489  269.489
# 30  False           7.2        1123  2021   269.489  269.489
# 39  False           7.0          67  2021   269.489  269.489
#
#     adjusted_revenue  adjusted_budget budget_bins
# 8          5370393.0        9100000.0    1 to 15m
# 24               0.0         250000.0    1 to 15m
# 29               0.0          45223.0    1 to 15m
# 30        19000000.0       14000000.0    1 to 15m
# 39        27658331.0        8400000.0    1 to 15m

# %% [markdown]
# ## Keywords DataFrame:

# %%
# Convert keywords to json
json_keywords_string = json.dumps(keywords)
# Convert json to dataframe
movie_keywords_df = pd.read_json(json_keywords_string)

# Export to save
# movie_keywords_df.to_csv("./static/data/movie_keywords.csv", index=False)
pprint(json_keywords_string)
# Out:
# ('[{"id": 580489, "keywords": [{"id": 1701, "name": "hero"}, {"id": 2095, '
#  '"name": "anti hero"}, {"id": 3289, "name": "villain"}, {"id": 9663, "name": '
#  '"sequel"}, {"id": 9715, "name": "superhero"}, {"id": 9717, "name": "based on '
#  'comic"}, {"id": 179430, "name": "aftercreditsstinger"}, {"id": 193132, '
#  '"name": "symbiote"}, {"id": 265894, "name": "marvel comics"}]}, {"id": '
#  '512195, "keywords": [{"id": 1812, "name": "fbi"}, {"id": 6710, "name": '
#  '"interpol"}, {"id": 10051, "name": "heist"}, {"id": 14789, "name": "art '
#  'thief"}]}, {"id": 585245, "keywords": [{"id": 818, "name": "based on novel '
#  'or book"}, {"id": 162628, "name": "giant dog"}]}, {"id": 617653, "keywords": '
#  '[{"id": 818, "name": "based on novel or book"}, {"id": 4299, "name": '
#  '"normandy, france"}, {"id": 9672, "name": "based on a true story"}, {"id": '
#  '10466, "name": "knight"}, {"id": 12965, "name": "duel"}, {"id": 15126, '
#  '"name": "historical"}, {"id": 175245, "name": "sword duel"}, {"id": 222842, '
#  '"name": "squire"}, {"id": 237612, "name": "14th century"}, {"id": 258962, '
#  '"name": "medieval france"}]}, {"id": 566525, "keywords": [{"id": 779, '
#  '"name": "martial arts"}, {"id": 9715, "name": "superhero"}, {"id": 9717, '
#  '"name": "based on comic"}, {"id": 9917, "name": "mixed martial arts"}, '
#  '{"id": 179431, "name": "duringcreditsstinger"}, {"id": 180547, "name": '
#  '"marvel cinematic universe (mcu)"}, {"id": 265894, "name": "marvel '
#  'comics"}]}, {"id": 568124, "keywords": []}, {"id": 634649, "keywords": '
#  '[{"id": 1701, "name": "hero"}, {"id": 5451, "name": "comic book"}, {"id": '
#  '9715, "name": "superhero"}, {"id": 9717, "name": "based on comic"}, {"id": '
#  '180547, "name": "marvel cinematic universe (mcu)"}]}, {"id": 482321, '
#  '"keywords": [{"id": 18035, "name": "family"}, {"id": 285795, "name": "best '
#  'friend forever"}]}, {"id": 589761, "keywords": [{"id": 210326, "name": '
#  '"chernobyl"}]}, {"id": 370172, "keywords": [{"id": 470, "name": "spy"}, '
#  '{"id": 156095, "name": "british secret service"}, {"id": 219965, "name": '
#  '"nanobots"}, {"id": 244739, "name": "007"}]}, {"id": 609972, "keywords": '
#  '[{"id": 9663, "name": "sequel"}, {"id": 9853, "name": "paranormal"}, {"id": '
#  '161261, "name": "demonic possession"}, {"id": 162846, "name": "ghost"}, '
#  '{"id": 163053, "name": "found footage"}, {"id": 172808, "name": "paranormal '
#  'activity"}, {"id": 190396, "name": "devil worship"}, {"id": 228761, "name": '
#  '"animal sacrifice"}, {"id": 287097, "name": "pagan cult"}]}, {"id": 524434, '
#  '"keywords": [{"id": 3925, "name": "boredom"}, {"id": 6152, "name": '
#  '"supernatural"}, {"id": 9715, "name": "superhero"}, {"id": 9717, "name": '
#  '"based on comic"}, {"id": 33637, "name": "super power"}, {"id": 180547, '
#  '"name": "marvel cinematic universe (mcu)"}, {"id": 188953, "name": "sign '
#  'languages"}, {"id": 189119, "name": "ancient"}, {"id": 244445, "name": '
#  '"god-like"}]}, {"id": 522402, "keywords": [{"id": 14544, "name": "robot"}, '
#  '{"id": 189092, "name": "journey"}, {"id": 202647, "name": "humanity"}, '
#  '{"id": 285366, "name": "post-apocalyptic"}]}, {"id": 762433, "keywords": '
#  '[{"id": 588, "name": "rome, italy"}, {"id": 949, "name": "terrorist"}, '
#  '"sequel"}, {"id": 9715, "name": "superhero"}, {"id": 9717, "name": "based on '
#  'comic"}, {"id": 14796, "name": "destruction"}, {"id": 179430, "name": '
#  '"aftercreditsstinger"}, {"id": 179431, "name": "duringcreditsstinger"}, '
#  '{"id": 180547, "name": "marvel cinematic universe (mcu)"}, {"id": 196413, '
#  '"name": "tower of london"}]}, {"id": 459151, "keywords": [{"id": 1009, '
#  '"name": "baby"}, {"id": 9663, "name": "sequel"}, {"id": 18035, "name": '
#  '"family"}]}, {"id": 315635, "keywords": [{"id": 242, "name": "new york '
#  'city"}, {"id": 521, "name": "washington dc, usa"}, {"id": 6270, "name": '
#  '"high school"}, {"id": 9715, "name": "superhero"}, {"id": 9717, "name": '
#  '"based on comic"}, {"id": 161184, "name": "reboot"}, {"id": 180547, "name": '
#  '"marvel cinematic universe (mcu)"}]}, {"id": 887767, "keywords": []}, {"id": '
#  '802217, "keywords": [{"id": 65, "name": "holiday"}, {"id": 282, "name": '
#  '"video game"}, {"id": 169829, "name": "suburban chicago"}, {"id": 207317, '
#  '"name": "christmas"}, {"id": 208289, "name": "1980s"}]}, {"id": 785538, '
#  '"keywords": [{"id": 6019, "name": "human trafficking"}, {"id": 8041, "name": '
#  '"sao paulo, brazil"}]}, {"id": 451048, "keywords": [{"id": 10787, "name": '
#  '"jungle"}, {"id": 158244, "name": "riverboat"}, {"id": 210184, "name": '
#  '"1910s"}, {"id": 217120, "name": "amazon river"}, {"id": 279987, "name": '
#  '"based on theme park ride"}]}, {"id": 589754, "keywords": [{"id": 197349, '
#  '"name": "children\'s story"}, {"id": 277388, "name": "the last hero"}]}, '
#  '{"id": 671043, "keywords": []}, {"id": 618162, "keywords": [{"id": 378, '
#  '"name": "prison"}, {"id": 3398, "name": "release from prison"}, {"id": 9748, '
#  '"name": "revenge"}, {"id": 10511, "name": "western"}, {"id": 155291, "name": '
#  '"cowboy"}, {"id": 155573, "name": "wild west"}]}, {"id": 654974, "keywords": '
#  '[{"id": 65, "name": "holiday"}, {"id": 169826, "name": "home alone"}, {"id": '
#  '193048, "name": "christmas spirit"}, {"id": 207317, "name": "christmas"}]}, '
#  '{"id": 774741, "keywords": [{"id": 13035, "name": "middle school"}, {"id": '
#  '288574, "name": "scrawny"}, {"id": 288575, "name": "preteen"}]}, {"id": '
#  '568620, "keywords": [{"id": 9675, "name": "prequel"}, {"id": 9717, "name": '
#  '"based on comic"}, {"id": 10244, "name": "based on cartoon"}, {"id": 10278, '
#  '"name": "ninja"}, {"id": 10542, "name": "based on toy"}, {"id": 15285, '
#  '"name": "spin off"}, {"id": 18932, "name": "origin of hero"}, {"id": 156863, '
#  '"name": "gi joe"}, {"id": 158773, "name": "female fighter"}, {"id": 219404, '
#  '"name": "action hero"}, {"id": 229607, "name": "female warrior"}, {"id": '
#  '255024, "name": "shared universe"}, {"id": 269769, "name": "based on tv '
#  'series"}]}, {"id": 508943, "keywords": [{"id": 131, "name": "italy"}, {"id": '
#  '1299, "name": "monster"}, {"id": 1328, "name": "secret"}, {"id": 6054, '
#  '"warrior"}]}, {"id": 482373, "keywords": [{"id": 1526, "name": "home"}, '
#  '{"id": 4278, "name": "invasion"}, {"id": 7412, "name": "sin"}, {"id": 9663, '
#  '"name": "sequel"}, {"id": 12371, "name": "gunfight"}, {"id": 12660, "name": '
#  '"blind"}, {"id": 14903, "name": "home invasion"}, {"id": 15009, "name": '
#  '"criminal"}, {"id": 173594, "name": "handgun"}, {"id": 207556, "name": '
#  '"blind man"}, {"id": 273593, "name": "hammer"}]}, {"id": 317442, "keywords": '
#  '[{"id": 210024, "name": "anime"}]}, {"id": 641501, "keywords": [{"id": 818, '
#  '"name": "based on novel or book"}, {"id": 9715, "name": "superhero"}]}, '
#  '{"id": 602223, "keywords": [{"id": 9663, "name": "sequel"}, {"id": 9675, '
#  '"name": "prequel"}, {"id": 9826, "name": "murder"}, {"id": 235742, "name": '
#  '"purge"}]}, {"id": 458576, "keywords": [{"id": 11024, "name": "female '
#  'soldier"}, {"id": 11100, "name": "giant monster"}, {"id": 12446, "name": '
#  '"another dimension"}, {"id": 18101, "name": "bow and arrow"}, {"id": 41645, '
#  '"name": "based on video game"}, {"id": 196068, "name": "swordswoman"}, '
#  '{"id": 196984, "name": "dimensional travel"}]}, {"id": 846167, "keywords": '
#  '[]}, {"id": 24428, "keywords": [{"id": 242, "name": "new york city"}, {"id": '
#  '5539, "name": "shield"}, {"id": 9715, "name": "superhero"}, {"id": 9717, '
#  '"name": "based on comic"}, {"id": 14909, "name": "alien invasion"}, {"id": '
#  '155030, "name": "superhero team"}, {"id": 179430, "name": '
#  '"aftercreditsstinger"}, {"id": 179431, "name": "duringcreditsstinger"}, '
#  '{"id": 180547, "name": "marvel cinematic universe (mcu)"}]}, {"id": 539885, '
#  '"keywords": [{"id": 782, "name": "assassin"}, {"id": 9826, "name": '
#  '"murder"}, {"id": 281405, "name": "violence"}]}, {"id": 831405, "keywords": '
#  '[{"id": 849, "name": "dc comics"}, {"id": 9717, "name": "based on comic"}, '
#  '{"id": 41645, "name": "based on video game"}]}, {"id": 464052, "keywords": '
#  '[{"id": 849, "name": "dc comics"}, {"id": 9715, "name": "superhero"}, {"id": '
#  '9717, "name": "based on comic"}, {"id": 208289, "name": "1980s"}, {"id": '
#  '219404, "name": "action hero"}, {"id": 229266, "name": "dc extended '
#  'universe"}]}, {"id": 813258, "keywords": [{"id": 261274, "name": "dracula"}, '
#  '{"id": 263548, "name": "short film"}]}, {"id": 347201, "keywords": [{"id": '
#  '210024, "name": "anime"}, {"id": 241320, "name": "boruto"}]}, {"id": 335797, '
#  '"keywords": [{"id": 11477, "name": "anthropomorphism"}, {"id": 12990, '
#  '"name": "singing"}, {"id": 186120, "name": "singing competition"}]}, {"id": '
#  '725273, "keywords": []}, {"id": 587807, "keywords": [{"id": 179430, "name": '
#  '"aftercreditsstinger"}, {"id": 209220, "name": "live action and animation"}, '
#  '{"id": 277447, "name": "rapping animal"}, {"id": 277448, "name": '
#  '"autotune"}]}, {"id": 613504, "keywords": [{"id": 818, "name": "based on '
#  '"name": "curse"}, {"id": 10623, "name": "jock"}, {"id": 162846, "name": '
#  '"ghost"}, {"id": 175387, "name": "communicating with the dead"}, {"id": '
#  '179430, "name": "aftercreditsstinger"}, {"id": 181820, "name": "witch '
#  'trial"}, {"id": 181822, "name": "child witch"}, {"id": 181834, "name": '
#  '"empathy"}, {"id": 215191, "name": "strange"}]}, {"id": 11470, "keywords": '
#  '[{"id": 586, "name": "new jersey"}, {"id": 1471, "name": "places and '
#  'planets"}, {"id": 1826, "name": "space marine"}, {"id": 2964, "name": '
#  '"future"}, {"id": 3385, "name": "cryogenics"}, {"id": 4426, "name": '
#  '"sadism"}, {"id": 6259, "name": "psychopath"}, {"id": 8087, "name": '
#  '"horror"}, {"id": 9720, "name": "woods"}, {"id": 9882, "name": "space"}, '
#  '{"id": 10089, "name": "slaughter"}, {"id": 10714, "name": "serial killer"}, '
#  '{"id": 12339, "name": "slasher"}, {"id": 14676, "name": "series of '
#  'murders"}, {"id": 14760, "name": "scientist"}, {"id": 256183, "name": '
#  '"supernatural horror"}]}, {"id": 425134, "keywords": [{"id": 3569, "name": '
#  '"latin"}, {"id": 4320, "name": "lover"}, {"id": 4995, "name": "aging"}, '
#  '{"id": 230478, "name": "dumped"}]}, {"id": 206487, "keywords": [{"id": 2532, '
#  '"name": "bomber"}, {"id": 3271, "name": "secret organization"}, {"id": 3458, '
#  '"name": "bartender"}, {"id": 3725, "name": "pregnancy"}, {"id": 4379, '
#  '"name": "time travel"}, {"id": 5455, "name": "time machine"}, {"id": 6783, '
#  '"name": "orphanage"}, {"id": 9331, "name": "intersexuality"}, {"id": 10364, '
#  '"name": "mission"}, {"id": 13015, "name": "terrorism"}, {"id": 167104, '
#  '"name": "loner"}, {"id": 208757, "name": "time paradox"}, {"id": 240109, '
#  '"name": "intersex"}, {"id": 240807, "name": "temporal agent"}]}, {"id": '
#  '571648, "keywords": [{"id": 818, "name": "based on novel or book"}, {"id": '
#  '10594, "name": "money"}, {"id": 10856, "name": "bag of money"}, {"id": '
#  '166631, "name": "loan shark"}]}, {"id": 411088, "keywords": [{"id": 107, '
#  '"name": "barcelona, spain"}, {"id": 769, "name": "falsely accused"}, {"id": '
#  '4480, "name": "business man"}, {"id": 157292, "name": "manipulative lover"}, '
#  '{"id": 174089, "name": "unreliable narrator"}, {"id": 207108, "name": '
#  '"uncover truth"}, {"id": 207525, "name": "grieving father"}, {"id": 207898, '
#  '"name": "accused of murder"}, {"id": 226302, "name": "mountain resort"}, '
#  '{"id": 236429, "name": "locked room mystery"}]}, {"id": 91342, "keywords": '
#  '[{"id": 5938, "name": "mermaid"}, {"id": 7376, "name": "princess"}, {"id": '
#  '10542, "name": "based on toy"}]}, {"id": 51739, "keywords": [{"id": 818, '
#  '"name": "based on novel or book"}, {"id": 977, "name": "cat"}, {"id": 5774, '
#  '"name": "forest"}, {"id": 15101, "name": "based on children\'s book"}, '
#  '{"id": 33873, "name": "little people"}, {"id": 161750, "name": "dollhouse"}, '
#  '{"id": 210024, "name": "anime"}]}, {"id": 10065, "keywords": [{"id": 3649, '
#  '"name": "holy water"}, {"id": 9398, "name": "long island"}, {"id": 9672, '
#  '"name": "based on a true story"}, {"id": 9714, "name": "remake"}, {"id": '
#  '9826, "name": "murder"}, {"id": 9848, "name": "family dinner"}, {"id": 9853, '
#  '"name": "paranormal"}, {"id": 162413, "name": "wood chopping"}, {"id": '
#  '172266, "name": "backwards"}, {"id": 172272, "name": "tortured to death"}, '
#  '{"id": 172274, "name": "moving in"}]}, {"id": 1255, "keywords": [{"id": '
#  '1261, "name": "river"}, {"id": 1299, "name": "monster"}, {"id": 3930, '
#  '"name": "bravery"}, {"id": 4393, "name": "archer"}, {"id": 5600, "name": '
#  '"daughter"}, {"id": 6304, "name": "sewerage"}, {"id": 6305, "name": '
#  '"pollution"}, {"id": 6617, "name": "formaldehyde"}, {"id": 6618, "name": '
#  '"snack bar"}, {"id": 18035, "name": "family"}, {"id": 241445, "name": "asian '
#  'origins"}]}, {"id": 15969, "keywords": [{"id": 539, "name": "middle east"}, '
#  '{"id": 4344, "name": "musical"}, {"id": 9663, "name": "sequel"}, {"id": '
#  '9748, "name": "revenge"}, {"id": 15252, "name": "magical object"}, {"id": '
#  '18165, "name": "animal"}, {"id": 179430, "name": "aftercreditsstinger"}, '
#  '{"id": 198756, "name": "aladdin"}]}, {"id": 77459, "keywords": [{"id": 90, '
#  '"name": "paris, france"}, {"id": 1299, "name": "monster"}]}, {"id": 694256, '
#  '"keywords": [{"id": 13088, "name": "summer"}, {"id": 200129, "name": "summer '
#  'romance"}]}, {"id": 57737, "keywords": [{"id": 2710, "name": "fairy"}, '
#  '{"id": 10542, "name": "based on toy"}, {"id": 11322, "name": "female '
#  'protagonist"}]}, {"id": 158011, "keywords": [{"id": 1353, "name": '
#  '"underground"}, {"id": 1420, "name": "gas station"}, {"id": 1930, "name": '
#  '"kidnapping"}, {"id": 6259, "name": "psychopath"}, {"id": 8087, "name": '
#  '"horror"}, {"id": 9826, "name": "murder"}, {"id": 10714, "name": "serial '
#  'killer"}, {"id": 11108, "name": "american flag"}, {"id": 12339, "name": '
#  '"slasher"}, {"id": 14688, "name": "multiple stabbings"}, {"id": 15000, '
#  '"name": "person on fire"}, {"id": 15156, "name": "cell phone"}, {"id": '
#  '176182, "name": "psycho"}]}, {"id": 2251, "keywords": [{"id": 242, "name": '
#  '"new york city"}, {"id": 596, "name": "adultery"}, {"id": 1326, "name": '
#  '"infidelity"}, {"id": 1664, "name": "eroticism"}, {"id": 2132, "name": '
#  '"literature"}, {"id": 4320, "name": "lover"}, {"id": 207767, "name": "erotic '
#  'thriller"}]}, {"id": 110552, "keywords": [{"id": 779, "name": "martial '
#  'arts"}]}, {"id": 406997, "keywords": [{"id": 3011, "name": "exclusion"}, '
#  '{"id": 6733, "name": "bullying"}, {"id": 9273, "name": "coney island"}, '
#  '{"id": 10360, "name": "prejudice"}, {"id": 10873, "name": "school"}, {"id": '
#  '15101, "name": "based on children\'s book"}, {"id": 18035, "name": '
#  '"human animal relationship"}, {"id": 6152, "name": "supernatural"}, {"id": '
#  '10683, "name": "coming of age"}, {"id": 210024, "name": "anime"}, {"id": '
#  '227480, "name": "chinese mythology"}]}, {"id": 227973, "keywords": [{"id": '
#  '9717, "name": "based on comic"}, {"id": 10238, "name": "red baron"}, {"id": '
#  '18035, "name": "family"}, {"id": 167884, "name": "comic strip"}]}, {"id": '
#  '716799, "keywords": [{"id": 10637, "name": "food"}, {"id": 18035, "name": '
#  '"family"}]}, {"id": 41439, "keywords": [{"id": 4426, "name": "sadism"}, '
#  '{"id": 8087, "name": "horror"}, {"id": 13006, "name": "torture"}, {"id": '
#  '18054, "name": "self help guru"}, {"id": 18056, "name": "tricycle"}, {"id": '
#  '18057, "name": "prosthetic arm"}, {"id": 18058, "name": "pig mask"}, {"id": '
#  '50009, "name": "survival horror"}, {"id": 157376, "name": "death match"}, '
#  '{"id": 184312, "name": "mind game"}, {"id": 286009, "name": "3d"}]}]')

# %% [markdown]
# ## Credits DataFrame:

# %%
# Convert credits to json
json_credits_string = json.dumps(credits)
# Convert json to dataframe
movie_credits_df = pd.read_json(json_credits_string)

# Export to save
# movie_credits_df.to_csv("./static/data/movie_credits.csv", index=False)
movie_credits_df.head()
# Out:
#        id                                               cast  \
# 0  580489  [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1  512195  [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 2  585245  [{'adult': False, 'gender': 1, 'id': 1696017, ...
# 3  617653  [{'adult': False, 'gender': 2, 'id': 1892, 'kn...
# 4  566525  [{'adult': False, 'gender': 2, 'id': 1489211, ...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 149, 'kno...
# 1  [{'adult': False, 'gender': 2, 'id': 9543, 'kn...
# 2  [{'adult': False, 'gender': 1, 'id': 8220, 'kn...
# 3  [{'adult': False, 'gender': 2, 'id': 120, 'kno...
# 4  [{'adult': False, 'gender': 1, 'id': 7232, 'kn...

# %%
movie_credits_df["cast_crew"] = movie_credits_df["cast"] + movie_credits_df["crew"]
movie_credits_df
# Out:
#           id                                               cast  \
# 0     580489  [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1     512195  [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 2     585245  [{'adult': False, 'gender': 1, 'id': 1696017, ...
# 3     617653  [{'adult': False, 'gender': 2, 'id': 1892, 'kn...
# 4     566525  [{'adult': False, 'gender': 2, 'id': 1489211, ...
# ...      ...                                                ...
# 1995  277355  [{'adult': False, 'gender': 1, 'id': 3136, 'kn...
# 1996  271706  [{'adult': False, 'gender': 0, 'id': 1674211, ...
# 1997  227973  [{'adult': False, 'gender': 2, 'id': 1393177, ...
# 1998  716799  [{'adult': False, 'gender': 2, 'id': 1402803, ...
# 1999   41439  [{'adult': False, 'gender': 2, 'id': 2144, 'kn...
#
#                                                    crew  \
# 0     [{'adult': False, 'gender': 2, 'id': 149, 'kno...
# 1     [{'adult': False, 'gender': 2, 'id': 9543, 'kn...
# 2     [{'adult': False, 'gender': 1, 'id': 8220, 'kn...
# 3     [{'adult': False, 'gender': 2, 'id': 120, 'kno...
# 4     [{'adult': False, 'gender': 1, 'id': 7232, 'kn...
# ...                                                 ...
# 1995  [{'adult': False, 'gender': 1, 'id': 53680, 'k...
# 1996  [{'adult': False, 'gender': 0, 'id': 81722, 'k...
# 1997  [{'adult': False, 'gender': 0, 'id': 13223, 'k...
# 1998  [{'adult': False, 'gender': 2, 'id': 224409, '...
# 1999  [{'adult': False, 'gender': 2, 'id': 2127, 'kn...
#
#                                               cast_crew
# 0     [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1     [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 2     [{'adult': False, 'gender': 1, 'id': 1696017, ...
# 3     [{'adult': False, 'gender': 2, 'id': 1892, 'kn...
# 4     [{'adult': False, 'gender': 2, 'id': 1489211, ...
# ...                                                 ...
# 1995  [{'adult': False, 'gender': 1, 'id': 3136, 'kn...
# 1996  [{'adult': False, 'gender': 0, 'id': 1674211, ...
# 1997  [{'adult': False, 'gender': 2, 'id': 1393177, ...
# 1998  [{'adult': False, 'gender': 2, 'id': 1402803, ...
# 1999  [{'adult': False, 'gender': 2, 'id': 2144, 'kn...
#
# [2000 rows x 4 columns]

# %%
movie_credits_df['percent_fm'] = movie_credits_df['cast_crew'].apply(fm_percentage)

# %%
# cast_crew_fm_percentage
movie_credits_df = movie_credits_df.drop(columns=['cast_crew'])
movie_credits_df
# Out:
#           id                                               cast  \
# 0     580489  [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1     512195  [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 2     585245  [{'adult': False, 'gender': 1, 'id': 1696017, ...
# 3     617653  [{'adult': False, 'gender': 2, 'id': 1892, 'kn...
# 4     566525  [{'adult': False, 'gender': 2, 'id': 1489211, ...
# ...      ...                                                ...
# 1995  277355  [{'adult': False, 'gender': 1, 'id': 3136, 'kn...
# 1996  271706  [{'adult': False, 'gender': 0, 'id': 1674211, ...
# 1997  227973  [{'adult': False, 'gender': 2, 'id': 1393177, ...
# 1998  716799  [{'adult': False, 'gender': 2, 'id': 1402803, ...
# 1999   41439  [{'adult': False, 'gender': 2, 'id': 2144, 'kn...
#
#                                                    crew percent_fm
# 0     [{'adult': False, 'gender': 2, 'id': 149, 'kno...     22.54%
# 1     [{'adult': False, 'gender': 2, 'id': 9543, 'kn...     14.58%
# 2     [{'adult': False, 'gender': 1, 'id': 8220, 'kn...     39.29%
# 3     [{'adult': False, 'gender': 2, 'id': 120, 'kno...     26.32%
# 4     [{'adult': False, 'gender': 1, 'id': 7232, 'kn...     33.33%
# ...                                                 ...        ...
# 1995  [{'adult': False, 'gender': 1, 'id': 53680, 'k...     38.89%
# 1996  [{'adult': False, 'gender': 0, 'id': 81722, 'k...      0.00%
# 1997  [{'adult': False, 'gender': 0, 'id': 13223, 'k...     25.33%
# 1998  [{'adult': False, 'gender': 2, 'id': 224409, '...     40.00%
# 1999  [{'adult': False, 'gender': 2, 'id': 2127, 'kn...     29.33%
#
# [2000 rows x 4 columns]

# %% [markdown]
# ## Certifications DataFrame:

# %%
# Convert certifications to json
json_certifications_string = json.dumps(certifications)
# Convert json to dataframe
movie_certifications_df = pd.read_json(json_certifications_string)

# Export to save
# movie_certifications_df.to_csv("./static/data/movie_certifications.csv", index=False)
movie_certifications_df.head()
# Out:
#        id                                            results
# 0  580489  [{'iso_3166_1': 'BR', 'release_dates': [{'cert...
# 1  512195  [{'iso_3166_1': 'GB', 'release_dates': [{'cert...
# 2  585245  [{'iso_3166_1': 'SE', 'release_dates': [{'cert...
# 3  617653  [{'iso_3166_1': 'DE', 'release_dates': [{'cert...
# 4  566525  [{'iso_3166_1': 'CZ', 'release_dates': [{'cert...

# %%
# Extract certification information and append to new column
movie_certifications_df['certification'] = movie_certifications_df['results'].apply(extract_certification)
movie_certifications_df = movie_certifications_df[['id', 'certification']]

# %%
movie_certifications_df.head()
# Out:
#        id certification
# 0  580489         PG-13
# 1  512195         PG-13
# 2  585245            PG
# 3  617653
# 4  566525         PG-13

# %%
# Convert ids to ints (to merge correctly)
movie_keywords_df['id'] = movie_keywords_df['id'].astype('int')
movie_details_df['id'] = movie_details_df['id'].astype('int')
movie_credits_df['id'] = movie_credits_df['id'].astype('int')
movie_certifications_df['id'] = movie_certifications_df['id'].astype('int')

# %%
# Merge keywords with details
movie_df = movie_details_df.merge(movie_keywords_df, on='id')
movie_df = movie_df.merge(movie_credits_df, on='id')
movie_df = movie_df.merge(movie_certifications_df, on='id')

# Export to save
# movie_df.to_csv("./static/data/movies_merged.csv", index=False)

# %%
movie_df.head(20)
# Out:
#     adult                     backdrop_path  \
# 0   False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1   False  /5uVhMGsps81CN0S4U9NF0Z4tytG.jpg
# 2   False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
# 3   False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg
# 4   False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
# 5   False  /g2djzUqA6mFplzC03gDk0WSyg99.jpg
# 6   False   /VlHt27nCqOuTnuX6bku8QZapzO.jpg
# 7   False  /iUeeZ5PWfZGgUtCJfwcgmCfdzoI.jpg
# 8   False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 9   False  /r2GAjd4rNOHJh6i6Y0FntmYuPQW.jpg
# 10  False  /39EQTf94Lckdo8yzS1CdWQSgmen.jpg
# 11  False  /lyvszvJJqqI8aqBJ70XzdCNoK0y.jpg
# 12  False  /oE6bhqqVFyIECtBzqIuvh6JdaB5.jpg
# 13  False  /uWGPC7j70LE64nbetxQGSSYJO53.jpg
# 14  False  /3cMfwbF1J9fglSssim4zKG6scIs.jpg
# 15  False  /h3HsfV8Kn9Sz2QWUYYdP5ya23hx.jpg
# 16  False  /8Y43POKjjKDGI9MH89NW0NAzzp8.jpg
# 17  False  /1zgob2Z8xVE3RZUgOKnHKcVPzOE.jpg
# 18  False  /vJ3ED2jPblACDqaJPZlbN6T1yjy.jpg
# 19  False  /5WnfgU7myfqgkbl3CSj7LQeHU0e.jpg
#
#                                 belongs_to_collection  original_budget  \
# 0   {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 1                                                None        200000000
# 2                                                None                0
# 3                                                None        100000000
# 4   {'id': 912503, 'name': 'Shang-Chi Collection',...        150000000
# 5                                                None                0
# 6   {'id': 531241, 'name': 'Spider-Man (Avengers) ...                0
# 7                                                None                0
# 8                                                None          9100000
# 9   {'id': 645, 'name': 'James Bond Collection', '...        242000000
# 10  {'id': 41437, 'name': 'Paranormal Activity Col...                0
# 11                                               None        200000000
# 12                                               None                0
# 13                                               None                0
# 14                                               None                0
# 15  {'id': 726871, 'name': 'Dune Collection', 'pos...        165000000
# 16  {'id': 861415, 'name': 'Free Guy Collection', ...        110000000
# 17                                               None                0
# 18                                               None                0
# 19                                               None                0
#
#                                                genres  \
# 0   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 5   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 6   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 7   [{'id': 16, 'name': 'Animation'}, {'id': 878, ...
# 8   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 12  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 13  [{'id': 53, 'name': 'Thriller'}, {'id': 10752,...
# 14                     [{'id': 28, 'name': 'Action'}]
# 15  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 16  [{'id': 35, 'name': 'Comedy'}, {'id': 28, 'nam...
# 17  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 18  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 19                     [{'id': 27, 'name': 'Horror'}]
#
#                                              homepage      id     imdb_id  \
# 0                             https://www.venom.movie  580489   tt7097896
# 1           https://www.netflix.com/us/title/81161626  512195   tt7991608
# 2                                                      585245   tt2397461
# 3   https://www.20thcenturystudios.com/movies/the-...  617653   tt4244994
# 4   https://www.marvel.com/movies/shang-chi-and-th...  566525   tt9376612
# 5                   https://movies.disney.com/encanto  568124   tt2953050
# 6                https://www.spidermannowayhome.movie  634649  tt10872600
# 7   https://family.20thcenturystudios.com/movies/r...  482321   tt7504818
# 8                                                      589761  tt10648714
# 9                 https://www.007.com/no-time-to-die/  370172   tt2382320
# 10                                                     609972  tt10515988
# 11         https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 12  https://tv.apple.com/movie/umc.cmc.47dkj9f2ho3...  522402   tt3420504
# 13                                                     762433  tt13432484
# 14                                                     876262  tt12802724
# 15                         https://www.dunemovie.com/  438631   tt1160419
# 16  https://www.20thcenturystudios.com/movies/free...  550988   tt6264654
# 17  https://www.disneyplus.com/movies/the-simpsons...  877183  tt15829632
# 18                                                     776821  tt11892272
# 16  /xmbU4JTUm8rsdtn7Y3Fcm30GpeT.jpg
# 17  /9xaAT3V3I9xxqnNiEjCivNFfdlh.jpg
# 18  /qrq7sGXraFM6H9OcHFKQTKe8A3f.jpg
# 19  /bPq6x47nEqMZED5PrKelcWWpezM.jpg
#
#                                  production_companies  \
# 0   [{'id': 7505, 'logo_path': '/837VMM4wOkODc1idN...
# 1   [{'id': 34081, 'logo_path': None, 'name': 'Fly...
# 2   [{'id': 4, 'logo_path': '/fycMZt242LVjagMByZOL...
# 3   [{'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEn...
# 4   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 5   [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...
# 6   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 7   [{'id': 121605, 'logo_path': '/4rc0vsJWygNm9oj...
# 8   [{'id': 5630, 'logo_path': '/s0mHCw53fp6EAapR7...
# 9   [{'id': 7576, 'logo_path': '/oYcUi1byZ312Z3xiz...
# 10  [{'id': 6302, 'logo_path': None, 'name': 'Room...
# 11  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 12  [{'id': 56, 'logo_path': '/cEaxANEisCqeEoRvODv...
# 13  [{'id': 106754, 'logo_path': '/1H4YyGx74OTzPtP...
# 14  [{'id': 138922, 'logo_path': None, 'name': 'Mi...
# 15  [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8D...
# 16  [{'id': 27711, 'logo_path': '/3e294jszfE6cE8TO...
# 17  [{'id': 18, 'logo_path': '/uqhagSwM7NAkQWVCQhK...
# 18  [{'id': 29566, 'logo_path': '/wHbtRtUnXGNzX0ri...
# 19  [{'id': 75111, 'logo_path': None, 'name': 'Tra...
#
#                                  production_countries release_date  \
# 0   [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-30
# 1   [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-04
# 2   [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2021-11-10
# 3   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2021-10-13
# 4   [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-01
# 5   [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-24
# 6   [{'iso_3166_1': 'US', 'name': 'United States o...   2021-12-15
# 7   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2021-10-15
# 8            [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2021-04-15
# 9   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2021-09-29
# 10  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-10-29
# 11  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-03
# 12  [{'iso_3166_1': 'IN', 'name': 'India'}, {'iso_...   2021-11-04
# 13  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2021-11-18
# 14           [{'iso_3166_1': 'BR', 'name': 'Brazil'}]   2021-09-23
# 15  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-15
# 16  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-08-11
# 17  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-12
# 18            [{'iso_3166_1': 'ES', 'name': 'Spain'}]   2021-10-08
# 19         [{'iso_3166_1': 'TH', 'name': 'Thailand'}]   2021-12-02
#
#     original_revenue  runtime  \
# 0          482000000       97
# 1                  0      117
# 2           51000000       97
# 3           27000000      152
# 4          430238384      132
# 5          151000000      102
# 6                  0      148
# 7           57000000      106
# 8            5370393      136
# 9          758000000      163
# 10                 0       98
# 11         395000000      157
# 12                 0      115
# 13                 0       85
# 14                 0        0
# 15         389000000      155
# 16         331096766      115
# 17                 0        4
# 18                 0      125
# 19                 0      125
#
#                                      spoken_languages    status  \
# 0   [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 1   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 6   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 7   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 8   [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 9   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 10  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 11  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...  Released
# 12  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 13  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 14  [{'english_name': 'Portuguese', 'iso_639_1': '...  Released
# 15  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...  Released
# 16  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 17  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 18  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 19  [{'english_name': 'Thai', 'iso_639_1': 'th', '...  Released
#
#                                               tagline  \
# 0
# 1                                       Pro and cons.
# 2                    Adventure has never been bigger.
# 3   The true story of a woman who defied a nation ...
# 4                      You can't outrun your destiny.
# 5   There's a little magic in all of us ...almost ...
# 6                           The Multiverse unleashed.
# 7       Best Friend Forever* (*battery life may vary)
# 8
# 9         The mission that changes everything begins…
# 10                            The activity is reborn.
# 11                                In the beginning...
# 12                     Take an unforgettable journey.
# 13              It's always deadliest before the dawn
# 14
# 15                       Beyond fear, destiny awaits.
# 16     Life's too short to be a background character.
# 17
# 18
# 19
#
#                                         title  video  vote_average  \
# 0                 Venom: Let There Be Carnage  False           7.2
# 1                                  Red Notice  False           6.8
# 2                    Clifford the Big Red Dog  False           7.6
# 3                               The Last Duel  False           7.6
# 4   Shang-Chi and the Legend of the Ten Rings  False           7.8
# 5                                     Encanto  False           7.4
# 6                     Spider-Man: No Way Home  False           8.4
# 7                            Ron's Gone Wrong  False           8.5
# 8                            Chernobyl: Abyss  False           6.3
# 9                              No Time to Die  False           7.6
# 10           Paranormal Activity: Next of Kin  False           6.7
# 11                                   Eternals  False           7.1
# 12                                      Finch  False           8.2
# 13                             Zeros and Ones  False           5.7
# 14                             Garota da Moto  False           4.9
# 15                                       Dune  False           8.0
# 16                                   Free Guy  False           7.8
# 17               The Simpsons in Plusaversary  False           6.7
# 18                                    Outlaws  False           6.7
# 19                            The Whole Truth  False           6.6
#
#     vote_count  year  cpi_2021  cpi_old  adjusted_revenue  adjusted_budget  \
# 0         4421  2021   269.489  269.489       482000000.0      110000000.0
# 1         1982  2021   269.489  269.489               0.0      200000000.0
# 2          540  2021   269.489  269.489        51000000.0              0.0
# 3          885  2021   269.489  269.489        27000000.0      100000000.0
# 4         4211  2021   269.489  269.489       430238384.0      150000000.0
# 5          313  2021   269.489  269.489       151000000.0              0.0
# 6           44  2021   269.489  269.489               0.0              0.0
# 7          330  2021   269.489  269.489        57000000.0              0.0
# 8          235  2021   269.489  269.489         5370393.0        9100000.0
# 9         2521  2021   269.489  269.489       758000000.0      242000000.0
# 10         147  2021   269.489  269.489               0.0              0.0
# 11        1404  2021   269.489  269.489       395000000.0      200000000.0
# 12        1428  2021   269.489  269.489               0.0              0.0
# 13          66  2021   269.489  269.489               0.0              0.0
# 14           4  2021   269.489  269.489               0.0              0.0
# 15        4709  2021   269.489  269.489       389000000.0      165000000.0
# 16        4073  2021   269.489  269.489       331096766.0      110000000.0
# 17         157  2021   269.489  269.489               0.0              0.0
# 18          67  2021   269.489  269.489               0.0              0.0
# 19          41  2021   269.489  269.489               0.0              0.0
#
#      budget_bins                                           keywords  \
# 0    51m to 150m  [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 1   151m to 380m  [{'id': 1812, 'name': 'fbi'}, {'id': 6710, 'na...
# 2            NaN  [{'id': 818, 'name': 'based on novel or book'}...
# 3    51m to 150m  [{'id': 818, 'name': 'based on novel or book'}...
# 4    51m to 150m  [{'id': 779, 'name': 'martial arts'}, {'id': 9...
# 5            NaN                                                 []
# 6            NaN  [{'id': 1701, 'name': 'hero'}, {'id': 5451, 'n...
# 7            NaN  [{'id': 18035, 'name': 'family'}, {'id': 28579...
# 8       1 to 15m              [{'id': 210326, 'name': 'chernobyl'}]
# 9   151m to 380m  [{'id': 470, 'name': 'spy'}, {'id': 156095, 'n...
# 10           NaN  [{'id': 9663, 'name': 'sequel'}, {'id': 9853, ...
# 11  151m to 380m  [{'id': 3925, 'name': 'boredom'}, {'id': 6152,...
# 12           NaN  [{'id': 14544, 'name': 'robot'}, {'id': 189092...
# 13           NaN  [{'id': 588, 'name': 'rome, italy'}, {'id': 94...
# 14           NaN                                                 []
# 15  151m to 380m  [{'id': 530, 'name': 'prophecy'}, {'id': 818, ...
# 16   51m to 150m  [{'id': 282, 'name': 'video game'}, {'id': 141...
# 17           NaN  [{'id': 4552, 'name': 'beer'}, {'id': 161919, ...
# 18           NaN  [{'id': 642, 'name': 'robbery'}, {'id': 818, '...
# 19           NaN                                                 []
#
#                                                  cast  \
# 0   [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1   [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 2   [{'adult': False, 'gender': 1, 'id': 1696017, ...
# 3   [{'adult': False, 'gender': 2, 'id': 1892, 'kn...
# 4   [{'adult': False, 'gender': 2, 'id': 1489211, ...
# 5   [{'adult': False, 'gender': 1, 'id': 968367, '...
# 6   [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 7   [{'adult': False, 'gender': 2, 'id': 58225, 'k...
# 8   [{'adult': False, 'gender': 2, 'id': 562730, '...
# 9   [{'adult': False, 'gender': 2, 'id': 8784, 'kn...
# 10  [{'adult': False, 'gender': 1, 'id': 1902689, ...
# 11  [{'adult': False, 'gender': 1, 'id': 97576, 'k...
# 12  [{'adult': False, 'gender': 2, 'id': 31, 'know...
# 13  [{'adult': False, 'gender': 2, 'id': 569, 'kno...
# 14  [{'adult': False, 'gender': 1, 'id': 1516033, ...
# 15  [{'adult': False, 'gender': 2, 'id': 1190668, ...
# 16  [{'adult': False, 'gender': 2, 'id': 10859, 'k...
# 17  [{'adult': False, 'gender': 2, 'id': 198, 'kno...
# 18  [{'adult': False, 'gender': 2, 'id': 224733, '...
# 19  [{'adult': False, 'gender': 0, 'id': 2253117, ...
#
#                                                  crew percent_fm certification
# 0   [{'adult': False, 'gender': 2, 'id': 149, 'kno...     22.54%         PG-13
# 1   [{'adult': False, 'gender': 2, 'id': 9543, 'kn...     14.58%         PG-13
# 2   [{'adult': False, 'gender': 1, 'id': 8220, 'kn...     39.29%            PG
# 3   [{'adult': False, 'gender': 2, 'id': 120, 'kno...     26.32%
# 4   [{'adult': False, 'gender': 1, 'id': 7232, 'kn...     33.33%         PG-13
# 5   [{'adult': False, 'gender': 0, 'id': 8159, 'kn...     42.86%
# 6   [{'adult': False, 'gender': 1, 'id': 2519, 'kn...     24.14%         PG-13
# 7   [{'adult': False, 'gender': 0, 'id': 5542, 'kn...     35.00%            PG
# 8   [{'adult': False, 'gender': 1, 'id': 30247, 'k...     37.14%
# 9   [{'adult': False, 'gender': 2, 'id': 947, 'kno...     22.06%         PG-13
# 10  [{'adult': False, 'gender': 1, 'id': 494, 'kno...     27.27%             R
# 11  [{'adult': False, 'gender': 2, 'id': 1722, 'kn...     26.87%
# 12  [{'adult': False, 'gender': 2, 'id': 24, 'know...     20.59%         PG-13
# 13  [{'adult': False, 'gender': 1, 'id': 21342, 'k...     27.78%             R
# 14  [{'adult': False, 'gender': 2, 'id': 90615, 'k...     40.00%
# 15  [{'adult': False, 'gender': 2, 'id': 27, 'know...     27.47%
# 16  [{'adult': False, 'gender': 1, 'id': 1720, 'kn...     31.11%         PG-13
# 17  [{'adult': False, 'gender': 2, 'id': 197, 'kno...     18.75%
# 18  [{'adult': False, 'gender': 2, 'id': 3788, 'kn...     47.06%
# 19  [{'adult': False, 'gender': 2, 'id': 28233, 'k...      0.00%             R

# %% [markdown]
# ## Call Functions to Extract Details:

# %%
# Director
movie_df['director'] = movie_df['crew'].apply(get_director)

# Director Gender
movie_df['director_gender'] = movie_df['crew'].apply(get_director_gender)

# Producers
movie_df['producers'] = movie_df['crew'].apply(get_producers)

# Screenplay writers
movie_df['writers'] = movie_df['crew'].apply(get_writers)

# Cast
movie_df['cast'] = movie_df['cast'].apply(get_cast_list)

# Production Company Country of Origin
movie_df['production_company_origin'] = movie_df['production_companies'].apply(get_production_company_country)

# Spoken Languages in Movie
movie_df['spoken_languages']  = movie_df['spoken_languages'].apply(get_languages)

# Create foreign language column for if the original language was not English
movie_df['foreign_language'] = movie_df['original_language'].apply(original_language_binary)

# Get List: Keywords, genres, & production countries
features = ['keywords', 'genres', 'production_companies']
            
for feature in features:
    movie_df[feature] = movie_df[feature].apply(get_list)

# %%
# Show the results
movie_df[['title', 'cast', 'director', 'director_gender', 'percent_fm', 'producers', 'writers', 'keywords', 'genres', 'production_companies', 'production_company_origin', 'spoken_languages', 'original_language', 'foreign_language']].head()
# Out:
#                                        title  \
# 0                Venom: Let There Be Carnage
# 1                                 Red Notice
# 2                   Clifford the Big Red Dog
# 3                              The Last Duel
# 4  Shang-Chi and the Legend of the Ten Rings
#
#                                                 cast  \
# 0  [Tom Hardy, Woody Harrelson, Michelle Williams...
# 1  [Dwayne Johnson, Ryan Reynolds, Gal Gadot, Rit...
# 2  [Darby Camp, Jack Whitehall, Izaac Wang, John ...
# 3  [Matt Damon, Adam Driver, Jodie Comer, Harriet...
# 4  [Simu Liu, Tony Leung Chiu-wai, Awkwafina, Men...
#
#                     director director_gender percent_fm  \
# 0              [Andy Serkis]             [2]     22.54%
# 1  [Rawson Marshall Thurber]             [2]     14.58%
# 2              [Walt Becker]             [2]     39.29%
# 3             [Ridley Scott]             [2]     26.32%
# 4    [Destin Daniel Cretton]             [2]     33.33%
#
#                                            producers  \
# 0  [Tom Hardy, K.C. Hodenfield, Avi Arad, Jonatha...
# 1  [Beau Flynn, Dwayne Johnson, Rawson Marshall T...
# 2  [Brad Fischer, Deborah Forte, Deborah Forte, B...
# 3  [Ridley Scott, Ben Affleck, Matt Damon, Jennif...
# 4  [Kevin Feige, Charles Newirth, Louis D'Esposit...
#
#                                              writers  \
# 0  [Tom Hardy, Todd McFarlane, Kelly Marcel, Kell...
# 1                          [Rawson Marshall Thurber]
# 2  [David Ronn, Jay Scherick, Norman Bridwell, An...
# 3  [Ben Affleck, Matt Damon, Nicole Holofcener, E...
# 4  [Dave Callaham, Dave Callaham, Destin Daniel C...
#
#                                             keywords  \
# 0  [hero, anti hero, villain, sequel, superhero, ...
# 1                  [fbi, interpol, heist, art thief]
# 2                [based on novel or book, giant dog]
# 3  [based on novel or book, normandy, france, bas...
# 4  [martial arts, superhero, based on comic, mixe...
#
#                                  genres  \
# 0  [Science Fiction, Action, Adventure]
# 1     [Action, Comedy, Crime, Thriller]
# 2           [Animation, Comedy, Family]
# 3              [Action, Drama, History]
# 4          [Action, Adventure, Fantasy]
#
#                                 production_companies  \
# 0  [Marvel Entertainment, Columbia Pictures, Pasc...
# 1  [Flynn Picture Company, Seven Bucks Production...
# 2  [Paramount, Entertainment One, Kerner Entertai...
# 3  [20th Century Studios, Scott Free Productions,...
# 4                                   [Marvel Studios]
#
#   production_company_origin             spoken_languages original_language  \
# 0      [US, US, US, US, US]           [Spanish, English]                en
# 1            [US, US, US, ]  [English, Italian, Russian]                en
# 2    [US, CA, , US, US, US]                    [English]                en
# 3          [US, GB, US, US]     [English, French, Latin]                en
# 4                      [US]          [English, Mandarin]                en
#
#    foreign_language
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
# Drop NA from selected columns
movie_df.dropna(inplace=True, how="any", subset=['genres', 'production_companies', 'keywords', 'cast'])
movie_df.dropna(inplace=True, how="any", subset=['director', 'producers', 'writers'])

# %%
len(movie_df)
# Out:
# 1688

# %%
# Clean Data: Convert all features to lowercase and remove spaces
features = ['cast', 'director', 'producers', 'writers', 'keywords', 'genres', 'production_companies']

for feature in features:
    movie_df[f"{feature}_cleaned"] = movie_df[feature].apply(clean_data)

# %%
# Call the clean overview function
movie_df['overview_cleaned'] = movie_df['overview'].apply(clean_overview)

# %%
# Create soup columns
movie_df['soup'] = movie_df.apply(create_soup, axis = 1)
movie_df['soup_overview'] = movie_df.apply(create_soup_overview, axis = 1)

# Export to save
# movie_df.to_csv("./static/data/movies_cleaned_soup.csv", index=False)

# %%
movie_df[['soup']].head(5)
# Out:
#                                                 soup
# 0  hero antihero villain sequel superhero basedon...
# 1  fbi interpol heist artthief dwaynejohnson ryan...
# 2  basedonnovelorbook giantdog darbycamp jackwhit...
# 3  basedonnovelorbook normandy,france basedonatru...
# 4  martialarts superhero basedoncomic mixedmartia...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1688 entries, 0 to 1973
# Data columns (total 52 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   adult                         1688 non-null   bool
#  1   backdrop_path                 1678 non-null   object
#  2   belongs_to_collection         707 non-null    object
#  3   original_budget               1688 non-null   int64
#  4   genres                        1688 non-null   object
#  5   homepage                      1688 non-null   object
#  6   id                            1688 non-null   int64
#  7   imdb_id                       1684 non-null   object
#  8   original_language             1688 non-null   object
#  9   original_title                1688 non-null   object
#  10  overview                      1688 non-null   object
#  11  popularity                    1688 non-null   float64
#  12  poster_path                   1688 non-null   object
#  13  production_companies          1688 non-null   object
#  14  production_countries          1688 non-null   object
#  15  release_date                  1688 non-null   object
#  16  original_revenue              1688 non-null   int64
#  17  runtime                       1688 non-null   int64
#  18  spoken_languages              1687 non-null   object
#  19  status                        1688 non-null   object
#  20  tagline                       1688 non-null   object
#  21  title                         1688 non-null   object
#  22  video                         1688 non-null   bool
#  23  vote_average                  1688 non-null   float64
#  24  vote_count                    1688 non-null   int64
#  25  year                          1688 non-null   int64
#  26  cpi_2021                      1688 non-null   float64
#  27  cpi_old                       1688 non-null   float64
#  28  adjusted_revenue              1688 non-null   float64
#  29  adjusted_budget               1688 non-null   float64
#  30  budget_bins                   1127 non-null   category
#  31  keywords                      1688 non-null   object
#  32  cast                          1688 non-null   object
#  33  crew                          1688 non-null   object
#  34  percent_fm                    1684 non-null   object
#  35  certification                 1688 non-null   object
#  36  director                      1688 non-null   object
#  37  director_gender               1688 non-null   object
#  38  producers                     1688 non-null   object
#  39  writers                       1688 non-null   object
#  40  production_company_origin     1688 non-null   object
#  41  foreign_language              1688 non-null   int64
#  42  cast_cleaned                  1688 non-null   object
#  43  director_cleaned              1688 non-null   object
#  44  producers_cleaned             1688 non-null   object
#  45  writers_cleaned               1688 non-null   object
#  46  keywords_cleaned              1688 non-null   object
#  47  genres_cleaned                1688 non-null   object
#  48  production_companies_cleaned  1688 non-null   object
#  49  overview_cleaned              1688 non-null   object
#  50  soup                          1688 non-null   object
#  51  soup_overview                 1688 non-null   object
# dtypes: bool(2), category(1), float64(6), int64(7), object(36)
# memory usage: 664.5+ KB

# %% [markdown]
# ## Configuration for Posters:

# %%
configuration_url = f"https://api.themoviedb.org/3/configuration?api_key={api_key}"
config_response = requests.get(configuration_url).json()
# config_response

# %%
# Get images structure
images_url = config_response['images']
# Get Base URL
secure_base_url = images_url['secure_base_url']
# secure_base_url

# %%
# Get the size of poster: 2: w185px, 4: w500px, 5: 780px
# images_url['poster_sizes']
poster_size = images_url['poster_sizes'][5]
# poster_size

# %%
# Copy poster paths to new df
poster_df = movie_df[['poster_path']].copy()

# %%
# Create column with full image path for posters
poster_df['poster_url'] = secure_base_url + poster_size + poster_df['poster_path']

# %%
# Export to separate csv
# poster_df.to_csv("./static/data/poster_path.csv", index=False)
poster_df.head()
# Out:
#                         poster_path  \
# 0  /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg
# 1  /q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg
# 2  /ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg
# 3  /zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg
# 4  /1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg
#
#                                           poster_url
# 0  https://image.tmdb.org/t/p/w780/rjkmN1dniUHVYA...
# 1  https://image.tmdb.org/t/p/w780/q2d56YvJ3s9W73...
# 2  https://image.tmdb.org/t/p/w780/ygPTrycbMSFDc5...
# 3  https://image.tmdb.org/t/p/w780/zjrJE0fpzPvX8s...
# 4  https://image.tmdb.org/t/p/w780/1BIoJGKbXjdFDA...

# %%
# Create column with full image path for posters (in real df this time)
movie_df['poster_url'] = secure_base_url + poster_size + movie_df['poster_path']

# %% [markdown]
# # TESTING

# %% [raw]
# movie_df = pd.read_csv("./static/data/movie_db.csv")

# %% [raw]
# # Converts strings into lists or dictionaries
# from ast import literal_eval
#
# # Selected features to apply function to
# features = ['cast', 'director', 'producers', 'writers', 'keywords', 'genres', 'production_companies']
#
# for feature in features:
#     movie_df[f"{feature}_cleaned"] = movie_df[f"{feature}_cleaned"].apply(literal_eval)

# %% [markdown]
# ## Export CSV:

# %%
# Create a lowercase column for easier search
movie_df["lowercase_title"] = movie_df['title'].apply(lambda x: x.lower())

# %%
# Save file - used for calling for information
movie_df.to_csv("../static/data/movie_db.csv", index=False)

# %%
movie_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1  False  /5uVhMGsps81CN0S4U9NF0Z4tytG.jpg
# 2  False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
# 3  False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg
# 4  False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 1                                               None        200000000
# 2                                               None                0
# 3                                               None        100000000
# 4  {'id': 912503, 'name': 'Shang-Chi Collection',...        150000000
#
#                                  genres  \
# 0  [Science Fiction, Action, Adventure]
# 1     [Action, Comedy, Crime, Thriller]
# 2           [Animation, Comedy, Family]
# 3              [Action, Drama, History]
# 4          [Action, Adventure, Fantasy]
#
#                                             homepage      id    imdb_id  \
# 0                            https://www.venom.movie  580489  tt7097896
# 1          https://www.netflix.com/us/title/81161626  512195  tt7991608
# 2                                                     585245  tt2397461
# 3  https://www.20thcenturystudios.com/movies/the-...  617653  tt4244994
# 4  https://www.marvel.com/movies/shang-chi-and-th...  566525  tt9376612
#
#   original_language                             original_title  \
# 0                en                Venom: Let There Be Carnage
# 1                en                                 Red Notice
# 2                en                   Clifford the Big Red Dog
# 3                en                              The Last Duel
# 4                en  Shang-Chi and the Legend of the Ten Rings
#
#                                             overview  popularity  \
# 0  After finding a host body in investigative rep...    8633.976
# 1  An Interpol-issued Red Notice is a global aler...    4825.133
# 2  As Emily struggles to fit in at home and at sc...    3280.160
# 3  King Charles VI declares that Knight Jean de C...    3256.364
# 4  Shang-Chi must confront the past he thought he...    3189.442
#
#                         poster_path  \
# 0  /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg
# 1  /q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg
# 2  /ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg
# 3  /zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg
# 4  /1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg
#
#                                 production_companies  \
# 0  [Marvel Entertainment, Columbia Pictures, Pasc...
# 1  [Flynn Picture Company, Seven Bucks Production...
# 2  [Paramount, Entertainment One, Kerner Entertai...
# 3  [20th Century Studios, Scott Free Productions,...
# 4                                   [Marvel Studios]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-04
# 2  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2021-11-10
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2021-10-13
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-01
#
#    original_revenue  runtime             spoken_languages    status  \
# 0         482000000       97           [Spanish, English]  Released
# 1                 0      117  [English, Italian, Russian]  Released
# 2          51000000       97                    [English]  Released
# 3          27000000      152     [English, French, Latin]  Released
# 4         430238384      132          [English, Mandarin]  Released
#
#                                              tagline  \
# 0
# 1                                      Pro and cons.
# 2                   Adventure has never been bigger.
# 3  The true story of a woman who defied a nation ...
# 4                     You can't outrun your destiny.
#
#                                        title  video  vote_average  vote_count  \
# 0                Venom: Let There Be Carnage  False           7.2        4421
# 1                                 Red Notice  False           6.8        1982
# 2                   Clifford the Big Red Dog  False           7.6         540
# 3                              The Last Duel  False           7.6         885
# 4  Shang-Chi and the Legend of the Ten Rings  False           7.8        4211
#
#    year  cpi_2021  cpi_old  adjusted_revenue  adjusted_budget   budget_bins  \
# 0  2021   269.489  269.489       482000000.0      110000000.0   51m to 150m
# 1  2021   269.489  269.489               0.0      200000000.0  151m to 380m
# 2  2021   269.489  269.489        51000000.0              0.0           NaN
# 3  2021   269.489  269.489        27000000.0      100000000.0   51m to 150m
# 4  2021   269.489  269.489       430238384.0      150000000.0   51m to 150m
#
#                                             keywords  \
# 0  [hero, anti hero, villain, sequel, superhero, ...
# 1                  [fbi, interpol, heist, art thief]
# 2                [based on novel or book, giant dog]
# 3  [based on novel or book, normandy, france, bas...
# 4  [martial arts, superhero, based on comic, mixe...
#
#                                                 cast  \
# 0  [Tom Hardy, Woody Harrelson, Michelle Williams...
# 1  [Dwayne Johnson, Ryan Reynolds, Gal Gadot, Rit...
# 2  [Darby Camp, Jack Whitehall, Izaac Wang, John ...
# 3  [Matt Damon, Adam Driver, Jodie Comer, Harriet...
# 4  [Simu Liu, Tony Leung Chiu-wai, Awkwafina, Men...
#
#                                                 crew percent_fm certification  \
# 0  [{'adult': False, 'gender': 2, 'id': 149, 'kno...     22.54%         PG-13
# 1  [{'adult': False, 'gender': 2, 'id': 9543, 'kn...     14.58%         PG-13
# 2  [{'adult': False, 'gender': 1, 'id': 8220, 'kn...     39.29%            PG
# 3  [{'adult': False, 'gender': 2, 'id': 120, 'kno...     26.32%
# 4  [{'adult': False, 'gender': 1, 'id': 7232, 'kn...     33.33%         PG-13
#
#                     director director_gender  \
# 0              [Andy Serkis]             [2]
# 1  [Rawson Marshall Thurber]             [2]
# 2              [Walt Becker]             [2]
# 3             [Ridley Scott]             [2]
# 4    [Destin Daniel Cretton]             [2]
#
#                                            producers  \
# 0  [Tom Hardy, K.C. Hodenfield, Avi Arad, Jonatha...
# 1  [Beau Flynn, Dwayne Johnson, Rawson Marshall T...
# 2  [Brad Fischer, Deborah Forte, Deborah Forte, B...
# 3  [Ridley Scott, Ben Affleck, Matt Damon, Jennif...
# 4  [Kevin Feige, Charles Newirth, Louis D'Esposit...
#
#                                              writers  \
# 0  [Tom Hardy, Todd McFarlane, Kelly Marcel, Kell...
# 1                          [Rawson Marshall Thurber]
# 2  [David Ronn, Jay Scherick, Norman Bridwell, An...
# 3  [Ben Affleck, Matt Damon, Nicole Holofcener, E...
# 4  [Dave Callaham, Dave Callaham, Destin Daniel C...
#
#   production_company_origin  foreign_language  \
# 0      [US, US, US, US, US]                 0
# 1            [US, US, US, ]                 0
# 2    [US, CA, , US, US, US]                 0
# 3          [US, GB, US, US]                 0
# 4                      [US]                 0
#
#                                         cast_cleaned         director_cleaned  \
# 0  [tomhardy, woodyharrelson, michellewilliams, n...             [andyserkis]
# 1  [dwaynejohnson, ryanreynolds, galgadot, rituar...  [rawsonmarshallthurber]
# 2  [darbycamp, jackwhitehall, izaacwang, johnclee...             [waltbecker]
# 3  [mattdamon, adamdriver, jodiecomer, harrietwal...            [ridleyscott]
# 4  [simuliu, tonyleungchiu-wai, awkwafina, meng'e...    [destindanielcretton]
#
#                                    producers_cleaned  \
# 0  [tomhardy, k.c.hodenfield, aviarad, jonathanca...
# 1  [beauflynn, dwaynejohnson, rawsonmarshallthurb...
# 2  [bradfischer, deborahforte, deborahforte, bria...
# 3  [ridleyscott, benaffleck, mattdamon, jenniferf...
# 4  [kevinfeige, charlesnewirth, louisd'esposito, ...
#
#                                      writers_cleaned  \
# 0  [tomhardy, toddmcfarlane, kellymarcel, kellyma...
# 1                            [rawsonmarshallthurber]
# 2  [davidronn, jayscherick, normanbridwell, annie...
# 3  [benaffleck, mattdamon, nicoleholofcener, eric...
# 4  [davecallaham, davecallaham, destindanielcrett...
#
#                                     keywords_cleaned  \
# 0  [hero, antihero, villain, sequel, superhero, b...
# 1                   [fbi, interpol, heist, artthief]
# 2                     [basedonnovelorbook, giantdog]
# 3  [basedonnovelorbook, normandy,france, basedona...
# 4  [martialarts, superhero, basedoncomic, mixedma...
#
#                         genres_cleaned  \
# 0  [sciencefiction, action, adventure]
# 1    [action, comedy, crime, thriller]
# 2          [animation, comedy, family]
# 3             [action, drama, history]
# 4         [action, adventure, fantasy]
#
#                         production_companies_cleaned  \
# 0  [marvelentertainment, columbiapictures, pascal...
# 1  [flynnpicturecompany, sevenbucksproductions, l...
# 2  [paramount, entertainmentone, kernerentertainm...
# 3  [20thcenturystudios, scottfreeproductions, pea...
# 4                                    [marvelstudios]
#
#                                     overview_cleaned  \
# 0  after finding a host body in investigative rep...
# 1  an interpol-issued red notice is a global aler...
# 2  as emily struggles to fit in at home and at sc...
# 3  king charles vi declares that knight jean de c...
# 4  shang-chi must confront the past he thought he...
#
#                                                 soup  \
# 0  hero antihero villain sequel superhero basedon...
# 1  fbi interpol heist artthief dwaynejohnson ryan...
# 2  basedonnovelorbook giantdog darbycamp jackwhit...
# 3  basedonnovelorbook normandy,france basedonatru...
# 4  martialarts superhero basedoncomic mixedmartia...
#
#                                        soup_overview  \
# 0  hero antihero villain sequel superhero basedon...
# 1  fbi interpol heist artthief fbi interpol heist...
# 2  basedonnovelorbook giantdog basedonnovelorbook...
# 3  basedonnovelorbook normandy,france basedonatru...
# 4  martialarts superhero basedoncomic mixedmartia...
#
#                                           poster_url  \
# 0  https://image.tmdb.org/t/p/w780/rjkmN1dniUHVYA...
# 1  https://image.tmdb.org/t/p/w780/q2d56YvJ3s9W73...
# 2  https://image.tmdb.org/t/p/w780/ygPTrycbMSFDc5...
# 3  https://image.tmdb.org/t/p/w780/zjrJE0fpzPvX8s...
# 4  https://image.tmdb.org/t/p/w780/1BIoJGKbXjdFDA...
#
#                              lowercase_title
# 0                venom: let there be carnage
# 1                                 red notice
# 2                   clifford the big red dog
# 3                              the last duel
# 4  shang-chi and the legend of the ten rings

# %% [markdown]
# # Machine Learning Recommender:

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Use Count Vectorizer to create counts for each word
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(movie_df['soup_overview'])

# %%
count_matrix.shape
# Out:
# (1688, 29906)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset the index
# movie_df = movie_df.reset_index()
# Create series with index & titles of movies
indices = pd.Series(movie_df.index, index=movie_df['title']).drop_duplicates()

# %%
movie_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1  False  /5uVhMGsps81CN0S4U9NF0Z4tytG.jpg
# 2  False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
# 3  False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg
# 4  False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 1                                               None        200000000
# 2                                               None                0
# 3                                               None        100000000
# 4  {'id': 912503, 'name': 'Shang-Chi Collection',...        150000000
#
#                                  genres  \
# 0  [Science Fiction, Action, Adventure]
# 1     [Action, Comedy, Crime, Thriller]
# 2           [Animation, Comedy, Family]
# 3              [Action, Drama, History]
# 4          [Action, Adventure, Fantasy]
#
#                                             homepage      id    imdb_id  \
# 0                            https://www.venom.movie  580489  tt7097896
# 1          https://www.netflix.com/us/title/81161626  512195  tt7991608
# 2                                                     585245  tt2397461
# 3  https://www.20thcenturystudios.com/movies/the-...  617653  tt4244994
# 4  https://www.marvel.com/movies/shang-chi-and-th...  566525  tt9376612
#
#   original_language                             original_title  \
# 0                en                Venom: Let There Be Carnage
# 1                en                                 Red Notice
# 2                en                   Clifford the Big Red Dog
# 3                en                              The Last Duel
# 4                en  Shang-Chi and the Legend of the Ten Rings
#
#                                             overview  popularity  \
# 0  After finding a host body in investigative rep...    8633.976
# 1  An Interpol-issued Red Notice is a global aler...    4825.133
# 2  As Emily struggles to fit in at home and at sc...    3280.160
# 3  King Charles VI declares that Knight Jean de C...    3256.364
# 4  Shang-Chi must confront the past he thought he...    3189.442
#
#                         poster_path  \
# 0  /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg
# 1  /q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg
# 2  /ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg
# 3  /zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg
# 4  /1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg
#
#                                 production_companies  \
# 0  [Marvel Entertainment, Columbia Pictures, Pasc...
# 1  [Flynn Picture Company, Seven Bucks Production...
# 2  [Paramount, Entertainment One, Kerner Entertai...
# 3  [20th Century Studios, Scott Free Productions,...
# 4                                   [Marvel Studios]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-11-04
# 2  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2021-11-10
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2021-10-13
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-09-01
#
#    original_revenue  runtime             spoken_languages    status  \
# 0         482000000       97           [Spanish, English]  Released
# 1                 0      117  [English, Italian, Russian]  Released
# 2          51000000       97                    [English]  Released
# 3          27000000      152     [English, French, Latin]  Released
# 4         430238384      132          [English, Mandarin]  Released
#
#                                              tagline  \
# 0
# 1                                      Pro and cons.
# 2                   Adventure has never been bigger.
# 3  The true story of a woman who defied a nation ...
# 4                     You can't outrun your destiny.
#
#                                        title  video  vote_average  vote_count  \
# 0                Venom: Let There Be Carnage  False           7.2        4421
# 1                                 Red Notice  False           6.8        1982
# 2                   Clifford the Big Red Dog  False           7.6         540
# 3                              The Last Duel  False           7.6         885
# 4  Shang-Chi and the Legend of the Ten Rings  False           7.8        4211
#
#    year  cpi_2021  cpi_old  adjusted_revenue  adjusted_budget   budget_bins  \
# 0  2021   269.489  269.489       482000000.0      110000000.0   51m to 150m
# 1  2021   269.489  269.489               0.0      200000000.0  151m to 380m
# 2  2021   269.489  269.489        51000000.0              0.0           NaN
# 3  2021   269.489  269.489        27000000.0      100000000.0   51m to 150m
# 4  2021   269.489  269.489       430238384.0      150000000.0   51m to 150m
#
#                                             keywords  \
# 0  [hero, anti hero, villain, sequel, superhero, ...
# 1                  [fbi, interpol, heist, art thief]
# 2                [based on novel or book, giant dog]
# 3  [based on novel or book, normandy, france, bas...
# 4  [martial arts, superhero, based on comic, mixe...
#
#                                                 cast  \
# 0  [{"adult": false, "gender": 2, "id": 2524, "kn...
# 1  [{"adult": false, "gender": 2, "id": 18918, "k...
# 2  [{"adult": false, "gender": 1, "id": 1696017, ...
# 3  [{"adult": false, "gender": 2, "id": 1892, "kn...
# 4  [{"adult": false, "gender": 2, "id": 1489211, ...
#
#                                                 crew percent_fm certification  \
# 0  [{"adult": false, "gender": 2, "id": 149, "kno...     22.54%         PG-13
# 1  [{"adult": false, "gender": 2, "id": 9543, "kn...     14.58%         PG-13
# 2  [{"adult": false, "gender": 1, "id": 8220, "kn...     39.29%            PG
# 3  [{"adult": false, "gender": 2, "id": 120, "kno...     26.32%
# 4  [{"adult": false, "gender": 1, "id": 7232, "kn...     33.33%         PG-13
#
#                     director director_gender  \
# 0              [Andy Serkis]             [2]
# 1  [Rawson Marshall Thurber]             [2]
# 2              [Walt Becker]             [2]
# 3             [Ridley Scott]             [2]
# 4    [Destin Daniel Cretton]             [2]
#
#                                            producers  \
# 0  [Tom Hardy, K.C. Hodenfield, Avi Arad, Jonatha...
# 1  [Beau Flynn, Dwayne Johnson, Rawson Marshall T...
# 2  [Brad Fischer, Deborah Forte, Deborah Forte, B...
# 3  [Ridley Scott, Ben Affleck, Matt Damon, Jennif...
# 4  [Kevin Feige, Charles Newirth, Louis D'Esposit...
#
#                                              writers  \
# 0  [Tom Hardy, Todd McFarlane, Kelly Marcel, Kell...
# 1                          [Rawson Marshall Thurber]
# 2  [David Ronn, Jay Scherick, Norman Bridwell, An...
# 3  [Ben Affleck, Matt Damon, Nicole Holofcener, E...
# 4  [Dave Callaham, Dave Callaham, Destin Daniel C...
#
#   production_company_origin  foreign_language  \
# 0      [US, US, US, US, US]                 0
# 1            [US, US, US, ]                 0
# 2    [US, CA, , US, US, US]                 0
# 3          [US, GB, US, US]                 0
# 4                      [US]                 0
#
#                                         cast_cleaned         director_cleaned  \
# 0  [tomhardy, woodyharrelson, michellewilliams, n...             [andyserkis]
# 1  [dwaynejohnson, ryanreynolds, galgadot, rituar...  [rawsonmarshallthurber]
# 2  [darbycamp, jackwhitehall, izaacwang, johnclee...             [waltbecker]
# 3  [mattdamon, adamdriver, jodiecomer, harrietwal...            [ridleyscott]
# 4  [simuliu, tonyleungchiu-wai, awkwafina, meng'e...    [destindanielcretton]
#
#                                    producers_cleaned  \
# 0  [tomhardy, k.c.hodenfield, aviarad, jonathanca...
# 1  [beauflynn, dwaynejohnson, rawsonmarshallthurb...
# 2  [bradfischer, deborahforte, deborahforte, bria...
# 3  [ridleyscott, benaffleck, mattdamon, jenniferf...
# 4  [kevinfeige, charlesnewirth, louisd'esposito, ...
#
#                                      writers_cleaned  \
# 0  [tomhardy, toddmcfarlane, kellymarcel, kellyma...
# 1                            [rawsonmarshallthurber]
# 2  [davidronn, jayscherick, normanbridwell, annie...
# 3  [benaffleck, mattdamon, nicoleholofcener, eric...
# 4  [davecallaham, davecallaham, destindanielcrett...
#
#                                     keywords_cleaned  \
# 0  [hero, antihero, villain, sequel, superhero, b...
# 1                   [fbi, interpol, heist, artthief]
# 2                     [basedonnovelorbook, giantdog]
# 3  [basedonnovelorbook, normandy,france, basedona...
# 4  [martialarts, superhero, basedoncomic, mixedma...
#
#                         genres_cleaned  \
# 0  [sciencefiction, action, adventure]
# 1    [action, comedy, crime, thriller]
# 2          [animation, comedy, family]
# 3             [action, drama, history]
# 4         [action, adventure, fantasy]
#
#                         production_companies_cleaned  \
# 0  [marvelentertainment, columbiapictures, pascal...
# 1  [flynnpicturecompany, sevenbucksproductions, l...
# 2  [paramount, entertainmentone, kernerentertainm...
# 3  [20thcenturystudios, scottfreeproductions, pea...
# 4                                    [marvelstudios]
#
#                                     overview_cleaned  \
# 0  after finding a host body in investigative rep...
# 1  an interpol-issued red notice is a global aler...
# 2  as emily struggles to fit in at home and at sc...
# 3  king charles vi declares that knight jean de c...
# 4  shang-chi must confront the past he thought he...
#
#                                                 soup  \
# 0  hero antihero villain sequel superhero basedon...
# 1  fbi interpol heist artthief dwaynejohnson ryan...
# 2  basedonnovelorbook giantdog darbycamp jackwhit...
# 3  basedonnovelorbook normandy,france basedonatru...
# 4  martialarts superhero basedoncomic mixedmartia...
#
#                                        soup_overview  \
# 0  hero antihero villain sequel superhero basedon...
# 1  fbi interpol heist artthief fbi interpol heist...
# 2  basedonnovelorbook giantdog basedonnovelorbook...
# 3  basedonnovelorbook normandy,france basedonatru...
# 4  martialarts superhero basedoncomic mixedmartia...
#
#                                           poster_url  \
# 0  https://image.tmdb.org/t/p/w780/rjkmN1dniUHVYA...
# 1  https://image.tmdb.org/t/p/w780/q2d56YvJ3s9W73...
# 2  https://image.tmdb.org/t/p/w780/ygPTrycbMSFDc5...
# 3  https://image.tmdb.org/t/p/w780/zjrJE0fpzPvX8s...
# 4  https://image.tmdb.org/t/p/w780/1BIoJGKbXjdFDA...
#
#                              lowercase_title
# 0                venom: let there be carnage
# 1                                 red notice
# 2                   clifford the big red dog
# 3                              the last duel
# 4  shang-chi and the legend of the ten rings

# %% [markdown]
# ## Function to Recommend Titles:

# %%
def get_similarity_scores(title, cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]
    
    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the most similar movies
    sim_scores = sim_scores[1:11]
#     print(sim_scores)
    
    # Convert list to DataFrame
    sim_scores_df = pd.DataFrame(sim_scores, columns = ["index", "similarity_score"])
    
    # Return top 10 most similar scores
    return sim_scores_df

# %%
def get_recommendations(original_df, score_df):
    original_df = original_df.merge(score_df, on="index")
    original_df = original_df.sort_values("similarity_score", ascending=False)
    
    return original_df

# %%
# Test out function
movie_title = "Get Out"
similarity_scores_df = get_similarity_scores(movie_title, cosine_sim)

# %%
# Call Get Recommendations Function
recommendations = get_recommendations(movie_df, similarity_scores_df)

# %%
# Print out dataframe
# recommendations[['title', 'similarity_score']].to_csv("./soup_test_3.csv")
recommendations[['title', 'similarity_score', 'id']].head(10)

# %% [markdown]
# ### Convert columns to list for SQL Database connection

# %%
movie_df_columns = list(movie_df.columns)
movie_df_columns
# Out:
# ['adult',
#  'backdrop_path',
#  'belongs_to_collection',
#  'original_budget',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'original_revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count',
#  'year',
#  'cpi_2021',
#  'cpi_old',
#  'adjusted_revenue',
#  'adjusted_budget',
#  'budget_bins',
#  'keywords',
#  'cast',
#  'crew',
#  'percent_fm',
#  'certification',
#  'director',
#  'director_gender',
#  'producers',
#  'writers',
#  'production_company_origin',
#  'foreign_language',
#  'cast_cleaned',
#  'director_cleaned',
#  'producers_cleaned',
#  'writers_cleaned',
#  'keywords_cleaned',
#  'genres_cleaned',
#  'production_companies_cleaned',
#  'overview_cleaned',
#  'soup',
#  'soup_overview',
#  'poster_url',
#  'lowercase_title']

# %%
for column_name in list(movie_df.columns):
    movie_df[column_name] = movie_df[column_name].apply(json.dumps)

# %%
movie_dict = movie_df.applymap(lambda x: isinstance(x, (dict, list))).all()
print(movie_dict)
# Out:
# adult                           False
# backdrop_path                   False
# belongs_to_collection           False
# original_budget                 False
# genres                          False
# homepage                        False
# id                              False
# imdb_id                         False
# original_language               False
# original_title                  False
# overview                        False
# popularity                      False
# poster_path                     False
# production_companies            False
# production_countries            False
# release_date                    False
# original_revenue                False
# runtime                         False
# spoken_languages                False
# status                          False
# tagline                         False
# title                           False
# video                           False
# vote_average                    False
# vote_count                      False
# year                            False
# cpi_2021                        False
# cpi_old                         False
# adjusted_revenue                False
# adjusted_budget                 False
# budget_bins                     False
# keywords                        False
# cast                            False
# crew                            False
# percent_fm                      False
# certification                   False
# director                        False
# director_gender                 False
# producers                       False
# writers                         False
# production_company_origin       False
# foreign_language                False
# cast_cleaned                    False
# director_cleaned                False
# producers_cleaned               False
# writers_cleaned                 False
# keywords_cleaned                False
# genres_cleaned                  False
# production_companies_cleaned    False
# overview_cleaned                False
# soup                            False
# soup_overview                   False
# poster_url                      False
# lowercase_title                 False
# dtype: bool

# %% [markdown]
# ## Database:

# %%
from sqlalchemy import create_engine, inspect

# %%
# configure the connection string
rds_connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
        
# connect to the database
engine = create_engine(rds_connection_string)
conn = engine.connect()

# %%
engine.execute("DROP TABLE IF EXISTS movies")

# %%
# Append data to table
movie_df.to_sql(name='movies', con=conn, if_exists='append', index=False)

# %%
# Use inspector to find table names
Inspector = inspect(engine)
Inspector.get_table_names()

# %%
# Check movies table
pd.read_sql_query('select * from movies', con=conn).head()
# Out:
#    adult                       backdrop_path  \
# 0  false  "/70nxSw3mFBsGmtkvcs91PbjerwD.jpg"
# 1  false  "/5uVhMGsps81CN0S4U9NF0Z4tytG.jpg"
# 2  false  "/zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg"
# 3  false  "/mFbS5TwN95BcSEfiztdchLgTQ0v.jpg"
# 4  false  "/cinER0ESG0eJ49kXlExM0MEWGxW.jpg"
#
#                                belongs_to_collection original_budget  \
# 0  {"id": 558216, "name": "Venom Collection", "po...       110000000
# 1                                               null       200000000
# 2                                               null               0
# 3                                               null       100000000
# 4  {"id": 912503, "name": "Shang-Chi Collection",...       150000000
#
#                                               genres  \
# 0  "\"[\\\"Science Fiction\\\", \\\"Action\\\", \...
# 1  "\"[\\\"Action\\\", \\\"Comedy\\\", \\\"Crime\...
# 2  "\"[\\\"Animation\\\", \\\"Comedy\\\", \\\"Fam...
# 3  "\"[\\\"Action\\\", \\\"Drama\\\", \\\"History...
# 4  "\"[\\\"Action\\\", \\\"Adventure\\\", \\\"Fan...
#
#                                             homepage      id      imdb_id  \
# 0                          "https://www.venom.movie"  580489  "tt7097896"
# 1        "https://www.netflix.com/us/title/81161626"  512195  "tt7991608"
# 2                                                 ""  585245  "tt2397461"
# 3  "https://www.20thcenturystudios.com/movies/the...  617653  "tt4244994"
# 4  "https://www.marvel.com/movies/shang-chi-and-t...  566525  "tt9376612"
#
#   original_language                               original_title  \
# 0              "en"                "Venom: Let There Be Carnage"
# 1              "en"                                 "Red Notice"
# 2              "en"                   "Clifford the Big Red Dog"
# 3              "en"                              "The Last Duel"
# 4              "en"  "Shang-Chi and the Legend of the Ten Rings"
#
#                                             overview popularity  \
# 0  "After finding a host body in investigative re...   8633.976
# 1  "An Interpol-issued Red Notice is a global ale...   4825.133
# 2  "As Emily struggles to fit in at home and at s...    3280.16
# 3  "King Charles VI declares that Knight Jean de ...   3256.364
# 4  "Shang-Chi must confront the past he thought h...   3189.442
#
#                           poster_path  \
# 0  "/rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg"
# 1  "/q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg"
# 2  "/ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg"
# 3  "/zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg"
# 4  "/1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg"
#
#                                 production_companies  \
# 0  "\"[\\\"Marvel Entertainment\\\", \\\"Columbia...
# 1  "\"[\\\"Flynn Picture Company\\\", \\\"Seven B...
# 2  "\"[\\\"Paramount\\\", \\\"Entertainment One\\...
# 3  "\"[\\\"20th Century Studios\\\", \\\"Scott Fr...
# 4                     "\"[\\\"Marvel Studios\\\"]\""
#
#                                 production_countries  release_date  \
# 0  "\"[{\\\"iso_3166_1\\\": \\\"US\\\", \\\"name\...  "2021-09-30"
# 1  "\"[{\\\"iso_3166_1\\\": \\\"US\\\", \\\"name\...  "2021-11-04"
# 2  "\"[{\\\"iso_3166_1\\\": \\\"CA\\\", \\\"name\...  "2021-11-10"
# 3  "\"[{\\\"iso_3166_1\\\": \\\"GB\\\", \\\"name\...  "2021-10-13"
# 4  "\"[{\\\"iso_3166_1\\\": \\\"US\\\", \\\"name\...  "2021-09-01"
#
#   original_revenue runtime                   spoken_languages      status  \
# 0        482000000      97             ["Spanish", "English"]  "Released"
# 1                0     117  ["English", "Italian", "Russian"]  "Released"
# 2         51000000      97                        ["English"]  "Released"
# 3         27000000     152     ["English", "French", "Latin"]  "Released"
# 4        430238384     132            ["English", "Mandarin"]  "Released"
#
#                                              tagline  \
# 0                                                 ""
# 1                                    "Pro and cons."
# 2                 "Adventure has never been bigger."
# 3  "The true story of a woman who defied a nation...
# 4                   "You can't outrun your destiny."
#
#                                          title  video vote_average vote_count  \
# 0                "Venom: Let There Be Carnage"  false          7.2       4421
# 1                                 "Red Notice"  false          6.8       1982
# 2                   "Clifford the Big Red Dog"  false          7.6        540
# 3                              "The Last Duel"  false          7.6        885
# 4  "Shang-Chi and the Legend of the Ten Rings"  false          7.8       4211
#
#    year cpi_2021  cpi_old adjusted_revenue adjusted_budget     budget_bins  \
# 0  2021  269.489  269.489      482000000.0     110000000.0   "51m to 150m"
# 1  2021  269.489  269.489              0.0     200000000.0  "151m to 380m"
# 2  2021  269.489  269.489       51000000.0             0.0            None
# 3  2021  269.489  269.489       27000000.0     100000000.0   "51m to 150m"
# 4  2021  269.489  269.489      430238384.0     150000000.0   "51m to 150m"
#
#                                             keywords  \
# 0  "[\"hero\", \"anti hero\", \"villain\", \"sequ...
# 1  "[\"fbi\", \"interpol\", \"heist\", \"art thie...
# 2      "[\"based on novel or book\", \"giant dog\"]"
# 3  "[\"based on novel or book\", \"normandy, fran...
# 4  "[\"martial arts\", \"superhero\", \"based on ...
#
#                                                 cast  \
# 0  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...
# 1  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...
# 2  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...
# 3  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...
# 4  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...
#
#                                                 crew percent_fm certification  \
# 0  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...   "22.54%"       "PG-13"
# 1  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...   "14.58%"       "PG-13"
# 2  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...   "39.29%"          "PG"
# 3  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...   "26.32%"            ""
# 4  "\"\\\"[{\\\\\\\"adult\\\\\\\": false, \\\\\\\...   "33.33%"       "PG-13"
#
#                           director director_gender  \
# 0              "[\"Andy Serkis\"]"           "[2]"
# 1  "[\"Rawson Marshall Thurber\"]"           "[2]"
# 2              "[\"Walt Becker\"]"           "[2]"
# 3             "[\"Ridley Scott\"]"           "[2]"
# 4    "[\"Destin Daniel Cretton\"]"           "[2]"
#
#                                            producers  \
# 0  "[\"Tom Hardy\", \"K.C. Hodenfield\", \"Avi Ar...
# 1  "[\"Beau Flynn\", \"Dwayne Johnson\", \"Rawson...
# 2  "[\"Brad Fischer\", \"Deborah Forte\", \"Debor...
# 3  "[\"Ridley Scott\", \"Ben Affleck\", \"Matt Da...
# 4  "[\"Kevin Feige\", \"Charles Newirth\", \"Loui...
#
#                                              writers  \
# 0  "[\"Tom Hardy\", \"Todd McFarlane\", \"Kelly M...
# 1                    "[\"Rawson Marshall Thurber\"]"
# 2  "[\"David Ronn\", \"Jay Scherick\", \"Norman B...
# 3  "[\"Ben Affleck\", \"Matt Damon\", \"Nicole Ho...
# 4  "[\"Dave Callaham\", \"Dave Callaham\", \"Dest...
#
#                           production_company_origin foreign_language  \
# 0        "[\"US\", \"US\", \"US\", \"US\", \"US\"]"                0
# 1                  "[\"US\", \"US\", \"US\", \"\"]"                0
# 2  "[\"US\", \"CA\", \"\", \"US\", \"US\", \"US\"]"                0
# 3                "[\"US\", \"GB\", \"US\", \"US\"]"                0
# 4                                        "[\"US\"]"                0
#
#                                         cast_cleaned  \
# 0  "[\"tomhardy\", \"woodyharrelson\", \"michelle...
# 1  "[\"dwaynejohnson\", \"ryanreynolds\", \"galga...
# 2  "[\"darbycamp\", \"jackwhitehall\", \"izaacwan...
# 3  "[\"mattdamon\", \"adamdriver\", \"jodiecomer\...
# 4  "[\"simuliu\", \"tonyleungchiu-wai\", \"awkwaf...
#
#                 director_cleaned  \
# 0             "[\"andyserkis\"]"
# 1  "[\"rawsonmarshallthurber\"]"
# 2             "[\"waltbecker\"]"
# 3            "[\"ridleyscott\"]"
# 4    "[\"destindanielcretton\"]"
#
#                                    producers_cleaned  \
# 0  "[\"tomhardy\", \"k.c.hodenfield\", \"aviarad\...
# 1  "[\"beauflynn\", \"dwaynejohnson\", \"rawsonma...
# 2  "[\"bradfischer\", \"deborahforte\", \"deborah...
# 3  "[\"ridleyscott\", \"benaffleck\", \"mattdamon...
# 4  "[\"kevinfeige\", \"charlesnewirth\", \"louisd...
#
#                                      writers_cleaned  \
# 0  "[\"tomhardy\", \"toddmcfarlane\", \"kellymarc...
# 1                      "[\"rawsonmarshallthurber\"]"
# 2  "[\"davidronn\", \"jayscherick\", \"normanbrid...
# 3  "[\"benaffleck\", \"mattdamon\", \"nicoleholof...
# 4  "[\"davecallaham\", \"davecallaham\", \"destin...
#
#                                     keywords_cleaned  \
# 0  "[\"hero\", \"antihero\", \"villain\", \"seque...
# 1  "[\"fbi\", \"interpol\", \"heist\", \"artthief...
# 2           "[\"basedonnovelorbook\", \"giantdog\"]"
# 3  "[\"basedonnovelorbook\", \"normandy,france\",...
# 4  "[\"martialarts\", \"superhero\", \"basedoncom...
#
#                                       genres_cleaned  \
# 0  "[\"sciencefiction\", \"action\", \"adventure\"]"
# 1  "[\"action\", \"comedy\", \"crime\", \"thrille...
# 2          "[\"animation\", \"comedy\", \"family\"]"
# 3             "[\"action\", \"drama\", \"history\"]"
# 4         "[\"action\", \"adventure\", \"fantasy\"]"
#
#                         production_companies_cleaned  \
# 0  "[\"marvelentertainment\", \"columbiapictures\...
# 1  "[\"flynnpicturecompany\", \"sevenbucksproduct...
# 2  "[\"paramount\", \"entertainmentone\", \"kerne...
# 3  "[\"20thcenturystudios\", \"scottfreeproductio...
# 4                              "[\"marvelstudios\"]"
#
#                                     overview_cleaned  \
# 0  "after finding a host body in investigative re...
# 1  "an interpol-issued red notice is a global ale...
# 2  "as emily struggles to fit in at home and at s...
# 3  "king charles vi declares that knight jean de ...
# 4  "shang-chi must confront the past he thought h...
#
#                                                 soup  \
# 0  "hero antihero villain sequel superhero basedo...
# 1  "fbi interpol heist artthief dwaynejohnson rya...
# 2  "basedonnovelorbook giantdog darbycamp jackwhi...
# 3  "basedonnovelorbook normandy,france basedonatr...
# 4  "martialarts superhero basedoncomic mixedmarti...
#
#                                        soup_overview  \
# 0  "hero antihero villain sequel superhero basedo...
# 1  "fbi interpol heist artthief fbi interpol heis...
# 2  "basedonnovelorbook giantdog basedonnovelorboo...
# 3  "basedonnovelorbook normandy,france basedonatr...
# 4  "martialarts superhero basedoncomic mixedmarti...
#
#                                           poster_url  \
# 0  "https://image.tmdb.org/t/p/w780/rjkmN1dniUHVY...
# 1  "https://image.tmdb.org/t/p/w780/q2d56YvJ3s9W7...
# 2  "https://image.tmdb.org/t/p/w780/ygPTrycbMSFDc...
# 3  "https://image.tmdb.org/t/p/w780/zjrJE0fpzPvX8...
# 4  "https://image.tmdb.org/t/p/w780/1BIoJGKbXjdFD...
#
#                                lowercase_title
# 0                "venom: let there be carnage"
# 1                                 "red notice"
# 2                   "clifford the big red dog"
# 3                              "the last duel"
# 4  "shang-chi and the legend of the ten rings"
