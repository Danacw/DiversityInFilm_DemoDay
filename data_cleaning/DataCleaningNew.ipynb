# %% [markdown]
# # The Movie Database: Data Extraction & Cleaning

# %%
# %pip install cpi

# %%
# Import dependencies
import pandas as pd
import json
import requests
from pprint import pprint
import numpy as np
import cpi

from datetime import datetime

# Import config
from config import api_key, db_user, db_password, db_host, db_port, db_name

# %%
cpi.update()

# %% [markdown]
# ### Testing:

# %% [raw]
# # Single Test: Discover Most Popular Movies
# page_number = 1
#
# # Endpoint for finding most popular movies
# discover_movies = "https://api.themoviedb.org/3/discover/movie"
# most_popular_url = f"{discover_movies}?api_key={api_key}&page={page_number}&sort_by=popularity.desc"
#
# # Most popular movies
# tmdb_response = requests.get(most_popular_url).json()
# results = tmdb_response["results"]
#
# json_string = json.dumps(results)
# df = pd.read_json(json_string)
# df

# %% [raw]
# # Single Test: Movie Details
# movie_id = 672582
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [raw]
# # Single Test: Credits
# # movie_id = 566525
# movie_id = 284052
#
# movie_credits = f"/movie/{movie_id}/credits"
# credits_url = f"https://api.themoviedb.org/3/{movie_credits}?api_key={api_key}"
#
# # Get the json response for the credits
# credits_response = requests.get(credits_url).json()
# pprint(credits_response)

# %% [raw]
# # Find job names for Writing Department
# for i in credits_response['crew']:
#     if i['department'] == 'Writing':
#         name = i['name']
#         job = i['job']
#         print(f"{name}: {job}")

# %% [raw]
# # Single Test: Movie Recommendations
# movie_id = 32657
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}/recommendations?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [raw]
# # Single Test: Movie Release Date/Certifications
# movie_id = 32657
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}/release_dates?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [markdown]
# # FUNCTIONS:

# %%
# Start Timer Function (check on API call performance)
def start_timer():
    start = datetime.now()
    
    return start

# %%
# Stop Timer Function (check on API call performance)
def stop_timer(start):
    end = datetime.now()
    elapsed_time = (end - start)

    print(f"Total Time Elapsed:  {elapsed_time.total_seconds()} seconds")

# %% [markdown]
# ### API CALLS:

# %%
# Returns most popular movies
def get_most_popular_movies(api_key):
    
    movies = []
    
    # Loop through pages to get results for movies
    for x in range(1, 101):
        page_number = x

        # Endpoint for finding most popular movies
        discover_movies = "https://api.themoviedb.org/3/discover/movie"
        most_popular_url = f"{discover_movies}?api_key={api_key}&page={page_number}&sort_by=popularity.desc"
        
        # Most popular movies
        tmdb_response = requests.get(most_popular_url).json()
        results = tmdb_response["results"]

#         for y in range(len(results)):
#             movies.append(results[y]) 
        for result in results:
            movies.append(result)
            
    return movies

# %%
# Returns movie details as a list
def get_movie_details(api_key, movie_ids):  
    
    movie_details = []
    
    for movie_id in movie_ids:
        # Endpoint & response
        movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
        movie_response = requests.get(movie_url).json()

        # Append results to lists
        movie_details.append(movie_response)
        
    return movie_details

# %%
# Returns keywords as a list
def get_movie_keywords(api_key, movie_ids):
    keyword_details = []
    
    for movie_id in movie_ids:
        # Get keywords for each movie
        keywords_url = f"https://api.themoviedb.org/3/movie/{movie_id}/keywords?api_key={api_key}"
        keywords_response = requests.get(keywords_url).json()
        keywords_results = keywords_response["keywords"]
        
         # Append results to lists
        keyword_details.append(keywords_response)
        
    return keyword_details

# %%
# Returns credits as a list
def get_credits(api_key, movie_ids):
    credit_details = []
    
    for movie_id in movie_ids:
        # Generate movie credits
        movie_credits = f"/movie/{movie_id}/credits"
        credits_url = f"https://api.themoviedb.org/3/{movie_credits}?api_key={api_key}"

        # Get the json response for the credits
        credits_response = requests.get(credits_url).json()
        
        credit_details.append(credits_response)
        
    return credit_details

# %%
# Returns certifications as a list (rating: G, PG, etc.)
def get_certifications(api_key, movie_ids):
    certifications = []
    
    for movie_id in movie_ids:
        # Get certifications for each movie
        certification_url = f"https://api.themoviedb.org/3/movie/{movie_id}/release_dates?api_key={api_key}"
        
        certification_response = requests.get(certification_url).json()
        
        certifications.append(certification_response)
        
    return certifications

# %% [markdown]
# ### GET TITLES & IDS:

# %%
# Returns single title for specified index number
def get_title(results, idx):
    movie_title = results[idx]["title"]
    
    return movie_title

# %%
# Returns ids list
def get_ids(results):
    movie_ids = []
    for x in results:
        movie_ids.append(x["id"])
        
    return movie_ids

# %%
# Returns titles list
def get_titles(results):
    movie_titles = []
    for x in results:
        movie_titles.append(x["title"])
        
    return movie_titles

# %% [markdown]
# ### EXTRACT NEEDED DETAILS FROM COLUMNS:

# %%
# Extract the certification (ratings)
def extract_certification(x):
    name = ""
    
    for i in x:
        # Get ratings for US
        if i['iso_3166_1'] == 'US':
             # Append results to lists
            name = i['release_dates'][0]['certification']
            break
    return name

# %%
# Function to get the director out of the crew
def get_director(x):
    names = []
    
    for i in x:
        if i['job'] == 'Director':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the director gender out of the crew
def get_director_gender(x):
    names = []
    
    for i in x:
        if i['job'] == 'Director':
            gender = i['gender']
            names.append(gender)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the producers out of the crew
def get_producers(x):
    names = []
    
    for i in x:
        if i['job'] == 'Producer':
            name = i['name']
            names.append(name)
        elif i['job'] == "Executive Producer":
            name = i['name']
            names.append(name)
        elif i['job'] == 'Co-Producer':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the screenplay writers out of the crew
def get_writers(x):
    names = []
    for i in x:
        if i['department'] == 'Writing':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to create cast list
def get_cast_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        
        # Condition for cast (keep top 5)
        if len(names) > 5:
            names = names[:5]
        return names

    return []

# %%
# Function to create lists of each feature
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        return names
        
    return []

# %%
# Function to get production companies
def get_production_companies(x):
    names = []
    if isinstance(x, list):
        for i in x:
            name = i['name']
            names.append(name)
        return names
        
    return []

# %%
# Get each production company's country of origin
def get_production_company_country(x):
    names = []
    if isinstance(x, list):
        for i in x:
            country = i['origin_country']
            names.append(country)
        return names
    return []

# %%
# Get list of all languages available for film
def get_languages(x):
    names = []
    for i in x:
        name = i['english_name']
#         iso = i['iso_639_1']
        names.append(name)
    
    if(names):
        return names
    
    return np.nan

# %%
# Create binary column for foreign language films
def original_language_binary(x):
    if (x == 'en'):
        return 0
    elif (x != 'en'):
        return 1
    elif (x == "" | x == " "):
        return 0
    else:
        return 0

# %% [markdown]
# ### CLEAN DATA FOR SOUP & CREATE SOUP:

# %%
# Convert all strings to lower case and strip names of spaces
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else: 
            return ''

# %%
# Clean the overview column (by converting to lowercase)
def clean_overview(x):
    if isinstance(x, str):
        return x.lower()
    else: 
        return ''

# %%
# Create soup of words
def create_soup(x):
    space = ' '
    return (space.join(x['keywords_cleaned']) + space + space.join(x['cast_cleaned']) + space 
            + space.join(x['director_cleaned']) + space + space.join(x['producers_cleaned']) + space 
            + space.join(x['writers_cleaned']) + space + space.join(x['genres_cleaned']) + space 
            + space.join(x['production_companies_cleaned']))

# %%
# Create soup of words - 2 keywords, 2 genres & overview
def create_soup_overview(x):
    space = ' '
    return (space.join(x['keywords_cleaned']) + space + space.join(x['keywords_cleaned']) + space 
            + space.join(x['cast_cleaned']) + space + space.join(x['director_cleaned']) + space 
            + space.join(x['producers_cleaned']) + space + space.join(x['writers_cleaned']) + space 
            + space.join(x['genres_cleaned']) + space + space.join(x['genres_cleaned']) + space 
            + space.join(x['production_companies_cleaned']) + space + x['overview_cleaned'])

# %% [markdown]
# # CALL API

# %% [markdown]
# ### Get Most Popular Movies JSON Results:

# %%
# Start the timer
start = start_timer()

# %%
most_popular_movies = get_most_popular_movies(api_key)
# print(most_popular_movies)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  33.07278 seconds

# %% [markdown]
# ### List of Movie IDs:

# %%
movie_ids = get_ids(most_popular_movies)
# print(movie_ids)

# %%
len(movie_ids)
# Out:
# 2000

# %% [markdown]
# ### List of Titles:

# %%
titles = get_titles(most_popular_movies)
# print(titles)

# %%
len(titles)
# Out:
# 2000

# %% [markdown]
# ### Print Individual Title:

# %%
# print(get_title(most_popular_movies, 0))

# %% [markdown]
# ### Get Movie Details:

# %%
# Start the timer
start = start_timer()

# %%
details = get_movie_details(api_key, movie_ids)

# %%
# print(details)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  259.913294 seconds

# %% [markdown]
# ### Get Keywords:

# %%
# Start the timer
start = start_timer()

# %%
keywords = get_movie_keywords(api_key, movie_ids)

# %%
# print(keywords)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  262.196792 seconds

# %% [markdown]
# ### Get Credits:

# %%
# Start the timer
start = start_timer()

# %%
credits = get_credits(api_key, movie_ids)

# %%
# print(credits)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  267.810107 seconds

# %% [markdown]
# ### Get Certifications:

# %%
# Start the timer
start = start_timer()

# %%
# Get the certifications for each movie (rating: G, PG, etc.)
certifications = get_certifications(api_key, movie_ids)
# certifications = get_certifications(api_key, [32657, 672582])

# %%
# print(certifications)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  265.061754 seconds

# %% [markdown]
# ## Movie Details DataFrame:

# %%
# Convert details to json
json_details_string = json.dumps(details)
# Convert json to dataframe
movie_details_df = pd.read_json(json_details_string)

# Export to save
# movie_details_df.to_csv("./static/data/movie_details.csv", index=False)
movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1  False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg
# 2  False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
# 3  False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 4  False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 558216, 'name': 'Venom Collection', 'po...  110000000
# 1                                               None  200000000
# 2                                               None  150000000
# 3                                               None    9100000
# 4                                               None          0
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                             homepage      id     imdb_id  \
# 0                            https://www.venom.movie  580489   tt7097896
# 1          https://www.netflix.com/us/title/81161626  512195   tt7991608
# 2  https://www.marvel.com/movies/shang-chi-and-th...  566525   tt9376612
# 3                                                     589761  tt10648714
# 4                                                     585245   tt2397461
#
#   original_language                             original_title  ...  \
# 0                en                Venom: Let There Be Carnage  ...
# 1                en                                 Red Notice  ...
# 2                en  Shang-Chi and the Legend of the Ten Rings  ...
# 3                ru                                  Чернобыль  ...
# 4                en                   Clifford the Big Red Dog  ...
#
#   release_date    revenue runtime  \
# 0   2021-09-30  454000000      97
# 1   2021-11-04          0     116
# 2   2021-09-01  430238384     132
# 3   2021-04-15    5370393     136
# 4   2021-11-10   40000000      97
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                             tagline  \
# 0
# 1                     Pro and cons.
# 2    You can't outrun your destiny.
# 3
# 4  Adventure has never been bigger.
#
#                                        title  video vote_average vote_count
# 0                Venom: Let There Be Carnage  False          7.2       3708
# 1                                 Red Notice  False          6.8       1616
# 2  Shang-Chi and the Legend of the Ten Rings  False          7.9       3844
# 3                             Chernobyl 1986  False          6.2        214
# 4                   Clifford the Big Red Dog  False          7.6        332
#
# [5 rows x 25 columns]

# %%
# Extract year from release date
movie_details_df["year"] = pd.DatetimeIndex(movie_details_df['release_date']).year
# Drop any N/A from year
movie_details_df.dropna(inplace=True, how="any", subset=['year','release_date'])
 
# Convert to int
movie_details_df["year"] = movie_details_df["year"].astype(int)
    
# Rename columns to prepare for inflation calculation
movie_details_df = movie_details_df.rename(columns = {
    "revenue": "original_revenue",
    "budget": "original_budget"
})

# %%
len(movie_details_df)
# Out:
# 1990

# %% [markdown]
# ## Adjust Budget & Revenue for Inflation

# %%
# Create dataframe for cpi
cpi_df = pd.DataFrame(columns=['year', 'cpi_2021', 'cpi_old'])

# %%
# Create list of years (1913-2021)
years = []
for i in range(1913, 2022):
    years.append(i)

# %%
# Define 2021 cpi
cpi_2021 = 269.489

# Loop through years to append to dataframe
for year in years:
    if year != 2021:
        cpi_old = cpi.get(year)
        cpi_df = cpi_df.append({"year": year, 'cpi_2021': cpi_2021, 'cpi_old': cpi_old}, ignore_index=True)
    elif year == 2021:
        cpi_df = cpi_df.append({"year": year, 'cpi_2021': cpi_2021, 'cpi_old': cpi_2021}, ignore_index=True)

# %%
# Convert year type to int
cpi_df['year'] = cpi_df['year'].astype(int)
cpi_df.head()
# Out:
#    year  cpi_2021  cpi_old
# 0  1913   269.489      9.9
# 1  1914   269.489     10.0
# 2  1915   269.489     10.1
# 3  1916   269.489     10.9
# 4  1917   269.489     12.8

# %%
# Merge movie details df with cpi df
movie_details_df = movie_details_df.merge(cpi_df, on="year")
movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1  False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg
# 2  False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
# 3  False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 4  False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 1                                               None        200000000
# 2                                               None        150000000
# 3                                               None          9100000
# 4                                               None                0
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                             homepage      id     imdb_id  \
# 0                            https://www.venom.movie  580489   tt7097896
# 1          https://www.netflix.com/us/title/81161626  512195   tt7991608
# 2  https://www.marvel.com/movies/shang-chi-and-th...  566525   tt9376612
# 3                                                     589761  tt10648714
# 4                                                     585245   tt2397461
#
#   original_language                             original_title  ...  \
# 0                en                Venom: Let There Be Carnage  ...
# 1                en                                 Red Notice  ...
# 2                en  Shang-Chi and the Legend of the Ten Rings  ...
# 3                ru                                  Чернобыль  ...
# 4                en                   Clifford the Big Red Dog  ...
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                             tagline  \
# 0
# 1                     Pro and cons.
# 2    You can't outrun your destiny.
# 3
# 4  Adventure has never been bigger.
#
#                                        title  video vote_average  vote_count  \
# 0                Venom: Let There Be Carnage  False          7.2        3708
# 1                                 Red Notice  False          6.8        1616
# 2  Shang-Chi and the Legend of the Ten Rings  False          7.9        3844
# 3                             Chernobyl 1986  False          6.2         214
# 4                   Clifford the Big Red Dog  False          7.6         332
#
#    year cpi_2021  cpi_old
# 0  2021  269.489  269.489
# 1  2021  269.489  269.489
# 2  2021  269.489  269.489
# 3  2021  269.489  269.489
# 4  2021  269.489  269.489
#
# [5 rows x 28 columns]

# %%
# Create adjusted column for each feature
features = ["revenue", "budget"]

for feature in features:
    movie_details_df[f'adjusted_{feature}'] = (movie_details_df[f'original_{feature}'] * movie_details_df['cpi_2021']) / movie_details_df['cpi_old']

movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1  False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg
# 2  False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
# 3  False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 4  False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 1                                               None        200000000
# 2                                               None        150000000
# 3                                               None          9100000
# 4                                               None                0
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                             homepage      id     imdb_id  \
# 0                            https://www.venom.movie  580489   tt7097896
# 1          https://www.netflix.com/us/title/81161626  512195   tt7991608
# 2  https://www.marvel.com/movies/shang-chi-and-th...  566525   tt9376612
# 3                                                     589761  tt10648714
# 4                                                     585245   tt2397461
#
#   original_language                             original_title  ...  \
# 0                en                Venom: Let There Be Carnage  ...
# 1                en                                 Red Notice  ...
# 2                en  Shang-Chi and the Legend of the Ten Rings  ...
# 3                ru                                  Чернобыль  ...
# 4                en                   Clifford the Big Red Dog  ...
#
#                             tagline  \
# 0
# 1                     Pro and cons.
# 2    You can't outrun your destiny.
# 3
# 4  Adventure has never been bigger.
#
#                                        title  video vote_average vote_count  \
# 0                Venom: Let There Be Carnage  False          7.2       3708
# 1                                 Red Notice  False          6.8       1616
# 2  Shang-Chi and the Legend of the Ten Rings  False          7.9       3844
# 3                             Chernobyl 1986  False          6.2        214
# 4                   Clifford the Big Red Dog  False          7.6        332
#
#    year  cpi_2021  cpi_old adjusted_revenue adjusted_budget
# 0  2021   269.489  269.489      454000000.0     110000000.0
# 1  2021   269.489  269.489              0.0     200000000.0
# 2  2021   269.489  269.489      430238384.0     150000000.0
# 3  2021   269.489  269.489        5370393.0       9100000.0
# 4  2021   269.489  269.489       40000000.0             0.0
#
# [5 rows x 30 columns]

# %%
# Check values
movie_details_df[['original_budget', 'adjusted_budget', 'original_revenue', 'adjusted_revenue', 'year']]
# Out:
#       original_budget  adjusted_budget  original_revenue  adjusted_revenue  \
# 0           110000000     1.100000e+08         454000000      4.540000e+08
# 1           200000000     2.000000e+08                 0      0.000000e+00
# 2           150000000     1.500000e+08         430238384      4.302384e+08
# 3             9100000     9.100000e+06           5370393      5.370393e+06
# 4                   0     0.000000e+00          40000000      4.000000e+07
# ...               ...              ...               ...               ...
# 1965          3000000     2.642049e+07          22182353      1.953562e+08
# 1966          7000000     3.506362e+07         470653000      2.357543e+09
# 1967          3180000     4.394744e+07           9644124      1.332813e+08
# 1968          6000000     5.215916e+07         102272727      8.890766e+08
# 1969           315000     2.620032e+06                 0      0.000000e+00
#
#       year
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021
# ...    ...
# 1965  1963
# 1966  1975
# 1967  1946
# 1968  1964
# 1969  1966
#
# [1970 rows x 5 columns]

# %% [markdown]
# ## Low Budget:

# %%
# Create budget bins
bins = [1, 15000000, 50000000, 150000000, 380000000] 
bin_names = ["1 to 15m", "16m to 50m", "51m to 150m", "151m to 380m"]

# Append a budget bin column
movie_details_df["budget_bins"] = pd.cut(movie_details_df["adjusted_budget"], bins, labels=bin_names)
movie_details_df["budget_bins"].value_counts()
# Out:
# 51m to 150m     371
# 16m to 50m      335
# 151m to 380m    245
# 1 to 15m        207
# Name: budget_bins, dtype: int64

# %%
# Low Budget
movie_details_df.loc[movie_details_df["budget_bins"] == "1 to 15m"].head()
# Out:
#     adult                     backdrop_path  \
# 3   False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 10  False  /4EJSMQOM1bZPHvzqAQe87suBxdf.jpg
# 17  False  /qXctHIfK4LAgHH7qZiJJVCPclaY.jpg
# 19  False  /lV3UFPPxDIPelh46G9oySXN9Mcz.jpg
# 29  False  /dIibeeq4QMay5bTJ2vjr72IFFRo.jpg
#
#                                 belongs_to_collection  original_budget  \
# 3                                                None          9100000
# 10                                               None           250000
# 17                                               None            45223
# 19  {'id': 702624, 'name': 'After Collection', 'po...         14000000
# 29  {'id': 589755, 'name': 'Последний богатырь (Ко...          8400000
#
#                                                genres  \
# 3   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 10  [{'id': 10752, 'name': 'War'}, {'id': 36, 'nam...
# 17  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 19  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 29  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
#
#                                              homepage      id     imdb_id  \
# 3                                                      589761  tt10648714
# 10             https://www.netflix.com/title/81450071  885110  tt15847872
# 17  https://www.disneyplus.com/movies/ciao-alberto...  876716  tt15476620
# 19                                                     744275  tt13069986
# 29                                                     589754  tt13606158
#
#    original_language                  original_title  ...  \
# 3                 ru                       Чернобыль  ...
# 10                en                           Amina  ...
# 17                en                    Ciao Alberto  ...
# 19                en                   After We Fell  ...
# 29                ru  Последний богатырь: Корень зла  ...
#
#                              title  video vote_average vote_count  year  \
# 3                   Chernobyl 1986  False          6.2        214  2021
# 10                           Amina  False          7.0         34  2021
# 17                    Ciao Alberto  False          7.7        222  2021
# 19                   After We Fell  False          7.2       1054  2021
# 29  The Last Warrior: Root of Evil  False          7.0         66  2021
#
#    cpi_2021  cpi_old  adjusted_revenue adjusted_budget budget_bins
# 3   269.489  269.489         5370393.0       9100000.0    1 to 15m
# 10  269.489  269.489               0.0        250000.0    1 to 15m
# 17  269.489  269.489               0.0         45223.0    1 to 15m
# 19  269.489  269.489        19000000.0      14000000.0    1 to 15m
# 29  269.489  269.489        27658331.0       8400000.0    1 to 15m
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Keywords DataFrame:

# %%
# Convert keywords to json
json_keywords_string = json.dumps(keywords)
# Convert json to dataframe
movie_keywords_df = pd.read_json(json_keywords_string)

# Export to save
# movie_keywords_df.to_csv("./static/data/movie_keywords.csv", index=False)
movie_keywords_df.head()
# Out:
#        id                                           keywords
# 0  580489  [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 1  512195  [{'id': 1812, 'name': 'fbi'}, {'id': 6710, 'na...
# 2  566525  [{'id': 779, 'name': 'martial arts'}, {'id': 9...
# 3  589761              [{'id': 210326, 'name': 'chernobyl'}]
# 4  585245  [{'id': 818, 'name': 'based on novel or book'}...

# %% [markdown]
# ## Credits DataFrame:

# %%
# Convert credits to json
json_credits_string = json.dumps(credits)
# Convert json to dataframe
movie_credits_df = pd.read_json(json_credits_string)

# Export to save
# movie_credits_df.to_csv("./static/data/movie_credits.csv", index=False)
movie_credits_df.head()
# Out:
#        id                                               cast  \
# 0  580489  [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1  512195  [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 2  566525  [{'adult': False, 'gender': 2, 'id': 1489211, ...
# 3  589761  [{'adult': False, 'gender': 2, 'id': 562730, '...
# 4  585245  [{'adult': False, 'gender': 1, 'id': 1696017, ...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 149, 'kno...
# 1  [{'adult': False, 'gender': 2, 'id': 9543, 'kn...
# 2  [{'adult': False, 'gender': 1, 'id': 7232, 'kn...
# 3  [{'adult': False, 'gender': 1, 'id': 30247, 'k...
# 4  [{'adult': False, 'gender': 1, 'id': 8220, 'kn...

# %% [markdown]
# ## Certifications DataFrame:

# %%
# Convert certifications to json
json_certifications_string = json.dumps(certifications)
# Convert json to dataframe
movie_certifications_df = pd.read_json(json_certifications_string)

# Export to save
# movie_certifications_df.to_csv("./static/data/movie_certifications.csv", index=False)
movie_certifications_df.head()
# Out:
#        id                                            results
# 0  580489  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 1  512195  [{'iso_3166_1': 'IT', 'release_dates': [{'cert...
# 2  566525  [{'iso_3166_1': 'TR', 'release_dates': [{'cert...
# 3  589761  [{'iso_3166_1': 'LT', 'release_dates': [{'cert...
# 4  585245  [{'iso_3166_1': 'US', 'release_dates': [{'cert...

# %%
# Extract certification information and append to new column
movie_certifications_df['certification'] = movie_certifications_df['results'].apply(extract_certification)
movie_certifications_df = movie_certifications_df[['id', 'certification']]

# %%
movie_certifications_df.head()
# Out:
#        id certification
# 0  580489         PG-13
# 1  512195         PG-13
# 2  566525         PG-13
# 3  589761
# 4  585245            PG

# %%
# Convert ids to ints (to merge correctly)
movie_keywords_df['id'] = movie_keywords_df['id'].astype('int')
movie_details_df['id'] = movie_details_df['id'].astype('int')
movie_credits_df['id'] = movie_credits_df['id'].astype('int')
movie_certifications_df['id'] = movie_certifications_df['id'].astype('int')

# %%
# Merge keywords with details
movie_df = movie_details_df.merge(movie_keywords_df, on='id')
movie_df = movie_df.merge(movie_credits_df, on='id')
movie_df = movie_df.merge(movie_certifications_df, on='id')

# Export to save
# movie_df.to_csv("./static/data/movies_merged.csv", index=False)

# %%
movie_df.head(20)
# Out:
#     adult                     backdrop_path  \
# 0   False  /70nxSw3mFBsGmtkvcs91PbjerwD.jpg
# 1   False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg
# 2   False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
# 3   False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 4   False  /zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg
# 5   False  /g2djzUqA6mFplzC03gDk0WSyg99.jpg
# 6   False  /vIPIyTJqcgOKgKcExCvTDpLpTYW.jpg
# 7   False  /uWGPC7j70LE64nbetxQGSSYJO53.jpg
# 8   False  /r2GAjd4rNOHJh6i6Y0FntmYuPQW.jpg
# 9   False  /oE6bhqqVFyIECtBzqIuvh6JdaB5.jpg
# 10  False  /4EJSMQOM1bZPHvzqAQe87suBxdf.jpg
# 11  False  /lyvszvJJqqI8aqBJ70XzdCNoK0y.jpg
# 12  False  /lNnnhBxQESk0WbUXNeh24Dx8XA7.jpg
# 13  False  /8Y43POKjjKDGI9MH89NW0NAzzp8.jpg
# 14  False  /1zgob2Z8xVE3RZUgOKnHKcVPzOE.jpg
# 15  False  /eeijXm3553xvuFbkPFkDG6CLCbQ.jpg
# 16  False  /4gKxQIW91hOTELjY5lzjMbLoGxB.jpg
# 17  False  /qXctHIfK4LAgHH7qZiJJVCPclaY.jpg
# 18  False  /pKgfWzxOpvGV3MQ0kLjLdjKAzUe.jpg
# 19  False  /lV3UFPPxDIPelh46G9oySXN9Mcz.jpg
#
#                                 belongs_to_collection  original_budget  \
# 0   {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 1                                                None        200000000
# 2                                                None        150000000
# 3                                                None          9100000
# 4                                                None                0
# 5                                                None                0
# 6   {'id': 531241, 'name': 'Spider-Man (Avengers) ...                0
# 7                                                None                0
# 8   {'id': 645, 'name': 'James Bond Collection', '...        242000000
# 9                                                None                0
# 10                                               None           250000
# 11                                               None        200000000
# 12                                               None                0
# 13  {'id': 861415, 'name': 'Free Guy Collection', ...        110000000
# 14                                               None                0
# 15  {'id': 726871, 'name': 'Dune Collection', 'pos...        165000000
# 16                                               None                0
# 17                                               None            45223
# 18                                               None                0
# 19  {'id': 702624, 'name': 'After Collection', 'po...         14000000
#
#                                                genres  \
# 0   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 4   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 5   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 6   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 7   [{'id': 53, 'name': 'Thriller'}, {'id': 10752,...
# 8   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 9   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 10  [{'id': 10752, 'name': 'War'}, {'id': 36, 'nam...
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 12  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 13  [{'id': 35, 'name': 'Comedy'}, {'id': 28, 'nam...
# 14  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 15  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 16  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 17  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 18  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 19  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                              homepage      id     imdb_id  \
# 0                             https://www.venom.movie  580489   tt7097896
# 1           https://www.netflix.com/us/title/81161626  512195   tt7991608
# 2   https://www.marvel.com/movies/shang-chi-and-th...  566525   tt9376612
# 3                                                      589761  tt10648714
# 4                                                      585245   tt2397461
# 5                   https://movies.disney.com/encanto  568124   tt2953050
# 6                https://www.spidermannowayhome.movie  634649  tt10872600
# 7                                                      762433  tt13432484
# 8                 https://www.007.com/no-time-to-die/  370172   tt2382320
# 9   https://tv.apple.com/movie/umc.cmc.47dkj9f2ho3...  522402   tt3420504
# 10             https://www.netflix.com/title/81450071  885110  tt15847872
# 11         https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 12          https://www.netflix.com/in/title/81423086  767377  tt13510660
# 13  https://www.20thcenturystudios.com/movies/free...  550988   tt6264654
# 14  https://www.disneyplus.com/movies/the-simpsons...  877183  tt15829632
# 15                         https://www.dunemovie.com/  438631   tt1160419
# 16                                                     763164  tt13265876
# 17  https://www.disneyplus.com/movies/ciao-alberto...  876716  tt15476620
# 18            https://www.netflix.com/title/81173970/  785538  tt14168118
# 19                                                     744275  tt13069986
#
#    original_language                             original_title  ...  year  \
# 0                 en                Venom: Let There Be Carnage  ...  2021
# 1                 en                                 Red Notice  ...  2021
# 2                 en  Shang-Chi and the Legend of the Ten Rings  ...  2021
# 3                 ru                                  Чернобыль  ...  2021
# 4                 en                   Clifford the Big Red Dog  ...  2021
# 5                 en                                    Encanto  ...  2021
# 6                 en                    Spider-Man: No Way Home  ...  2021
# 7                 en                             Zeros and Ones  ...  2021
# 8                 en                             No Time to Die  ...  2021
# 9                 en                                      Finch  ...  2021
# 10                en                                      Amina  ...  2021
# 11                en                                   Eternals  ...  2021
# 12                hi                                      धमाका  ...  2021
# 13                en                                   Free Guy  ...  2021
# 14                en               The Simpsons in Plusaversary  ...  2021
# 15                en                                       Dune  ...  2021
# 16                en                                       Apex  ...  2021
# 17                en                               Ciao Alberto  ...  2021
# 18                pt                             7 Prisioneiros  ...  2021
# 19                en                              After We Fell  ...  2021
#
#     cpi_2021  cpi_old adjusted_revenue adjusted_budget   budget_bins  \
# 0    269.489  269.489      454000000.0     110000000.0   51m to 150m
# 1    269.489  269.489              0.0     200000000.0  151m to 380m
# 2    269.489  269.489      430238384.0     150000000.0   51m to 150m
# 3    269.489  269.489        5370393.0       9100000.0      1 to 15m
# 4    269.489  269.489       40000000.0             0.0           NaN
# 5    269.489  269.489       69000000.0             0.0           NaN
# 6    269.489  269.489              0.0             0.0           NaN
# 7    269.489  269.489              0.0             0.0           NaN
# 8    269.489  269.489      758000000.0     242000000.0  151m to 380m
# 9    269.489  269.489              0.0             0.0           NaN
# 10   269.489  269.489              0.0        250000.0      1 to 15m
# 11   269.489  269.489      368000000.0     200000000.0  151m to 380m
# 12   269.489  269.489              0.0             0.0           NaN
# 13   269.489  269.489      331096766.0     110000000.0   51m to 150m
# 14   269.489  269.489              0.0             0.0           NaN
# 15   269.489  269.489      368077000.0     165000000.0  151m to 380m
# 16   269.489  269.489              0.0             0.0           NaN
# 17   269.489  269.489              0.0         45223.0      1 to 15m
# 18   269.489  269.489              0.0             0.0           NaN
# 19   269.489  269.489       19000000.0      14000000.0      1 to 15m
#
#                                              keywords  \
# 0   [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 1   [{'id': 1812, 'name': 'fbi'}, {'id': 6710, 'na...
# 2   [{'id': 779, 'name': 'martial arts'}, {'id': 9...
# 3               [{'id': 210326, 'name': 'chernobyl'}]
# 4   [{'id': 818, 'name': 'based on novel or book'}...
# 5                                                  []
# 6   [{'id': 1701, 'name': 'hero'}, {'id': 5451, 'n...
# 7   [{'id': 588, 'name': 'rome, italy'}, {'id': 94...
# 8   [{'id': 470, 'name': 'spy'}, {'id': 156095, 'n...
# 9   [{'id': 14544, 'name': 'robot'}, {'id': 189092...
# 10  [{'id': 10292, 'name': 'gore'}, {'id': 13073, ...
# 11  [{'id': 3925, 'name': 'boredom'}, {'id': 6152,...
# 12  [{'id': 9714, 'name': 'remake'}, {'id': 184998...
# 13  [{'id': 282, 'name': 'video game'}, {'id': 141...
# 14  [{'id': 4552, 'name': 'beer'}, {'id': 161919, ...
# 15  [{'id': 530, 'name': 'prophecy'}, {'id': 818, ...
# 16  [{'id': 1563, 'name': 'prisoner'}, {'id': 3249...
# 17  [{'id': 658, 'name': 'sea'}, {'id': 1310, 'nam...
# 18  [{'id': 6019, 'name': 'human trafficking'}, {'...
# 19  [{'id': 818, 'name': 'based on novel or book'}...
#
#                                                  cast  \
# 0   [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 1   [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 2   [{'adult': False, 'gender': 2, 'id': 1489211, ...
# 3   [{'adult': False, 'gender': 2, 'id': 562730, '...
# 4   [{'adult': False, 'gender': 1, 'id': 1696017, ...
# 5   [{'adult': False, 'gender': 1, 'id': 968367, '...
# 6   [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 7   [{'adult': False, 'gender': 2, 'id': 569, 'kno...
# 8   [{'adult': False, 'gender': 2, 'id': 8784, 'kn...
# 9   [{'adult': False, 'gender': 2, 'id': 31, 'know...
# 10  [{'adult': False, 'gender': 0, 'id': 2010333, ...
# 11  [{'adult': False, 'gender': 1, 'id': 97576, 'k...
# 12  [{'adult': False, 'gender': 2, 'id': 1846859, ...
# 13  [{'adult': False, 'gender': 2, 'id': 10859, 'k...
# 14  [{'adult': False, 'gender': 2, 'id': 198, 'kno...
# 15  [{'adult': False, 'gender': 2, 'id': 1190668, ...
# 16  [{'adult': False, 'gender': 2, 'id': 2203, 'kn...
# 17  [{'adult': False, 'gender': 2, 'id': 1774679, ...
# 18  [{'adult': False, 'gender': 0, 'id': 2172524, ...
# 19  [{'adult': False, 'gender': 1, 'id': 1753914, ...
#
#                                                  crew certification
# 0   [{'adult': False, 'gender': 2, 'id': 149, 'kno...         PG-13
# 1   [{'adult': False, 'gender': 2, 'id': 9543, 'kn...         PG-13
# 2   [{'adult': False, 'gender': 1, 'id': 7232, 'kn...         PG-13
# 3   [{'adult': False, 'gender': 1, 'id': 30247, 'k...
# 4   [{'adult': False, 'gender': 1, 'id': 8220, 'kn...            PG
# 5   [{'adult': False, 'gender': 0, 'id': 8159, 'kn...
# 6   [{'adult': False, 'gender': 1, 'id': 2519, 'kn...         PG-13
# 7   [{'adult': False, 'gender': 1, 'id': 21342, 'k...             R
# 8   [{'adult': False, 'gender': 2, 'id': 947, 'kno...         PG-13
# 9   [{'adult': False, 'gender': 2, 'id': 24, 'know...         PG-13
# 10  [{'adult': False, 'gender': 1, 'id': 97852, 'k...         PG-13
# 11  [{'adult': False, 'gender': 2, 'id': 1722, 'kn...
# 12  [{'adult': False, 'gender': 2, 'id': 53677, 'k...
# 13  [{'adult': False, 'gender': 1, 'id': 1720, 'kn...         PG-13
# 14  [{'adult': False, 'gender': 2, 'id': 197, 'kno...
# 15  [{'adult': False, 'gender': 2, 'id': 27, 'know...
# 16  [{'adult': False, 'gender': 2, 'id': 77109, 'k...
# 17  [{'adult': False, 'gender': 2, 'id': 12890, 'k...             G
# 18  [{'adult': False, 'gender': 2, 'id': 8557, 'kn...
# 19  [{'adult': False, 'gender': 1, 'id': 20742, 'k...             R
#
# [20 rows x 35 columns]

# %% [markdown]
# ## Call Functions to Extract Details:

# %%
# Director
movie_df['director'] = movie_df['crew'].apply(get_director)

# Director Gender
movie_df['director_gender'] = movie_df['crew'].apply(get_director_gender)

# Producers
movie_df['producers'] = movie_df['crew'].apply(get_producers)

# Screenplay writers
movie_df['writers'] = movie_df['crew'].apply(get_writers)

# Cast
movie_df['cast'] = movie_df['cast'].apply(get_cast_list)

# Production Company Country of Origin
movie_df['production_company_origin'] = movie_df['production_companies'].apply(get_production_company_country)

# Spoken Languages in Movie
movie_df['spoken_languages']  = movie_df['spoken_languages'].apply(get_languages)

# Create foreign language column for if the original language was not English
movie_df['foreign_language'] = movie_df['original_language'].apply(original_language_binary)

# Get List: Keywords, genres, & production countries
features = ['keywords', 'genres', 'production_companies']

for feature in features:
    movie_df[feature] = movie_df[feature].apply(get_list)

# %%
# Show the results
movie_df[['title', 'cast', 'director', 'director_gender', 'producers', 'writers', 'keywords', 'genres', 'production_companies', 'production_company_origin', 'spoken_languages', 'original_language', 'foreign_language']].head()
# Out:
#                                        title  \
# 0                Venom: Let There Be Carnage
# 1                                 Red Notice
# 2  Shang-Chi and the Legend of the Ten Rings
# 3                             Chernobyl 1986
# 4                   Clifford the Big Red Dog
#
#                                                 cast  \
# 0  [Tom Hardy, Woody Harrelson, Michelle Williams...
# 1  [Dwayne Johnson, Ryan Reynolds, Gal Gadot, Rit...
# 2  [Simu Liu, Tony Leung Chiu-wai, Awkwafina, Men...
# 3  [Danila Kozlovsky, Oksana Akinshina, Philip Av...
# 4  [Darby Camp, Jack Whitehall, Izaac Wang, John ...
#
#                     director director_gender  \
# 0              [Andy Serkis]             [2]
# 1  [Rawson Marshall Thurber]             [2]
# 2    [Destin Daniel Cretton]             [2]
# 3         [Danila Kozlovsky]             [2]
# 4              [Walt Becker]             [2]
#
#                                            producers  \
# 0  [Tom Hardy, K.C. Hodenfield, Avi Arad, Jonatha...
# 1  [Beau Flynn, Dwayne Johnson, Rawson Marshall T...
# 2  [Kevin Feige, Charles Newirth, Louis D'Esposit...
# 3  [Danila Kozlovsky, Danila Kozlovsky, Alexandr ...
# 4  [Brad Fischer, Deborah Forte, Deborah Forte, B...
#
#                                              writers  \
# 0  [Tom Hardy, Todd McFarlane, Kelly Marcel, Kell...
# 1                          [Rawson Marshall Thurber]
# 2  [Dave Callaham, Dave Callaham, Destin Daniel C...
# 3                    [Alexey Kazakov, Elena Ivanova]
# 4  [David Ronn, Jay Scherick, Norman Bridwell, An...
#
#                                             keywords  \
# 0  [hero, anti hero, villain, sequel, superhero, ...
# 1                  [fbi, interpol, heist, art thief]
# 2  [martial arts, superhero, based on comic, mixe...
# 3                                        [chernobyl]
# 4                [based on novel or book, giant dog]
#
#                                  genres  \
# 0  [Science Fiction, Action, Adventure]
# 1     [Action, Comedy, Crime, Thriller]
# 2          [Action, Adventure, Fantasy]
# 3           [Drama, History, Adventure]
# 4           [Animation, Comedy, Family]
#
#                                 production_companies  \
# 0  [Marvel Entertainment, Pascal Pictures, Columb...
# 1  [Flynn Picture Company, Seven Bucks Production...
# 2                                   [Marvel Studios]
# 3  [Non-Stop Productions, DK Entertainment, Centr...
# 4  [Paramount, Entertainment One, Kerner Entertai...
#
#   production_company_origin             spoken_languages original_language  \
# 0      [US, US, US, US, CN]           [Spanish, English]                en
# 1            [US, US, US, ]  [English, Italian, Russian]                en
# 2                      [US]          [English, Mandarin]                en
# 3          [RU, RU, RU, RU]                    [Russian]                ru
# 4    [US, CA, , US, US, US]                    [English]                en
#
#    foreign_language
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 0

# %%
# Drop NA from selected columns
movie_df.dropna(inplace=True, how="any", subset=['genres', 'production_companies', 'keywords', 'cast'])
movie_df.dropna(inplace=True, how="any", subset=['director', 'producers', 'writers'])

# %%
len(movie_df)
# Out:
# 1683

# %%
# Clean Data: Convert all features to lowercase and remove spaces
features = ['cast', 'director', 'producers', 'writers', 'keywords', 'genres', 'production_companies']

for feature in features:
    movie_df[f"{feature}_cleaned"] = movie_df[feature].apply(clean_data)

# %%
# Call the clean overview function
movie_df['overview_cleaned'] = movie_df['overview'].apply(clean_overview)

# %%
# Create soup columns
movie_df['soup'] = movie_df.apply(create_soup, axis = 1)
movie_df['soup_overview'] = movie_df.apply(create_soup_overview, axis = 1)

# Export to save
# movie_df.to_csv("./static/data/movies_cleaned_soup.csv", index=False)

# %%
movie_df[['soup']].head(5)
# Out:
#                                                 soup
# 0  hero antihero villain sequel superhero basedon...
# 1  fbi interpol heist artthief dwaynejohnson ryan...
# 2  martialarts superhero basedoncomic mixedmartia...
# 3  chernobyl danilakozlovsky oksanaakinshina phil...
# 4  basedonnovelorbook giantdog darbycamp jackwhit...

# %% [markdown]
# ## Configuration for Posters:

# %%
configuration_url = f"https://api.themoviedb.org/3/configuration?api_key={api_key}"
config_response = requests.get(configuration_url).json()
# config_response

# %%
# Get images structure
images_url = config_response['images']
# Get Base URL
secure_base_url = images_url['secure_base_url']
# secure_base_url

# %%
# Get the size of poster: 2: w185px, 4: w500px, 5: 780px
# images_url['poster_sizes']
poster_size = images_url['poster_sizes'][5]
# poster_size

# %%
# Copy poster paths to new df
poster_df = movie_df[['poster_path']].copy()

# %%
# Create column with full image path for posters
poster_df['poster_url'] = secure_base_url + poster_size + poster_df['poster_path']

# %%
# Export to separate csv
# poster_df.to_csv("./static/data/poster_path.csv", index=False)
poster_df.head()
# Out:
#                         poster_path  \
# 0  /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg
# 1  /wdE6ewaKZHr62bLqCn7A2DiGShm.jpg
# 2  /1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg
# 3  /kfQJQWFEoWRVBH8FUKnT0HX1yRS.jpg
# 4  /ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg
#
#                                           poster_url
# 0  https://image.tmdb.org/t/p/w780/rjkmN1dniUHVYA...
# 1  https://image.tmdb.org/t/p/w780/wdE6ewaKZHr62b...
# 2  https://image.tmdb.org/t/p/w780/1BIoJGKbXjdFDA...
# 3  https://image.tmdb.org/t/p/w780/kfQJQWFEoWRVBH...
# 4  https://image.tmdb.org/t/p/w780/ygPTrycbMSFDc5...

# %%
# Create column with full image path for posters (in real df this time)
movie_df['poster_url'] = secure_base_url + poster_size + movie_df['poster_path']

# %% [markdown]
# # TESTING

# %% [raw]
# movie_df = pd.read_csv("./static/data/movie_db.csv")

# %% [raw]
# # Converts strings into lists or dictionaries
# from ast import literal_eval
#
# # Selected features to apply function to
# features = ['cast', 'director', 'producers', 'writers', 'keywords', 'genres', 'production_companies']
#
# for feature in features:
#     movie_df[f"{feature}_cleaned"] = movie_df[f"{feature}_cleaned"].apply(literal_eval)

# %% [markdown]
# ## Export CSV:

# %%
# Create a lowercase column for easier search
movie_df["lowercase_title"] = movie_df['title'].apply(lambda x: x.lower())

# %%
# Save file - used for calling for information
movie_df.to_csv("../static/data/movie_db.csv", index=False)

# %%
movie_df.head()

# %% [markdown]
# # Machine Learning Recommender:

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Use Count Vectorizer to create counts for each word
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(movie_df['soup_overview'])

# %%
count_matrix.shape

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset the index
# movie_df = movie_df.reset_index()
# Create series with index & titles of movies
indices = pd.Series(movie_df.index, index=movie_df['title']).drop_duplicates()

# %%
movie_df.head()

# %% [markdown]
# ## Function to Recommend Titles:

# %%
def get_similarity_scores(title, cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]
    
    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the most similar movies
    sim_scores = sim_scores[1:11]
#     print(sim_scores)
    
    # Convert list to DataFrame
    sim_scores_df = pd.DataFrame(sim_scores, columns = ["index", "similarity_score"])
    
    # Return top 10 most similar scores
    return sim_scores_df

# %%
def get_recommendations(original_df, score_df):
    original_df = original_df.merge(score_df, on="index")
    original_df = original_df.sort_values("similarity_score", ascending=False)
    
    return original_df

# %%
# Test out function
movie_title = "Get Out"
similarity_scores_df = get_similarity_scores(movie_title, cosine_sim)

# %%
# Call Get Recommendations Function
recommendations = get_recommendations(movie_df, similarity_scores_df)

# %%
# Print out dataframe
# recommendations[['title', 'similarity_score']].to_csv("./soup_test_3.csv")
recommendations[['title', 'similarity_score', 'id']].head(10)

# %% [markdown]
# ## Database:

# %%
from sqlalchemy import create_engine, inspect

# %%
# configure the connection string
rds_connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
        
# connect to the database
engine = create_engine(rds_connection_string)
conn = engine.connect()

# %%
engine.execute("DROP TABLE movies")

# %%
# Append data to table
movie_df.to_sql(name='movies', con=conn, if_exists='append', index=False)

# %%
# Use inspector to find table names
Inspector = inspect(engine)
Inspector.get_table_names()

# %%
# Check movies table
pd.read_sql_query('select * from movies', con=conn).head()
