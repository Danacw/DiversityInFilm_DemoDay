# %% [markdown]
# # The Movie Database: Data Extraction & Cleaning

# %%
#  %pip install cpi

# %%
# Import dependencies
import pandas as pd
import json
import requests
from pprint import pprint
import numpy as np
import cpi

from datetime import datetime

# Import config
from config import api_key, db_user, db_password, db_host, db_port, db_name
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/cpi/__init__.py:46: StaleDataWarning: CPI data is out of date. To accurately inflate to today's dollars, you must run `cpi.update()`.
#   warnings.warn(StaleDataWarning())

# %%
cpi.update()

# %% [markdown]
# ### Testing:

# %%
# Single Test: Discover Most Popular Movies
page_number = 1

# Endpoint for finding most popular movies
discover_movies = "https://api.themoviedb.org/3/discover/movie"
most_popular_url = f"{discover_movies}?api_key={api_key}&page={page_number}&sort_by=popularity.desc"

# Most popular movies
tmdb_response = requests.get(most_popular_url).json()
results = tmdb_response["results"]

json_string = json.dumps(results)
df = pd.read_json(json_string)
df
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg   [16, 35, 10751, 10402]  438695
# 1   False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg             [35, 14, 12]  425909
# 2   False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg            [28, 12, 878]  634649
# 3   False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg      [16, 35, 10751, 14]  568124
# 4   False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg            [27, 28, 878]  460458
# 5   False  /eNI7PtK6DEYgZmHWP9gQNuff8pv.jpg            [878, 28, 12]  624860
# 6   False  /vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg            [878, 28, 12]  580489
# 7   False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg         [28, 35, 80, 53]  512195
# 8   False  /lyvszvJJqqI8aqBJ70XzdCNoK0y.jpg        [28, 12, 14, 878]  524434
# 9   False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg             [28, 12, 14]  566525
# 10  False  /srDyClcl2J0L3ZP9tpahwoTcNxj.jpg             [28, 53, 80]  787310
# 11  False  /1BqX34aJS5J8PefVnQSfQIEPfkl.jpg             [80, 28, 53]  826749
# 12  False  /xPpXYnCWfjkt3zzE0dpCNME1pXF.jpg         [16, 28, 12, 14]  635302
# 13  False  /1Wlwnhn5sXUIwlxpJgWszT622PS.jpg          [16, 35, 10751]  585245
# 14  False  /8rft8A9nH43IReybFtYt21ezfMK.jpg                     [99]  899082
# 15  False  /7h5WAPAcUzOWpp2jrwHBB48790j.jpg                 [16, 14]  843241
# 16  False  /sLWUtbrpiLp23a0XDSiUiltdFPJ.jpg             [28, 12, 14]    1930
# 17  False  /weneJTnAb1IFI94SKcaXzBFmPKH.jpg         [80, 53, 18, 28]  818192
# 18  False  /qBLEWvJNVsehJkEJqIigPsWyBse.jpg  [10751, 16, 14, 35, 12]  585083
# 19  False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg             [18, 36, 12]  589761
#
#    original_language                                     original_title  \
# 13  /oifhfVhUcuDjE61V5bS5dfShQrm.jpg   2021-11-10
# 14  /jntLBq0MLR3hrwKaTQswxACRPMs.jpg   2022-01-01
# 15  /k0ThmZQl5nHe4JefC2bXjqtgYp0.jpg   2021-07-02
# 16  /fSbqPbqXa7ePo8bcnZYN9AHv6zA.jpg   2012-06-23
# 17  /etMxKseW67499tUJonLNHXTF538.jpg   2021-11-05
# 18  /6zt5l4DYV1kLPL5Vqz1kLq3THXD.jpg   2022-01-14
# 19  /AmJLuHjxPdIJO6vmymeWADG6jK5.jpg   2021-04-15
#
#                                                 title  video  vote_average  \
# 0                                              Sing 2  False           7.5
# 1                             Ghostbusters: Afterlife  False           7.2
# 2                             Spider-Man: No Way Home  False           8.4
# 3                                             Encanto  False           7.8
# 4              Resident Evil: Welcome to Raccoon City  False           6.0
# 5                            The Matrix Resurrections  False           7.0
# 6                         Venom: Let There Be Carnage  False           7.2
# 7                                          Red Notice  False           6.8
# 8                                            Eternals  False           7.1
# 9           Shang-Chi and the Legend of the Ten Rings  False           7.8
# 10                                   Survive the Game  False           5.9
# 11                                           Fortress  False           6.3
# 12  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...  False           8.4
# 13                           Clifford the Big Red Dog  False           7.4
# 14  Harry Potter 20th Anniversary: Return to Hogwarts  False           8.4
# 15             The Seven Deadly Sins: Cursed by Light  False           8.0
# 16                             The Amazing Spider-Man  False           6.6
# 17                                            Ida Red  False           6.0
# 18                  Hotel Transylvania: Transformania  False           6.0
# 19                                   Chernobyl: Abyss  False           6.3
#
#     vote_count
# 0          264
# 1          753
# 2         4020
# 3         2616
# 4          824
# 5         2056
# 6         5749
# 7         2611
# 8         1726
# 9         5058
# 10          75
# 11         102
# 12        2018
# 13         862
# 14         680
# 15         275
# 16       14242
# 17          20
# 18           2
# 19         264

# %%
#Single Test: Crew
movie_id = 672582

# Endpoint & response
movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
movie_response = requests.get(movie_url).json()

pprint(movie_response)
# Out:
# {'adult': False,
#  'backdrop_path': '/yL9RRZbDVbptqLwiZcK304ck4PL.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 27, 'name': 'Horror'}],
#  'homepage': '',
#  'id': 672582,
#  'imdb_id': 'tt11686490',
#  'original_language': 'en',
#  'original_title': 'The Deep House',
#  'overview': 'While diving in a remote French lake, a couple of YouTubers who '
#              'specialize in underwater exploration videos discover a house '
#              'submerged in the deep waters. What was initially a unique '
#              'finding soon turns into a nightmare when they discover that the '
#              'house was the scene of atrocious crimes. Trapped, with their '
#              'oxygen reserves falling dangerously, they realize the worst is '
#              'yet to come: they are not alone in the house.',
#  'popularity': 387.29,
#  'poster_path': '/5xhAPxRr64oQPEFnUOrttuI4ZEU.jpg',
#  'production_companies': [{'id': 12689,
#                            'logo_path': None,
#                            'name': 'Radar Films',
#                            'origin_country': 'FR'},
#                           {'id': 92840,
#                            'logo_path': None,
#                            'name': 'Logical Pictures',
#                            'origin_country': 'FR'},
#                           {'id': 49755,
#                            'logo_path': '/iom7Z8e1dzoTfCvwq8F4bJvbeIJ.png',
#                            'name': 'Apollo Films',
#                            'origin_country': 'FR'},
#                           {'id': 19037,
#                            'logo_path': '/tceh2aAORA5JxIZSLQ1GkzTBZDL.png',
#                            'name': 'uMedia',
#                            'origin_country': 'BE'},
#                           {'id': 12686,
#                            'logo_path': None,
#                            'name': 'Forecast Pictures',
#                            'origin_country': ''},
#                           {'id': 78299,
#                            'logo_path': None,
#                            'name': 'Screen Flanders',
#                            'origin_country': 'BE'},
#                           {'id': 11620,
#                            'logo_path': '/f3hRdCaK1w9qH1Qs8nLd2L2bae1.png',
#                            'name': 'OCS',
#                            'origin_country': 'FR'},
#                           {'id': 12352,
#                            'logo_path': '/fkIacb6MddD6trIWamr33SIcUAn.png',
#                            'name': 'Wallimage',
#                            'origin_country': 'BE'},
#                           {'id': 114955,
#                            'logo_path': None,
#                            'name': 'Tax Shelter du Gouvernement Fédéral Belge',
#                            'origin_country': 'BE'},
#                           {'id': 102877,
#                            'logo_path': '/zjkjypyhDQA0dNCv8WzIzEmqAQk.png',
#                            'name': 'Investisseurs Tax Shelter',
#                            'origin_country': 'BE'},
#                           {'id': 310,
#                            'logo_path': '/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png',
#                            'name': 'CNC',
#                            'origin_country': 'FR'}],
#  'production_countries': [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#                           {'iso_3166_1': 'FR', 'name': 'France'}],
#  'release_date': '2021-06-30',
#  'revenue': 0,
#  'runtime': 85,
#  'spoken_languages': [{'english_name': 'French',
#                        'iso_639_1': 'fr',
#                        'name': 'Français'},
#                       {'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'Portuguese',
#                        'iso_639_1': 'pt',
#                        'name': 'Português'}],
#  'status': 'Released',
#  'tagline': 'Breathe while you still can.',
#  'title': 'The Deep House',
#  'video': False,
#  'vote_average': 6.5,
#  'vote_count': 427}

# %% [raw]
# # Single Test: Movie Details
# movie_id = 672582
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [raw]
# # Single Test: Credits
# # movie_id = 566525
# movie_id = 284052
#
# movie_credits = f"/movie/{movie_id}/credits"
# credits_url = f"https://api.themoviedb.org/3/{movie_credits}?api_key={api_key}"
#
# # Get the json response for the credits
# credits_response = requests.get(credits_url).json()
# pprint(credits_response)

# %% [raw]
# # Find job names for Writing Department
# for i in credits_response['crew']:
#     if i['department'] == 'Writing':
#         name = i['name']
#         job = i['job']
#         print(f"{name}: {job}")

# %% [raw]
# # Single Test: Movie Recommendations
# movie_id = 32657
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}/recommendations?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [raw]
# # Single Test: Movie Release Date/Certifications
# movie_id = 32657
#
# # Endpoint & response
# movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}/release_dates?api_key={api_key}"
# movie_response = requests.get(movie_url).json()
#
# pprint(movie_response)

# %% [markdown]
# # Functions: Define API calls to extract key data points

# %%
# Start Timer Function (check on API call performance)
def start_timer():
    start = datetime.now()
    
    return start

# %%
# Stop Timer Function (check on API call performance)
def stop_timer(start):
    end = datetime.now()
    elapsed_time = (end - start)

    print(f"Total Time Elapsed:  {elapsed_time.total_seconds()} seconds")

# %% [markdown]
# ### API CALLS:

# %%
# Returns most popular movies
def get_most_popular_movies(api_key):
    
    movies = []
    
    # Loop through pages to get results for movies
    for x in range(1, 301):
        page_number = x

        # Endpoint for finding most popular movies
        discover_movies = "https://api.themoviedb.org/3/discover/movie"
        most_popular_url = f"{discover_movies}?api_key={api_key}&page={page_number}&sort_by=popularity.desc"
        
        # Most popular movies
        tmdb_response = requests.get(most_popular_url).json()
        results = tmdb_response["results"]

#         for y in range(len(results)):
#             movies.append(results[y]) 
        for result in results:
            movies.append(result)
            
    return movies

# %%
# Returns movie details as a list
def get_movie_details(api_key, movie_ids):  
    
    movie_details = []
    
    for movie_id in movie_ids:
        # Endpoint & response
        movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
        movie_response = requests.get(movie_url).json()

        # Append results to lists
        movie_details.append(movie_response)
        
    return movie_details

# %%
# Returns keywords as a list
def get_movie_keywords(api_key, movie_ids):
    keyword_details = []
    
    for movie_id in movie_ids:
        # Get keywords for each movie
        keywords_url = f"https://api.themoviedb.org/3/movie/{movie_id}/keywords?api_key={api_key}"
        keywords_response = requests.get(keywords_url).json()
        keywords_results = keywords_response["keywords"]
        
         # Append results to lists
        keyword_details.append(keywords_response)
        
    return keyword_details

# %%
# Returns credits as a list
def get_credits(api_key, movie_ids):
    credit_details = []
    
    for movie_id in movie_ids:
        # Generate movie credits
        movie_credits = f"/movie/{movie_id}/credits"
        credits_url = f"https://api.themoviedb.org/3/{movie_credits}?api_key={api_key}"

        # Get the json response for the credits
        credits_response = requests.get(credits_url).json()
        
        credit_details.append(credits_response)
        
    return credit_details

# %%
# Returns certifications as a list (rating: G, PG, etc.)
def get_certifications(api_key, movie_ids):
    certifications = []
    
    for movie_id in movie_ids:
        # Get certifications for each movie
        certification_url = f"https://api.themoviedb.org/3/movie/{movie_id}/release_dates?api_key={api_key}"
        
        certification_response = requests.get(certification_url).json()
        
        certifications.append(certification_response)
        
    return certifications

# %% [markdown]
# ### GET TITLES & IDS:

# %%
# Returns single title for specified index number
def get_title(results, idx):
    movie_title = results[idx]["title"]
    
    return movie_title

# %%
# Returns ids list
def get_ids(results):
    movie_ids = []
    for x in results:
        movie_ids.append(x["id"])
        
    return movie_ids

# %%
# Returns titles list
def get_titles(results):
    movie_titles = []
    for x in results:
        movie_titles.append(x["title"])
        
    return movie_titles

# %% [markdown]
# ### EXTRACT NEEDED DETAILS FROM COLUMNS: Cast, Crew, Gender, Production Countries etc.

# %%
# Extract the certification (ratings)
def extract_certification(x):
    name = ""
    
    for i in x:
        # Get ratings for US
        if i['iso_3166_1'] == 'US':
             # Append results to lists
            name = i['release_dates'][0]['certification']
            break
    return name

# %%
# Function to get the director out of the crew
def get_director(x):
    names = []
    
    for i in x:
        if i['job'] == 'Director':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the director gender out of the crew
def get_director_gender(x):
    names = []
    
    for i in x:
        if i['job'] == 'Director':
            gender = i['gender']
            names.append(gender)
            
    if(names):
        return names
    
    return np.nan

# %%
def fm_percentage(results):
    fm_count = 0
    total_count = 0
    for x in results:
        if x['gender'] == 1:
            fm_count += 1
        if x['gender'] == 1 or x['gender'] == 2:
            total_count += 1
    
    if total_count == 0:        
        return np.nan
            
    return percentage_format(100 * fm_count/total_count)

# %%
# Function to get the producers out of the crew
def get_producers(x):
    names = []
    
    for i in x:
        if i['job'] == 'Producer':
            name = i['name']
            names.append(name)
        elif i['job'] == "Executive Producer":
            name = i['name']
            names.append(name)
        elif i['job'] == 'Co-Producer':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to get the screenplay writers out of the crew
def get_writers(x):
    names = []
    for i in x:
        if i['department'] == 'Writing':
            name = i['name']
            names.append(name)
            
    if(names):
        return names
    
    return np.nan

# %%
# Function to create cast list
def get_cast_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        
        # Condition for cast (keep top 5)
        if len(names) > 5:
            names = names[:5]
        return names

    return []

# %%
# Function to create lists of each feature
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        return names
        
    return []

# %%
# Function to get production companies
def get_production_companies(x):
    names = []
    if isinstance(x, list):
        for i in x:
            name = i['name']
            names.append(name)
        return names
        
    return []

# %%
# Get each production company's country of origin
def get_production_company_country(x):
    names = []
    if isinstance(x, list):
        for i in x:
            country = i['origin_country']
            names.append(country)
        return names
    return []

# %%
# Get list of all languages available for film
def get_languages(x):
    names = []
    for i in x:
        name = i['english_name']
#         iso = i['iso_639_1']
        names.append(name)
    
    if(names):
        return names
    
    return np.nan

# %%
# Create binary column for foreign language films
def original_language_binary(x):
    if (x == 'en'):
        return 0
    elif (x != 'en'):
        return 1
    elif (x == "" | x == " "):
        return 0
    else:
        return 0

# %%
def percentage_format(percentage):
    return "{:,.2f}%".format(percentage)

# %% [markdown]
# ### CLEAN DATA FOR SOUP & CREATE SOUP: Used for Machine Learning

# %%
# Convert all strings to lower case and strip names of spaces
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else: 
            return ''

# %%
# Clean the overview column (by converting to lowercase)
def clean_overview(x):
    if isinstance(x, str):
        return x.lower()
    else: 
        return ''

# %%
# Create soup of words
def create_soup(x):
    space = ' '
    return (space.join(x['keywords_cleaned']) + space + space.join(x['cast_cleaned']) + space 
            + space.join(x['director_cleaned']) + space + space.join(x['producers_cleaned']) + space 
            + space.join(x['writers_cleaned']) + space + space.join(x['genres_cleaned']) + space 
            + space.join(x['production_companies_cleaned']))

# %%
# Create soup of words - 2 keywords, 2 genres & overview
def create_soup_overview(x):
    space = ' '
    return (space.join(x['keywords_cleaned']) + space + space.join(x['keywords_cleaned']) + space 
            + space.join(x['cast_cleaned']) + space + space.join(x['director_cleaned']) + space 
            + space.join(x['producers_cleaned']) + space + space.join(x['writers_cleaned']) + space 
            + space.join(x['genres_cleaned']) + space + space.join(x['genres_cleaned']) + space 
            + space.join(x['production_companies_cleaned']) + space + x['overview_cleaned'])

# %% [markdown]
# # CALL API

# %% [markdown]
# ### Get Most Popular Movies JSON Results:

# %%
# Start the timer
start = start_timer()

# %%
most_popular_movies = get_most_popular_movies(api_key)
# print(most_popular_movies)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  98.044416 seconds

# %% [markdown]
# ### List of Movie IDs:

# %%
movie_ids = get_ids(most_popular_movies)
#print(movie_ids)

# %%
len(movie_ids)
# Out:
# 6000

# %% [markdown]
# ### List of Titles:

# %%
titles = get_titles(most_popular_movies)
# print(titles)

# %%
len(titles)
# Out:
# 6000

# %% [markdown]
# ### Print Individual Title:

# %%
print(get_title(most_popular_movies, 0))
# Out:
# Sing 2

# %% [markdown]
# ### Get Movie Details:

# %%
# Start the timer
start = start_timer()

# %%
details = get_movie_details(api_key, movie_ids)

# %%
pprint(details[0:10])
# Out:
# [{'adult': False,
#   'backdrop_path': '/70nxSw3mFBsGmtkvcs91PbjerwD.jpg',
#   'belongs_to_collection': {'backdrop_path': '/rhLspFB1B8ZCkWEHFYmc3NKagzq.jpg',
#                             'id': 558216,
#                             'name': 'Venom Collection',
#                             'poster_path': '/670x9sf0Ru8y6ezBggmYudx61yB.jpg'},
#   'budget': 110000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#              {'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.venom.movie',
#   'id': 580489,
#   'imdb_id': 'tt7097896',
#   'original_language': 'en',
#   'original_title': 'Venom: Let There Be Carnage',
#   'overview': 'After finding a host body in investigative reporter Eddie '
#               'Brock, the alien symbiote must face a new enemy, Carnage, the '
#               'alter ego of serial killer Cletus Kasady.',
#   'popularity': 8633.976,
#   'poster_path': '/rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg',
#   'production_companies': [{'id': 7505,
#                             'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png',
#                             'name': 'Marvel Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'},
#                            {'id': 84041,
#                             'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png',
#                             'name': 'Pascal Pictures',
#                             'origin_country': 'US'},
#                            {'id': 53462,
#                             'logo_path': None,
#                             'name': 'Matt Tolmach Productions',
#                             'origin_country': 'US'},
#                            {'id': 166230,
#                             'logo_path': None,
#                             'name': 'Avi Arad Productions',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-09-30',
#   'revenue': 482000000,
#   'runtime': 97,
#   'spoken_languages': [{'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'},
#                        {'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Venom: Let There Be Carnage',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 4421},
#  {'adult': False,
#   'backdrop_path': '/5uVhMGsps81CN0S4U9NF0Z4tytG.jpg',
#   'belongs_to_collection': None,
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 80, 'name': 'Crime'},
#              {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.netflix.com/us/title/81161626',
#   'id': 512195,
#   'imdb_id': 'tt7991608',
#   'original_language': 'en',
#   'original_title': 'Red Notice',
#   'overview': 'An Interpol-issued Red Notice is a global alert to hunt and '
#               "capture the world's most wanted. But when a daring heist brings "
#               "together the FBI's top profiler and two rival criminals, "
#               "there's no telling what will happen.",
#   'popularity': 4825.133,
#   'poster_path': '/q2d56YvJ3s9W73lqrk16Nzcc7xD.jpg',
#   'production_companies': [{'id': 34081,
#                             'logo_path': None,
#                             'name': 'Flynn Picture Company',
#                             'origin_country': 'US'},
#                            {'id': 73669,
#                             'logo_path': '/7tmSGstK3KwgcDIuBYLTAayjit9.png',
#                             'name': 'Seven Bucks Productions',
#                             'origin_country': 'US'},
#                            {'id': 923,
#                             'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png',
#                             'name': 'Legendary Pictures',
#                             'origin_country': 'US'},
#                            {'id': 102182,
#                             'logo_path': None,
#                             'name': 'Bad Version, Inc.',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-04',
#   'revenue': 0,
#   'runtime': 117,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Italian',
#                         'iso_639_1': 'it',
#                         'name': 'Italiano'},
#                        {'english_name': 'Russian',
#                         'iso_639_1': 'ru',
#                         'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'Pro and cons.',
#   'title': 'Red Notice',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 1982},
#  {'adult': False,
#   'backdrop_path': '/zBkHCpLmHjW2uVURs5uZkaVmgKR.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 10751, 'name': 'Family'}],
#   'homepage': '',
#   'id': 585245,
#   'imdb_id': 'tt2397461',
#   'original_language': 'en',
#   'original_title': 'Clifford the Big Red Dog',
#   'overview': 'As Emily struggles to fit in at home and at school, she '
#               'discovers a small red puppy who is destined to become her best '
#               'friend. When Clifford magically undergoes one heck of a growth '
#               'spurt, becomes a gigantic dog and attracts the attention of a '
#               'genetics company, Emily and her Uncle Casey have to fight the '
#               'forces of greed as they go on the run across New York City. '
#               'Along the way, Clifford affects the lives of everyone around '
#               'him and teaches Emily and her uncle the true meaning of '
#               'acceptance and unconditional love.',
#   'popularity': 3280.16,
#   'poster_path': '/ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg',
#   'production_companies': [{'id': 4,
#                             'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png',
#                             'name': 'Paramount',
#                             'origin_country': 'US'},
#                            {'id': 8147,
#                             'logo_path': '/q6HOAdSNgCbeOqwoMVRc6REgbXF.png',
#                             'name': 'Entertainment One',
#                             'origin_country': 'CA'},
#                            {'id': 7311,
#                             'logo_path': None,
#                             'name': 'Kerner Entertainment Company',
#                             'origin_country': ''},
#                            {'id': 30246,
#                             'logo_path': None,
#                             'name': 'Scholastic Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 114732,
#                             'logo_path': '/tNCbisMxO5mX2X2bOQxHHQZVYnT.png',
#                             'name': 'New Republic Pictures',
#                             'origin_country': 'US'},
#                            {'id': 10221,
#                             'logo_path': '/99VfWRgKasZoyK9UVB39gnYvFrZ.png',
#                             'name': 'Walden Media',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'},
#                            {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-10',
#   'revenue': 51000000,
#   'runtime': 97,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Adventure has never been bigger.',
#   'title': 'Clifford the Big Red Dog',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 540},
#  {'adult': False,
#   'backdrop_path': '/mFbS5TwN95BcSEfiztdchLgTQ0v.jpg',
#   'belongs_to_collection': None,
#   'budget': 100000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 18, 'name': 'Drama'},
#              {'id': 36, 'name': 'History'}],
#   'homepage': 'https://www.20thcenturystudios.com/movies/the-last-duel',
#   'id': 617653,
#   'imdb_id': 'tt4244994',
#   'original_language': 'en',
#   'original_title': 'The Last Duel',
#   'overview': 'King Charles VI declares that Knight Jean de Carrouges settle '
#               'his dispute with his squire, Jacques Le Gris, by challenging '
#               'him to a duel.',
#   'popularity': 3256.364,
#   'poster_path': '/zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg',
#   'production_companies': [{'id': 127928,
#                             'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#                             'name': '20th Century Studios',
#                             'origin_country': 'US'},
#                            {'id': 1645,
#                             'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png',
#                             'name': 'Scott Free Productions',
#                             'origin_country': 'GB'},
#                            {'id': 29313,
#                             'logo_path': '/1whsMqm5kAPxKBhnTlKNcbXBQJK.png',
#                             'name': 'Pearl Street Films',
#                             'origin_country': 'US'},
#                            {'id': 22213,
#                             'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png',
#                             'name': 'TSG Entertainment',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-10-13',
#   'revenue': 27000000,
#   'runtime': 152,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'French',
#                         'iso_639_1': 'fr',
#                         'name': 'Français'},
#                        {'english_name': 'Latin',
#                         'iso_639_1': 'la',
#                         'name': 'Latin'}],
#   'status': 'Released',
#   'tagline': 'The true story of a woman who defied a nation and made history.',
#   'title': 'The Last Duel',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 885},
#  {'adult': False,
#   'backdrop_path': '/cinER0ESG0eJ49kXlExM0MEWGxW.jpg',
#   'belongs_to_collection': {'backdrop_path': None,
#                             'id': 912503,
#                             'name': 'Shang-Chi Collection',
#                             'poster_path': None},
#   'budget': 150000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://www.marvel.com/movies/shang-chi-and-the-legend-of-the-ten-rings',
#   'id': 566525,
#   'imdb_id': 'tt9376612',
#   'original_language': 'en',
#   'original_title': 'Shang-Chi and the Legend of the Ten Rings',
#   'overview': 'Shang-Chi must confront the past he thought he left behind when '
#               'he is drawn into the web of the mysterious Ten Rings '
#               'organization.',
#   'popularity': 3189.442,
#   'poster_path': '/1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg',
#   'production_companies': [{'id': 420,
#                             'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#                             'name': 'Marvel Studios',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-09-01',
#   'revenue': 430238384,
#   'runtime': 132,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Mandarin',
#                         'iso_639_1': 'zh',
#                         'name': '普通话'}],
#   'status': 'Released',
#   'tagline': "You can't outrun your destiny.",
#   'title': 'Shang-Chi and the Legend of the Ten Rings',
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 4211},
#  {'adult': False,
#   'backdrop_path': '/g2djzUqA6mFplzC03gDk0WSyg99.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#              {'id': 16, 'name': 'Animation'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 10751, 'name': 'Family'},
#              {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://movies.disney.com/encanto',
#   'id': 568124,
#   'imdb_id': 'tt2953050',
#   'original_language': 'en',
#   'original_title': 'Encanto',
#   'overview': 'The tale of an extraordinary family, the Madrigals, who live '
#               'hidden in the mountains of Colombia, in a magical house, in a '
#               'vibrant town, in a wondrous, charmed place called an Encanto. '
#               'The magic of the Encanto has blessed every child in the family '
#               'with a unique gift from super strength to the power to '
#               'heal—every child except one, Mirabel. But when she discovers '
#               'that the magic surrounding the Encanto is in danger, Mirabel '
#               'decides that she, the only ordinary Madrigal, might just be her '
#               "exceptional family's last hope.",
#   'popularity': 2989.673,
#   'poster_path': '/4j0PNHkMr5ax3IA8tjtxcmPU3QT.jpg',
#   'production_companies': [{'id': 6125,
#                             'logo_path': '/tVPmo07IHhBs4HuilrcV0yujsZ9.png',
#                             'name': 'Walt Disney Animation Studios',
#                             'origin_country': 'US'},
#                            {'id': 2,
#                             'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#                             'name': 'Walt Disney Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-11-24',
#   'revenue': 151000000,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'}],
#   'status': 'Released',
#   'tagline': "There's a little magic in all of us ...almost all of us.",
#   'title': 'Encanto',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 313},
#  {'adult': False,
#   'backdrop_path': '/VlHt27nCqOuTnuX6bku8QZapzO.jpg',
#   'belongs_to_collection': {'backdrop_path': '/AvnqpRwlEaYNVL6wzC4RN94EdSd.jpg',
#                             'id': 531241,
#                             'name': 'Spider-Man (Avengers) Collection',
#                             'poster_path': '/nogV4th2P5QWYvQIMiWHj4CFLU9.jpg'},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.spidermannowayhome.movie',
#   'id': 634649,
#   'imdb_id': 'tt10872600',
#   'original_language': 'en',
#   'original_title': 'Spider-Man: No Way Home',
#   'overview': 'Peter Parker is unmasked and no longer able to separate his '
#               'normal life from the high-stakes of being a super-hero. When he '
#               'asks for help from Doctor Strange the stakes become even more '
#               'dangerous, forcing him to discover what it truly means to be '
#               'Spider-Man.',
#   'popularity': 2774.306,
#   'poster_path': '/1g0dhYtq4irTY1GPXvft6k4YLjm.jpg',
#   'production_companies': [{'id': 420,
#                             'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#                             'name': 'Marvel Studios',
#                             'origin_country': 'US'},
#                            {'id': 84041,
#                             'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png',
#                             'name': 'Pascal Pictures',
#                             'origin_country': 'US'},
#                            {'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-12-15',
#   'revenue': 0,
#   'runtime': 148,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The Multiverse unleashed.',
#   'title': 'Spider-Man: No Way Home',
#   'video': False,
#   'vote_average': 8.4,
#   'vote_count': 44},
#  {'adult': False,
#   'backdrop_path': '/iUeeZ5PWfZGgUtCJfwcgmCfdzoI.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#              {'id': 878, 'name': 'Science Fiction'},
#              {'id': 10751, 'name': 'Family'},
#              {'id': 35, 'name': 'Comedy'}],
#   'homepage': 'https://family.20thcenturystudios.com/movies/rons-gone-wrong',
#   'id': 482321,
#   'imdb_id': 'tt7504818',
#   'original_language': 'en',
#   'original_title': "Ron's Gone Wrong",
#   'overview': 'In a world where walking, talking, digitally connected bots '
#               "have become children's best friends, an 11-year-old finds that "
#               "his robot buddy doesn't quite work the same as the others do.",
#   'popularity': 2662.308,
#   'poster_path': '/gA9QxSravC2EVEkEKgyEmDrfL0e.jpg',
#   'production_companies': [{'id': 121605,
#                             'logo_path': '/4rc0vsJWygNm9ojrxSdPVU9jKyj.png',
#                             'name': 'Locksmith Animation',
#                             'origin_country': 'GB'},
#                            {'id': 127928,
#                             'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#                             'name': '20th Century Studios',
#                             'origin_country': 'US'},
#                            {'id': 141821,
#                             'logo_path': '/dvIQq8TmQJydp9BzBCVyNZBlOnA.png',
#                             'name': '20th Century Animation',
#                             'origin_country': 'US'},
#                            {'id': 22213,
#                             'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png',
#                             'name': 'TSG Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 107183,
#                             'logo_path': None,
#                             'name': 'Double Negative (DNEG)',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-10-15',
#   'revenue': 57000000,
#   'runtime': 106,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Best Friend Forever* (*battery life may vary)',
#   'title': "Ron's Gone Wrong",
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 330},
#  {'adult': False,
#   'backdrop_path': '/xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg',
#   'belongs_to_collection': None,
#   'budget': 9100000,
#   'genres': [{'id': 18, 'name': 'Drama'},
#              {'id': 36, 'name': 'History'},
#              {'id': 12, 'name': 'Adventure'}],
#   'homepage': '',
#   'id': 589761,
#   'imdb_id': 'tt10648714',
#   'original_language': 'ru',
#   'original_title': 'Чернобыль',
#   'overview': 'The aftermath of a shocking explosion at the Chernobyl nuclear '
#               'power station made hundreds of people sacrifice their lives to '
#               'clean up the site of the catastrophe and to successfully '
#               'prevent an even bigger disaster that could have turned a large '
#               'part of the European continent into an uninhabitable exclusion '
#               'zone. This is their story.',
#   'popularity': 2438.508,
#   'poster_path': '/kfQJQWFEoWRVBH8FUKnT0HX1yRS.jpg',
#   'production_companies': [{'id': 5630,
#                             'logo_path': '/s0mHCw53fp6EAapR7g0dwYbz0l5.png',
#                             'name': 'Non-Stop Productions',
#                             'origin_country': 'RU'},
#                            {'id': 103131,
#                             'logo_path': None,
#                             'name': 'DK Entertainment',
#                             'origin_country': 'RU'},
#                            {'id': 3419,
#                             'logo_path': '/byrxE2pJD9JLyBCIzyK0pYVanyG.png',
#                             'name': 'Central Partnership',
#                             'origin_country': 'RU'},
#                            {'id': 99796,
#                             'logo_path': '/86PJsqqWyGhpZdcq6DbtD35tJeQ.png',
#                             'name': 'KIT Film Studio',
#                             'origin_country': 'RU'}],
#   'production_countries': [{'iso_3166_1': 'RU', 'name': 'Russia'}],
#   'release_date': '2021-04-15',
#   'revenue': 5370393,
#   'runtime': 136,
#   'spoken_languages': [{'english_name': 'Russian',
#                         'iso_639_1': 'ru',
#                         'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Chernobyl: Abyss',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 235},
#  {'adult': False,
#   'backdrop_path': '/r2GAjd4rNOHJh6i6Y0FntmYuPQW.jpg',
#   'belongs_to_collection': {'backdrop_path': '/dOSECZImeyZldoq0ObieBE0lwie.jpg',
#                             'id': 645,
#                             'name': 'James Bond Collection',
#                             'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg'},
#   'budget': 242000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#              {'id': 28, 'name': 'Action'},
#              {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.007.com/no-time-to-die/',
#   'id': 370172,
#   'imdb_id': 'tt2382320',
#   'original_language': 'en',
#   'original_title': 'No Time to Die',
#   'overview': 'Bond has left active service and is enjoying a tranquil life in '
#               'Jamaica. His peace is short-lived when his old friend Felix '
#               'Leiter from the CIA turns up asking for help. The mission to '
#               'rescue a kidnapped scientist turns out to be far more '
#               'treacherous than expected, leading Bond onto the trail of a '
#               'mysterious villain armed with dangerous new technology.',
#   'popularity': 1999.424,
#   'poster_path': '/iUgygt3fscRoKWCV1d0C7FbM9TP.jpg',
#   'production_companies': [{'id': 7576,
#                             'logo_path': '/oYcUi1byZ312Z3xiz5ojz9RQLND.png',
#                             'name': 'Eon Productions',
#                             'origin_country': 'GB'},
#                            {'id': 21,
#                             'logo_path': '/aOWKh4gkNrfFZ3Ep7n0ckPhoGb5.png',
#                             'name': 'Metro-Goldwyn-Mayer',
#                             'origin_country': 'US'},
#                            {'id': 60,
#                             'logo_path': '/oJXpAs4I3W46e4dkaOEzCa4yBko.png',
#                             'name': 'United Artists',
#                             'origin_country': 'US'},
#                            {'id': 33,
#                             'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#                             'name': 'Universal Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2021-09-29',
#   'revenue': 758000000,
#   'runtime': 163,
#   'spoken_languages': [{'english_name': 'English',
#                         'iso_639_1': 'en',
#                         'name': 'English'},
#                        {'english_name': 'French',
#                         'iso_639_1': 'fr',
#                         'name': 'Français'},
#                        {'english_name': 'Italian',
#                         'iso_639_1': 'it',
#                         'name': 'Italiano'},
#                        {'english_name': 'Russian',
#                         'iso_639_1': 'ru',
#                         'name': 'Pусский'},
#                        {'english_name': 'Spanish',
#                         'iso_639_1': 'es',
#                         'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'The mission that changes everything begins…',
#   'title': 'No Time to Die',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 2521}]

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  2925.561604 seconds

# %% [markdown]
# ### Get Keywords:

# %%
# Start the timer
start = start_timer()

# %%
keywords = get_movie_keywords(api_key, movie_ids)

# %%
# print(keywords)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  1603.671694 seconds

# %% [markdown]
# ### Get Credits:

# %%
# Start the timer
start = start_timer()

# %%
credits = get_credits(api_key, movie_ids)

# %%
# print(credits)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  1750.395193 seconds

# %% [markdown]
# ### Get Certifications:

# %%
# Start the timer
start = start_timer()

# %%
# Get the certifications for each movie (rating: G, PG, etc.)
certifications = get_certifications(api_key, movie_ids)
# certifications = get_certifications(api_key, [32657, 672582])

# %%
# print(certifications)

# %%
# Stop the timer
stop_timer(start)
# Out:
# Total Time Elapsed:  2468.58483 seconds

# %% [markdown]
# ## Movie Details DataFrame:

# %%
# Convert details to json
json_details_string = json.dumps(details)
# Convert json to dataframe
movie_details_df = pd.read_json(json_details_string)

# Export to save
# movie_details_df.to_csv("./static/data/movie_details.csv", index=False)

movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 1  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
# 2  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 544670, 'name': 'Sing Collection', 'pos...   85000000
# 1  {'id': 2980, 'name': 'Ghostbusters Collection'...   75000000
# 2  {'id': 531241, 'name': 'Spider-Man (Avengers) ...  200000000
# 3                                               None   50000000
# 4                                               None   40000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
#
#                                      homepage      id     imdb_id  \
# 0  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 1                   https://ghostbusters.com/  425909   tt4513678
# 2        https://www.spidermannowayhome.movie  634649  tt10872600
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4              https://www.residentevil.movie  460458   tt6920084
#
#   original_language                          original_title  ... release_date  \
# 0                en                                  Sing 2  ...   2021-12-01
# 1                en                 Ghostbusters: Afterlife  ...   2021-11-11
# 2                en                 Spider-Man: No Way Home  ...   2021-12-15
# 3                en                                 Encanto  ...   2021-11-24
# 4                en  Resident Evil: Welcome to Raccoon City  ...   2021-11-24
#
#       revenue runtime                                   spoken_languages  \
# 0   190860000   110.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1   191000000   124.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2  1538282364   148.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3   215000000   102.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4    31000000   107.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#      status                                            tagline  \
# 0  Released                   Where will your dreams take you?
# 1  Released             Discover the past. Protect the future.
# 2  Released                          The Multiverse unleashed.
# 3  Released  There's a little magic in all of us ...almost ...
# 4  Released                     Witness the beginning of evil.
#
#                                     title  video vote_average vote_count
# 0                                  Sing 2  False          7.6        322
# 1                 Ghostbusters: Afterlife  False          7.3        806
# 2                 Spider-Man: No Way Home  False          8.4       4053
# 3                                 Encanto  False          7.8       2660
# 4  Resident Evil: Welcome to Raccoon City  False          6.0        833
#
# [5 rows x 25 columns]

# %%
# Extract year from release date
movie_details_df["year"] = pd.DatetimeIndex(movie_details_df['release_date']).year
# Drop any N/A from year
movie_details_df.dropna(inplace=True, how="any", subset=['year','release_date'])
 
# Convert to int
movie_details_df["year"] = movie_details_df["year"].astype(int)
    
# Rename columns to prepare for inflation calculation
movie_details_df = movie_details_df.rename(columns = {
    "revenue": "original_revenue",
    "budget": "original_budget"
})

# %%
len(movie_details_df)
# Out:
# 5970

# %% [markdown]
# ## Adjust Budget & Revenue for Inflation

# %%
# Create dataframe for cpi
cpi_df = pd.DataFrame(columns=['year', 'cpi_2021', 'cpi_old'])

# %%
# Create list of years (1913-2021)
years = []
for i in range(1913, 2022):
    years.append(i)

# %%
# Define 2021 cpi
cpi_2021 = 269.489

# Loop through years to append to dataframe
for year in years:
    if year != 2021:
        cpi_old = cpi.get(year)
        cpi_df = cpi_df.append({"year": year, 'cpi_2021': cpi_2021, 'cpi_old': cpi_old}, ignore_index=True)
    elif year == 2021:
        cpi_df = cpi_df.append({"year": year, 'cpi_2021': cpi_2021, 'cpi_old': cpi_2021}, ignore_index=True)

# %%
# Convert year type to int
cpi_df['year'] = cpi_df['year'].astype(int)
cpi_df.head()
# Out:
#    year  cpi_2021  cpi_old
# 0  1913   269.489      9.9
# 1  1914   269.489     10.0
# 2  1915   269.489     10.1
# 3  1916   269.489     10.9
# 4  1917   269.489     12.8

# %%
# Merge movie details df with cpi df
movie_details_df = movie_details_df.merge(cpi_df, on="year")
movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 1  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
# 2  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 1  {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
# 2  {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 3                                               None         50000000
# 4                                               None         40000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
#
#                                      homepage      id     imdb_id  \
# 0  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 1                   https://ghostbusters.com/  425909   tt4513678
# 2        https://www.spidermannowayhome.movie  634649  tt10872600
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4              https://www.residentevil.movie  460458   tt6920084
#
#   original_language                          original_title  ...  \
# 0                en                                  Sing 2  ...
# 1                en                 Ghostbusters: Afterlife  ...
# 2                en                 Spider-Man: No Way Home  ...
# 3                en                                 Encanto  ...
# 4                en  Resident Evil: Welcome to Raccoon City  ...
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0                   Where will your dreams take you?
# 1             Discover the past. Protect the future.
# 2                          The Multiverse unleashed.
# 3  There's a little magic in all of us ...almost ...
# 4                     Witness the beginning of evil.
#
#                                     title  video vote_average  vote_count  \
# 0                                  Sing 2  False          7.6         322
# 1                 Ghostbusters: Afterlife  False          7.3         806
# 2                 Spider-Man: No Way Home  False          8.4        4053
# 3                                 Encanto  False          7.8        2660
# 4  Resident Evil: Welcome to Raccoon City  False          6.0         833
#
#    year cpi_2021  cpi_old
# 0  2021  269.489  269.489
# 1  2021  269.489  269.489
# 2  2021  269.489  269.489
# 3  2021  269.489  269.489
# 4  2021  269.489  269.489
#
# [5 rows x 28 columns]

# %%
# Create adjusted column for each feature
features = ["revenue", "budget"]

for feature in features:
    movie_details_df[f'adjusted_{feature}'] = (movie_details_df[f'original_{feature}'] * movie_details_df['cpi_2021']) / movie_details_df['cpi_old']

movie_details_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 1  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
# 2  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 1  {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
# 2  {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 3                                               None         50000000
# 4                                               None         40000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
#
#                                      homepage      id     imdb_id  \
# 0  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 1                   https://ghostbusters.com/  425909   tt4513678
# 2        https://www.spidermannowayhome.movie  634649  tt10872600
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4              https://www.residentevil.movie  460458   tt6920084
#
#   original_language                          original_title  ...  \
# 0                en                                  Sing 2  ...
# 1                en                 Ghostbusters: Afterlife  ...
# 2                en                 Spider-Man: No Way Home  ...
# 3                en                                 Encanto  ...
# 4                en  Resident Evil: Welcome to Raccoon City  ...
#
#                                              tagline  \
# 0                   Where will your dreams take you?
# 1             Discover the past. Protect the future.
# 2                          The Multiverse unleashed.
# 3  There's a little magic in all of us ...almost ...
# 4                     Witness the beginning of evil.
#
#                                     title  video vote_average vote_count  \
# 0                                  Sing 2  False          7.6        322
# 1                 Ghostbusters: Afterlife  False          7.3        806
# 2                 Spider-Man: No Way Home  False          8.4       4053
# 3                                 Encanto  False          7.8       2660
# 4  Resident Evil: Welcome to Raccoon City  False          6.0        833
#
#    year  cpi_2021  cpi_old adjusted_revenue adjusted_budget
# 0  2021   269.489  269.489     1.908600e+08      85000000.0
# 1  2021   269.489  269.489     1.910000e+08      75000000.0
# 2  2021   269.489  269.489     1.538282e+09     200000000.0
# 3  2021   269.489  269.489     2.150000e+08      50000000.0
# 4  2021   269.489  269.489     3.100000e+07      40000000.0
#
# [5 rows x 30 columns]

# %%
# Check values
movie_details_df[['original_budget', 'adjusted_budget', 'original_revenue', 'adjusted_revenue', 'year']]
# Out:
#       original_budget  adjusted_budget  original_revenue  adjusted_revenue  \
# 0            85000000     8.500000e+07         190860000      1.908600e+08
# 1            75000000     7.500000e+07         191000000      1.910000e+08
# 2           200000000     2.000000e+08        1538282364      1.538282e+09
# 3            50000000     5.000000e+07         215000000      2.150000e+08
# 4            40000000     4.000000e+07          31000000      3.100000e+07
# ...               ...              ...               ...               ...
# 5850          2479000     2.311637e+07           7797728      7.271287e+07
# 5851          1300000     2.013424e+07            650422      1.007365e+07
# 5852                0     0.000000e+00                 0      0.000000e+00
# 5853           923000     1.421362e+07           4000000      6.159749e+07
# 5854            18000     2.425401e+05              8811      1.187234e+05
#
#       year
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021
# ...    ...
# 5850  1958
# 5851  1927
# 5852  1935
# 5853  1925
# 5854  1920
#
# [5855 rows x 5 columns]

# %% [markdown]
# ## Low Budget:

# %%
# Create budget bins
bins = [1, 15000000, 50000000, 150000000, 380000000] 
bin_names = ["1 to 15m", "16m to 50m", "51m to 150m", "151m to 380m"]

# Append a budget bin column
movie_details_df["budget_bins"] = pd.cut(movie_details_df["adjusted_budget"], bins, labels=bin_names)
movie_details_df["budget_bins"].value_counts()
# Out:
# 16m to 50m      1189
# 51m to 150m     1006
# 1 to 15m         836
# 151m to 380m     343
# Name: budget_bins, dtype: int64

# %%
# Low Budget
movie_details_df.loc[movie_details_df["budget_bins"] == "1 to 15m"].head()
# Out:
#     adult                     backdrop_path  \
# 14  False  /weneJTnAb1IFI94SKcaXzBFmPKH.jpg
# 15  False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 16  False  /gg2w8QYf6o5elN95RHtikQaVIsc.jpg
# 33  False  /lV3UFPPxDIPelh46G9oySXN9Mcz.jpg
# 34  False  /hAv1GwwatyWV1RFXOfaASxgUVm4.jpg
#
#                                 belongs_to_collection  original_budget  \
# 14                                               None         12400000
# 15                                               None          9100000
# 16                                               None         13000000
# 33  {'id': 702624, 'name': 'After Collection', 'po...         14000000
# 34                                               None          2800000
#
#                                                genres homepage      id  \
# 14  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...           818192
# 15  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...           589761
# 16  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...           592508
# 33  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...           744275
# 34  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           657644
#
#        imdb_id original_language original_title  ...             title  video  \
# 14  tt11388416                en        Ida Red  ...           Ida Red  False
# 15  tt10648714                ru      Чернобыль  ...  Chernobyl: Abyss  False
# 16   tt9531772                hi   Sooryavanshi  ...      Sooryavanshi  False
# 33  tt13069986                en  After We Fell  ...     After We Fell  False
# 34   tt7268738                ml   മിന്നൽ മുരളി  ...     Minnal Murali  False
#
#    vote_average vote_count  year cpi_2021  cpi_old  adjusted_revenue  \
# 14          6.0         20  2021  269.489  269.489               0.0
# 15          6.3        264  2021  269.489  269.489         5370393.0
# 16          5.8         68  2021  269.489  269.489        37700000.0
# 33          7.2       1324  2021  269.489  269.489        19000000.0
# 34          7.2        128  2021  269.489  269.489               0.0
#
#    adjusted_budget budget_bins
# 14      12400000.0    1 to 15m
# 15       9100000.0    1 to 15m
# 16      13000000.0    1 to 15m
# 33      14000000.0    1 to 15m
# 34       2800000.0    1 to 15m
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Keywords DataFrame:

# %%
# Convert keywords to json
json_keywords_string = json.dumps(keywords)
# Convert json to dataframe
movie_keywords_df = pd.read_json(json_keywords_string)

# Export to save
# movie_keywords_df.to_csv("./static/data/movie_keywords.csv", index=False)
pprint(json_keywords_string)
# Out:
# ('[{"id": 438695, "keywords": [{"id": 11477, "name": "anthropomorphism"}, '
#  '{"id": 12990, "name": "singing"}]}, {"id": 425909, "keywords": [{"id": 1415, '
#  '"name": "small town"}, {"id": 3093, "name": "ghostbuster"}, {"id": 5609, '
#  '"name": "nostalgia"}, {"id": 6155, "name": "afterlife"}, {"id": 9663, '
#  '"name": "sequel"}, {"id": 162846, "name": "ghost"}, {"id": 179430, "name": '
#  '"aftercreditsstinger"}, {"id": 179431, "name": "duringcreditsstinger"}, '
#  '{"id": 196960, "name": "dead grandfather"}, {"id": 229863, "name": "ancient '
#  'evil"}, {"id": 245207, "name": "otherworldly beings"}, {"id": 276130, '
#  '"keywords": []}, {"id": 826749, "keywords": []}, {"id": 635302, "keywords": '
#  '[{"id": 1721, "name": "fight"}, {"id": 2343, "name": "magic"}, {"id": 2800, '
#  '"name": "psychology"}, {"id": 6152, "name": "supernatural"}, {"id": 10292, '
#  '"name": "gore"}, {"id": 10349, "name": "survival"}, {"id": 10614, "name": '
#  '"tragedy"}, {"id": 10683, "name": "coming of age"}, {"id": 13141, "name": '
#  '"based on manga"}, {"id": 15001, "name": "demon"}, {"id": 15126, "name": '
#  '"historical"}, {"id": 18035, "name": "family"}, {"id": 157512, "name": '
#  '"mutilation"}, {"id": 177895, "name": "dark fantasy"}, {"id": 207826, '
#  '"name": "shounen"}, {"id": 210024, "name": "anime"}, {"id": 254547, "name": '
#  '"taisho"}]}, {"id": 585245, "keywords": [{"id": 818, "name": "based on novel '
#  'or book"}, {"id": 162628, "name": "giant dog"}]}, {"id": 899082, "keywords": '
#  '[{"id": 9824, "name": "reunion"}]}, {"id": 843241, "keywords": [{"id": 2343, '
#  '"name": "magic"}, {"id": 9663, "name": "sequel"}, {"id": 210024, "name": '
#  '"anime"}]}, {"id": 1930, "keywords": [{"id": 697, "name": "loss of loved '
#  'one"}, {"id": 1706, "name": "experiment"}, {"id": 7002, "name": '
#  '"vigilante"}, {"id": 9717, "name": "based on comic"}, {"id": 10809, "name": '
#  '"teenage girl"}, {"id": 14690, "name": "violent death"}, {"id": 18068, '
#  '"name": "teenage boy"}, {"id": 33637, "name": "super power"}, {"id": 158124, '
#  '"name": "spider bite"}, {"id": 158456, "name": "masked vigilante"}, {"id": '
#  '161184, "name": "reboot"}, {"id": 163561, "name": "genetic engineering"}, '
#  '{"id": 171556, "name": "social outcast"}, {"id": 175421, "name": "death of '
#  'husband"}, {"id": 179431, "name": "duringcreditsstinger"}, {"id": 188178, '
#  '"name": "teenage hero"}, {"id": 188957, "name": "virus"}, {"id": 246862, '
#  '"name": "teenage angst"}, {"id": 256086, "name": "spiderverse"}, {"id": '
#  '265894, "name": "marvel comics"}, {"id": 266013, "name": "vigilante '
#  'justice"}]}, {"id": 818192, "keywords": [{"id": 286171, "name": "ida '
#  'red"}]}, {"id": 585083, "keywords": [{"id": 3133, "name": "vampire"}]}, '
#  '{"id": 589761, "keywords": [{"id": 269, "name": "diving"}, {"id": 1618, '
#  '"name": "radiation"}, {"id": 192094, "name": "firefighter"}, {"id": 210326, '
#  '"name": "chernobyl"}, {"id": 287834, "name": "based on true events"}]}, '
#  '{"id": 592508, "keywords": [{"id": 6149, "name": "police"}, {"id": 9663, '
#  '"name": "sequel"}, {"id": 15090, "name": "police officer"}, {"id": 287118, '
#  '"name": "cop universe"}]}, {"id": 617653, "keywords": [{"id": 818, "name": '
#  '"based on novel or book"}, {"id": 4299, "name": "normandy, france"}, {"id": '
#  '9672, "name": "based on a true story"}, {"id": 10466, "name": "knight"}, '
#  '{"id": 12965, "name": "duel"}, {"id": 15126, "name": "historical"}, {"id": '
#  '175245, "name": "sword duel"}, {"id": 184352, "name": "rape and revenge"}, '
#  '"mentor"}, {"id": 1422, "name": "boat"}, {"id": 173388, "name": "dad"}, '
#  '{"id": 235070, "name": "pasta"}, {"id": 262086, "name": "luca"}, {"id": '
#  '263548, "name": "short film"}, {"id": 274386, "name": "silence"}, {"id": '
#  '282965, "name": "genoa"}, {"id": 287663, "name": "portorosso"}]}, {"id": '
#  '876262, "keywords": []}, {"id": 335797, "keywords": [{"id": 11477, "name": '
#  '"anthropomorphism"}, {"id": 12990, "name": "singing"}, {"id": 186120, '
#  '"name": "singing competition"}]}, {"id": 885110, "keywords": [{"id": 10292, '
#  '"name": "gore"}, {"id": 13073, "name": "fear"}, {"id": 281405, "name": '
#  '"violence"}, {"id": 287834, "name": "based on true events"}]}, {"id": '
#  '610253, "keywords": [{"id": 3335, "name": "halloween"}, {"id": 7002, "name": '
#  '"vigilante"}, {"id": 9663, "name": "sequel"}, {"id": 9826, "name": '
#  '"murder"}, {"id": 10714, "name": "serial killer"}, {"id": 11612, "name": '
#  '"hospital"}, {"id": 12339, "name": "slasher"}, {"id": 13112, "name": '
#  '"murderer"}, {"id": 15127, "name": "killer"}, {"id": 15235, "name": "house '
#  'fire"}, {"id": 177695, "name": "crime spree"}, {"id": 193551, "name": '
#  '"vigilantism"}, {"id": 207159, "name": "escaped killer"}, {"id": 234906, '
#  '"name": "murder spree"}, {"id": 266013, "name": "vigilante justice"}]}, '
#  '{"id": 379686, "keywords": [{"id": 6075, "name": "sports"}, {"id": 6496, '
#  '"name": "basketball"}, {"id": 6513, "name": "cartoon"}, {"id": 18249, '
#  '"name": "game"}, {"id": 209220, "name": "live action and animation"}]}, '
#  '{"id": 823610, "keywords": [{"id": 275172, "name": "sharks"}]}, {"id": '
#  '864390, "keywords": []}, {"id": 568620, "keywords": [{"id": 9675, "name": '
#  '"prequel"}, {"id": 9717, "name": "based on comic"}, {"id": 10244, "name": '
#  '"based on cartoon"}, {"id": 10278, "name": "ninja"}, {"id": 10542, "name": '
#  '"based on toy"}, {"id": 15285, "name": "spin off"}, {"id": 18932, "name": '
#  '"origin of hero"}, {"id": 156863, "name": "gi joe"}, {"id": 158773, "name": '
#  '"female fighter"}, {"id": 219404, "name": "action hero"}, {"id": 229607, '
#  '"name": "female warrior"}, {"id": 255024, "name": "shared universe"}, {"id": '
#  '269769, "name": "based on tv series"}]}, {"id": 581726, "keywords": [{"id": '
#  '818, "name": "based on novel or book"}, {"id": 5484, "name": '
#  '"reincarnation"}]}, {"id": 860623, "keywords": []}, {"id": 399566, '
#  '"keywords": [{"id": 11100, "name": "giant monster"}, {"id": 11873, "name": '
#  '"king kong"}, {"id": 12616, "name": "dinosaur"}, {"id": 158126, "name": '
#  '"creature feature"}, {"id": 161791, "name": "kaiju"}, {"id": 188953, "name": '
#  '"sign languages"}, {"id": 196425, "name": "giant ape"}, {"id": 257384, '
#  '"name": "godzilla"}, {"id": 272228, "name": "monsterverse"}, {"id": 283841, '
#  '"name": "robot dinosaur"}]}, {"id": 893164, "keywords": []}, {"id": 776821, '
#  '"keywords": [{"id": 642, "name": "robbery"}, {"id": 818, "name": "based on '
#  'novel or book"}, {"id": 1228, "name": "1970s"}, {"id": 207573, "name": "cine '
#  'quinqui"}, {"id": 247968, "name": "juvenile delinquency"}]}, {"id": 716810, '
#  '"keywords": [{"id": 269769, "name": "based on tv series"}]}, {"id": 476669, '
#  '"keywords": [{"id": 212, "name": "london, england"}, {"id": 470, "name": '
#  '"spy"}, {"id": 2504, "name": "world war i"}, {"id": 9717, "name": "based on '
#  'comic"}, {"id": 15285, "name": "spin off"}, {"id": 41249, "name": "secret '
#  'service"}, {"id": 176217, "name": "world domination"}, {"id": 210184, '
#  '"name": "1910s"}]}, {"id": 324857, "keywords": [{"id": 9715, "name": '
#  '"superhero"}, {"id": 9717, "name": "based on comic"}, {"id": 179430, "name": '
#  '"aftercreditsstinger"}, {"id": 245157, "name": "alternate universe"}]}, '
#  '{"id": 299534, "keywords": [{"id": 3801, "name": "space travel"}, {"id": '
#  '4379, "name": "time travel"}, {"id": 5455, "name": "time machine"}, {"id": '
#  '9663, "name": "sequel"}, {"id": 9717, "name": "based on comic"}, {"id": '
#  '14909, "name": "alien invasion"}, {"id": 155030, "name": "superhero team"}, '
#  '{"id": 173776, "name": "iron man"}, {"id": 180547, "name": "marvel cinematic '
#  'universe (mcu)"}, {"id": 186760, "name": "alternate timeline"}, {"id": '
#  '218015, "name": "final battle"}, {"id": 240303, "name": "father daughter '
#  'relationship"}, {"id": 241738, "name": "sister sister relationship"}]}, '
#  '{"id": 24428, "keywords": [{"id": 242, "name": "new york city"}, {"id": '
#  '5539, "name": "shield"}, {"id": 9715, "name": "superhero"}, {"id": 9717, '
#  '"name": "based on comic"}, {"id": 14909, "name": "alien invasion"}, {"id": '
#  '155030, "name": "superhero team"}, {"id": 179430, "name": '
#  '"aftercreditsstinger"}, {"id": 179431, "name": "duringcreditsstinger"}, '
#  '{"id": 180547, "name": "marvel cinematic universe (mcu)"}]}, {"id": 613504, '
#  '"keywords": [{"id": 818, "name": "based on novel or book"}, {"id": 9673, '
#  '"name": "love"}, {"id": 10791, "name": "teenage crush"}]}, {"id": 791373, '
#  '"keywords": [{"id": 849, "name": "dc comics"}, {"id": 9715, "name": '
#  '"superhero"}, {"id": 9717, "name": "based on comic"}, {"id": 155030, "name": '
#  '"superhero team"}, {"id": 229266, "name": "dc extended universe"}, {"id": '
#  '265979, "name": "superhero teamup"}]}, {"id": 767377, "keywords": [{"id": '
#  '9714, "name": "remake"}, {"id": 184998, "name": "film adaptation"}]}, {"id": '
#  '813258, "keywords": [{"id": 261274, "name": "dracula"}, {"id": 263548, '
#  '"name": "short film"}]}, {"id": 670429, "keywords": []}, {"id": 646385, '
#  '"keywords": [{"id": 2546, "name": "mask"}, {"id": 9826, "name": "murder"}, '
#  '{"id": 10714, "name": "serial killer"}, {"id": 12339, "name": "slasher"}, '
#  '{"id": 12570, "name": "whodunit"}, {"id": 17987, "name": "killing spree"}, '
#  '{"id": 155808, "name": "hometown"}, {"id": 161184, "name": "reboot"}, {"id": '
#  '{"id": 256086, "name": "spiderverse"}]}, {"id": 654974, "keywords": [{"id": '
#  '65, "name": "holiday"}, {"id": 169826, "name": "home alone"}, {"id": 193048, '
#  '"name": "christmas spirit"}, {"id": 207317, "name": "christmas"}]}, {"id": '
#  '755437, "keywords": [{"id": 9714, "name": "remake"}, {"id": 156195, "name": '
#  '"family feud"}]}, {"id": 829358, "keywords": []}, {"id": 673, "keywords": '
#  '[{"id": 334, "name": "flying"}, {"id": 2052, "name": "traitor"}, {"id": '
#  '2343, "name": "magic"}, {"id": 2921, "name": "school friend"}, {"id": 3650, '
#  '"name": "child hero"}, {"id": 3884, "name": "school of witchcraft"}, {"id": '
#  '4252, "name": "black magic"}, {"id": 4379, "name": "time travel"}, {"id": '
#  '6054, "name": "friendship"}, {"id": 10873, "name": "school"}, {"id": 12392, '
#  '"name": "best friend"}, {"id": 12564, "name": "werewolf"}, {"id": 33784, '
#  '"name": "muggle"}, {"id": 179430, "name": "aftercreditsstinger"}, {"id": '
#  '229184, "name": "school class"}, {"id": 246466, "name": "based on young '
#  'adult novel"}, {"id": 249692, "name": "magic spell"}]}, {"id": 805411, '
#  '"keywords": [{"id": 13027, "name": "wedding"}, {"id": 285310, "name": '
#  '"animated wedding"}]}, {"id": 763152, "keywords": [{"id": 463, "name": '
#  '"swinger club"}, {"id": 1759, "name": "night life"}, {"id": 9706, "name": '
#  '"anthology"}, {"id": 9799, "name": "romantic comedy"}, {"id": 170827, '
#  '"name": "sex comedy"}]}, {"id": 674, "keywords": [{"id": 818, "name": "based '
#  'on novel or book"}, {"id": 2343, "name": "magic"}, {"id": 3737, "name": '
#  '"dying and death"}, {"id": 3884, "name": "school of witchcraft"}, {"id": '
#  '4238, "name": "chosen one"}, {"id": 4252, "name": "black magic"}, {"id": '
#  '6271, "name": "boarding school"}, {"id": 10629, "name": "vision"}, {"id": '
#  '10873, "name": "school"}, {"id": 12380, "name": "tournament"}, {"id": '
#  '188178, "name": "teenage hero"}, {"id": 246466, "name": "based on young '
#  'adult novel"}]}, {"id": 284052, "keywords": [{"id": 2343, "name": "magic"}, '
#  '{"id": 3667, "name": "time"}, {"id": 4613, "name": "training"}, {"id": 9715, '
#  '"name": "superhero"}, {"id": 9717, "name": "based on comic"}, {"id": 10821, '
#  '"name": "sorcerer"}, {"id": 13005, "name": "doctor"}, {"id": 155583, "name": '
#  '"neurosurgeon"}, {"id": 177912, "name": "wizard"}, {"id": 179430, "name": '
#  '"aftercreditsstinger"}, {"id": 179431, "name": "duringcreditsstinger"}, '
#  '{"id": 180547, "name": "marvel cinematic universe (mcu)"}]}, {"id": 675353, '
#  '"keywords": [{"id": 9663, "name": "sequel"}, {"id": 41645, "name": "based on '
#  'video game"}, {"id": 208927, "name": "hedgehog"}, {"id": 209220, "name": '
#  '"live action and animation"}]}, {"id": 99861, "keywords": [{"id": 310, '
#  '"name": "artificial intelligence"}, {"id": 9663, "name": "sequel"}, {"id": '
#  '9715, "name": "superhero"}, {"id": 9717, "name": "based on comic"}, {"id": '
#  '463116, "keywords": [{"id": 2343, "name": "magic"}, {"id": 2679, "name": '
#  '"artist"}, {"id": 7376, "name": "princess"}, {"id": 10466, "name": '
#  '"knight"}, {"id": 10821, "name": "sorcerer"}, {"id": 13084, "name": "king"}, '
#  '{"id": 15074, "name": "vortex"}]}]')

# %% [markdown]
# ## Credits DataFrame:

# %%
# Convert credits to json
json_credits_string = json.dumps(credits)
# Convert json to dataframe
movie_credits_df = pd.read_json(json_credits_string)

# Export to save
# movie_credits_df.to_csv("./static/data/movie_credits.csv", index=False)
movie_credits_df.head()
# Out:
#        id                                               cast  \
# 0  438695  [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 1  425909  [{'adult': False, 'gender': 1, 'id': 1308445, ...
# 2  634649  [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3  568124  [{'adult': False, 'gender': 1, 'id': 968367, '...
# 4  460458  [{'adult': False, 'gender': 1, 'id': 115150, '...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 5720, 'kn...
# 1  [{'adult': False, 'gender': 2, 'id': 561, 'kno...
# 2  [{'adult': False, 'gender': 1, 'id': 2519, 'kn...
# 3  [{'adult': False, 'gender': 0, 'id': 8159, 'kn...
# 4  [{'adult': False, 'gender': 2, 'id': 4014, 'kn...

# %%
movie_credits_df["cast_crew"] = movie_credits_df["cast"] + movie_credits_df["crew"]
movie_credits_df
# Out:
#           id                                               cast  \
# 0     438695  [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 1     425909  [{'adult': False, 'gender': 1, 'id': 1308445, ...
# 2     634649  [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3     568124  [{'adult': False, 'gender': 1, 'id': 968367, '...
# 4     460458  [{'adult': False, 'gender': 1, 'id': 115150, '...
# ...      ...                                                ...
# 5995  513302  [{'adult': False, 'gender': 2, 'id': 77928, 'k...
# 5996  534259  [{'adult': False, 'gender': 2, 'id': 1968476, ...
# 5997   52212  [{'adult': False, 'gender': 1, 'id': 41163, 'k...
# 5998  659959  [{'adult': False, 'gender': 2, 'id': 1859007, ...
# 5999  463116  [{'adult': False, 'gender': 0, 'id': 2071872, ...
#
#                                                    crew  \
# 0     [{'adult': False, 'gender': 2, 'id': 5720, 'kn...
# 1     [{'adult': False, 'gender': 2, 'id': 561, 'kno...
# 2     [{'adult': False, 'gender': 1, 'id': 2519, 'kn...
# 3     [{'adult': False, 'gender': 0, 'id': 8159, 'kn...
# 4     [{'adult': False, 'gender': 2, 'id': 4014, 'kn...
# ...                                                 ...
# 5995  [{'adult': False, 'gender': 2, 'id': 66866, 'k...
# 5996  [{'adult': False, 'gender': 1, 'id': 1302, 'kn...
# 5997  [{'adult': False, 'gender': 2, 'id': 33804, 'k...
# 5998  [{'adult': False, 'gender': 2, 'id': 4387, 'kn...
# 5999  [{'adult': False, 'gender': 2, 'id': 1461680, ...
#
#                                               cast_crew
# 0     [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 1     [{'adult': False, 'gender': 1, 'id': 1308445, ...
# 2     [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3     [{'adult': False, 'gender': 1, 'id': 968367, '...
# 4     [{'adult': False, 'gender': 1, 'id': 115150, '...
# ...                                                 ...
# 5995  [{'adult': False, 'gender': 2, 'id': 77928, 'k...
# 5996  [{'adult': False, 'gender': 2, 'id': 1968476, ...
# 5997  [{'adult': False, 'gender': 1, 'id': 41163, 'k...
# 5998  [{'adult': False, 'gender': 2, 'id': 1859007, ...
# 5999  [{'adult': False, 'gender': 0, 'id': 2071872, ...
#
# [6000 rows x 4 columns]

# %%
movie_credits_df['percent_fm'] = movie_credits_df['cast_crew'].apply(fm_percentage)

# %%
# cast_crew_fm_percentage
movie_credits_df = movie_credits_df.drop(columns=['cast_crew'])
movie_credits_df
# Out:
#           id                                               cast  \
# 0     438695  [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 1     425909  [{'adult': False, 'gender': 1, 'id': 1308445, ...
# 2     634649  [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3     568124  [{'adult': False, 'gender': 1, 'id': 968367, '...
# 4     460458  [{'adult': False, 'gender': 1, 'id': 115150, '...
# ...      ...                                                ...
# 5995  513302  [{'adult': False, 'gender': 2, 'id': 77928, 'k...
# 5996  534259  [{'adult': False, 'gender': 2, 'id': 1968476, ...
# 5997   52212  [{'adult': False, 'gender': 1, 'id': 41163, 'k...
# 5998  659959  [{'adult': False, 'gender': 2, 'id': 1859007, ...
# 5999  463116  [{'adult': False, 'gender': 0, 'id': 2071872, ...
#
#                                                    crew percent_fm
# 0     [{'adult': False, 'gender': 2, 'id': 5720, 'kn...     25.00%
# 1     [{'adult': False, 'gender': 2, 'id': 561, 'kno...     25.40%
# 2     [{'adult': False, 'gender': 1, 'id': 2519, 'kn...     25.81%
# 3     [{'adult': False, 'gender': 0, 'id': 8159, 'kn...     42.86%
# 4     [{'adult': False, 'gender': 2, 'id': 4014, 'kn...     31.58%
# ...                                                 ...        ...
# 5995  [{'adult': False, 'gender': 2, 'id': 66866, 'k...     27.27%
# 5996  [{'adult': False, 'gender': 1, 'id': 1302, 'kn...     37.04%
# 5997  [{'adult': False, 'gender': 2, 'id': 33804, 'k...     23.53%
# 5998  [{'adult': False, 'gender': 2, 'id': 4387, 'kn...     30.43%
# 5999  [{'adult': False, 'gender': 2, 'id': 1461680, ...      0.00%
#
# [6000 rows x 4 columns]

# %% [markdown]
# ## Certifications DataFrame:

# %%
# Convert certifications to json
json_certifications_string = json.dumps(certifications)
# Convert json to dataframe
movie_certifications_df = pd.read_json(json_certifications_string)

# Export to save
# movie_certifications_df.to_csv("./static/data/movie_certifications.csv", index=False)
movie_certifications_df.head()
# Out:
#        id                                            results
# 0  438695  [{'iso_3166_1': 'CA', 'release_dates': [{'cert...
# 1  425909  [{'iso_3166_1': 'SE', 'release_dates': [{'cert...
# 2  634649  [{'iso_3166_1': 'MX', 'release_dates': [{'cert...
# 3  568124  [{'iso_3166_1': 'FI', 'release_dates': [{'cert...
# 4  460458  [{'iso_3166_1': 'CZ', 'release_dates': [{'cert...

# %%
# Extract certification information and append to new column
movie_certifications_df['certification'] = movie_certifications_df['results'].apply(extract_certification)
movie_certifications_df = movie_certifications_df[['id', 'certification']]

# %%
movie_certifications_df.head()
# Out:
#        id certification
# 0  438695
# 1  425909
# 2  634649         PG-13
# 3  568124
# 4  460458             R

# %%
# Convert ids to ints (to merge correctly)
movie_keywords_df['id'] = movie_keywords_df['id'].astype('int')
movie_details_df['id'] = movie_details_df['id'].astype('int')
movie_credits_df['id'] = movie_credits_df['id'].astype('int')
movie_certifications_df['id'] = movie_certifications_df['id'].astype('int')

# %%
# Merge keywords with details
movie_df = movie_details_df.merge(movie_keywords_df, on='id')
movie_df = movie_df.merge(movie_credits_df, on='id')
movie_df = movie_df.merge(movie_certifications_df, on='id')

# Export to save
# movie_df.to_csv("./static/data/movies_merged.csv", index=False)

# %%
movie_df.head(20)
# Out:
#     adult                     backdrop_path  \
# 0   False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 1   False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
# 2   False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 3   False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4   False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg
# 5   False  /eNI7PtK6DEYgZmHWP9gQNuff8pv.jpg
# 6   False  /vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg
# 7   False  /dK12GIdhGP6NPGFssK2Fh265jyr.jpg
# 8   False  /lyvszvJJqqI8aqBJ70XzdCNoK0y.jpg
# 9   False  /cinER0ESG0eJ49kXlExM0MEWGxW.jpg
# 10  False  /srDyClcl2J0L3ZP9tpahwoTcNxj.jpg
# 11  False  /1BqX34aJS5J8PefVnQSfQIEPfkl.jpg
# 12  False  /1Wlwnhn5sXUIwlxpJgWszT622PS.jpg
# 13  False  /7h5WAPAcUzOWpp2jrwHBB48790j.jpg
# 14  False  /weneJTnAb1IFI94SKcaXzBFmPKH.jpg
# 15  False  /xGrTm3J0FTafmuQ85vF7ZCw94x6.jpg
# 16  False  /gg2w8QYf6o5elN95RHtikQaVIsc.jpg
# 17  False  /mFbS5TwN95BcSEfiztdchLgTQ0v.jpg
# 18  False  /zlj0zHo67xXoj7hvwGtaKRkSdBV.jpg
# 19  False  /nvxrQQspxmSblCYDtvDAbVFX8Jt.jpg
#
#                                 belongs_to_collection  original_budget  \
# 0   {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 1   {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
# 2   {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 3                                                None         50000000
# 4                                                None         40000000
# 5   {'id': 2344, 'name': 'The Matrix Collection', ...        190000000
# 6   {'id': 558216, 'name': 'Venom Collection', 'po...        110000000
# 7                                                None        160000000
# 8                                                None        200000000
# 9   {'id': 912503, 'name': 'Shang-Chi Collection',...        150000000
# 10                                               None                0
# 11  {'id': 883509, 'name': 'Fortress Collection', ...                0
# 12                                               None         64000000
# 13  {'id': 703485, 'name': 'The Seven Deadly Sins ...                0
# 14                                               None         12400000
# 15                                               None          9100000
# 16                                               None         13000000
# 17                                               None        100000000
# 18                                               None                0
# 19                                               None         75000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4   [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 5   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 6   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 7   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 11  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 12  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 14, '...
# 14  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 15  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 16  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 17  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 18  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 19  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#
#                                              homepage      id     imdb_id  \
# 0          https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 1                           https://ghostbusters.com/  425909   tt4513678
# 2                https://www.spidermannowayhome.movie  634649  tt10872600
# 3                   https://movies.disney.com/encanto  568124   tt2953050
# 4                      https://www.residentevil.movie  460458   tt6920084
# 5                     https://www.whatisthematrix.com  624860  tt10838180
# 6                             https://www.venom.movie  580489   tt7097896
# 7           https://www.netflix.com/us/title/81161626  512195   tt7991608
# 8          https://www.marvel.com/movies/the-eternals  524434   tt9032400
# 9   https://www.marvel.com/movies/shang-chi-and-th...  566525   tt9376612
# 10                                                     787310  tt12861508
# 11                                                     826749  tt14577300
# 12                                                     585245   tt2397461
# 13                         https://eiga.7-taizai.net/  843241  tt13884144
# 14                                                     818192  tt11388416
# 15                                                     589761  tt10648714
# 16                                                     592508   tt9531772
# 17  https://www.20thcenturystudios.com/movies/the-...  617653   tt4244994
# 18              https://www.amazon.com/dp/B09F8YDBBH/  728526  tt12800524
# 19             https://www.netflix.com/title/81252357  646380  tt11286314
#
#    original_language                             original_title  ... cpi_2021  \
# 0                 en                                     Sing 2  ...  269.489
# 1                 en                    Ghostbusters: Afterlife  ...  269.489
# 2                 en                    Spider-Man: No Way Home  ...  269.489
# 3                 en                                    Encanto  ...  269.489
# 4                 en     Resident Evil: Welcome to Raccoon City  ...  269.489
# 5                 en                   The Matrix Resurrections  ...  269.489
# 6                 en                Venom: Let There Be Carnage  ...  269.489
# 7                 en                                 Red Notice  ...  269.489
# 8                 en                                   Eternals  ...  269.489
# 9                 en  Shang-Chi and the Legend of the Ten Rings  ...  269.489
# 10                en                           Survive the Game  ...  269.489
# 11                en                                   Fortress  ...  269.489
# 12                en                   Clifford the Big Red Dog  ...  269.489
# 13                ja                        劇場版 七つの大罪 光に呪われし者たち  ...  269.489
# 14                en                                    Ida Red  ...  269.489
# 15                ru                                  Чернобыль  ...  269.489
# 16                hi                               Sooryavanshi  ...  269.489
# 17                en                              The Last Duel  ...  269.489
# 18                en                                  Encounter  ...  269.489
# 19                en                              Don't Look Up  ...  269.489
#
#     cpi_old adjusted_revenue adjusted_budget   budget_bins  \
# 0   269.489     1.908600e+08      85000000.0   51m to 150m
# 1   269.489     1.910000e+08      75000000.0   51m to 150m
# 2   269.489     1.538282e+09     200000000.0  151m to 380m
# 3   269.489     2.150000e+08      50000000.0    16m to 50m
# 4   269.489     3.100000e+07      40000000.0    16m to 50m
# 5   269.489     1.240000e+08     190000000.0  151m to 380m
# 6   269.489     5.000000e+08     110000000.0   51m to 150m
# 7   269.489     1.781430e+05     160000000.0  151m to 380m
# 8   269.489     3.994372e+08     200000000.0  151m to 380m
# 9   269.489     4.302384e+08     150000000.0   51m to 150m
# 10  269.489     0.000000e+00             0.0           NaN
# 11  269.489     0.000000e+00             0.0           NaN
# 12  269.489     6.700000e+07      64000000.0   51m to 150m
# 13  269.489     0.000000e+00             0.0           NaN
# 14  269.489     0.000000e+00      12400000.0      1 to 15m
# 15  269.489     5.370393e+06       9100000.0      1 to 15m
# 16  269.489     3.770000e+07      13000000.0      1 to 15m
# 17  269.489     2.700000e+07     100000000.0   51m to 150m
# 18  269.489     0.000000e+00             0.0           NaN
# 19  269.489     6.707310e+05      75000000.0   51m to 150m
#
#                                              keywords  \
# 0   [{'id': 11477, 'name': 'anthropomorphism'}, {'...
# 1   [{'id': 1415, 'name': 'small town'}, {'id': 30...
# 2   [{'id': 1701, 'name': 'hero'}, {'id': 5451, 'n...
# 3   [{'id': 2343, 'name': 'magic'}, {'id': 4344, '...
# 4   [{'id': 1852, 'name': 'mutant'}, {'id': 1865, ...
# 5   [{'id': 310, 'name': 'artificial intelligence'...
# 6   [{'id': 1701, 'name': 'hero'}, {'id': 2095, 'n...
# 7   [{'id': 1812, 'name': 'fbi'}, {'id': 6710, 'na...
# 8   [{'id': 3925, 'name': 'boredom'}, {'id': 6152,...
# 9   [{'id': 779, 'name': 'martial arts'}, {'id': 9...
# 10                                                 []
# 11                                                 []
# 12  [{'id': 818, 'name': 'based on novel or book'}...
# 13  [{'id': 2343, 'name': 'magic'}, {'id': 9663, '...
# 14                [{'id': 286171, 'name': 'ida red'}]
# 15  [{'id': 269, 'name': 'diving'}, {'id': 1618, '...
# 16  [{'id': 6149, 'name': 'police'}, {'id': 9663, ...
# 17  [{'id': 818, 'name': 'based on novel or book'}...
# 18  [{'id': 9951, 'name': 'alien'}, {'id': 12553, ...
# 19  [{'id': 310, 'name': 'artificial intelligence'...
#
#                                                  cast  \
# 0   [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 1   [{'adult': False, 'gender': 1, 'id': 1308445, ...
# 2   [{'adult': False, 'gender': 2, 'id': 1136406, ...
# 3   [{'adult': False, 'gender': 1, 'id': 968367, '...
# 4   [{'adult': False, 'gender': 1, 'id': 115150, '...
# 5   [{'adult': False, 'gender': 2, 'id': 6384, 'kn...
# 6   [{'adult': False, 'gender': 2, 'id': 2524, 'kn...
# 7   [{'adult': False, 'gender': 2, 'id': 18918, 'k...
# 8   [{'adult': False, 'gender': 1, 'id': 97576, 'k...
# 9   [{'adult': False, 'gender': 2, 'id': 1489211, ...
# 10  [{'adult': False, 'gender': 2, 'id': 62747, 'k...
# 11  [{'adult': False, 'gender': 2, 'id': 57171, 'k...
# 12  [{'adult': False, 'gender': 1, 'id': 1696017, ...
# 13  [{'adult': False, 'gender': 2, 'id': 149894, '...
# 14  [{'adult': False, 'gender': 2, 'id': 2299, 'kn...
# 15  [{'adult': False, 'gender': 2, 'id': 562730, '...
# 16  [{'adult': False, 'gender': 2, 'id': 35070, 'k...
# 17  [{'adult': False, 'gender': 2, 'id': 1892, 'kn...
# 18  [{'adult': False, 'gender': 2, 'id': 53240, 'k...
# 19  [{'adult': False, 'gender': 1, 'id': 72129, 'k...
#
#                                                  crew percent_fm certification
# 0   [{'adult': False, 'gender': 2, 'id': 5720, 'kn...     25.00%
# 1   [{'adult': False, 'gender': 2, 'id': 561, 'kno...     25.40%
# 2   [{'adult': False, 'gender': 1, 'id': 2519, 'kn...     25.81%         PG-13
# 3   [{'adult': False, 'gender': 0, 'id': 8159, 'kn...     42.86%
# 4   [{'adult': False, 'gender': 2, 'id': 4014, 'kn...     31.58%             R
# 5   [{'adult': False, 'gender': 2, 'id': 1071, 'kn...     25.86%
# 6   [{'adult': False, 'gender': 2, 'id': 149, 'kno...     23.68%         PG-13
# 7   [{'adult': False, 'gender': 2, 'id': 9543, 'kn...     14.58%         PG-13
# 8   [{'adult': False, 'gender': 2, 'id': 1722, 'kn...     26.47%
# 9   [{'adult': False, 'gender': 1, 'id': 7232, 'kn...     34.29%         PG-13
# 10  [{'adult': False, 'gender': 2, 'id': 21003, 'k...     20.00%             R
# 11  [{'adult': False, 'gender': 2, 'id': 17210, 'k...     18.18%             R
# 12  [{'adult': False, 'gender': 1, 'id': 8220, 'kn...     40.35%            PG
# 13  [{'adult': False, 'gender': 2, 'id': 1250035, ...     35.71%
# 14  [{'adult': False, 'gender': 0, 'id': 1504645, ...     25.00%             R
# 15  [{'adult': False, 'gender': 1, 'id': 30247, 'k...     37.14%
# 16  [{'adult': False, 'gender': 2, 'id': 35070, 'k...     12.50%
# 17  [{'adult': False, 'gender': 2, 'id': 120, 'kno...     26.32%
# 18  [{'adult': False, 'gender': 1, 'id': 2952, 'kn...     26.92%
# 19  [{'adult': False, 'gender': 1, 'id': 6410, 'kn...     29.17%             R
#
# [20 rows x 36 columns]

# %% [markdown]
# ## Call Functions to Extract Details:

# %%
# Director
movie_df['director'] = movie_df['crew'].apply(get_director)

# Director Gender
movie_df['director_gender'] = movie_df['crew'].apply(get_director_gender)

# Producers
movie_df['producers'] = movie_df['crew'].apply(get_producers)

# Screenplay writers
movie_df['writers'] = movie_df['crew'].apply(get_writers)

# Cast
movie_df['cast'] = movie_df['cast'].apply(get_cast_list)

# Production Company Country of Origin
movie_df['production_company_origin'] = movie_df['production_companies'].apply(get_production_company_country)

# Spoken Languages in Movie
movie_df['spoken_languages']  = movie_df['spoken_languages'].apply(get_languages)

# Create foreign language column for if the original language was not English
movie_df['foreign_language'] = movie_df['original_language'].apply(original_language_binary)

# Get List: Keywords, genres, & production countries
features = ['keywords', 'genres', 'production_companies']
            
for feature in features:
    movie_df[feature] = movie_df[feature].apply(get_list)

# %%
# Show the results
movie_df[['title', 'cast', 'director', 'director_gender', 'percent_fm', 'producers', 'writers', 'keywords', 'genres', 'production_companies', 'production_company_origin', 'spoken_languages', 'original_language', 'foreign_language']].head()
# Out:
#                                     title  \
# 0                                  Sing 2
# 1                 Ghostbusters: Afterlife
# 2                 Spider-Man: No Way Home
# 3                                 Encanto
# 4  Resident Evil: Welcome to Raccoon City
#
#                                                 cast  \
# 0  [Matthew McConaughey, Reese Witherspoon, Scarl...
# 1  [Carrie Coon, Finn Wolfhard, Mckenna Grace, Pa...
# 2  [Tom Holland, Zendaya, Benedict Cumberbatch, J...
# 3  [Stephanie Beatriz, María Cecilia Botero, John...
# 4  [Kaya Scodelario, Robbie Amell, Hannah John-Ka...
#
#                      director director_gender percent_fm  \
# 0            [Garth Jennings]             [2]     25.00%
# 1             [Jason Reitman]             [2]     25.40%
# 2                 [Jon Watts]             [2]     25.81%
# 3  [Byron Howard, Jared Bush]          [2, 2]     42.86%
# 4          [Johannes Roberts]             [2]     31.58%
#
#                                            producers  \
# 0  [Christopher Meledandri, Janet Healy, Dana Kru...
# 1  [Dan Aykroyd, Ivan Reitman, Gil Kenan, Michael...
# 2  [Avi Arad, Kevin Feige, Louis D'Esposito, JoAn...
# 3  [Clark Spencer, Jennifer Lee, Yvett Merino Flo...
# 4  [Paul W. S. Anderson, Jeremy Bolt, Robert Kulz...
#
#                                              writers  \
# 0                   [Garth Jennings, Garth Jennings]
# 1  [Dan Aykroyd, Harold Ramis, Jason Reitman, Gil...
# 2  [Stan Lee, Stan Lee, Steve Ditko, Steve Ditko,...
# 3                 [Jared Bush, Charise Castro Smith]
# 4  [Johannes Roberts, Noboru Sugimura, Kenichi Iw...
#
#                                             keywords  \
# 0                        [anthropomorphism, singing]
# 1  [small town, ghostbuster, nostalgia, afterlife...
# 2  [hero, comic book, superhero, based on comic, ...
# 3  [magic, musical, forest, family relationships,...
# 4  [mutant, biological weapon, quarantine, zombie...
#
#                                  genres  \
# 0    [Animation, Comedy, Family, Music]
# 1          [Comedy, Fantasy, Adventure]
# 2  [Action, Adventure, Science Fiction]
# 3  [Animation, Comedy, Family, Fantasy]
# 4     [Horror, Action, Science Fiction]
#
#                                 production_companies  \
# 0   [Illumination Entertainment, Universal Pictures]
# 1  [Columbia Pictures, Bron Studios, The Montecit...
# 2  [Marvel Studios, Pascal Pictures, Columbia Pic...
# 3  [Walt Disney Animation Studios, Walt Disney Pi...
# 4  [Constantin Film, Tea Shop & Film Company, Dav...
#
#   production_company_origin    spoken_languages original_language  \
# 0                  [US, US]           [English]                en
# 1          [US, CA, US, US]           [English]                en
# 2              [US, US, US]  [English, Tagalog]                en
# 3                  [US, US]  [English, Spanish]                en
# 4      [DE, GB, FR, GB, US]           [English]                en
#
#    foreign_language
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
# Drop NA from selected columns
movie_df.dropna(inplace=True, how="any", subset=['genres', 'production_companies', 'keywords', 'cast'])
movie_df.dropna(inplace=True, how="any", subset=['director', 'producers', 'writers'])

# %%
len(movie_df)
# Out:
# 4992

# %%
# Clean Data: Convert all features to lowercase and remove spaces
features = ['cast', 'director', 'producers', 'writers', 'keywords', 'genres', 'production_companies']

for feature in features:
    movie_df[f"{feature}_cleaned"] = movie_df[feature].apply(clean_data)

# %%
# Call the clean overview function
movie_df['overview_cleaned'] = movie_df['overview'].apply(clean_overview)

# %%
# Create soup columns
movie_df['soup'] = movie_df.apply(create_soup, axis = 1)
movie_df['soup_overview'] = movie_df.apply(create_soup_overview, axis = 1)

# Export to save
# movie_df.to_csv("./static/data/movies_cleaned_soup.csv", index=False)

# %%
movie_df[['soup']].head(5)
# Out:
#                                                 soup
# 0  anthropomorphism singing matthewmcconaughey re...
# 1  smalltown ghostbuster nostalgia afterlife sequ...
# 2  hero comicbook superhero basedoncomic marvelci...
# 3  magic musical forest familyrelationships femal...
# 4  mutant biologicalweapon quarantine zombie base...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4992 entries, 0 to 5854
# Data columns (total 52 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   adult                         4992 non-null   bool
#  1   backdrop_path                 4936 non-null   object
#  2   belongs_to_collection         1624 non-null   object
#  3   original_budget               4992 non-null   int64
#  4   genres                        4992 non-null   object
#  5   homepage                      4990 non-null   object
#  6   id                            4992 non-null   int64
#  7   imdb_id                       4985 non-null   object
#  8   original_language             4992 non-null   object
#  9   original_title                4992 non-null   object
#  10  overview                      4992 non-null   object
#  11  popularity                    4992 non-null   float64
#  12  poster_path                   4991 non-null   object
#  13  production_companies          4992 non-null   object
#  14  production_countries          4992 non-null   object
#  15  release_date                  4992 non-null   object
#  16  original_revenue              4992 non-null   int64
#  17  runtime                       4991 non-null   float64
#  18  spoken_languages              4983 non-null   object
#  19  status                        4992 non-null   object
#  20  tagline                       4992 non-null   object
#  21  title                         4992 non-null   object
#  22  video                         4992 non-null   bool
#  23  vote_average                  4992 non-null   float64
#  24  vote_count                    4992 non-null   int64
#  25  year                          4992 non-null   int64
#  26  cpi_2021                      4992 non-null   float64
#  27  cpi_old                       4992 non-null   float64
#  28  adjusted_revenue              4992 non-null   float64
#  29  adjusted_budget               4992 non-null   float64
#  30  budget_bins                   3256 non-null   category
#  31  keywords                      4992 non-null   object
#  32  cast                          4992 non-null   object
#  33  crew                          4992 non-null   object
#  34  percent_fm                    4985 non-null   object
#  35  certification                 4992 non-null   object
#  36  director                      4992 non-null   object
#  37  director_gender               4992 non-null   object
#  38  producers                     4992 non-null   object
#  39  writers                       4992 non-null   object
#  40  production_company_origin     4992 non-null   object
#  41  foreign_language              4992 non-null   int64
#  42  cast_cleaned                  4992 non-null   object
#  43  director_cleaned              4992 non-null   object
#  44  producers_cleaned             4992 non-null   object
#  45  writers_cleaned               4992 non-null   object
#  46  keywords_cleaned              4992 non-null   object
#  47  genres_cleaned                4992 non-null   object
#  48  production_companies_cleaned  4992 non-null   object
#  49  overview_cleaned              4992 non-null   object
#  50  soup                          4992 non-null   object
#  51  soup_overview                 4992 non-null   object
# dtypes: bool(2), category(1), float64(7), int64(6), object(36)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Configuration for Posters:

# %%
configuration_url = f"https://api.themoviedb.org/3/configuration?api_key={api_key}"
config_response = requests.get(configuration_url).json()
# config_response

# %%
# Get images structure
images_url = config_response['images']
# Get Base URL
secure_base_url = images_url['secure_base_url']
# secure_base_url

# %%
# Get the size of poster: 2: w185px, 4: w500px, 5: 780px
# images_url['poster_sizes']
poster_size = images_url['poster_sizes'][5]
# poster_size

# %%
# Copy poster paths to new df
poster_df = movie_df[['poster_path']].copy()

# %%
# Create column with full image path for posters
poster_df['poster_url'] = secure_base_url + poster_size + poster_df['poster_path']

# %%
# Export to separate csv
# poster_df.to_csv("./static/data/poster_path.csv", index=False)
poster_df.head()
# Out:
#                         poster_path  \
# 0  /aWeKITRFbbwY8txG5uCj4rMCfSP.jpg
# 1  /sg4xJaufDiQl7caFEskBtQXfD4x.jpg
# 2  /1g0dhYtq4irTY1GPXvft6k4YLjm.jpg
# 3  /4j0PNHkMr5ax3IA8tjtxcmPU3QT.jpg
# 4  /7uRbWOXxpWDMtnsd2PF3clu65jc.jpg
#
#                                           poster_url
# 0  https://image.tmdb.org/t/p/w780/aWeKITRFbbwY8t...
# 1  https://image.tmdb.org/t/p/w780/sg4xJaufDiQl7c...
# 2  https://image.tmdb.org/t/p/w780/1g0dhYtq4irTY1...
# 3  https://image.tmdb.org/t/p/w780/4j0PNHkMr5ax3I...
# 4  https://image.tmdb.org/t/p/w780/7uRbWOXxpWDMtn...

# %%
# Create column with full image path for posters (in real df this time)
movie_df['poster_url'] = secure_base_url + poster_size + movie_df['poster_path']

# %% [markdown]
# # TESTING

# %% [raw]
# movie_df = pd.read_csv("./static/data/movie_db.csv")

# %% [raw]
# # Converts strings into lists or dictionaries
# from ast import literal_eval
#
# # Selected features to apply function to
# features = ['cast', 'director', 'producers', 'writers', 'keywords', 'genres', 'production_companies']
#
# for feature in features:
#     movie_df[f"{feature}_cleaned"] = movie_df[f"{feature}_cleaned"].apply(literal_eval)

# %% [markdown]
# ## Export CSV:

# %%
# Create a lowercase column for easier search
movie_df["lowercase_title"] = movie_df['title'].apply(lambda x: x.lower())

# %%
# # Save file - used for calling for information
movie_df.to_csv("../static/data/movie_db.csv", index=False)

# %%
movie_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 1  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
# 2  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 1  {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
# 2  {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 3                                               None         50000000
# 4                                               None         40000000
#
#                                  genres  \
# 0    [Animation, Comedy, Family, Music]
# 1          [Comedy, Fantasy, Adventure]
# 2  [Action, Adventure, Science Fiction]
# 3  [Animation, Comedy, Family, Fantasy]
# 4     [Horror, Action, Science Fiction]
#
#                                      homepage      id     imdb_id  \
# 0  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 1                   https://ghostbusters.com/  425909   tt4513678
# 2        https://www.spidermannowayhome.movie  634649  tt10872600
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4              https://www.residentevil.movie  460458   tt6920084
#
#   original_language                          original_title  ...  \
# 0                en                                  Sing 2  ...
# 1                en                 Ghostbusters: Afterlife  ...
# 2                en                 Spider-Man: No Way Home  ...
# 3                en                                 Encanto  ...
# 4                en  Resident Evil: Welcome to Raccoon City  ...
#
#                                    producers_cleaned  \
# 0  [christophermeledandri, janethealy, danakrupin...
# 1  [danaykroyd, ivanreitman, gilkenan, michaelbeu...
# 2  [aviarad, kevinfeige, louisd'esposito, joannpe...
# 3     [clarkspencer, jenniferlee, yvettmerinoflores]
# 4  [paulw.s.anderson, jeremybolt, robertkulzer, m...
#
#                                      writers_cleaned  \
# 0                     [garthjennings, garthjennings]
# 1  [danaykroyd, haroldramis, jasonreitman, gilkenan]
# 2  [stanlee, stanlee, steveditko, steveditko, chr...
# 3                    [jaredbush, charisecastrosmith]
# 4  [johannesroberts, noborusugimura, kenichiiwao,...
#
#                                     keywords_cleaned  \
# 0                        [anthropomorphism, singing]
# 1  [smalltown, ghostbuster, nostalgia, afterlife,...
# 2  [hero, comicbook, superhero, basedoncomic, mar...
# 3  [magic, musical, forest, familyrelationships, ...
# 4  [mutant, biologicalweapon, quarantine, zombie,...
#
#                          genres_cleaned  \
# 0    [animation, comedy, family, music]
# 1          [comedy, fantasy, adventure]
# 2   [action, adventure, sciencefiction]
# 3  [animation, comedy, family, fantasy]
# 4      [horror, action, sciencefiction]
#
#                         production_companies_cleaned  \
# 0     [illuminationentertainment, universalpictures]
# 1  [columbiapictures, bronstudios, themontecitopi...
# 2  [marvelstudios, pascalpictures, columbiapictures]
# 3   [waltdisneyanimationstudios, waltdisneypictures]
# 4  [constantinfilm, teashop&filmcompany, davisfil...
#
#                                     overview_cleaned  \
# 0  buster and his new cast now have their sights ...
# 1  when a single mom and her two kids arrive in a...
# 2  peter parker is unmasked and no longer able to...
# 3  the tale of an extraordinary family, the madri...
# 4  once the booming home of pharmaceutical giant ...
#
#                                                 soup  \
# 0  anthropomorphism singing matthewmcconaughey re...
# 1  smalltown ghostbuster nostalgia afterlife sequ...
# 2  hero comicbook superhero basedoncomic marvelci...
# 3  magic musical forest familyrelationships femal...
# 4  mutant biologicalweapon quarantine zombie base...
#
#                                        soup_overview  \
# 0  anthropomorphism singing anthropomorphism sing...
# 1  smalltown ghostbuster nostalgia afterlife sequ...
# 2  hero comicbook superhero basedoncomic marvelci...
# 3  magic musical forest familyrelationships femal...
# 4  mutant biologicalweapon quarantine zombie base...
#
#                                           poster_url  \
# 0  https://image.tmdb.org/t/p/w780/aWeKITRFbbwY8t...
# 1  https://image.tmdb.org/t/p/w780/sg4xJaufDiQl7c...
# 2  https://image.tmdb.org/t/p/w780/1g0dhYtq4irTY1...
# 3  https://image.tmdb.org/t/p/w780/4j0PNHkMr5ax3I...
# 4  https://image.tmdb.org/t/p/w780/7uRbWOXxpWDMtn...
#
#                           lowercase_title
# 0                                  sing 2
# 1                 ghostbusters: afterlife
# 2                 spider-man: no way home
# 3                                 encanto
# 4  resident evil: welcome to raccoon city
#
# [5 rows x 54 columns]

# %% [markdown]
# # Machine Learning Recommender:

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Use Count Vectorizer to create counts for each word
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(movie_df['soup_overview'])

# %%
count_matrix.shape
# Out:
# (4992, 61382)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset the index
# movie_df = movie_df.reset_index()
# Create series with index & titles of movies
indices = pd.Series(movie_df.index, index=movie_df['title']).drop_duplicates()

# %%
movie_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg
# 1  False   /EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg
# 2  False  /1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg
# 3  False  /3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg
# 4  False  /o76ZDm8PS9791XiuieNB93UZcRV.jpg
#
#                                belongs_to_collection  original_budget  \
# 0  {'id': 544670, 'name': 'Sing Collection', 'pos...         85000000
# 1  {'id': 2980, 'name': 'Ghostbusters Collection'...         75000000
# 2  {'id': 531241, 'name': 'Spider-Man (Avengers) ...        200000000
# 3                                               None         50000000
# 4                                               None         40000000
#
#                                  genres  \
# 0    [Animation, Comedy, Family, Music]
# 1          [Comedy, Fantasy, Adventure]
# 2  [Action, Adventure, Science Fiction]
# 3  [Animation, Comedy, Family, Fantasy]
# 4     [Horror, Action, Science Fiction]
#
#                                      homepage      id     imdb_id  \
# 0  https://www.illumination.com/movie/sing-2/  438695   tt6467266
# 1                   https://ghostbusters.com/  425909   tt4513678
# 2        https://www.spidermannowayhome.movie  634649  tt10872600
# 3           https://movies.disney.com/encanto  568124   tt2953050
# 4              https://www.residentevil.movie  460458   tt6920084
#
#   original_language                          original_title  ...  \
# 0                en                                  Sing 2  ...
# 1                en                 Ghostbusters: Afterlife  ...
# 2                en                 Spider-Man: No Way Home  ...
# 3                en                                 Encanto  ...
# 4                en  Resident Evil: Welcome to Raccoon City  ...
#
#                                    producers_cleaned  \
# 0  [christophermeledandri, janethealy, danakrupin...
# 1  [danaykroyd, ivanreitman, gilkenan, michaelbeu...
# 2  [aviarad, kevinfeige, louisd'esposito, joannpe...
# 3     [clarkspencer, jenniferlee, yvettmerinoflores]
# 4  [paulw.s.anderson, jeremybolt, robertkulzer, m...
#
#                                      writers_cleaned  \
# 0                     [garthjennings, garthjennings]
# 1  [danaykroyd, haroldramis, jasonreitman, gilkenan]
# 2  [stanlee, stanlee, steveditko, steveditko, chr...
# 3                    [jaredbush, charisecastrosmith]
# 4  [johannesroberts, noborusugimura, kenichiiwao,...
#
#                                     keywords_cleaned  \
# 0                        [anthropomorphism, singing]
# 1  [smalltown, ghostbuster, nostalgia, afterlife,...
# 2  [hero, comicbook, superhero, basedoncomic, mar...
# 3  [magic, musical, forest, familyrelationships, ...
# 4  [mutant, biologicalweapon, quarantine, zombie,...
#
#                          genres_cleaned  \
# 0    [animation, comedy, family, music]
# 1          [comedy, fantasy, adventure]
# 2   [action, adventure, sciencefiction]
# 3  [animation, comedy, family, fantasy]
# 4      [horror, action, sciencefiction]
#
#                         production_companies_cleaned  \
# 0     [illuminationentertainment, universalpictures]
# 1  [columbiapictures, bronstudios, themontecitopi...
# 2  [marvelstudios, pascalpictures, columbiapictures]
# 3   [waltdisneyanimationstudios, waltdisneypictures]
# 4  [constantinfilm, teashop&filmcompany, davisfil...
#
#                                     overview_cleaned  \
# 0  buster and his new cast now have their sights ...
# 1  when a single mom and her two kids arrive in a...
# 2  peter parker is unmasked and no longer able to...
# 3  the tale of an extraordinary family, the madri...
# 4  once the booming home of pharmaceutical giant ...
#
#                                                 soup  \
# 0  anthropomorphism singing matthewmcconaughey re...
# 1  smalltown ghostbuster nostalgia afterlife sequ...
# 2  hero comicbook superhero basedoncomic marvelci...
# 3  magic musical forest familyrelationships femal...
# 4  mutant biologicalweapon quarantine zombie base...
#
#                                        soup_overview  \
# 0  anthropomorphism singing anthropomorphism sing...
# 1  smalltown ghostbuster nostalgia afterlife sequ...
# 2  hero comicbook superhero basedoncomic marvelci...
# 3  magic musical forest familyrelationships femal...
# 4  mutant biologicalweapon quarantine zombie base...
#
#                                           poster_url  \
# 0  https://image.tmdb.org/t/p/w780/aWeKITRFbbwY8t...
# 1  https://image.tmdb.org/t/p/w780/sg4xJaufDiQl7c...
# 2  https://image.tmdb.org/t/p/w780/1g0dhYtq4irTY1...
# 3  https://image.tmdb.org/t/p/w780/4j0PNHkMr5ax3I...
# 4  https://image.tmdb.org/t/p/w780/7uRbWOXxpWDMtn...
#
#                           lowercase_title
# 0                                  sing 2
# 1                 ghostbusters: afterlife
# 2                 spider-man: no way home
# 3                                 encanto
# 4  resident evil: welcome to raccoon city
#
# [5 rows x 54 columns]

# %% [markdown]
# ## Function to Recommend Titles:

# %%
def get_similarity_scores(title, cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]
    
    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the most similar movies
    sim_scores = sim_scores[1:11]
#     print(sim_scores)
    
    # Convert list to DataFrame
    sim_scores_df = pd.DataFrame(sim_scores, columns = ["index", "similarity_score"])
    
    # Return top 10 most similar scores
    return sim_scores_df

# %%
def get_recommendations(original_df, score_df):
    original_df = original_df.merge(score_df, on="index")
    original_df = original_df.sort_values("similarity_score", ascending=False)
    
    return original_df

# %%
# Test out function
movie_title = "Get Out"
similarity_scores_df = get_similarity_scores(movie_title, cosine_sim)

# %%
# Call Get Recommendations Function
recommendations = get_recommendations(movie_df, similarity_scores_df)

# %%
# Print out dataframe
# recommendations[['title', 'similarity_score']].to_csv("./soup_test_3.csv")
recommendations[['title', 'similarity_score', 'id']].head(10)

# %% [markdown]
# ### Convert columns to list for SQL Database connection

# %%
movie_df_columns = list(movie_df.columns)
movie_df_columns
# Out:
# ['adult',
#  'backdrop_path',
#  'belongs_to_collection',
#  'original_budget',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'original_revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count',
#  'year',
#  'cpi_2021',
#  'cpi_old',
#  'adjusted_revenue',
#  'adjusted_budget',
#  'budget_bins',
#  'keywords',
#  'cast',
#  'crew',
#  'percent_fm',
#  'certification',
#  'director',
#  'director_gender',
#  'producers',
#  'writers',
#  'production_company_origin',
#  'foreign_language',
#  'cast_cleaned',
#  'director_cleaned',
#  'producers_cleaned',
#  'writers_cleaned',
#  'keywords_cleaned',
#  'genres_cleaned',
#  'production_companies_cleaned',
#  'overview_cleaned',
#  'soup',
#  'soup_overview',
#  'poster_url',
#  'lowercase_title']

# %%
for column_name in list(movie_df.columns):
    movie_df[column_name] = movie_df[column_name].apply(json.dumps)

# %%
movie_dict = movie_df.applymap(lambda x: isinstance(x, (dict, list))).all()
print(movie_dict)
# Out:
# adult                           False
# backdrop_path                   False
# belongs_to_collection           False
# original_budget                 False
# genres                          False
# homepage                        False
# id                              False
# imdb_id                         False
# original_language               False
# original_title                  False
# overview                        False
# popularity                      False
# poster_path                     False
# production_companies            False
# production_countries            False
# release_date                    False
# original_revenue                False
# runtime                         False
# spoken_languages                False
# status                          False
# tagline                         False
# title                           False
# video                           False
# vote_average                    False
# vote_count                      False
# year                            False
# cpi_2021                        False
# cpi_old                         False
# adjusted_revenue                False
# adjusted_budget                 False
# budget_bins                     False
# keywords                        False
# cast                            False
# crew                            False
# percent_fm                      False
# certification                   False
# director                        False
# director_gender                 False
# producers                       False
# writers                         False
# production_company_origin       False
# foreign_language                False
# cast_cleaned                    False
# director_cleaned                False
# producers_cleaned               False
# writers_cleaned                 False
# keywords_cleaned                False
# genres_cleaned                  False
# production_companies_cleaned    False
# overview_cleaned                False
# soup                            False
# soup_overview                   False
# poster_url                      False
# lowercase_title                 False
# dtype: bool

# %% [markdown]
# ## Database:

# %%
from sqlalchemy import create_engine, inspect

# %%
# configure the connection string
rds_connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
        
# connect to the database
engine = create_engine(rds_connection_string)
conn = engine.connect()

# %%
engine.execute("DROP TABLE IF EXISTS movies")

# %%
# Append data to table
movie_df.to_sql(name='movies', con=conn, if_exists='append', index=False)

# %%
# Use inspector to find table names
Inspector = inspect(engine)
Inspector.get_table_names()
# Out:
# ['movies',
#  'duplicate_search',
#  'low_budget_filter',
#  'no_filter',
#  'female_filter',
#  'international_filter']

# %%
# Check movies table
pd.read_sql_query('select * from movies', con=conn)
# Out:
#       adult                       backdrop_path  \
# 0     false  "/tutaKitJJIaqZPyMz7rxrhb4Yxm.jpg"
# 1     false   "/EnDlndEvw6Ptpp8HIwmRcSSNKQ.jpg"
# 2     false  "/1Rr5SrvHxMXHu5RjKpaMba8VTzi.jpg"
# 3     false  "/3G1Q5xF40HkUBJXxt2DQgQzKTp5.jpg"
# 4     false  "/o76ZDm8PS9791XiuieNB93UZcRV.jpg"
# ...     ...                                 ...
# 4987  false  "/97Nv4cIsVaf8nesmpjNW5uWWQY3.jpg"
# 4988  false  "/r8pUcom5Mw8igtBpj3AHSAUvH0R.jpg"
# 4989  false  "/2SCZfhWvFgjmVrpGWN24UpXZVbf.jpg"
# 4990  false  "/jIqp5xXY2aw1kxnBPyCXkKQBOJ3.jpg"
# 4991  false  "/m0N89MIIu6qYZcujCRzBHrkZbns.jpg"
#
#                                   belongs_to_collection original_budget  \
# 0     {"id": 544670, "name": "Sing Collection", "pos...        85000000
# 1     {"id": 2980, "name": "Ghostbusters Collection"...        75000000
# 2     {"id": 531241, "name": "Spider-Man (Avengers) ...       200000000
# 3                                                  null        50000000
# 4                                                  null        40000000
# ...                                                 ...             ...
# 4987                                               null         2479000
# 4988                                               null         1300000
# 4989                                               null               0
# 4990                                               null          923000
# 4991                                               null           18000
#
#                                             genres  \
# 0       ["Animation", "Comedy", "Family", "Music"]
# 1               ["Comedy", "Fantasy", "Adventure"]
# 2       ["Action", "Adventure", "Science Fiction"]
# 3     ["Animation", "Comedy", "Family", "Fantasy"]
# 4          ["Horror", "Action", "Science Fiction"]
# ...                                            ...
# 4987            ["Mystery", "Romance", "Thriller"]
# 4988                  ["Drama", "Science Fiction"]
# 4989                       ["Mystery", "Thriller"]
# 4990              ["Adventure", "Comedy", "Drama"]
# 4991      ["Drama", "Horror", "Thriller", "Crime"]
#
#                                           homepage      id       imdb_id  \
# 0     "https://www.illumination.com/movie/sing-2/"  438695   "tt6467266"
# 1                      "https://ghostbusters.com/"  425909   "tt4513678"
# 2           "https://www.spidermannowayhome.movie"  634649  "tt10872600"
# 3              "https://movies.disney.com/encanto"  568124   "tt2953050"
# 4                 "https://www.residentevil.movie"  460458   "tt6920084"
# ...                                            ...     ...           ...
# 4987                                            ""     426   "tt0052357"
# 4988                                            ""      19   "tt0017136"
# 4989                                            ""     260   "tt0026029"
# 4990                                            ""     962   "tt0015864"
# 4991                                            ""     234   "tt0010323"
#
#      original_language                            original_title  ...  \
# 0                 "en"                                  "Sing 2"  ...
# 1                 "en"                 "Ghostbusters: Afterlife"  ...
# 2                 "en"                 "Spider-Man: No Way Home"  ...
# 3                 "en"                                 "Encanto"  ...
# 4                 "en"  "Resident Evil: Welcome to Raccoon City"  ...
# ...                ...                                       ...  ...
# 4987              "en"                                 "Vertigo"  ...
# 4988              "de"                              "Metropolis"  ...
# 4989              "en"                            "The 39 Steps"  ...
# 4990              "en"                           "The Gold Rush"  ...
# 4991              "de"            "Das Cabinet des Dr. Caligari"  ...
#
#                                       producers_cleaned  \
# 0     ["christophermeledandri", "janethealy", "danak...
# 1     ["danaykroyd", "ivanreitman", "gilkenan", "mic...
# 2     ["aviarad", "kevinfeige", "louisd'esposito", "...
# 3     ["clarkspencer", "jenniferlee", "yvettmerinofl...
# 4     ["paulw.s.anderson", "jeremybolt", "robertkulz...
# ...                                                 ...
# 4987                                ["alfredhitchcock"]
# 4988                                    ["erichpommer"]
# 4989                                  ["michaelbalcon"]
# 4990                                 ["charliechaplin"]
# 4991                   ["erichpommer", "rudolfmeinert"]
#
#                                         writers_cleaned  \
# 0                    ["garthjennings", "garthjennings"]
# 1     ["danaykroyd", "haroldramis", "jasonreitman", ...
# 2     ["stanlee", "stanlee", "steveditko", "stevedit...
# 3                   ["jaredbush", "charisecastrosmith"]
# 4     ["johannesroberts", "noborusugimura", "kenichi...
# ...                                                 ...
# 4987  ["pierreboileau", "thomasnarcejac", "aleccoppe...
# 4988    ["fritzlang", "theavonharbou", "theavonharbou"]
# 4989         ["charlesbennett", "ianhay", "johnbuchan"]
# 4990                                 ["charliechaplin"]
# 4991  ["carlmayer", "carlmayer", "hansjanowitz", "ha...
#
#                                        keywords_cleaned  \
# 0                       ["anthropomorphism", "singing"]
# 1     ["smalltown", "ghostbuster", "nostalgia", "aft...
# 2     ["hero", "comicbook", "superhero", "basedoncom...
# 3     ["magic", "musical", "forest", "familyrelation...
# 4     ["mutant", "biologicalweapon", "quarantine", "...
# ...                                                 ...
# 4987  ["sanfrancisco,california", "detective", "sens...
# 4988  ["manvsmachine", "basedonnovelorbook", "underg...
# 4989  ["london,england", "scotland", "falselyaccused...
# 4990  ["river", "gold", "dance", "worker", "cabin", ...
# 4991  ["insaneasylum", "blackandwhite", "cultfilm", ...
#
#                                     genres_cleaned  \
# 0       ["animation", "comedy", "family", "music"]
# 1               ["comedy", "fantasy", "adventure"]
# 2        ["action", "adventure", "sciencefiction"]
# 3     ["animation", "comedy", "family", "fantasy"]
# 4           ["horror", "action", "sciencefiction"]
# ...                                            ...
# 4987            ["mystery", "romance", "thriller"]
# 4988                   ["drama", "sciencefiction"]
# 4989                       ["mystery", "thriller"]
# 4990              ["adventure", "comedy", "drama"]
# 4991      ["drama", "horror", "thriller", "crime"]
#
#                            production_companies_cleaned  \
# 0     ["illuminationentertainment", "universalpictur...
# 1     ["columbiapictures", "bronstudios", "themontec...
# 2     ["marvelstudios", "pascalpictures", "columbiap...
# 3     ["waltdisneyanimationstudios", "waltdisneypict...
# 4     ["constantinfilm", "teashop&filmcompany", "dav...
# ...                                                 ...
# 4987      ["paramount", "alfredj.hitchcockproductions"]
# 4988                                            ["ufa"]
# 4989              ["gaumont-britishpicturecorporation"]
# 4990     ["charleschaplinproductions", "unitedartists"]
# 4991                  ["declafilmgesellschaftholz&co."]
#
#                                        overview_cleaned  \
# 0     "buster and his new cast now have their sights...
# 1     "when a single mom and her two kids arrive in ...
# 2     "peter parker is unmasked and no longer able t...
# 3     "the tale of an extraordinary family, the madr...
# 4     "once the booming home of pharmaceutical giant...
# ...                                                 ...
# 4987  "a retired san francisco detective suffering f...
# 4988  "in a futuristic city sharply divided between ...
# 4989  "richard hanney has a rude awakening when a gl...
# 4990  "a lone prospector ventures into alaska lookin...
# 4991  "francis, a young man, recalls in his memory t...
#
#                                                    soup  \
# 0     "anthropomorphism singing matthewmcconaughey r...
# 1     "smalltown ghostbuster nostalgia afterlife seq...
# 2     "hero comicbook superhero basedoncomic marvelc...
# 3     "magic musical forest familyrelationships fema...
# 4     "mutant biologicalweapon quarantine zombie bas...
# ...                                                 ...
# 4987  "sanfrancisco,california detective senseofguil...
# 4988  "manvsmachine basedonnovelorbook undergroundwo...
# 4989  "london,england scotland falselyaccused scotla...
# 4990  "river gold dance worker cabin goldrush thanks...
# 4991  "insaneasylum blackandwhite cultfilm silentfil...
#
#                                           soup_overview  \
# 0     "anthropomorphism singing anthropomorphism sin...
# 1     "smalltown ghostbuster nostalgia afterlife seq...
# 2     "hero comicbook superhero basedoncomic marvelc...
# 3     "magic musical forest familyrelationships fema...
# 4     "mutant biologicalweapon quarantine zombie bas...
# ...                                                 ...
# 4987  "sanfrancisco,california detective senseofguil...
# 4988  "manvsmachine basedonnovelorbook undergroundwo...
# 4989  "london,england scotland falselyaccused scotla...
# 4990  "river gold dance worker cabin goldrush thanks...
# 4991  "insaneasylum blackandwhite cultfilm silentfil...
#
#                                              poster_url  \
# 0     "https://image.tmdb.org/t/p/w780/aWeKITRFbbwY8...
# 1     "https://image.tmdb.org/t/p/w780/sg4xJaufDiQl7...
# 2     "https://image.tmdb.org/t/p/w780/1g0dhYtq4irTY...
# 3     "https://image.tmdb.org/t/p/w780/4j0PNHkMr5ax3...
# 4     "https://image.tmdb.org/t/p/w780/7uRbWOXxpWDMt...
# ...                                                 ...
# 4987  "https://image.tmdb.org/t/p/w780/dg9escdBIAAAT...
# 4988  "https://image.tmdb.org/t/p/w780/hUK9rewffKGqt...
# 4989  "https://image.tmdb.org/t/p/w780/paI9Tmqm2cZG6...
# 4990  "https://image.tmdb.org/t/p/w780/eQRFo1qwRREYw...
# 4991  "https://image.tmdb.org/t/p/w780/myK9DeIsXWGKg...
#
#                                lowercase_title
# 0                                     "sing 2"
# 1                    "ghostbusters: afterlife"
# 2                    "spider-man: no way home"
# 3                                    "encanto"
# 4     "resident evil: welcome to raccoon city"
# ...                                        ...
# 4987                                 "vertigo"
# 4988                              "metropolis"
# 4989                            "the 39 steps"
# 4990                           "the gold rush"
# 4991             "the cabinet of dr. caligari"
#
# [4992 rows x 54 columns]
